# %% [markdown]
# # Data Preproccesing for CNN Model

# %% [markdown]
# ## Data Downloader from iNaturlist

# %%
import pandas as pd
import requests
import os
from urllib.parse import urlparse
from tqdm import tqdm  # Import tqdm for the progress bar

# Read the CSV file
df = pd.read_csv('../Datasets/Inat/observations-all-recordings.csv/observations-598206.csv')

# Create a directory to save the sound files
os.makedirs('frog_sounds', exist_ok=True)

# Helper function to generate a unique filename
def get_unique_filename(directory, base_name, extension):
    full_path = os.path.join(directory, base_name + extension)
    counter = 1
    while os.path.exists(full_path):
        full_path = os.path.join(directory, f"{base_name}_{counter}{extension}")
        counter += 1
    return full_path

# Create a progress bar for the total number of downloads
with tqdm(total=len(df), desc="Downloading frog sounds") as pbar:
    # Iterate through each row in the DataFrame
    for index, row in df.iterrows():
        sound_url = row['sound_url']
        common_name = row['common_name']
        
        if pd.notna(sound_url) and pd.notna(common_name):
            try:
                # Extract the file extension from the URL
                parsed_url = urlparse(sound_url)
                filename = os.path.basename(parsed_url.path)
                extension = os.path.splitext(filename)[1]
                
                # Clean the common name to make it a valid filename
                clean_name = "".join(c if c.isalnum() or c in (' ', '-') else '_' for c in common_name).strip()
                clean_name = clean_name.replace(' ', '_')  # Optional: replace spaces with underscores
                
                # Generate a unique filename
                unique_filename = get_unique_filename('frog_sounds', clean_name, extension)
                
                # Download the file
                response = requests.get(sound_url, stream=True)
                if response.status_code == 200:
                    with open(unique_filename, 'wb') as f:
                        for chunk in response.iter_content(1024):
                            f.write(chunk)
                    # print(f"Downloaded: {unique_filename}")
                else:
                    print(f"Failed to download: {sound_url}")
            except Exception as e:
                print(f"Error processing {sound_url}: {e}")

            # Update the progress bar after each download
            pbar.update(1)

print("Download complete.")

# %% [markdown]
# ## Convert all files into .WAV

# %%
import os
import subprocess
from pathlib import Path
from tqdm import tqdm

def convert_to_spectrogram_ready(input_dir, output_dir, sample_rate=22050, mono=True):
    
    Path(output_dir).mkdir(parents=True, exist_ok=True)
    
    audio_files = []
    extensions = ('.wav', '.mp3', '.mp4', '.m4a', '.aac', '.flac', '.ogg', '.mpga')
    
    for root, _, files in os.walk(input_dir):
        for file in files:
            # if file.lower().endswith(extensions):
                audio_files.append(Path(root) / file)
    
    print(f"Found {len(audio_files)} audio files to process")
    
    for input_file in tqdm(audio_files, desc="Converting for spectrograms"):
        output_file = Path(output_dir) / f"{input_file.stem}.wav"
        
        # Check if file exists and modify name if needed
        counter = 1
        while output_file.exists():
            output_file = Path(output_dir) / f"{input_file.stem}_{counter}.wav"
            counter += 1
        
        cmd = [
            'ffmpeg',
            '-i', str(input_file),
            '-ac', '1' if mono else '2',  # mono recommended for spectrograms
            '-ar', str(sample_rate),  # 22050 is standard for many ML models
            '-sample_fmt', 's16',  # 16-bit PCM
            '-acodec', 'pcm_s16le',  # Standard WAV format
            '-y',  # Still overwrites if same name, but we prevent that with the loop
            str(output_file)
        ]
        
        try:
            subprocess.run(cmd, check=True, 
                         stdout=subprocess.DEVNULL, 
                         stderr=subprocess.PIPE)
        except subprocess.CalledProcessError as e:
            print(f"\nError processing {input_file}: {e.stderr.decode('utf-8')}")
    
    print(f"\nConversion complete. Files ready for spectrogram generation in {output_dir}")

if __name__ == "__main__":
    convert_to_spectrogram_ready(
        input_dir="../Datasets/Raw-audio/aug-test/",
        output_dir="../Datasets/Raw-audio/aug-test/"
    )
# Out:
# Found 5 audio files to process
# Converting for spectrograms: 100%|██████████| 5/5 [00:00<00:00, 20.72it/s]
# Conversion complete. Files ready for spectrogram generation in ../Datasets/Raw-audio/aug-test/

# %% [markdown]
# ## Rename files for only ID most common frogs

# %%
import os
from pathlib import Path
from collections import defaultdict

def rename_frog_files(directory):
    # Files to keep original names (all lowercase for comparison)
    KEEP_NAMES = {
        "painted_reed_frog",
        "weale_s_running_frog",
        "de_villiers_moss_frog",
        "cape_peninsula_moss_frog",
        "eastern_rose_rain_frog",
        "banded_stream_frog",
        "Rain",
        "clicking_stream_frog",
        "southern_dainty_frog",
        "cape_mountain_rain_frog"
    }
    
    # Initialize counter for other_frog files
    other_counter = 1
    
    # Get all .wav files in directory
    for filepath in Path(directory).glob("*.wav"):
        original_name = filepath.stem.lower()  # Get filename without extension
        
        # Check if we should keep original name
        should_keep = any(
            keep_name.lower() in original_name 
            for keep_name in KEEP_NAMES
        )
        
        if should_keep:
            print(f"Keeping: {filepath.name}")
            continue  # Skip renaming
        
        # Generate new name
        new_name = f"other_frog_{other_counter}.wav"
        new_path = filepath.with_name(new_name)
        
        # Handle potential name conflicts
        while new_path.exists():
            other_counter += 1
            new_name = f"other_frog_{other_counter}.wav"
            new_path = filepath.with_name(new_name)
        
        # Rename the file
        filepath.rename(new_path)
        print(f"Renamed: {filepath.name} -> {new_name}")
        other_counter += 1

if __name__ == "__main__":
    directory_path = "../Datasets/Raw-audio/calls-clipped/"
    rename_frog_files(directory_path)
    print("File renaming complete!")
# Out:
# Renamed: 51_Eastern_Leopard_Toad_segment_5.wav -> other_frog_1.wav
# Renamed: 94_Tinker_Reed_Frog_segment_4.wav -> other_frog_2.wav
# Renamed: 110_Nile_Grass_Frog_segment_2.wav -> other_frog_3.wav
# Renamed: 60_Cederberg_Ghost_Frog_segment_6.wav -> other_frog_4.wav
# Renamed: 149_Striped_Caco_segment_1.wav -> other_frog_5.wav
# Keeping: 159_Clicking_Stream_Frog_segment_1.wav
# Renamed: 03_Bush_Squeaker_segment_2.wav -> other_frog_6.wav
# Renamed: 73_Knysna_Leaffolding_Frog_segment_3.wav -> other_frog_7.wav
# Renamed: 89_Powers_Long_Reed_Frog_segment_3.wav -> other_frog_8.wav
# Renamed: 59_Natal_Cascade_Frog_segment_1.wav -> other_frog_9.wav
# Renamed: 117_Cape_Platanna_segment_1.wav -> other_frog_10.wav
# Renamed: 78_Arum_Lily_Frog_segment_1.wav -> other_frog_11.wav
# Keeping: 16_Zululand_Rain_Frog_segment_1.wav
# Keeping: 14_Bilbos_Rain_Frog_segment_3.wav
# Keeping: 29_Northern_Forest_Rain_Frog_B_s_taeniatus_segment_2.wav
# Renamed: 168_Natal_Sand_Frog_segment_3.wav -> other_frog_12.wav
# Renamed: 127_Maluti_River_Frog_segment_5.wav -> other_frog_13.wav
# Keeping: 137_De_Villiers_Moss_Frog_segment_3.wav
# Renamed: 60_Cederberg_Ghost_Frog_segment_4.wav -> other_frog_14.wav
# Renamed: 147_Flat_Caco_segment_3.wav -> other_frog_15.wav
# Renamed: 100_Banded_Rubber_Frog_segment_4.wav -> other_frog_16.wav
# Renamed: 46_Raucous_Toad_segment_5.wav -> other_frog_17.wav
# Renamed: 166_Knocking_Sand_Frog_segment_4.wav -> other_frog_18.wav
# Renamed: 104_Small_Puddle_Frog_segment_1.wav -> other_frog_19.wav
# Renamed: 125_Poyntons_River_Frog_segment_4.wav -> other_frog_20.wav
# Keeping: 16_Phinda_Rain_Frog_segment_2.wav
# Renamed: 95_Redlegged_Kassina_segment_3.wav -> other_frog_21.wav
# Renamed: 47_Eastern_Olive_Toad_segment_5.wav -> other_frog_22.wav
# Renamed: 69_Golden_Leaffolding_Frog_segment_2.wav -> other_frog_23.wav
# Renamed: 128_Natal_Chirping_Frog_segment_1.wav -> other_frog_24.wav
# Renamed: 70_Snoring_Leaffolding_Frog_segment_2.wav -> other_frog_25.wav
# Keeping: 12_Bushveld_Rain_Frog_B_a_adspersus_segment_3.wav
# Renamed: 52_Western_Olive_Toad_segment_5.wav -> other_frog_26.wav
# Keeping: 134_Cape_Peninsula_Moss_Frog_segment_4.wav
# Renamed: 156_African_Bullfrog_segment_5.wav -> other_frog_27.wav
# Renamed: 61_Hewitts_Ghost_Frog_segment_1.wav -> other_frog_28.wav
# Renamed: 49_Lemaires_Toad_segment_2.wav -> other_frog_29.wav
# Renamed: 72_Greater_Leaffolding_Frog_segment_5.wav -> other_frog_30.wav
# Renamed: 96_Bubbling_Kassina_segment_3.wav -> other_frog_31.wav
# Renamed: 154_Giant_Bullfrog_segment_2.wav -> other_frog_32.wav
# Renamed: 145_Bronze_Caco_segment_6.wav -> other_frog_33.wav
# Renamed: 02_Chimanimani_Squeaker_segment_1.wav -> other_frog_34.wav
# Renamed: 151_Micro_Frog_segment_2.wav -> other_frog_35.wav
# Keeping: 157_Banded_Stream_Frog_segment_5.wav
# Renamed: 67_Spotted_Shovelnosed_Frog_segment_3.wav -> other_frog_36.wav
# Renamed: 62_Eastern_Ghost_Frog_segment_1.wav -> other_frog_37.wav
# Keeping: 28_Northern_Forest_Rain_Frog_B_s_sylvestris_segment_2.wav
# Keeping: 18_Cape_Rain_Frog_segment_5.wav
# Keeping: 137_De_Villiers_Moss_Frog_segment_5.wav
# Renamed: 01_Shovelfooted_Squeaker_segment_2.wav -> other_frog_38.wav
# Renamed: 06_Broadleys_Tree_Frog_segment_1.wav -> other_frog_39.wav
# Keeping: 30_Plaintive_Rain_Frog_segment_4.wav
# Renamed: 72_Greater_Leaffolding_Frog_segment_4.wav -> other_frog_40.wav
# Renamed: 126_Van_Dijks_River_Frog_segment_5.wav -> other_frog_41.wav
# Renamed: 111_Sharpnosed_Grass_Frog_segment_2.wav -> other_frog_42.wav
# Keeping: 21_Mozambique_Rain_Frog_segment_4.wav
# Keeping: 22_Namaqua_Rain_Frog_segment_5.wav
# Renamed: 166_Knocking_Sand_Frog_segment_2.wav -> other_frog_43.wav
# Renamed: 122_Cape_River_Frog_segment_4.wav -> other_frog_44.wav
# Renamed: 54_Amatola_Toad_segment_5.wav -> other_frog_45.wav
# Renamed: 101_East_African_Puddle_Frog_segment_1.wav -> other_frog_46.wav
# Renamed: 147_Flat_Caco_segment_6.wav -> other_frog_47.wav
# Renamed: 155_East_African_Bullfrog_segment_3.wav -> other_frog_48.wav
# Renamed: 123_Phofung_River_Frog_segment_1.wav -> other_frog_49.wav
# Keeping: 25_Sand_Rain_Frog_B_r_rosei_segment_4.wav
# Renamed: 144_KwaZulu_Caco_segment_3.wav -> other_frog_50.wav
# Renamed: 133_Landdroskop_Moss_Frog_segment_5.wav -> other_frog_51.wav
# Renamed: 49_Lemaires_Toad_segment_1.wav -> other_frog_52.wav
# Keeping: 137_De_Villiers_Moss_Frog_segment_6.wav
# Renamed: 127_Maluti_River_Frog_segment_3.wav -> other_frog_53.wav
# Renamed: 164_Damaraland_Sand_Frog_segment_3.wav -> other_frog_54.wav
# Renamed: 172_Galam_Goldenbacked_Frog_segment_1.wav -> other_frog_55.wav
# Renamed: 93_Swynnertons_Reed_Frog_segment_3.wav -> other_frog_56.wav
# Keeping: 20_Cape_Mountain_Rain_Frog_segment_5.wav
# Renamed: 109_Broadbanded_Grass_Frog_segment_4.wav -> other_frog_57.wav
# Renamed: 148_Rhythmic_Caco_segment_4.wav -> other_frog_58.wav
# Keeping: 137_De_Villiers_Moss_Frog_segment_2.wav
# Renamed: 45_Red_Toad_segment_2.wav -> other_frog_59.wav
# Renamed: 51_Eastern_Leopard_Toad_segment_4.wav -> other_frog_60.wav
# Renamed: 95_Redlegged_Kassina_segment_2.wav -> other_frog_61.wav
# Renamed: 102_Dwarf_Puddle_Frog_segment_6.wav -> other_frog_62.wav
# Keeping: 22_Namaqua_Rain_Frog_segment_2.wav
# Renamed: 67_Spotted_Shovelnosed_Frog_segment_6.wav -> other_frog_63.wav
# Keeping: 159_Clicking_Stream_Frog_segment_2.wav
# Renamed: 95_Redlegged_Kassina_segment_4.wav -> other_frog_64.wav
# Renamed: 115_Dwarf_Grass_Frog_segment_6.wav -> other_frog_65.wav
# Renamed: 143_Namaqua_Caco_segment_5.wav -> other_frog_66.wav
# Renamed: 103_Snoring_Puddle_Frog_segment_4.wav -> other_frog_67.wav
# Renamed: 162_Plain_Stream_Frog_segment_1.wav -> other_frog_68.wav
# Renamed: 160_Chimanimani_Stream_Frog_segment_6.wav -> other_frog_69.wav
# Renamed: 65_Table_Mountain_Ghost_Frog_segment_2.wav -> other_frog_70.wav
# Renamed: 162_Plain_Stream_Frog_segment_3.wav -> other_frog_71.wav
# Renamed: 132_Drewes_Moss_Frog_segment_4.wav -> other_frog_72.wav
# Renamed: 42_Hoeschs_Pygmy_Toad_segment_5.wav -> other_frog_73.wav
# Keeping: 19_Desert_Rain_Frog_segment_3.wav
# Renamed: 151_Micro_Frog_segment_3.wav -> other_frog_74.wav
# Renamed: 142_Karoo_Caco_segment_3.wav -> other_frog_75.wav
# Renamed: 160_Chimanimani_Stream_Frog_segment_3.wav -> other_frog_76.wav
# Renamed: 06_Broadleys_Tree_Frog_segment_2.wav -> other_frog_77.wav
# Renamed: 131_Bainskloof_Moss_Frog_segment_5.wav -> other_frog_78.wav
# Renamed: 118_Common_Platanna_segment_5.wav -> other_frog_79.wav
# Renamed: 56_Karoo_Toad_segment_2.wav -> other_frog_80.wav
# Renamed: 69_Golden_Leaffolding_Frog_segment_3.wav -> other_frog_81.wav
# Renamed: 112_Striped_Grass_Frog_segment_1.wav -> other_frog_82.wav
# Keeping: 20_Cape_Mountain_Rain_Frog_segment_4.wav
# Renamed: 131_Bainskloof_Moss_Frog_segment_6.wav -> other_frog_83.wav
# Renamed: 123_Phofung_River_Frog_segment_4.wav -> other_frog_84.wav
# Renamed: 148_Rhythmic_Caco_segment_2.wav -> other_frog_85.wav
# Renamed: 76_Argus_Reed_Frog_segment_1.wav -> other_frog_86.wav
# Renamed: 133_Landdroskop_Moss_Frog_segment_1.wav -> other_frog_87.wav
# Renamed: 77_Bocages_Sharpnosed_segment_3.wav -> other_frog_88.wav
# Renamed: 95_Redlegged_Kassina_segment_1.wav -> other_frog_89.wav
# Renamed: 141_Cape_Caco_segment_1.wav -> other_frog_90.wav
# Renamed: 73_Knysna_Leaffolding_Frog_segment_4.wav -> other_frog_91.wav
# Renamed: 62_Eastern_Ghost_Frog_segment_2.wav -> other_frog_92.wav
# Renamed: 158_Striped_Stream_Frog_segment_1.wav -> other_frog_93.wav
# Renamed: 07_Yellowspotted_Tree_Frog_segment_1.wav -> other_frog_94.wav
# Renamed: 118_Common_Platanna_segment_6.wav -> other_frog_95.wav
# Renamed: 147_Flat_Caco_segment_1.wav -> other_frog_96.wav
# Renamed: 92_Yellowstriped_Reed_Frog_segment_5.wav -> other_frog_97.wav
# Keeping: 134_Cape_Peninsula_Moss_Frog_segment_3.wav
# Renamed: 160_Chimanimani_Stream_Frog_segment_2.wav -> other_frog_98.wav
# Renamed: 165_Cape_Sand_Frog_segment_4.wav -> other_frog_99.wav
# Renamed: 61_Hewitts_Ghost_Frog_segment_5.wav -> other_frog_100.wav
# Renamed: 40_Dombe_Pygmy_Toad_segment_1.wav -> other_frog_101.wav
# Renamed: 121_Common_River_Frog_segment_5.wav -> other_frog_102.wav
# Renamed: 130_Hogsback_Chirping_Frog_segment_4.wav -> other_frog_103.wav
# Keeping: 11_Strawberry_Rain_Frog_segment_1.wav
# Renamed: 99_Marbled_Rubber_Frog_segment_6.wav -> other_frog_104.wav
# Renamed: 93_Swynnertons_Reed_Frog_segment_1.wav -> other_frog_105.wav
# Renamed: 08_Brownbacked_Tree_Frog_segment_1.wav -> other_frog_106.wav
# Renamed: 92_Yellowstriped_Reed_Frog_segment_4.wav -> other_frog_107.wav
# Renamed: 142_Karoo_Caco_segment_1.wav -> other_frog_108.wav
# Keeping: 12_Bushveld_Rain_Frog_B_a_adspersus_segment_2.wav
# Renamed: 04_Dwarf_Squeaker_segment_1.wav -> other_frog_109.wav
# Renamed: 130_Hogsback_Chirping_Frog_segment_3.wav -> other_frog_110.wav
# Keeping: 19_Desert_Rain_Frog_segment_2.wav
# Renamed: 02_Chimanimani_Squeaker_segment_7.wav -> other_frog_111.wav
# Renamed: 132_Drewes_Moss_Frog_segment_3.wav -> other_frog_112.wav
# Renamed: 115_Dwarf_Grass_Frog_segment_3.wav -> other_frog_113.wav
# Renamed: 127_Maluti_River_Frog_segment_1.wav -> other_frog_114.wav
# Renamed: 169_Tandys_Sand_Frog_segment_3.wav -> other_frog_115.wav
# Keeping: 13_Bushveld_Rain_Frog_B_a_pentheri_segment_1.wav
# Renamed: 143_Namaqua_Caco_segment_3.wav -> other_frog_116.wav
# Renamed: 73_Knysna_Leaffolding_Frog_segment_2.wav -> other_frog_117.wav
# Renamed: 156_African_Bullfrog_segment_6.wav -> other_frog_118.wav
# Renamed: 136_Northern_Moss_Frog_segment_4.wav -> other_frog_119.wav
# Keeping: 137_De_Villiers_Moss_Frog_segment_4.wav
# Renamed: 75_Natal_Leaffolding_Frog_A_s_spinifrons_segment_4.wav -> other_frog_120.wav
# Renamed: 164_Damaraland_Sand_Frog_segment_2.wav -> other_frog_121.wav
# Renamed: 148_Rhythmic_Caco_segment_3.wav -> other_frog_122.wav
# Renamed: 135_Rough_Moss_Frog_segment_6.wav -> other_frog_123.wav
# Renamed: 118_Common_Platanna_segment_3.wav -> other_frog_124.wav
# Renamed: 59_Natal_Cascade_Frog_segment_3.wav -> other_frog_125.wav
# Renamed: 122_Cape_River_Frog_segment_6.wav -> other_frog_126.wav
# Renamed: 72_Greater_Leaffolding_Frog_segment_2.wav -> other_frog_127.wav
# Renamed: 158_Striped_Stream_Frog_segment_3.wav -> other_frog_128.wav
# Renamed: 170_Rough_Sand_Frog_segment_1.wav -> other_frog_129.wav
# Renamed: 82_Sharpheaded_Long_Reed_Frog_segment_3.wav -> other_frog_130.wav
# Renamed: 09_Natal_Tree_Frog_segment_2.wav -> other_frog_131.wav
# Renamed: 128_Natal_Chirping_Frog_segment_5.wav -> other_frog_132.wav
# Renamed: 97_Rattling_Frog_segment_2.wav -> other_frog_133.wav
# Renamed: 153_Montane_Marsh_Frog_segment_3.wav -> other_frog_134.wav
# Renamed: 90_Water_Lily_Frog_segment_1.wav -> other_frog_135.wav
# Renamed: 122_Cape_River_Frog_segment_1.wav -> other_frog_136.wav
# Renamed: 106_Plain_Grass_Frog_segment_2.wav -> other_frog_137.wav
# Renamed: 138_Klipheuwel_Caco_segment_7.wav -> other_frog_138.wav
# Keeping: 23_Ndumo_Rain_Frog_segment_2.wav
# Renamed: 75_Natal_Leaffolding_Frog_A_s_spinifrons_segment_3.wav -> other_frog_139.wav
# Renamed: 142_Karoo_Caco_segment_2.wav -> other_frog_140.wav
# Keeping: 24_Powers_Rain_Frog_segment_2.wav
# Renamed: 121_Common_River_Frog_segment_2.wav -> other_frog_141.wav
# Renamed: 116_Udzungwa_Grass_Frog_segment_2.wav -> other_frog_142.wav
# Renamed: 113_Schilluk_Grass_Frog_segment_3.wav -> other_frog_143.wav
# Renamed: 144_KwaZulu_Caco_segment_5.wav -> other_frog_144.wav
# Renamed: 164_Damaraland_Sand_Frog_segment_1.wav -> other_frog_145.wav
# Renamed: 135_Rough_Moss_Frog_segment_3.wav -> other_frog_146.wav
# Renamed: 139_Southern_Caco_segment_4.wav -> other_frog_147.wav
# Keeping: 20_Cape_Mountain_Rain_Frog_segment_3.wav
# Keeping: 27_Whistling_Rain_Frog_segment_4.wav
# Renamed: 125_Poyntons_River_Frog_segment_1.wav -> other_frog_148.wav
# Keeping: 28_Northern_Forest_Rain_Frog_B_s_sylvestris_segment_1.wav
# Renamed: 161_Namaqua_Stream_Frog_segment_3.wav -> other_frog_149.wav
# Renamed: 102_Dwarf_Puddle_Frog_segment_2.wav -> other_frog_150.wav
# Renamed: 153_Montane_Marsh_Frog_segment_5.wav -> other_frog_151.wav
# Renamed: 125_Poyntons_River_Frog_segment_7.wav -> other_frog_152.wav
# Renamed: 46_Raucous_Toad_segment_3.wav -> other_frog_153.wav
# Renamed: 140_Boettgers_Caco_segment_3.wav -> other_frog_154.wav
# Keeping: 19_Desert_Rain_Frog_segment_4.wav
# Renamed: 163_Tremolo_Sand_Frog_segment_6.wav -> other_frog_155.wav
# Renamed: 136_Northern_Moss_Frog_segment_6.wav -> other_frog_156.wav
# Renamed: 36_Tradouw_Mountain_Toadlet_segment_1.wav -> other_frog_157.wav
# Renamed: 52_Western_Olive_Toad_segment_2.wav -> other_frog_158.wav
# Renamed: 127_Maluti_River_Frog_segment_4.wav -> other_frog_159.wav
# Renamed: 95_Redlegged_Kassina_segment_5.wav -> other_frog_160.wav
# Renamed: 42_Hoeschs_Pygmy_Toad_segment_6.wav -> other_frog_161.wav
# Keeping: 159_Clicking_Stream_Frog_segment_3.wav
# Renamed: 88_Pickersgills_Reed_Frog_segment_3.wav -> other_frog_162.wav
# Renamed: 113_Schilluk_Grass_Frog_segment_2.wav -> other_frog_163.wav
# Keeping: 23_Ndumo_Rain_Frog_segment_1.wav
# Renamed: 118_Common_Platanna_segment_2.wav -> other_frog_164.wav
# Renamed: 148_Rhythmic_Caco_segment_1.wav -> other_frog_165.wav
# Renamed: 05_Bocages_Tree_Frog_segment_4.wav -> other_frog_166.wav
# Renamed: 143_Namaqua_Caco_segment_1.wav -> other_frog_167.wav
# Renamed: 47_Eastern_Olive_Toad_segment_3.wav -> other_frog_168.wav
# Renamed: 129_Mistbelt_Chirping_Frog_segment_3.wav -> other_frog_169.wav
# Renamed: 139_Southern_Caco_segment_10.wav -> other_frog_170.wav
# Renamed: 36_Tradouw_Mountain_Toadlet_segment_2.wav -> other_frog_171.wav
# Renamed: 102_Dwarf_Puddle_Frog_segment_3.wav -> other_frog_172.wav
# Renamed: 167_Russetbacked_Sand_Frog_segment_5.wav -> other_frog_173.wav
# Renamed: 05_Bocages_Tree_Frog_segment_2.wav -> other_frog_174.wav
# Renamed: 76_Argus_Reed_Frog_segment_3.wav -> other_frog_175.wav
# Renamed: 10_Longtoed_Tree_Frog_segment_1.wav -> other_frog_176.wav
# Keeping: 17_Plain_Rain_Frog_segment_5.wav
# Renamed: 125_Poyntons_River_Frog_segment_5.wav -> other_frog_177.wav
# Keeping: 17_Plain_Rain_Frog_segment_3.wav
# Renamed: 163_Tremolo_Sand_Frog_segment_2.wav -> other_frog_178.wav
# Renamed: 07_Yellowspotted_Tree_Frog_segment_2.wav -> other_frog_179.wav
# Renamed: 166_Knocking_Sand_Frog_segment_1.wav -> other_frog_180.wav
# Renamed: 115_Dwarf_Grass_Frog_segment_4.wav -> other_frog_181.wav
# Renamed: 146_Mountain_Caco_segment_1.wav -> other_frog_182.wav
# Renamed: 156_African_Bullfrog_segment_2.wav -> other_frog_183.wav
# Keeping: 13_Bushveld_Rain_Frog_B_a_pentheri_segment_6.wav
# Renamed: 55_Cape_Sand_Toad_segment_2.wav -> other_frog_184.wav
# Keeping: 12_Bushveld_Rain_Frog_B_a_adspersus_segment_1.wav
# Renamed: 121_Common_River_Frog_segment_6.wav -> other_frog_185.wav
# Renamed: 05_Bocages_Tree_Frog_segment_1.wav -> other_frog_186.wav
# Renamed: 36_Tradouw_Mountain_Toadlet_segment_6.wav -> other_frog_187.wav
# Renamed: 150_Hogsback_Caco_segment_1.wav -> other_frog_188.wav
# Renamed: 69_Golden_Leaffolding_Frog_segment_1.wav -> other_frog_189.wav
# Renamed: 75_Natal_Leaffolding_Frog_A_s_spinifrons_segment_5.wav -> other_frog_190.wav
# Renamed: 155_East_African_Bullfrog_segment_4.wav -> other_frog_191.wav
# Renamed: 74_Natal_Leaffolding_Frog_A_s_intermedius_segment_2.wav -> other_frog_192.wav
# Renamed: 04_Dwarf_Squeaker_segment_4.wav -> other_frog_193.wav
# Renamed: 122_Cape_River_Frog_segment_2.wav -> other_frog_194.wav
# Renamed: 107_Guibes_Grass_Frog_segment_2.wav -> other_frog_195.wav
# Renamed: 168_Natal_Sand_Frog_segment_4.wav -> other_frog_196.wav
# Renamed: 141_Cape_Caco_segment_5.wav -> other_frog_197.wav
# Renamed: 109_Broadbanded_Grass_Frog_segment_1.wav -> other_frog_198.wav
# Renamed: 58_Paradise_Toad_segment_2.wav -> other_frog_199.wav
# Renamed: 69_Golden_Leaffolding_Frog_segment_7.wav -> other_frog_200.wav
# Renamed: 99_Marbled_Rubber_Frog_segment_2.wav -> other_frog_201.wav
# Renamed: 04_Dwarf_Squeaker_segment_2.wav -> other_frog_202.wav
# Renamed: 44_Southern_Pygmy_Toad_segment_1.wav -> other_frog_203.wav
# Renamed: 113_Schilluk_Grass_Frog_segment_1.wav -> other_frog_204.wav
# Renamed: 141_Cape_Caco_segment_3.wav -> other_frog_205.wav
# Renamed: 46_Raucous_Toad_segment_4.wav -> other_frog_206.wav
# Renamed: 92_Yellowstriped_Reed_Frog_segment_2.wav -> other_frog_207.wav
# Renamed: 142_Karoo_Caco_segment_5.wav -> other_frog_208.wav
# Renamed: 106_Plain_Grass_Frog_segment_3.wav -> other_frog_209.wav
# Renamed: 151_Micro_Frog_segment_1.wav -> other_frog_210.wav
# Renamed: 01_Shovelfooted_Squeaker_segment_1.wav -> other_frog_211.wav
# Keeping: 21_Mozambique_Rain_Frog_segment_2.wav
# Renamed: 85_Long_Reed_Frog_segment_5.wav -> other_frog_212.wav
# Keeping: 16_Zululand_Rain_Frog_segment_3.wav
# Renamed: 86_Angolan_Reed_Frog_segment_2.wav -> other_frog_213.wav
# Renamed: 165_Cape_Sand_Frog_segment_3.wav -> other_frog_214.wav
# Keeping: 24_Powers_Rain_Frog_segment_1.wav
# Renamed: 130_Hogsback_Chirping_Frog_segment_1.wav -> other_frog_215.wav
# Renamed: 50_Western_Leopard_Toad_segment_4.wav -> other_frog_216.wav
# Renamed: 105_Ornate_Frog_segment_4.wav -> other_frog_217.wav
# Keeping: 137_De_Villiers_Moss_Frog_segment_7.wav
# Keeping: 137_De_Villiers_Moss_Frog_segment_1.wav
# Renamed: 144_KwaZulu_Caco_segment_4.wav -> other_frog_218.wav
# Renamed: 167_Russetbacked_Sand_Frog_segment_6.wav -> other_frog_219.wav
# Keeping: 81_Painted_Reed_Frog_segment_4.wav
# Renamed: 05_Bocages_Tree_Frog_segment_3.wav -> other_frog_220.wav
# Keeping: 16_Zululand_Rain_Frog_segment_5.wav
# Renamed: 100_Banded_Rubber_Frog_segment_2.wav -> other_frog_221.wav
# Renamed: 01_Shovelfooted_Squeaker_segment_3.wav -> other_frog_222.wav
# Renamed: 117_Cape_Platanna_segment_3.wav -> other_frog_223.wav
# Renamed: 01_Shovelfooted_Squeaker_segment_4.wav -> other_frog_224.wav
# Renamed: 142_Karoo_Caco_segment_7.wav -> other_frog_225.wav
# Renamed: 52_Western_Olive_Toad_segment_4.wav -> other_frog_226.wav
# Renamed: 09_Natal_Tree_Frog_segment_4.wav -> other_frog_227.wav
# Renamed: 40_Dombe_Pygmy_Toad_segment_3.wav -> other_frog_228.wav
# Renamed: 125_Poyntons_River_Frog_segment_3.wav -> other_frog_229.wav
# Renamed: 86_Angolan_Reed_Frog_segment_3.wav -> other_frog_230.wav
# Renamed: 48_Guttural_Toad_segment_1.wav -> other_frog_231.wav
# Keeping: 11_Strawberry_Rain_Frog_segment_2.wav
# Renamed: 97_Rattling_Frog_segment_1.wav -> other_frog_232.wav
# Renamed: 145_Bronze_Caco_segment_1.wav -> other_frog_233.wav
# Renamed: 128_Natal_Chirping_Frog_segment_3.wav -> other_frog_234.wav
# Renamed: 115_Dwarf_Grass_Frog_segment_1.wav -> other_frog_235.wav
# Renamed: 129_Mistbelt_Chirping_Frog_segment_2.wav -> other_frog_236.wav
# Renamed: 153_Montane_Marsh_Frog_segment_1.wav -> other_frog_237.wav
# Renamed: 115_Dwarf_Grass_Frog_segment_5.wav -> other_frog_238.wav
# Keeping: 22_Namaqua_Rain_Frog_segment_4.wav
# Renamed: 77_Bocages_Sharpnosed_segment_1.wav -> other_frog_239.wav
# Renamed: 71_Delicate_Leaffolding_Frog_segment_1.wav -> other_frog_240.wav
# Keeping: 27_Whistling_Rain_Frog_segment_2.wav
# Renamed: 119_Mullers_Platanna_segment_2.wav -> other_frog_241.wav
# Renamed: 139_Southern_Caco_segment_5.wav -> other_frog_242.wav
# Keeping: 18_Cape_Rain_Frog_segment_3.wav
# Renamed: 122_Cape_River_Frog_segment_3.wav -> other_frog_243.wav
# Renamed: 08_Brownbacked_Tree_Frog_segment_4.wav -> other_frog_244.wav
# Renamed: 70_Snoring_Leaffolding_Frog_segment_1.wav -> other_frog_245.wav
# Renamed: 79_Nyanga_Long_Reed_Frog_segment_1.wav -> other_frog_246.wav
# Renamed: 105_Ornate_Frog_segment_1.wav -> other_frog_247.wav
# Keeping: 25_Sand_Rain_Frog_B_r_rosei_segment_3.wav
# Renamed: 105_Ornate_Frog_segment_3.wav -> other_frog_248.wav
# Renamed: 69_Golden_Leaffolding_Frog_segment_6.wav -> other_frog_249.wav
# Renamed: 132_Drewes_Moss_Frog_segment_6.wav -> other_frog_250.wav
# Renamed: 146_Mountain_Caco_segment_7.wav -> other_frog_251.wav
# Renamed: 161_Namaqua_Stream_Frog_segment_4.wav -> other_frog_252.wav
# Renamed: 61_Hewitts_Ghost_Frog_segment_2.wav -> other_frog_253.wav
# Renamed: 51_Eastern_Leopard_Toad_segment_1.wav -> other_frog_254.wav
# Renamed: 109_Broadbanded_Grass_Frog_segment_3.wav -> other_frog_255.wav
# Renamed: 44_Southern_Pygmy_Toad_segment_2.wav -> other_frog_256.wav
# Renamed: 112_Striped_Grass_Frog_segment_4.wav -> other_frog_257.wav
# Renamed: 41_Northern_Pygmy_Toad_segment_1.wav -> other_frog_258.wav
# Renamed: 08_Brownbacked_Tree_Frog_segment_2.wav -> other_frog_259.wav
# Renamed: 147_Flat_Caco_segment_5.wav -> other_frog_260.wav
# Keeping: 30_Plaintive_Rain_Frog_segment_2.wav
# Renamed: 41_Northern_Pygmy_Toad_segment_3.wav -> other_frog_261.wav
# Renamed: 101_East_African_Puddle_Frog_segment_5.wav -> other_frog_262.wav
# Renamed: 83_Mitchells_Reed_Frog_segment_3.wav -> other_frog_263.wav
# Renamed: 61_Hewitts_Ghost_Frog_segment_3.wav -> other_frog_264.wav
# Renamed: 138_Klipheuwel_Caco_segment_5.wav -> other_frog_265.wav
# Renamed: 131_Bainskloof_Moss_Frog_segment_2.wav -> other_frog_266.wav
# Renamed: 02_Chimanimani_Squeaker_segment_4.wav -> other_frog_267.wav
# Renamed: 172_Galam_Goldenbacked_Frog_segment_5.wav -> other_frog_268.wav
# Keeping: 157_Banded_Stream_Frog_segment_2.wav
# Renamed: 155_East_African_Bullfrog_segment_2.wav -> other_frog_269.wav
# Renamed: 147_Flat_Caco_segment_4.wav -> other_frog_270.wav
# Renamed: 171_Darlings_Goldenbacked_Frog_segment_2.wav -> other_frog_271.wav
# Renamed: 59_Natal_Cascade_Frog_segment_4.wav -> other_frog_272.wav
# Renamed: 151_Micro_Frog_segment_4.wav -> other_frog_273.wav
# Renamed: 144_KwaZulu_Caco_segment_2.wav -> other_frog_274.wav
# Renamed: 60_Cederberg_Ghost_Frog_segment_3.wav -> other_frog_275.wav
# Renamed: 126_Van_Dijks_River_Frog_segment_3.wav -> other_frog_276.wav
# Keeping: 134_Cape_Peninsula_Moss_Frog_segment_5.wav
# Renamed: 112_Striped_Grass_Frog_segment_2.wav -> other_frog_277.wav
# Keeping: 25_Sand_Rain_Frog_B_r_rosei_segment_2.wav
# Renamed: 54_Amatola_Toad_segment_2.wav -> other_frog_278.wav
# Renamed: 87_Parkers_Reed_Frog_segment_2.wav -> other_frog_279.wav
# Renamed: 74_Natal_Leaffolding_Frog_A_s_intermedius_segment_1.wav -> other_frog_280.wav
# Renamed: 130_Hogsback_Chirping_Frog_segment_2.wav -> other_frog_281.wav
# Renamed: 171_Darlings_Goldenbacked_Frog_segment_4.wav -> other_frog_282.wav
# Renamed: 109_Broadbanded_Grass_Frog_segment_5.wav -> other_frog_283.wav
# Renamed: 60_Cederberg_Ghost_Frog_segment_5.wav -> other_frog_284.wav
# Renamed: 42_Hoeschs_Pygmy_Toad_segment_2.wav -> other_frog_285.wav
# Renamed: 144_KwaZulu_Caco_segment_6.wav -> other_frog_286.wav
# Renamed: 97_Rattling_Frog_segment_3.wav -> other_frog_287.wav
# Renamed: 80_Marginated_Reed_Frog_segment_2.wav -> other_frog_288.wav
# Keeping: 11_Strawberry_Rain_Frog_segment_4.wav
# Renamed: 161_Namaqua_Stream_Frog_segment_2.wav -> other_frog_289.wav
# Renamed: 119_Mullers_Platanna_segment_4.wav -> other_frog_290.wav
# Renamed: 115_Dwarf_Grass_Frog_segment_2.wav -> other_frog_291.wav
# Keeping: 16_Zululand_Rain_Frog_segment_4.wav
# Renamed: 78_Arum_Lily_Frog_segment_4.wav -> other_frog_292.wav
# Renamed: 172_Galam_Goldenbacked_Frog_segment_2.wav -> other_frog_293.wav
# Keeping: 159_Clicking_Stream_Frog_segment_4.wav
# Renamed: 146_Mountain_Caco_segment_6.wav -> other_frog_294.wav
# Renamed: 173_Southern_Foam_Nest_Frog_segment_4.wav -> other_frog_295.wav
# Renamed: 111_Sharpnosed_Grass_Frog_segment_5.wav -> other_frog_296.wav
# Renamed: 132_Drewes_Moss_Frog_segment_1.wav -> other_frog_297.wav
# Renamed: 85_Long_Reed_Frog_segment_1.wav -> other_frog_298.wav
# Renamed: 08_Brownbacked_Tree_Frog_segment_5.wav -> other_frog_299.wav
# Renamed: 105_Ornate_Frog_segment_5.wav -> other_frog_300.wav
# Keeping: 27_Whistling_Rain_Frog_segment_1.wav
# Keeping: 134_Cape_Peninsula_Moss_Frog_segment_2.wav
# Renamed: 83_Mitchells_Reed_Frog_segment_1.wav -> other_frog_301.wav
# Renamed: 67_Spotted_Shovelnosed_Frog_segment_4.wav -> other_frog_302.wav
# Keeping: 13_Bushveld_Rain_Frog_B_a_pentheri_segment_2.wav
# Renamed: 110_Nile_Grass_Frog_segment_1.wav -> other_frog_303.wav
# Renamed: 47_Eastern_Olive_Toad_segment_4.wav -> other_frog_304.wav
# Renamed: 153_Montane_Marsh_Frog_segment_6.wav -> other_frog_305.wav
# Renamed: 126_Van_Dijks_River_Frog_segment_2.wav -> other_frog_306.wav
# Keeping: 21_Mozambique_Rain_Frog_segment_5.wav
# Renamed: 122_Cape_River_Frog_segment_7.wav -> other_frog_307.wav
# Keeping: 16_Phinda_Rain_Frog_segment_3.wav
# Keeping: 157_Banded_Stream_Frog_segment_6.wav
# Renamed: 143_Namaqua_Caco_segment_6.wav -> other_frog_308.wav
# Renamed: 171_Darlings_Goldenbacked_Frog_segment_5.wav -> other_frog_309.wav
# Renamed: 111_Sharpnosed_Grass_Frog_segment_3.wav -> other_frog_310.wav
# Renamed: 10_Longtoed_Tree_Frog_segment_4.wav -> other_frog_311.wav
# Renamed: 38_Beira_Pygmy_Toad_segment_3.wav -> other_frog_312.wav
# Renamed: 50_Western_Leopard_Toad_segment_2.wav -> other_frog_313.wav
# Renamed: 167_Russetbacked_Sand_Frog_segment_3.wav -> other_frog_314.wav
# Renamed: 133_Landdroskop_Moss_Frog_segment_2.wav -> other_frog_315.wav
# Renamed: 52_Western_Olive_Toad_segment_6.wav -> other_frog_316.wav
# Renamed: 89_Powers_Long_Reed_Frog_segment_4.wav -> other_frog_317.wav
# Renamed: 84_Pointed_Long_Reed_Frog_segment_2.wav -> other_frog_318.wav
# Renamed: 61_Hewitts_Ghost_Frog_segment_4.wav -> other_frog_319.wav
# Keeping: 16_Phinda_Rain_Frog_segment_1.wav
# Keeping: 30_Plaintive_Rain_Frog_segment_5.wav
# Renamed: 163_Tremolo_Sand_Frog_segment_3.wav -> other_frog_320.wav
# Renamed: 138_Klipheuwel_Caco_segment_4.wav -> other_frog_321.wav
# Renamed: 170_Rough_Sand_Frog_segment_2.wav -> other_frog_322.wav
# Renamed: 143_Namaqua_Caco_segment_2.wav -> other_frog_323.wav
# Renamed: 58_Paradise_Toad_segment_1.wav -> other_frog_324.wav
# Renamed: 02_Chimanimani_Squeaker_segment_6.wav -> other_frog_325.wav
# Renamed: 139_Southern_Caco_segment_14.wav -> other_frog_326.wav
# Renamed: 107_Guibes_Grass_Frog_segment_4.wav -> other_frog_327.wav
# Keeping: 81_Painted_Reed_Frog_segment_2.wav
# Renamed: 45_Red_Toad_segment_1.wav -> other_frog_328.wav
# Renamed: 90_Water_Lily_Frog_segment_5.wav -> other_frog_329.wav
# Renamed: 68_Mottled_Shovelnosed_Frog_segment_4.wav -> other_frog_330.wav
# Renamed: 119_Mullers_Platanna_segment_1.wav -> other_frog_331.wav
# Keeping: 19_Desert_Rain_Frog_segment_6.wav
# Renamed: 78_Arum_Lily_Frog_segment_3.wav -> other_frog_332.wav
# Renamed: 36_Tradouw_Mountain_Toadlet_segment_3.wav -> other_frog_333.wav
# Keeping: 23_Ndumo_Rain_Frog_segment_5.wav
# Renamed: 87_Parkers_Reed_Frog_segment_3.wav -> other_frog_334.wav
# Renamed: 155_East_African_Bullfrog_segment_1.wav -> other_frog_335.wav
# Renamed: 152_Kloof_Frog_segment_1.wav -> other_frog_336.wav
# Renamed: 50_Western_Leopard_Toad_segment_3.wav -> other_frog_337.wav
# Renamed: 36_Tradouw_Mountain_Toadlet_segment_4.wav -> other_frog_338.wav
# Renamed: 59_Natal_Cascade_Frog_segment_2.wav -> other_frog_339.wav
# Keeping: 28_Northern_Forest_Rain_Frog_B_s_sylvestris_segment_3.wav
# Renamed: 123_Phofung_River_Frog_segment_2.wav -> other_frog_340.wav
# Keeping: 23_Passmores_Rain_Frog_segment_3.wav
# Renamed: 64_Southern_Ghost_Frog_segment_1.wav -> other_frog_341.wav
# Renamed: 50_Western_Leopard_Toad_segment_1.wav -> other_frog_342.wav
# Renamed: 102_Dwarf_Puddle_Frog_segment_1.wav -> other_frog_343.wav
# Renamed: 173_Southern_Foam_Nest_Frog_segment_1.wav -> other_frog_344.wav
# Renamed: 02_Chimanimani_Squeaker_segment_3.wav -> other_frog_345.wav
# Renamed: 06_Broadleys_Tree_Frog_segment_5.wav -> other_frog_346.wav
# Renamed: 108_Mapacha_Grass_Frog_segment_2.wav -> other_frog_347.wav
# Renamed: 145_Bronze_Caco_segment_3.wav -> other_frog_348.wav
# Keeping: 18_Cape_Rain_Frog_segment_4.wav
# Renamed: 50_Western_Leopard_Toad_segment_6.wav -> other_frog_349.wav
# Keeping: 11_Strawberry_Rain_Frog_segment_6.wav
# Renamed: 68_Mottled_Shovelnosed_Frog_segment_3.wav -> other_frog_350.wav
# Renamed: 36_Tradouw_Mountain_Toadlet_segment_5.wav -> other_frog_351.wav
# Renamed: 85_Long_Reed_Frog_segment_4.wav -> other_frog_352.wav
# Renamed: 41_Northern_Pygmy_Toad_segment_2.wav -> other_frog_353.wav
# Renamed: 131_Bainskloof_Moss_Frog_segment_1.wav -> other_frog_354.wav
# Renamed: 63_Cape_Ghost_Frog_segment_1.wav -> other_frog_355.wav
# Renamed: 89_Powers_Long_Reed_Frog_segment_2.wav -> other_frog_356.wav
# Renamed: 40_Dombe_Pygmy_Toad_segment_2.wav -> other_frog_357.wav
# Renamed: 68_Mottled_Shovelnosed_Frog_segment_2.wav -> other_frog_358.wav
# Keeping: 16_Phinda_Rain_Frog_segment_5.wav
# Renamed: 92_Yellowstriped_Reed_Frog_segment_1.wav -> other_frog_359.wav
# Keeping: 24_Powers_Rain_Frog_segment_5.wav
# Renamed: 139_Southern_Caco_segment_2.wav -> other_frog_360.wav
# Keeping: 19_Desert_Rain_Frog_segment_1.wav
# Renamed: 173_Southern_Foam_Nest_Frog_segment_2.wav -> other_frog_361.wav
# Renamed: 52_Western_Olive_Toad_segment_3.wav -> other_frog_362.wav
# Keeping: 22_Namaqua_Rain_Frog_segment_1.wav
# Renamed: 149_Striped_Caco_segment_3.wav -> other_frog_363.wav
# Renamed: 86_Angolan_Reed_Frog_segment_5.wav -> other_frog_364.wav
# Keeping: 23_Passmores_Rain_Frog_segment_4.wav
# Renamed: 126_Van_Dijks_River_Frog_segment_4.wav -> other_frog_365.wav
# Keeping: 23_Ndumo_Rain_Frog_segment_3.wav
# Renamed: 09_Natal_Tree_Frog_segment_5.wav -> other_frog_366.wav
# Renamed: 56_Karoo_Toad_segment_4.wav -> other_frog_367.wav
# Renamed: 135_Rough_Moss_Frog_segment_5.wav -> other_frog_368.wav
# Renamed: 131_Bainskloof_Moss_Frog_segment_4.wav -> other_frog_369.wav
# Renamed: 171_Darlings_Goldenbacked_Frog_segment_3.wav -> other_frog_370.wav
# Renamed: 144_KwaZulu_Caco_segment_1.wav -> other_frog_371.wav
# Renamed: 55_Cape_Sand_Toad_segment_3.wav -> other_frog_372.wav
# Renamed: 46_Raucous_Toad_segment_2.wav -> other_frog_373.wav
# Renamed: 60_Cederberg_Ghost_Frog_segment_1.wav -> other_frog_374.wav
# Renamed: 165_Cape_Sand_Frog_segment_2.wav -> other_frog_375.wav
# Renamed: 87_Parkers_Reed_Frog_segment_1.wav -> other_frog_376.wav
# Renamed: 53_Flatbacked_Toad_segment_3.wav -> other_frog_377.wav
# Renamed: 113_Schilluk_Grass_Frog_segment_5.wav -> other_frog_378.wav
# Renamed: 48_Guttural_Toad_segment_4.wav -> other_frog_379.wav
# Keeping: 30_Plaintive_Rain_Frog_segment_3.wav
# Renamed: 67_Spotted_Shovelnosed_Frog_segment_2.wav -> other_frog_380.wav
# Renamed: 99_Marbled_Rubber_Frog_segment_4.wav -> other_frog_381.wav
# Keeping: 16_Zululand_Rain_Frog_segment_2.wav
# Renamed: 136_Northern_Moss_Frog_segment_8.wav -> other_frog_382.wav
# Renamed: 155_East_African_Bullfrog_segment_5.wav -> other_frog_383.wav
# Renamed: 138_Klipheuwel_Caco_segment_6.wav -> other_frog_384.wav
# Keeping: 27_Whistling_Rain_Frog_segment_5.wav
# Renamed: 168_Natal_Sand_Frog_segment_1.wav -> other_frog_385.wav
# Renamed: 111_Sharpnosed_Grass_Frog_segment_4.wav -> other_frog_386.wav
# Renamed: 94_Tinker_Reed_Frog_segment_5.wav -> other_frog_387.wav
# Keeping: 20_Cape_Mountain_Rain_Frog_segment_1.wav
# Renamed: 128_Natal_Chirping_Frog_segment_2.wav -> other_frog_388.wav
# Renamed: 45_Red_Toad_segment_6.wav -> other_frog_389.wav
# Renamed: 166_Knocking_Sand_Frog_segment_3.wav -> other_frog_390.wav
# Renamed: 133_Landdroskop_Moss_Frog_segment_4.wav -> other_frog_391.wav
# Keeping: 23_Passmores_Rain_Frog_segment_1.wav
# Renamed: 101_East_African_Puddle_Frog_segment_3.wav -> other_frog_392.wav
# Keeping: 26_Sand_Rain_Frog_B_r_vansoni_segment_4.wav
# Renamed: 67_Spotted_Shovelnosed_Frog_segment_5.wav -> other_frog_393.wav
# Renamed: 140_Boettgers_Caco_segment_1.wav -> other_frog_394.wav
# Renamed: 45_Red_Toad_segment_5.wav -> other_frog_395.wav
# Renamed: 86_Angolan_Reed_Frog_segment_6.wav -> other_frog_396.wav
# Renamed: 100_Banded_Rubber_Frog_segment_1.wav -> other_frog_397.wav
# Renamed: 162_Plain_Stream_Frog_segment_4.wav -> other_frog_398.wav
# Renamed: 107_Guibes_Grass_Frog_segment_5.wav -> other_frog_399.wav
# Keeping: 21_Mozambique_Rain_Frog_segment_1.wav
# Renamed: 147_Flat_Caco_segment_2.wav -> other_frog_400.wav
# Renamed: 03_Bush_Squeaker_segment_4.wav -> other_frog_401.wav
# Renamed: 136_Northern_Moss_Frog_segment_3.wav -> other_frog_402.wav
# Renamed: 78_Arum_Lily_Frog_segment_2.wav -> other_frog_403.wav
# Renamed: 101_East_African_Puddle_Frog_segment_6.wav -> other_frog_404.wav
# Renamed: 108_Mapacha_Grass_Frog_segment_3.wav -> other_frog_405.wav
# Keeping: 13_Bushveld_Rain_Frog_B_a_pentheri_segment_4.wav
# Renamed: 141_Cape_Caco_segment_2.wav -> other_frog_406.wav
# Renamed: 64_Southern_Ghost_Frog_segment_5.wav -> other_frog_407.wav
# Renamed: 04_Dwarf_Squeaker_segment_3.wav -> other_frog_408.wav
# Renamed: 103_Snoring_Puddle_Frog_segment_2.wav -> other_frog_409.wav
# Renamed: 140_Boettgers_Caco_segment_2.wav -> other_frog_410.wav
# Renamed: 139_Southern_Caco_segment_11.wav -> other_frog_411.wav
# Keeping: 17_Plain_Rain_Frog_segment_1.wav
# Renamed: 03_Bush_Squeaker_segment_5.wav -> other_frog_412.wav
# Renamed: 140_Boettgers_Caco_segment_4.wav -> other_frog_413.wav
# Renamed: 46_Raucous_Toad_segment_1.wav -> other_frog_414.wav
# Renamed: 108_Mapacha_Grass_Frog_segment_1.wav -> other_frog_415.wav
# Renamed: 135_Rough_Moss_Frog_segment_1.wav -> other_frog_416.wav
# Renamed: 64_Southern_Ghost_Frog_segment_3.wav -> other_frog_417.wav
# Renamed: 52_Western_Olive_Toad_segment_1.wav -> other_frog_418.wav
# Renamed: 90_Water_Lily_Frog_segment_4.wav -> other_frog_419.wav
# Renamed: 64_Southern_Ghost_Frog_segment_2.wav -> other_frog_420.wav
# Keeping: 157_Banded_Stream_Frog_segment_3.wav
# Renamed: 71_Delicate_Leaffolding_Frog_segment_4.wav -> other_frog_421.wav
# Keeping: 19_Desert_Rain_Frog_segment_5.wav
# Renamed: 151_Micro_Frog_segment_5.wav -> other_frog_422.wav
# Renamed: 63_Cape_Ghost_Frog_segment_2.wav -> other_frog_423.wav
# Renamed: 136_Northern_Moss_Frog_segment_7.wav -> other_frog_424.wav
# Renamed: 129_Mistbelt_Chirping_Frog_segment_1.wav -> other_frog_425.wav
# Renamed: 110_Nile_Grass_Frog_segment_4.wav -> other_frog_426.wav
# Renamed: 172_Galam_Goldenbacked_Frog_segment_4.wav -> other_frog_427.wav
# Renamed: 160_Chimanimani_Stream_Frog_segment_1.wav -> other_frog_428.wav
# Renamed: 154_Giant_Bullfrog_segment_1.wav -> other_frog_429.wav
# Renamed: 90_Water_Lily_Frog_segment_2.wav -> other_frog_430.wav
# Renamed: 67_Spotted_Shovelnosed_Frog_segment_1.wav -> other_frog_431.wav
# Renamed: 54_Amatola_Toad_segment_1.wav -> other_frog_432.wav
# Renamed: 121_Common_River_Frog_segment_4.wav -> other_frog_433.wav
# Renamed: 10_Longtoed_Tree_Frog_segment_3.wav -> other_frog_434.wav
# Renamed: 103_Snoring_Puddle_Frog_segment_3.wav -> other_frog_435.wav
# Renamed: 83_Mitchells_Reed_Frog_segment_2.wav -> other_frog_436.wav
# Renamed: 94_Tinker_Reed_Frog_segment_3.wav -> other_frog_437.wav
# Renamed: 99_Marbled_Rubber_Frog_segment_1.wav -> other_frog_438.wav
# Renamed: 73_Knysna_Leaffolding_Frog_segment_5.wav -> other_frog_439.wav
# Renamed: 152_Kloof_Frog_segment_2.wav -> other_frog_440.wav
# Renamed: 90_Water_Lily_Frog_segment_3.wav -> other_frog_441.wav
# Renamed: 60_Cederberg_Ghost_Frog_segment_7.wav -> other_frog_442.wav
# Renamed: 10_Longtoed_Tree_Frog_segment_2.wav -> other_frog_443.wav
# Renamed: 54_Amatola_Toad_segment_4.wav -> other_frog_444.wav
# Keeping: 17_Plain_Rain_Frog_segment_4.wav
# Renamed: 161_Namaqua_Stream_Frog_segment_1.wav -> other_frog_445.wav
# Renamed: 51_Eastern_Leopard_Toad_segment_3.wav -> other_frog_446.wav
# Renamed: 123_Phofung_River_Frog_segment_3.wav -> other_frog_447.wav
# Renamed: 38_Beira_Pygmy_Toad_segment_1.wav -> other_frog_448.wav
# Renamed: 156_African_Bullfrog_segment_4.wav -> other_frog_449.wav
# Renamed: 93_Swynnertons_Reed_Frog_segment_2.wav -> other_frog_450.wav
# Renamed: 88_Pickersgills_Reed_Frog_segment_1.wav -> other_frog_451.wav
# Renamed: 96_Bubbling_Kassina_segment_1.wav -> other_frog_452.wav
# Keeping: 27_Whistling_Rain_Frog_segment_6.wav
# Renamed: 132_Drewes_Moss_Frog_segment_2.wav -> other_frog_453.wav
# Renamed: 54_Amatola_Toad_segment_3.wav -> other_frog_454.wav
# Keeping: 21_Mozambique_Rain_Frog_segment_3.wav
# Renamed: 143_Namaqua_Caco_segment_4.wav -> other_frog_455.wav
# Renamed: 118_Common_Platanna_segment_4.wav -> other_frog_456.wav
# Keeping: 14_Bilbos_Rain_Frog_segment_1.wav
# Renamed: 139_Southern_Caco_segment_1.wav -> other_frog_457.wav
# Renamed: 97_Rattling_Frog_segment_5.wav -> other_frog_458.wav
# Keeping: 23_Passmores_Rain_Frog_segment_5.wav
# Renamed: 82_Sharpheaded_Long_Reed_Frog_segment_1.wav -> other_frog_459.wav
# Renamed: 96_Bubbling_Kassina_segment_2.wav -> other_frog_460.wav
# Renamed: 105_Ornate_Frog_segment_2.wav -> other_frog_461.wav
# Renamed: 71_Delicate_Leaffolding_Frog_segment_6.wav -> other_frog_462.wav
# Renamed: 93_Swynnertons_Reed_Frog_segment_5.wav -> other_frog_463.wav
# Renamed: 138_Klipheuwel_Caco_segment_3.wav -> other_frog_464.wav
# Keeping: 134_Cape_Peninsula_Moss_Frog_segment_1.wav
# Keeping: 22_Namaqua_Rain_Frog_segment_3.wav
# Renamed: 138_Klipheuwel_Caco_segment_8.wav -> other_frog_465.wav
# Renamed: 94_Tinker_Reed_Frog_segment_1.wav -> other_frog_466.wav
# Renamed: 123_Phofung_River_Frog_segment_5.wav -> other_frog_467.wav
# Renamed: 146_Mountain_Caco_segment_3.wav -> other_frog_468.wav
# Renamed: 132_Drewes_Moss_Frog_segment_5.wav -> other_frog_469.wav
# Renamed: 103_Snoring_Puddle_Frog_segment_1.wav -> other_frog_470.wav
# Renamed: 101_East_African_Puddle_Frog_segment_2.wav -> other_frog_471.wav
# Keeping: 27_Whistling_Rain_Frog_segment_3.wav
# Renamed: 53_Flatbacked_Toad_segment_1.wav -> other_frog_472.wav
# Renamed: 156_African_Bullfrog_segment_1.wav -> other_frog_473.wav
# Renamed: 106_Plain_Grass_Frog_segment_1.wav -> other_frog_474.wav
# Renamed: 121_Common_River_Frog_segment_1.wav -> other_frog_475.wav
# Renamed: 139_Southern_Caco_segment_9.wav -> other_frog_476.wav
# Renamed: 139_Southern_Caco_segment_12.wav -> other_frog_477.wav
# Renamed: 45_Red_Toad_segment_3.wav -> other_frog_478.wav
# Renamed: 145_Bronze_Caco_segment_2.wav -> other_frog_479.wav
# Renamed: 146_Mountain_Caco_segment_8.wav -> other_frog_480.wav
# Renamed: 141_Cape_Caco_segment_4.wav -> other_frog_481.wav
# Renamed: 03_Bush_Squeaker_segment_3.wav -> other_frog_482.wav
# Renamed: 75_Natal_Leaffolding_Frog_A_s_spinifrons_segment_2.wav -> other_frog_483.wav
# Renamed: 38_Beira_Pygmy_Toad_segment_2.wav -> other_frog_484.wav
# Renamed: 64_Southern_Ghost_Frog_segment_4.wav -> other_frog_485.wav
# Renamed: 126_Van_Dijks_River_Frog_segment_1.wav -> other_frog_486.wav
# Keeping: 14_Bilbos_Rain_Frog_segment_2.wav
# Renamed: 68_Mottled_Shovelnosed_Frog_segment_1.wav -> other_frog_487.wav
# Renamed: 142_Karoo_Caco_segment_4.wav -> other_frog_488.wav
# Renamed: 167_Russetbacked_Sand_Frog_segment_7.wav -> other_frog_489.wav
# Keeping: 20_Cape_Mountain_Rain_Frog_segment_6.wav
# Renamed: 167_Russetbacked_Sand_Frog_segment_2.wav -> other_frog_490.wav
# Renamed: 62_Eastern_Ghost_Frog_segment_3.wav -> other_frog_491.wav
# Renamed: 47_Eastern_Olive_Toad_segment_2.wav -> other_frog_492.wav
# Renamed: 133_Landdroskop_Moss_Frog_segment_3.wav -> other_frog_493.wav
# Renamed: 145_Bronze_Caco_segment_5.wav -> other_frog_494.wav
# Renamed: 155_East_African_Bullfrog_segment_6.wav -> other_frog_495.wav
# Renamed: 99_Marbled_Rubber_Frog_segment_5.wav -> other_frog_496.wav
# Renamed: 127_Maluti_River_Frog_segment_2.wav -> other_frog_497.wav
# Renamed: 69_Golden_Leaffolding_Frog_segment_4.wav -> other_frog_498.wav
# Renamed: 89_Powers_Long_Reed_Frog_segment_1.wav -> other_frog_499.wav
# Renamed: 03_Bush_Squeaker_segment_1.wav -> other_frog_500.wav
# Renamed: 169_Tandys_Sand_Frog_segment_5.wav -> other_frog_501.wav
# Renamed: 02_Chimanimani_Squeaker_segment_2.wav -> other_frog_502.wav
# Keeping: 23_Passmores_Rain_Frog_segment_2.wav
# Keeping: 81_Painted_Reed_Frog_segment_1.wav
# Renamed: 80_Marginated_Reed_Frog_segment_1.wav -> other_frog_503.wav
# Renamed: 122_Cape_River_Frog_segment_5.wav -> other_frog_504.wav
# Renamed: 160_Chimanimani_Stream_Frog_segment_4.wav -> other_frog_505.wav
# Renamed: 84_Pointed_Long_Reed_Frog_segment_1.wav -> other_frog_506.wav
# Keeping: 21_Mozambique_Rain_Frog_segment_6.wav
# Renamed: 136_Northern_Moss_Frog_segment_2.wav -> other_frog_507.wav
# Renamed: 116_Udzungwa_Grass_Frog_segment_1.wav -> other_frog_508.wav
# Renamed: 138_Klipheuwel_Caco_segment_1.wav -> other_frog_509.wav
# Renamed: 97_Rattling_Frog_segment_4.wav -> other_frog_510.wav
# Renamed: 75_Natal_Leaffolding_Frog_A_s_spinifrons_segment_1.wav -> other_frog_511.wav
# Renamed: 102_Dwarf_Puddle_Frog_segment_5.wav -> other_frog_512.wav
# Renamed: 103_Snoring_Puddle_Frog_segment_5.wav -> other_frog_513.wav
# Renamed: 06_Broadleys_Tree_Frog_segment_3.wav -> other_frog_514.wav
# Renamed: 107_Guibes_Grass_Frog_segment_3.wav -> other_frog_515.wav
# Keeping: 23_Ndumo_Rain_Frog_segment_4.wav
# Renamed: 63_Cape_Ghost_Frog_segment_4.wav -> other_frog_516.wav
# Renamed: 165_Cape_Sand_Frog_segment_1.wav -> other_frog_517.wav
# Renamed: 71_Delicate_Leaffolding_Frog_segment_5.wav -> other_frog_518.wav
# Renamed: 163_Tremolo_Sand_Frog_segment_1.wav -> other_frog_519.wav
# Renamed: 135_Rough_Moss_Frog_segment_2.wav -> other_frog_520.wav
# Renamed: 60_Cederberg_Ghost_Frog_segment_2.wav -> other_frog_521.wav
# Renamed: 146_Mountain_Caco_segment_4.wav -> other_frog_522.wav
# Renamed: 151_Micro_Frog_segment_6.wav -> other_frog_523.wav
# Renamed: 142_Karoo_Caco_segment_6.wav -> other_frog_524.wav
# Renamed: 139_Southern_Caco_segment_3.wav -> other_frog_525.wav
# Renamed: 128_Natal_Chirping_Frog_segment_6.wav -> other_frog_526.wav
# Renamed: 120_Powers_Platanna_segment_1.wav -> other_frog_527.wav
# Renamed: 92_Yellowstriped_Reed_Frog_segment_3.wav -> other_frog_528.wav
# Renamed: 07_Yellowspotted_Tree_Frog_segment_3.wav -> other_frog_529.wav
# Renamed: 107_Guibes_Grass_Frog_segment_1.wav -> other_frog_530.wav
# Keeping: 12_Bushveld_Rain_Frog_B_a_adspersus_segment_4.wav
# Renamed: 88_Pickersgills_Reed_Frog_segment_4.wav -> other_frog_531.wav
# Keeping: 81_Painted_Reed_Frog_segment_3.wav
# Keeping: 29_Northern_Forest_Rain_Frog_B_s_taeniatus_segment_4.wav
# Renamed: 72_Greater_Leaffolding_Frog_segment_3.wav -> other_frog_532.wav
# Renamed: 113_Schilluk_Grass_Frog_segment_4.wav -> other_frog_533.wav
# Renamed: 76_Argus_Reed_Frog_segment_2.wav -> other_frog_534.wav
# Renamed: 09_Natal_Tree_Frog_segment_1.wav -> other_frog_535.wav
# Renamed: 173_Southern_Foam_Nest_Frog_segment_3.wav -> other_frog_536.wav
# Keeping: 13_Bushveld_Rain_Frog_B_a_pentheri_segment_3.wav
# Renamed: 65_Table_Mountain_Ghost_Frog_segment_1.wav -> other_frog_537.wav
# Renamed: 84_Pointed_Long_Reed_Frog_segment_3.wav -> other_frog_538.wav
# Renamed: 139_Southern_Caco_segment_8.wav -> other_frog_539.wav
# Keeping: 14_Bilbos_Rain_Frog_segment_7.wav
# Renamed: 94_Tinker_Reed_Frog_segment_2.wav -> other_frog_540.wav
# Renamed: 72_Greater_Leaffolding_Frog_segment_1.wav -> other_frog_541.wav
# Keeping: 18_Cape_Rain_Frog_segment_2.wav
# Keeping: 30_Plaintive_Rain_Frog_segment_1.wav
# Keeping: 24_Powers_Rain_Frog_segment_4.wav
# Renamed: 60_Cederberg_Ghost_Frog_segment_8.wav -> other_frog_542.wav
# Renamed: 112_Striped_Grass_Frog_segment_3.wav -> other_frog_543.wav
# Keeping: 134_Cape_Peninsula_Moss_Frog_segment_6.wav
# Renamed: 96_Bubbling_Kassina_segment_4.wav -> other_frog_544.wav
# Renamed: 135_Rough_Moss_Frog_segment_4.wav -> other_frog_545.wav
# Renamed: 101_East_African_Puddle_Frog_segment_4.wav -> other_frog_546.wav
# Keeping: 29_Northern_Forest_Rain_Frog_B_s_taeniatus_segment_1.wav
# Renamed: 114_Speckledbellied_Grass_Frog_segment_1.wav -> other_frog_547.wav
# Renamed: 100_Banded_Rubber_Frog_segment_3.wav -> other_frog_548.wav
# Renamed: 86_Angolan_Reed_Frog_segment_4.wav -> other_frog_549.wav
# Renamed: 47_Eastern_Olive_Toad_segment_1.wav -> other_frog_550.wav
# Renamed: 106_Plain_Grass_Frog_segment_4.wav -> other_frog_551.wav
# Renamed: 139_Southern_Caco_segment_7.wav -> other_frog_552.wav
# Renamed: 100_Banded_Rubber_Frog_segment_5.wav -> other_frog_553.wav
# Renamed: 48_Guttural_Toad_segment_3.wav -> other_frog_554.wav
# Renamed: 71_Delicate_Leaffolding_Frog_segment_2.wav -> other_frog_555.wav
# Keeping: 20_Cape_Mountain_Rain_Frog_segment_2.wav
# Keeping: 16_Phinda_Rain_Frog_segment_4.wav
# Keeping: 25_Sand_Rain_Frog_B_r_rosei_segment_5.wav
# Renamed: 160_Chimanimani_Stream_Frog_segment_5.wav -> other_frog_556.wav
# Renamed: 129_Mistbelt_Chirping_Frog_segment_4.wav -> other_frog_557.wav
# Renamed: 53_Flatbacked_Toad_segment_2.wav -> other_frog_558.wav
# Keeping: 26_Sand_Rain_Frog_B_r_vansoni_segment_2.wav
# Renamed: 71_Delicate_Leaffolding_Frog_segment_7.wav -> other_frog_559.wav
# Renamed: 138_Klipheuwel_Caco_segment_2.wav -> other_frog_560.wav
# Renamed: 63_Cape_Ghost_Frog_segment_3.wav -> other_frog_561.wav
# Renamed: 146_Mountain_Caco_segment_5.wav -> other_frog_562.wav
# Renamed: 86_Angolan_Reed_Frog_segment_1.wav -> other_frog_563.wav
# Renamed: 111_Sharpnosed_Grass_Frog_segment_1.wav -> other_frog_564.wav
# Renamed: 162_Plain_Stream_Frog_segment_2.wav -> other_frog_565.wav
# Renamed: 68_Mottled_Shovelnosed_Frog_segment_5.wav -> other_frog_566.wav
# Renamed: 102_Dwarf_Puddle_Frog_segment_4.wav -> other_frog_567.wav
# Renamed: 02_Chimanimani_Squeaker_segment_8.wav -> other_frog_568.wav
# Renamed: 110_Nile_Grass_Frog_segment_3.wav -> other_frog_569.wav
# Keeping: 26_Sand_Rain_Frog_B_r_vansoni_segment_1.wav
# Keeping: 18_Cape_Rain_Frog_segment_6.wav
# Renamed: 07_Yellowspotted_Tree_Frog_segment_4.wav -> other_frog_570.wav
# Renamed: 149_Striped_Caco_segment_2.wav -> other_frog_571.wav
# Renamed: 169_Tandys_Sand_Frog_segment_4.wav -> other_frog_572.wav
# Renamed: 172_Galam_Goldenbacked_Frog_segment_6.wav -> other_frog_573.wav
# Renamed: 45_Red_Toad_segment_4.wav -> other_frog_574.wav
# Renamed: 48_Guttural_Toad_segment_2.wav -> other_frog_575.wav
# Renamed: 136_Northern_Moss_Frog_segment_1.wav -> other_frog_576.wav
# Keeping: 25_Sand_Rain_Frog_B_r_rosei_segment_1.wav
# Renamed: 133_Landdroskop_Moss_Frog_segment_6.wav -> other_frog_577.wav
# Renamed: 156_African_Bullfrog_segment_3.wav -> other_frog_578.wav
# Renamed: 71_Delicate_Leaffolding_Frog_segment_3.wav -> other_frog_579.wav
# Renamed: 117_Cape_Platanna_segment_2.wav -> other_frog_580.wav
# Renamed: 125_Poyntons_River_Frog_segment_2.wav -> other_frog_581.wav
# Renamed: 153_Montane_Marsh_Frog_segment_4.wav -> other_frog_582.wav
# Renamed: 140_Boettgers_Caco_segment_5.wav -> other_frog_583.wav
# Renamed: 110_Nile_Grass_Frog_segment_5.wav -> other_frog_584.wav
# Renamed: 64_Southern_Ghost_Frog_segment_6.wav -> other_frog_585.wav
# Renamed: 146_Mountain_Caco_segment_2.wav -> other_frog_586.wav
# Renamed: 55_Cape_Sand_Toad_segment_1.wav -> other_frog_587.wav
# Renamed: 154_Giant_Bullfrog_segment_3.wav -> other_frog_588.wav
# Renamed: 163_Tremolo_Sand_Frog_segment_5.wav -> other_frog_589.wav
# Keeping: 14_Bilbos_Rain_Frog_segment_4.wav
# Renamed: 171_Darlings_Goldenbacked_Frog_segment_1.wav -> other_frog_590.wav
# Keeping: 24_Powers_Rain_Frog_segment_3.wav
# Renamed: 149_Striped_Caco_segment_4.wav -> other_frog_591.wav
# Keeping: 157_Banded_Stream_Frog_segment_4.wav
# Keeping: 159_Clicking_Stream_Frog_segment_5.wav
# Renamed: 55_Cape_Sand_Toad_segment_4.wav -> other_frog_592.wav
# Keeping: 14_Bilbos_Rain_Frog_segment_5.wav
# Keeping: 18_Cape_Rain_Frog_segment_1.wav
# Renamed: 169_Tandys_Sand_Frog_segment_1.wav -> other_frog_593.wav
# Renamed: 56_Karoo_Toad_segment_1.wav -> other_frog_594.wav
# Renamed: 09_Natal_Tree_Frog_segment_3.wav -> other_frog_595.wav
# Keeping: 26_Sand_Rain_Frog_B_r_vansoni_segment_3.wav
# Renamed: 158_Striped_Stream_Frog_segment_2.wav -> other_frog_596.wav
# Renamed: 121_Common_River_Frog_segment_3.wav -> other_frog_597.wav
# Renamed: 82_Sharpheaded_Long_Reed_Frog_segment_2.wav -> other_frog_598.wav
# Renamed: 02_Chimanimani_Squeaker_segment_5.wav -> other_frog_599.wav
# Renamed: 88_Pickersgills_Reed_Frog_segment_2.wav -> other_frog_600.wav
# Renamed: 158_Striped_Stream_Frog_segment_4.wav -> other_frog_601.wav
# Keeping: 157_Banded_Stream_Frog_segment_1.wav
# Renamed: 41_Northern_Pygmy_Toad_segment_4.wav -> other_frog_602.wav
# Keeping: 29_Northern_Forest_Rain_Frog_B_s_taeniatus_segment_3.wav
# Renamed: 50_Western_Leopard_Toad_segment_5.wav -> other_frog_603.wav
# Renamed: 128_Natal_Chirping_Frog_segment_4.wav -> other_frog_604.wav
# Renamed: 99_Marbled_Rubber_Frog_segment_3.wav -> other_frog_605.wav
# Keeping: 11_Strawberry_Rain_Frog_segment_5.wav
# Renamed: 42_Hoeschs_Pygmy_Toad_segment_3.wav -> other_frog_606.wav
# Renamed: 79_Nyanga_Long_Reed_Frog_segment_2.wav -> other_frog_607.wav
# Renamed: 85_Long_Reed_Frog_segment_2.wav -> other_frog_608.wav
# Renamed: 04_Dwarf_Squeaker_segment_5.wav -> other_frog_609.wav
# Renamed: 08_Brownbacked_Tree_Frog_segment_3.wav -> other_frog_610.wav
# Renamed: 53_Flatbacked_Toad_segment_4.wav -> other_frog_611.wav
# Renamed: 168_Natal_Sand_Frog_segment_2.wav -> other_frog_612.wav
# Renamed: 06_Broadleys_Tree_Frog_segment_4.wav -> other_frog_613.wav
# Renamed: 153_Montane_Marsh_Frog_segment_2.wav -> other_frog_614.wav
# Keeping: 14_Bilbos_Rain_Frog_segment_6.wav
# Keeping: 13_Bushveld_Rain_Frog_B_a_pentheri_segment_5.wav
# Renamed: 150_Hogsback_Caco_segment_2.wav -> other_frog_615.wav
# Renamed: 93_Swynnertons_Reed_Frog_segment_4.wav -> other_frog_616.wav
# Renamed: 167_Russetbacked_Sand_Frog_segment_1.wav -> other_frog_617.wav
# Renamed: 136_Northern_Moss_Frog_segment_5.wav -> other_frog_618.wav
# Renamed: 69_Golden_Leaffolding_Frog_segment_8.wav -> other_frog_619.wav
# Renamed: 131_Bainskloof_Moss_Frog_segment_3.wav -> other_frog_620.wav
# Keeping: 17_Plain_Rain_Frog_segment_2.wav
# Renamed: 69_Golden_Leaffolding_Frog_segment_5.wav -> other_frog_621.wav
# Renamed: 167_Russetbacked_Sand_Frog_segment_4.wav -> other_frog_622.wav
# Renamed: 109_Broadbanded_Grass_Frog_segment_2.wav -> other_frog_623.wav
# Renamed: 56_Karoo_Toad_segment_3.wav -> other_frog_624.wav
# Renamed: 125_Poyntons_River_Frog_segment_6.wav -> other_frog_625.wav
# Renamed: 42_Hoeschs_Pygmy_Toad_segment_4.wav -> other_frog_626.wav
# Renamed: 73_Knysna_Leaffolding_Frog_segment_1.wav -> other_frog_627.wav
# Renamed: 151_Micro_Frog_segment_7.wav -> other_frog_628.wav
# Renamed: 76_Argus_Reed_Frog_segment_4.wav -> other_frog_629.wav
# Renamed: 99_Marbled_Rubber_Frog_segment_7.wav -> other_frog_630.wav
# Renamed: 44_Southern_Pygmy_Toad_segment_3.wav -> other_frog_631.wav
# Renamed: 119_Mullers_Platanna_segment_3.wav -> other_frog_632.wav
# Renamed: 79_Nyanga_Long_Reed_Frog_segment_3.wav -> other_frog_633.wav
# Renamed: 169_Tandys_Sand_Frog_segment_2.wav -> other_frog_634.wav
# Renamed: 145_Bronze_Caco_segment_4.wav -> other_frog_635.wav
# Renamed: 42_Hoeschs_Pygmy_Toad_segment_1.wav -> other_frog_636.wav
# Renamed: 172_Galam_Goldenbacked_Frog_segment_3.wav -> other_frog_637.wav
# Renamed: 139_Southern_Caco_segment_13.wav -> other_frog_638.wav
# Renamed: 118_Common_Platanna_segment_1.wav -> other_frog_639.wav
# Renamed: 139_Southern_Caco_segment_6.wav -> other_frog_640.wav
# Keeping: 11_Strawberry_Rain_Frog_segment_3.wav
# Renamed: 163_Tremolo_Sand_Frog_segment_4.wav -> other_frog_641.wav
# Renamed: 85_Long_Reed_Frog_segment_3.wav -> other_frog_642.wav
# Renamed: 51_Eastern_Leopard_Toad_segment_2.wav -> other_frog_643.wav
# Renamed: 77_Bocages_Sharpnosed_segment_2.wav -> other_frog_644.wav
# File renaming complete!

# %% [markdown]
# ## Get file Info

# %%
import os
from pathlib import Path
import wave
import contextlib
from collections import defaultdict

def analyze_short_frog_files(directory, max_duration=4):
    """
    Finds all WAV files shorter than specified duration and counts by frog type.
    
    Args:
        directory (str): Path to directory containing WAV files
        max_duration (float): Maximum duration in seconds to consider as "short"
        
    Returns:
        tuple: (list of short files with durations, frog type counts, total count)
    """
    short_files = []
    frog_counts = defaultdict(int)
    special_frogs = {
        'mountain_rain_frog',
        'southern_dainty_frog',
        'clicking_stream_frog'
    }

    for filepath in Path(directory).glob('*.wav'):
        try:
            with contextlib.closing(wave.open(str(filepath), 'r')) as wav_file:
                frames = wav_file.getnframes()
                rate = wav_file.getframerate()
                duration = frames / float(rate)
                
                if duration < max_duration:
                    filename = filepath.stem.lower()
                    
                    # Determine frog type
                    frog_type = "other"
                    for special in special_frogs:
                        if special in filename:
                            frog_type = special.replace('_', ' ').title()
                            break
                    
                    short_files.append((filepath.name, duration, frog_type))
                    frog_counts[frog_type] += 1
                    
        except (wave.Error, EOFError) as e:
            print(f"Error processing {filepath.name}: {str(e)}")
            continue
    
    return short_files, frog_counts, len(short_files)

if __name__ == "__main__":
    folder_path = "./frog_sounds_wav/"  # Replace with your folder path
    try:
        short_files, frog_counts, total_count = analyze_short_frog_files(folder_path)
        
        if not short_files:
            print("No files shorter than 5 seconds found.")
        else:
            print("Files shorter than 5 seconds:")
            print("-" * 65)
            print(f"{'Filename':<40} {'Duration':<10} {'Frog Type':<15}")
            print("-" * 65)
            for filename, duration, frog_type in short_files:
                print(f"{filename:<40} {duration:.2f}s{'':<5} {frog_type:<15}")
            
            print("-" * 65)
            print("\nFrog Type Counts:")
            for frog_type, count in sorted(frog_counts.items(), key=lambda x: x[1], reverse=True):
                print(f"{frog_type:<20}: {count}")
            
            print("-" * 65)
            print(f"Total files shorter than 5 seconds: {total_count}")
            
    except Exception as e:
        print(f"Error: {str(e)}")
# Out:
# Files shorter than 5 seconds:
# -----------------------------------------------------------------
# Filename                                 Duration   Frog Type
# -----------------------------------------------------------------
# other_frog_1818.wav                      3.01s      other
# other_frog_3281.wav                      2.40s      other
# other_frog_2736.wav                      2.53s      other
# Clicking_Stream_Frog_191.wav             3.76s      Clicking Stream Frog
# other_frog_269.wav                       3.16s      other
# other_frog_111.wav                       2.03s      other
# other_frog_661.wav                       3.37s      other
# other_frog_962.wav                       3.99s      other
# other_frog_1705.wav                      1.08s      other
# other_frog_523.wav                       1.19s      other
# other_frog_3282.wav                      1.21s      other
# other_frog_2594.wav                      0.40s      other
# other_frog_2158.wav                      2.09s      other
# other_frog_2325.wav                      3.40s      other
# other_frog_44.wav                        2.56s      other
# other_frog_1145.wav                      3.75s      other
# other_frog_2582.wav                      3.43s      other
# other_frog_3202.wav                      3.78s      other
# other_frog_3169.wav                      3.41s      other
# other_frog_2925.wav                      3.05s      other
# other_frog_1180.wav                      3.36s      other
# other_frog_780.wav                       3.72s      other
# other_frog_2543.wav                      2.19s      other
# Clicking_Stream_Frog_59.wav              3.60s      Clicking Stream Frog
# other_frog_2133.wav                      1.01s      other
# other_frog_2928.wav                      3.76s      other
# other_frog_703.wav                       3.65s      other
# other_frog_2487.wav                      3.03s      other
# other_frog_594.wav                       3.46s      other
# Clicking_Stream_Frog_43.wav              2.65s      Clicking Stream Frog
# other_frog_1375.wav                      3.58s      other
# other_frog_1146.wav                      1.25s      other
# other_frog_2326.wav                      3.44s      other
# other_frog_2196.wav                      3.74s      other
# other_frog_1225.wav                      2.83s      other
# other_frog_2927.wav                      3.41s      other
# other_frog_2628.wav                      3.99s      other
# other_frog_379.wav                       3.20s      other
# Clicking_Stream_Frog_199.wav             3.48s      Clicking Stream Frog
# other_frog_3425.wav                      2.02s      other
# other_frog_10.wav                        3.74s      other
# other_frog_1510.wav                      2.81s      other
# other_frog_1990.wav                      1.98s      other
# other_frog_3423.wav                      2.93s      other
# other_frog_338.wav                       2.37s      other
# other_frog_214.wav                       1.26s      other
# other_frog_1367.wav                      3.79s      other
# other_frog_2948.wav                      3.04s      other
# Clicking_Stream_Frog_439.wav             3.25s      Clicking Stream Frog
# other_frog_1547.wav                      1.02s      other
# Clicking_Stream_Frog_24.wav              2.30s      Clicking Stream Frog
# Clicking_Stream_Frog_317.wav             2.93s      Clicking Stream Frog
# other_frog_424.wav                       1.28s      other
# other_frog_2637.wav                      3.90s      other
# other_frog_3316.wav                      3.82s      other
# Mountain_Rain_Frog_3.wav                 2.30s      Mountain Rain Frog
# other_frog_2774.wav                      1.51s      other
# other_frog_1229.wav                      3.29s      other
# -----------------------------------------------------------------
#
# Frog Type Counts:
# other               : 50
# Clicking Stream Frog: 7
# Mountain Rain Frog  : 1
# -----------------------------------------------------------------
# Total files shorter than 5 seconds: 58

# %%
import os
import csv
from collections import defaultdict
from pathlib import Path

def analyze_frog_recordings(directory_path, min_threshold=100000):
    """
    Analyze frog recordings to find species with few recordings.
    
    Args:
        directory_path: Path to directory containing audio files
        min_threshold: Minimum number of recordings to not be considered "few"
    
    Returns:
        dict: {frog_species: count} for species with fewer than min_threshold recordings
    """
    # Initialize dictionary to store counts
    frog_counts = defaultdict(int)
    
    # Supported audio file extensions
    audio_extensions = {'.wav'}
    
    # Count recordings per frog species
    for file in Path(directory_path).iterdir():
        if file.suffix.lower() in audio_extensions:
            parts = file.stem.split('_')
            frog_species_parts = []
            
            # Iterate through parts until we find a number
            for part in parts:
                if part.isdigit():
                    break
                frog_species_parts.append(part)
            
            if frog_species_parts:  # Only proceed if we found at least one non-number part
                frog_species = '_'.join(frog_species_parts)
                frog_counts[frog_species] += 1
    
    # Filter for species with few recordings
    few_recordings = {
        species: count 
        for species, count in frog_counts.items() 
    }
    
    return few_recordings

def print_frog_report(few_recordings, output_csv=None):
    """Print a formatted report of frogs with few recordings and optionally save to CSV."""
    if not few_recordings:
        print("All frog species have sufficient recordings (10 or more each).")
        if output_csv:
            with open(output_csv, 'w', newline='') as csvfile:
                writer = csv.writer(csvfile)
                writer.writerow(["Species", "Recording Count"])
                writer.writerow(["All species have sufficient recordings", ""])
        return
    
    # Print console report
    print("Frog species with fewer than 10 recordings:")
    print("-" * 45)
    for species, count in sorted(few_recordings.items(), key=lambda item: (item[1], item[0])):
        print(f"{species.ljust(30)}: {count} recording{'s' if count != 1 else ''}")
    print("-" * 45)
    print(f"Total under-represented species: {len(few_recordings)}")
    
    # Save to CSV if requested
    if output_csv:
        with open(output_csv, 'w', newline='') as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow(["Species", "Recording Count"])
            for species, count in sorted(few_recordings.items(), key=lambda item: (item[1], item[0])):
                writer.writerow([species, count])


# Example usage
if __name__ == "__main__":
    directory_path = "../Datasets/clipped-3.05s/"  # Change this to your directory
    # output_csv = "frog_recording_report.csv"  # Output CSV filename
    few_recordings = analyze_frog_recordings(directory_path, min_threshold=10)
    print_frog_report(few_recordings)
# Out:
# Frog species with fewer than 10 recordings:
# ---------------------------------------------
# Painted                       : 276 recordings
# Weale                         : 390 recordings
# De                            : 410 recordings
# Peninsula                     : 425 recordings
# Eastern                       : 725 recordings
# Banded                        : 982 recordings
# Rain                          : 1158 recordings
# Clicking                      : 1248 recordings
# Southern                      : 1716 recordings
# none                          : 2441 recordings
# Mountain                      : 2884 recordings
# other                         : 5275 recordings
# ---------------------------------------------
# Total under-represented species: 12

# %% [markdown]
# ## Clip files to 3.05 seconds

# %%
import os
import numpy as np
from pathlib import Path
from scipy.io import wavfile

def process_audio_files(input_dir, output_dir="../Datasets/clipped-3.05s/"):
    """
    Process mono audio files:
    - For files >2 seconds: create 2-second clips centered at max amplitude points
    - For files <=2 seconds: skip (commented out but can be enabled)
    - All files saved to output directory
    """
    input_path = Path(input_dir)
    output_path = Path(output_dir)
    
    output_path.mkdir(exist_ok=True)
    
    processed_count = 0
    clipped_count = 0
    copied_count = 0
    clipped_duration = 3.05
    
    for filepath in input_path.glob('*.wav'):
        try:
            # Read WAV file (mono)
            sample_rate, data = wavfile.read(filepath)
            
            # Ensure mono audio
            if len(data.shape) > 1:
                print(f"Skipping {filepath.name} - stereo audio not supported")
                continue
            
            duration = len(data) / sample_rate
            output_file = output_path / filepath.name
            
            if duration <= clipped_duration:
                # For short files, skip (can uncomment to copy)
                # wavfile.write(output_file, sample_rate, data)
                # copied_count += 1
                # print(f"Copied: {filepath.name} ({duration:.2f}s)")
                continue
            else:
                abs_data = np.abs(data)
                sorted_indices = np.argsort(abs_data)
                max_idx = sorted_indices[-1]
                
                # Find secondary peak
                exclusion_radius = int((clipped_duration/2) * sample_rate)  # 1 second radius
                valid_mask = np.ones(len(data), dtype=bool)
                valid_mask[max(0, max_idx-exclusion_radius):min(len(data), max_idx+exclusion_radius)] = False
                
                if np.any(valid_mask):
                    modified_data = abs_data.copy()
                    modified_data[~valid_mask] = 0
                    second_max_idx = np.argmax(modified_data)
                    
                    # Only accept if secondary peak is at least 10% as loud as primary
                    if abs_data[second_max_idx] < 0.1 * abs_data[max_idx]:
                        second_max_idx = None
                else:
                    second_max_idx = None

                # Create 2-second clip around primary peak
                target_len = int(round(clipped_duration * sample_rate))
                half_window = target_len // 2  # 3.05s clip => half window in samples


                # --- primary clip around primary peak ---
                start = max(0, max_idx - half_window)
                end   = min(len(data), max_idx + half_window)
                primary_clip = data[start:end]

                # Pad to exact target_len (symmetric)
                if len(primary_clip) < target_len:
                    remaining = target_len - len(primary_clip)
                    pad_before = int(remaining // 2)
                    pad_after  = int(remaining - pad_before)
                    primary_clip = np.pad(primary_clip, (pad_before, pad_after), mode='constant')

                wavfile.write(output_path / f"{filepath.stem}_primary.wav", sample_rate, primary_clip)
                clipped_count += 1

                # --- secondary clip (if valid peak exists) ---
                if second_max_idx is not None:
                    start2 = max(0, second_max_idx - half_window)
                    end2   = min(len(data), second_max_idx + half_window)
                    secondary_clip = data[start2:end2]

                    if len(secondary_clip) < target_len:
                        remaining = target_len - len(secondary_clip)
                        pad_before = int(remaining // 2)
                        pad_after  = int(remaining - pad_before)
                        secondary_clip = np.pad(secondary_clip, (pad_before, pad_after), mode='constant')

                    wavfile.write(output_path / f"{filepath.stem}_secondary.wav", sample_rate, secondary_clip)
                    clipped_count += 1



                # half_window = int((clipped_duration/2) * sample_rate)  # 1 second = half of 2s clip
                # primary_clip = data[max(0, max_idx - half_window):min(len(data), max_idx + half_window)]
                
                # # Pad if needed
                # if len(primary_clip) < clipped_duration * sample_rate:
                #     pad_before = (clipped_duration * sample_rate - len(primary_clip)) // 4
                #     pad_after = (clipped_duration * sample_rate - len(primary_clip)) - pad_before
                #     primary_clip = np.pad(primary_clip, (pad_before, pad_after), mode='constant')
                
                # wavfile.write(output_path / f"{filepath.stem}_primary.wav", sample_rate, primary_clip)
                # clipped_count += 1

                # # Create secondary clip if valid peak exists
                # if second_max_idx is not None:
                #     secondary_clip = data[max(0, second_max_idx - half_window):min(len(data), second_max_idx + half_window)]
                    
                #     if len(secondary_clip) < clipped_duration * sample_rate:
                #         pad_before = (clipped_duration * sample_rate - len(secondary_clip)) // 2
                #         pad_after = (clipped_duration * sample_rate - len(secondary_clip)) - pad_before
                #         secondary_clip = np.pad(secondary_clip, (pad_before, pad_after), mode='constant')
                    
                #     wavfile.write(output_path / f"{filepath.stem}_secondary.wav", sample_rate, secondary_clip)
                #     clipped_count += 1
                
                processed_count += 1
                
        except Exception as e:
            print(f"Error processing {filepath.name}: {str(e)}")
            continue
    
    print("\nProcessing complete!")
    print(f"Processed {processed_count} files")
    print(f"- Created {clipped_count} {clipped_duration}-second clips")
    print(f"- {copied_count} files copied as-is (<=2 seconds)")
    print(f"Output directory: {output_path.resolve()}")

if __name__ == "__main__":
    input_directory = "../Datasets/Raw-audio/frog_wav/" 
    process_audio_files(input_directory)
# Out:
# Processing complete!
# Processed 7570 files
# - Created 15054 3.05-second clips
# - 0 files copied as-is (<=2 seconds)
# Output directory: /home/james/Documents/semester-2/skripsie/code/Datasets/clipped-3.05s

# %%
import os
import numpy as np
from pathlib import Path
from scipy.io import wavfile

def process_audio_files(input_dir, clips_per_file=2, output_dir="../Datasets/mega-clipped-2s/"):
    """
    Process mono audio files:
    - For files >2 seconds: create specified number of 2-second clips
    - For files <=2 seconds: create as many clips as possible with max 1/3 overlap
    - Clips are distributed evenly across the file with 1/3 overlap
    """
    input_path = Path(input_dir)
    output_path = Path(output_dir)
    
    output_path.mkdir(exist_ok=True)
    
    processed_count = 0
    total_clips = 0
    
    for filepath in input_path.glob('*.wav'):
        try:
            # Read WAV file (mono)
            sample_rate, data = wavfile.read(filepath)
            
            # Ensure mono audio
            if len(data.shape) > 1:
                print(f"Skipping {filepath.name} - stereo audio not supported")
                continue
            
            duration = len(data) / sample_rate
            clip_length = 2.0  # 2-second clips
            samples_per_clip = int(clip_length * sample_rate)
            
            if duration <= clip_length:
                # For short files, create as many clips as possible with max 1/3 overlap
                possible_clips = max(1, int(1 + (duration * sample_rate - samples_per_clip) / (samples_per_clip * (2/3))))
                step_size = max(1, (len(data) - samples_per_clip) // max(1, possible_clips - 1))
            else:
                possible_clips = clips_per_file
                step_size = max(1, (len(data) - samples_per_clip) // max(1, possible_clips - 1))
            
            # Ensure we don't create more clips than possible
            actual_clips = min(possible_clips, clips_per_file)
            
            # Calculate start positions with 1/3 overlap
            start_positions = []
            for i in range(actual_clips):
                if actual_clips == 1:
                    pos = max(0, (len(data) - samples_per_clip) // 2)  # center if only one clip
                else:
                    pos = min(len(data) - samples_per_clip, 
                             int(i * (len(data) - samples_per_clip) / max(1, actual_clips - 1)))
                start_positions.append(pos)
            
            # Create clips
            for i, start in enumerate(start_positions):
                end = start + samples_per_clip
                clip = data[start:end]
                
                # Pad if needed (shouldn't happen with proper positioning)
                if len(clip) < samples_per_clip:
                    pad_before = (samples_per_clip - len(clip)) // 2
                    pad_after = samples_per_clip - len(clip) - pad_before
                    clip = np.pad(clip, (pad_before, pad_after), mode='constant')
                
                # Save clip
                clip_name = f"{filepath.stem}_clip{i+1}.wav"
                wavfile.write(output_path / clip_name, sample_rate, clip)
                total_clips += 1
            
            processed_count += 1
            print(f"Processed {filepath.name} - created {actual_clips} clips")
            
        except Exception as e:
            print(f"Error processing {filepath.name}: {str(e)}")
            continue
    
    print("\nProcessing complete!")
    print(f"Processed {processed_count} files")
    print(f"- Created {total_clips} total clips")
    print(f"Output directory: {output_path.resolve()}")

if __name__ == "__main__":
    input_directory = "../Datasets/Raw-audio/frog_wav_nope/"
    process_audio_files(input_directory, clips_per_file=4)  # Example: 3 clips per file

# %% [markdown]
# ## Rename files to first word_number

# %%
import os
import re
from collections import defaultdict

def rename_wav_files(directory):
    # Get all .wav files in the directory
    wav_files = [f for f in os.listdir(directory) if f.lower().endswith('.wav')]
    
    # Sort the files to ensure consistent ordering
    wav_files.sort()
    
    # Dictionary to keep track of counters for each prefix
    counters = defaultdict(int)
    
    for filename in wav_files:
        # Split the filename at the first underscore
        parts = re.split('_', filename, 1)
        
        # Get the first part (before first underscore) or whole filename if no underscore
        prefix = parts[0]
        
        # Increment the counter for this prefix
        counters[prefix] += 1
        
        # Create new filename
        new_name = f"{prefix}_{counters[prefix]}.wav"
        
        # Full paths for old and new names
        old_path = os.path.join(directory, filename)
        new_path = os.path.join(directory, new_name)
        
        # Rename the file
        try:
            os.rename(old_path, new_path)
            print(f"Renamed: {filename} -> {new_name}")
        except OSError as e:
            print(f"Error renaming {filename}: {e}")

if __name__ == "__main__":
    # Get the directory containing the .wav files
    # dir_path = input("Enter the directory path containing .wav files: ").strip()
    dir_path = "../Datasets/clipped-3.05s/"
    
    # Verify the directory exists
    if os.path.isdir(dir_path):
        rename_wav_files(dir_path)
        print("Renaming complete!")
    else:
        print("Error: The specified directory does not exist.")
# Out:
# Renamed: Banded_1_segment_1.wav -> Banded_1.wav
# Renamed: Banded_2_segment_1.wav -> Banded_2.wav
# Renamed: Banded_4_segment_1.wav -> Banded_3.wav
# Renamed: Banded_5_segment_1.wav -> Banded_4.wav
# Renamed: Banded_6_segment_1.wav -> Banded_5.wav
# Renamed: Banded_Stream_Frog_100_primary.wav -> Banded_6.wav
# Renamed: Banded_Stream_Frog_100_secondary.wav -> Banded_7.wav
# Renamed: Banded_Stream_Frog_101_primary.wav -> Banded_8.wav
# Renamed: Banded_Stream_Frog_101_secondary.wav -> Banded_9.wav
# Renamed: Banded_Stream_Frog_102_primary.wav -> Banded_10.wav
# Renamed: Banded_Stream_Frog_102_secondary.wav -> Banded_11.wav
# Renamed: Banded_Stream_Frog_103_primary.wav -> Banded_12.wav
# Renamed: Banded_Stream_Frog_103_secondary.wav -> Banded_13.wav
# Renamed: Banded_Stream_Frog_104_primary.wav -> Banded_14.wav
# Renamed: Banded_Stream_Frog_104_secondary.wav -> Banded_15.wav
# Renamed: Banded_Stream_Frog_105_primary.wav -> Banded_16.wav
# Renamed: Banded_Stream_Frog_105_secondary.wav -> Banded_17.wav
# Renamed: Banded_Stream_Frog_106_primary.wav -> Banded_18.wav
# Renamed: Banded_Stream_Frog_106_secondary.wav -> Banded_19.wav
# Renamed: Banded_Stream_Frog_107_primary.wav -> Banded_20.wav
# Renamed: Banded_Stream_Frog_107_secondary.wav -> Banded_21.wav
# Renamed: Banded_Stream_Frog_108_primary.wav -> Banded_22.wav
# Renamed: Banded_Stream_Frog_108_secondary.wav -> Banded_23.wav
# Renamed: Banded_Stream_Frog_109_primary.wav -> Banded_24.wav
# Renamed: Banded_Stream_Frog_109_secondary.wav -> Banded_25.wav
# Renamed: Banded_Stream_Frog_10_1_primary.wav -> Banded_26.wav
# Renamed: Banded_Stream_Frog_10_1_secondary.wav -> Banded_27.wav
# Renamed: Banded_Stream_Frog_10_primary.wav -> Banded_28.wav
# Renamed: Banded_Stream_Frog_10_secondary.wav -> Banded_29.wav
# Renamed: Banded_Stream_Frog_110_primary.wav -> Banded_30.wav
# Renamed: Banded_Stream_Frog_110_secondary.wav -> Banded_31.wav
# Renamed: Banded_Stream_Frog_111_primary.wav -> Banded_32.wav
# Renamed: Banded_Stream_Frog_111_secondary.wav -> Banded_33.wav
# Renamed: Banded_Stream_Frog_112_primary.wav -> Banded_34.wav
# Renamed: Banded_Stream_Frog_112_secondary.wav -> Banded_35.wav
# Renamed: Banded_Stream_Frog_113_primary.wav -> Banded_36.wav
# Renamed: Banded_Stream_Frog_113_secondary.wav -> Banded_37.wav
# Renamed: Banded_Stream_Frog_114_primary.wav -> Banded_38.wav
# Renamed: Banded_Stream_Frog_114_secondary.wav -> Banded_39.wav
# Renamed: Banded_Stream_Frog_115_primary.wav -> Banded_40.wav
# Renamed: Banded_Stream_Frog_115_secondary.wav -> Banded_41.wav
# Renamed: Banded_Stream_Frog_116_primary.wav -> Banded_42.wav
# Renamed: Banded_Stream_Frog_116_secondary.wav -> Banded_43.wav
# Renamed: Banded_Stream_Frog_117_primary.wav -> Banded_44.wav
# Renamed: Banded_Stream_Frog_117_secondary.wav -> Banded_45.wav
# Renamed: Banded_Stream_Frog_118_primary.wav -> Banded_46.wav
# Renamed: Banded_Stream_Frog_118_secondary.wav -> Banded_47.wav
# Renamed: Banded_Stream_Frog_119_primary.wav -> Banded_48.wav
# Renamed: Banded_Stream_Frog_119_secondary.wav -> Banded_49.wav
# Renamed: Banded_Stream_Frog_11_1_primary.wav -> Banded_50.wav
# Renamed: Banded_Stream_Frog_11_1_secondary.wav -> Banded_51.wav
# Renamed: Banded_Stream_Frog_11_primary.wav -> Banded_52.wav
# Renamed: Banded_Stream_Frog_11_secondary.wav -> Banded_53.wav
# Renamed: Banded_Stream_Frog_120_primary.wav -> Banded_54.wav
# Renamed: Banded_Stream_Frog_120_secondary.wav -> Banded_55.wav
# Renamed: Banded_Stream_Frog_121_primary.wav -> Banded_56.wav
# Renamed: Banded_Stream_Frog_121_secondary.wav -> Banded_57.wav
# Renamed: Banded_Stream_Frog_122_primary.wav -> Banded_58.wav
# Renamed: Banded_Stream_Frog_122_secondary.wav -> Banded_59.wav
# Renamed: Banded_Stream_Frog_123_primary.wav -> Banded_60.wav
# Renamed: Banded_Stream_Frog_123_secondary.wav -> Banded_61.wav
# Renamed: Banded_Stream_Frog_124_primary.wav -> Banded_62.wav
# Renamed: Banded_Stream_Frog_124_secondary.wav -> Banded_63.wav
# Renamed: Banded_Stream_Frog_125_primary.wav -> Banded_64.wav
# Renamed: Banded_Stream_Frog_125_secondary.wav -> Banded_65.wav
# Renamed: Banded_Stream_Frog_126_primary.wav -> Banded_66.wav
# Renamed: Banded_Stream_Frog_126_secondary.wav -> Banded_67.wav
# Renamed: Banded_Stream_Frog_127_primary.wav -> Banded_68.wav
# Renamed: Banded_Stream_Frog_127_secondary.wav -> Banded_69.wav
# Renamed: Banded_Stream_Frog_128_primary.wav -> Banded_70.wav
# Renamed: Banded_Stream_Frog_128_secondary.wav -> Banded_71.wav
# Renamed: Banded_Stream_Frog_129_primary.wav -> Banded_72.wav
# Renamed: Banded_Stream_Frog_129_secondary.wav -> Banded_73.wav
# Renamed: Banded_Stream_Frog_12_1_primary.wav -> Banded_74.wav
# Renamed: Banded_Stream_Frog_12_1_secondary.wav -> Banded_75.wav
# Renamed: Banded_Stream_Frog_12_primary.wav -> Banded_76.wav
# Renamed: Banded_Stream_Frog_12_secondary.wav -> Banded_77.wav
# Renamed: Banded_Stream_Frog_130_primary.wav -> Banded_78.wav
# Renamed: Banded_Stream_Frog_130_secondary.wav -> Banded_79.wav
# Renamed: Banded_Stream_Frog_131_primary.wav -> Banded_80.wav
# Renamed: Banded_Stream_Frog_131_secondary.wav -> Banded_81.wav
# Renamed: Banded_Stream_Frog_132_primary.wav -> Banded_82.wav
# Renamed: Banded_Stream_Frog_132_secondary.wav -> Banded_83.wav
# Renamed: Banded_Stream_Frog_133_primary.wav -> Banded_84.wav
# Renamed: Banded_Stream_Frog_133_secondary.wav -> Banded_85.wav
# Renamed: Banded_Stream_Frog_134_primary.wav -> Banded_86.wav
# Renamed: Banded_Stream_Frog_134_secondary.wav -> Banded_87.wav
# Renamed: Banded_Stream_Frog_135_primary.wav -> Banded_88.wav
# Renamed: Banded_Stream_Frog_135_secondary.wav -> Banded_89.wav
# Renamed: Banded_Stream_Frog_136_primary.wav -> Banded_90.wav
# Renamed: Banded_Stream_Frog_136_secondary.wav -> Banded_91.wav
# Renamed: Banded_Stream_Frog_137_primary.wav -> Banded_92.wav
# Renamed: Banded_Stream_Frog_137_secondary.wav -> Banded_93.wav
# Renamed: Banded_Stream_Frog_138_primary.wav -> Banded_94.wav
# Renamed: Banded_Stream_Frog_138_secondary.wav -> Banded_95.wav
# Renamed: Banded_Stream_Frog_139_primary.wav -> Banded_96.wav
# Renamed: Banded_Stream_Frog_139_secondary.wav -> Banded_97.wav
# Renamed: Banded_Stream_Frog_13_1_primary.wav -> Banded_98.wav
# Renamed: Banded_Stream_Frog_13_1_secondary.wav -> Banded_99.wav
# Renamed: Banded_Stream_Frog_13_2_primary.wav -> Banded_100.wav
# Renamed: Banded_Stream_Frog_13_2_secondary.wav -> Banded_101.wav
# Renamed: Banded_Stream_Frog_13_primary.wav -> Banded_102.wav
# Renamed: Banded_Stream_Frog_13_secondary.wav -> Banded_103.wav
# Renamed: Banded_Stream_Frog_140_primary.wav -> Banded_104.wav
# Renamed: Banded_Stream_Frog_140_secondary.wav -> Banded_105.wav
# Renamed: Banded_Stream_Frog_141_primary.wav -> Banded_106.wav
# Renamed: Banded_Stream_Frog_141_secondary.wav -> Banded_107.wav
# Renamed: Banded_Stream_Frog_142_primary.wav -> Banded_108.wav
# Renamed: Banded_Stream_Frog_142_secondary.wav -> Banded_109.wav
# Renamed: Banded_Stream_Frog_143_primary.wav -> Banded_110.wav
# Renamed: Banded_Stream_Frog_143_secondary.wav -> Banded_111.wav
# Renamed: Banded_Stream_Frog_144_primary.wav -> Banded_112.wav
# Renamed: Banded_Stream_Frog_144_secondary.wav -> Banded_113.wav
# Renamed: Banded_Stream_Frog_145_primary.wav -> Banded_114.wav
# Renamed: Banded_Stream_Frog_145_secondary.wav -> Banded_115.wav
# Renamed: Banded_Stream_Frog_146_primary.wav -> Banded_116.wav
# Renamed: Banded_Stream_Frog_146_secondary.wav -> Banded_117.wav
# Renamed: Banded_Stream_Frog_147_primary.wav -> Banded_118.wav
# Renamed: Banded_Stream_Frog_147_secondary.wav -> Banded_119.wav
# Renamed: Banded_Stream_Frog_148_primary.wav -> Banded_120.wav
# Renamed: Banded_Stream_Frog_148_secondary.wav -> Banded_121.wav
# Renamed: Banded_Stream_Frog_149_primary.wav -> Banded_122.wav
# Renamed: Banded_Stream_Frog_149_secondary.wav -> Banded_123.wav
# Renamed: Banded_Stream_Frog_14_1_primary.wav -> Banded_124.wav
# Renamed: Banded_Stream_Frog_14_primary.wav -> Banded_125.wav
# Renamed: Banded_Stream_Frog_14_secondary.wav -> Banded_126.wav
# Renamed: Banded_Stream_Frog_150_primary.wav -> Banded_127.wav
# Renamed: Banded_Stream_Frog_150_secondary.wav -> Banded_128.wav
# Renamed: Banded_Stream_Frog_151_primary.wav -> Banded_129.wav
# Renamed: Banded_Stream_Frog_151_secondary.wav -> Banded_130.wav
# Renamed: Banded_Stream_Frog_152_primary.wav -> Banded_131.wav
# Renamed: Banded_Stream_Frog_152_secondary.wav -> Banded_132.wav
# Renamed: Banded_Stream_Frog_153_primary.wav -> Banded_133.wav
# Renamed: Banded_Stream_Frog_153_secondary.wav -> Banded_134.wav
# Renamed: Banded_Stream_Frog_154_primary.wav -> Banded_135.wav
# Renamed: Banded_Stream_Frog_154_secondary.wav -> Banded_136.wav
# Renamed: Banded_Stream_Frog_155_primary.wav -> Banded_137.wav
# Renamed: Banded_Stream_Frog_155_secondary.wav -> Banded_138.wav
# Renamed: Banded_Stream_Frog_156_primary.wav -> Banded_139.wav
# Renamed: Banded_Stream_Frog_156_secondary.wav -> Banded_140.wav
# Renamed: Banded_Stream_Frog_157_primary.wav -> Banded_141.wav
# Renamed: Banded_Stream_Frog_157_secondary.wav -> Banded_142.wav
# Renamed: Banded_Stream_Frog_158_primary.wav -> Banded_143.wav
# Renamed: Banded_Stream_Frog_158_secondary.wav -> Banded_144.wav
# Renamed: Banded_Stream_Frog_159_primary.wav -> Banded_145.wav
# Renamed: Banded_Stream_Frog_159_secondary.wav -> Banded_146.wav
# Renamed: Banded_Stream_Frog_15_1_primary.wav -> Banded_147.wav
# Renamed: Banded_Stream_Frog_15_1_secondary.wav -> Banded_148.wav
# Renamed: Banded_Stream_Frog_15_primary.wav -> Banded_149.wav
# Renamed: Banded_Stream_Frog_15_secondary.wav -> Banded_150.wav
# Renamed: Banded_Stream_Frog_160_primary.wav -> Banded_151.wav
# Renamed: Banded_Stream_Frog_160_secondary.wav -> Banded_152.wav
# Renamed: Banded_Stream_Frog_161_primary.wav -> Banded_153.wav
# Renamed: Banded_Stream_Frog_161_secondary.wav -> Banded_154.wav
# Renamed: Banded_Stream_Frog_162_primary.wav -> Banded_155.wav
# Renamed: Banded_Stream_Frog_162_secondary.wav -> Banded_156.wav
# Renamed: Banded_Stream_Frog_163_primary.wav -> Banded_157.wav
# Renamed: Banded_Stream_Frog_163_secondary.wav -> Banded_158.wav
# Renamed: Banded_Stream_Frog_164_primary.wav -> Banded_159.wav
# Renamed: Banded_Stream_Frog_164_secondary.wav -> Banded_160.wav
# Renamed: Banded_Stream_Frog_165_primary.wav -> Banded_161.wav
# Renamed: Banded_Stream_Frog_165_secondary.wav -> Banded_162.wav
# Renamed: Banded_Stream_Frog_166_primary.wav -> Banded_163.wav
# Renamed: Banded_Stream_Frog_166_secondary.wav -> Banded_164.wav
# Renamed: Banded_Stream_Frog_167_primary.wav -> Banded_165.wav
# Renamed: Banded_Stream_Frog_167_secondary.wav -> Banded_166.wav
# Renamed: Banded_Stream_Frog_168_primary.wav -> Banded_167.wav
# Renamed: Banded_Stream_Frog_168_secondary.wav -> Banded_168.wav
# Renamed: Banded_Stream_Frog_169_primary.wav -> Banded_169.wav
# Renamed: Banded_Stream_Frog_169_secondary.wav -> Banded_170.wav
# Renamed: Banded_Stream_Frog_16_1_primary.wav -> Banded_171.wav
# Renamed: Banded_Stream_Frog_16_1_secondary.wav -> Banded_172.wav
# Renamed: Banded_Stream_Frog_16_primary.wav -> Banded_173.wav
# Renamed: Banded_Stream_Frog_16_secondary.wav -> Banded_174.wav
# Renamed: Banded_Stream_Frog_170_primary.wav -> Banded_175.wav
# Renamed: Banded_Stream_Frog_170_secondary.wav -> Banded_176.wav
# Renamed: Banded_Stream_Frog_171_primary.wav -> Banded_177.wav
# Renamed: Banded_Stream_Frog_171_secondary.wav -> Banded_178.wav
# Renamed: Banded_Stream_Frog_172_primary.wav -> Banded_179.wav
# Renamed: Banded_Stream_Frog_172_secondary.wav -> Banded_180.wav
# Renamed: Banded_Stream_Frog_173_primary.wav -> Banded_181.wav
# Renamed: Banded_Stream_Frog_173_secondary.wav -> Banded_182.wav
# Renamed: Banded_Stream_Frog_174_primary.wav -> Banded_183.wav
# Renamed: Banded_Stream_Frog_174_secondary.wav -> Banded_184.wav
# Renamed: Banded_Stream_Frog_175_primary.wav -> Banded_185.wav
# Renamed: Banded_Stream_Frog_175_secondary.wav -> Banded_186.wav
# Renamed: Banded_Stream_Frog_176_primary.wav -> Banded_187.wav
# Renamed: Banded_Stream_Frog_176_secondary.wav -> Banded_188.wav
# Renamed: Banded_Stream_Frog_177_primary.wav -> Banded_189.wav
# Renamed: Banded_Stream_Frog_177_secondary.wav -> Banded_190.wav
# Renamed: Banded_Stream_Frog_178_primary.wav -> Banded_191.wav
# Renamed: Banded_Stream_Frog_178_secondary.wav -> Banded_192.wav
# Renamed: Banded_Stream_Frog_179_primary.wav -> Banded_193.wav
# Renamed: Banded_Stream_Frog_179_secondary.wav -> Banded_194.wav
# Renamed: Banded_Stream_Frog_17_1_primary.wav -> Banded_195.wav
# Renamed: Banded_Stream_Frog_17_1_secondary.wav -> Banded_196.wav
# Renamed: Banded_Stream_Frog_17_primary.wav -> Banded_197.wav
# Renamed: Banded_Stream_Frog_17_secondary.wav -> Banded_198.wav
# Renamed: Banded_Stream_Frog_180_primary.wav -> Banded_199.wav
# Renamed: Banded_Stream_Frog_180_secondary.wav -> Banded_200.wav
# Renamed: Banded_Stream_Frog_181_primary.wav -> Banded_201.wav
# Renamed: Banded_Stream_Frog_181_secondary.wav -> Banded_202.wav
# Renamed: Banded_Stream_Frog_182_primary.wav -> Banded_203.wav
# Renamed: Banded_Stream_Frog_182_secondary.wav -> Banded_204.wav
# Renamed: Banded_Stream_Frog_183_primary.wav -> Banded_205.wav
# Renamed: Banded_Stream_Frog_183_secondary.wav -> Banded_206.wav
# Renamed: Banded_Stream_Frog_184_primary.wav -> Banded_207.wav
# Renamed: Banded_Stream_Frog_184_secondary.wav -> Banded_208.wav
# Renamed: Banded_Stream_Frog_185_primary.wav -> Banded_209.wav
# Renamed: Banded_Stream_Frog_185_secondary.wav -> Banded_210.wav
# Renamed: Banded_Stream_Frog_186_primary.wav -> Banded_211.wav
# Renamed: Banded_Stream_Frog_186_secondary.wav -> Banded_212.wav
# Renamed: Banded_Stream_Frog_187_primary.wav -> Banded_213.wav
# Renamed: Banded_Stream_Frog_187_secondary.wav -> Banded_214.wav
# Renamed: Banded_Stream_Frog_188_primary.wav -> Banded_215.wav
# Renamed: Banded_Stream_Frog_188_secondary.wav -> Banded_216.wav
# Renamed: Banded_Stream_Frog_189_primary.wav -> Banded_217.wav
# Renamed: Banded_Stream_Frog_189_secondary.wav -> Banded_218.wav
# Renamed: Banded_Stream_Frog_18_1_primary.wav -> Banded_219.wav
# Renamed: Banded_Stream_Frog_18_1_secondary.wav -> Banded_220.wav
# Renamed: Banded_Stream_Frog_18_primary.wav -> Banded_221.wav
# Renamed: Banded_Stream_Frog_18_secondary.wav -> Banded_222.wav
# Renamed: Banded_Stream_Frog_190_primary.wav -> Banded_223.wav
# Renamed: Banded_Stream_Frog_190_secondary.wav -> Banded_224.wav
# Renamed: Banded_Stream_Frog_191_primary.wav -> Banded_225.wav
# Renamed: Banded_Stream_Frog_191_secondary.wav -> Banded_226.wav
# Renamed: Banded_Stream_Frog_192_primary.wav -> Banded_227.wav
# Renamed: Banded_Stream_Frog_192_secondary.wav -> Banded_228.wav
# Renamed: Banded_Stream_Frog_193_primary.wav -> Banded_229.wav
# Renamed: Banded_Stream_Frog_193_secondary.wav -> Banded_230.wav
# Renamed: Banded_Stream_Frog_194_primary.wav -> Banded_231.wav
# Renamed: Banded_Stream_Frog_194_secondary.wav -> Banded_232.wav
# Renamed: Banded_Stream_Frog_195_primary.wav -> Banded_233.wav
# Renamed: Banded_Stream_Frog_195_secondary.wav -> Banded_234.wav
# Renamed: Banded_Stream_Frog_196_primary.wav -> Banded_235.wav
# Renamed: Banded_Stream_Frog_196_secondary.wav -> Banded_236.wav
# Renamed: Banded_Stream_Frog_197_primary.wav -> Banded_237.wav
# Renamed: Banded_Stream_Frog_197_secondary.wav -> Banded_238.wav
# Renamed: Banded_Stream_Frog_198_primary.wav -> Banded_239.wav
# Renamed: Banded_Stream_Frog_198_secondary.wav -> Banded_240.wav
# Renamed: Banded_Stream_Frog_199_primary.wav -> Banded_241.wav
# Renamed: Banded_Stream_Frog_199_secondary.wav -> Banded_242.wav
# Renamed: Banded_Stream_Frog_19_1_primary.wav -> Banded_243.wav
# Renamed: Banded_Stream_Frog_19_1_secondary.wav -> Banded_244.wav
# Renamed: Banded_Stream_Frog_19_primary.wav -> Banded_245.wav
# Renamed: Banded_Stream_Frog_19_secondary.wav -> Banded_246.wav
# Renamed: Banded_Stream_Frog_1_1_primary.wav -> Banded_247.wav
# Renamed: Banded_Stream_Frog_1_1_secondary.wav -> Banded_248.wav
# Renamed: Banded_Stream_Frog_1_2_primary.wav -> Banded_249.wav
# Renamed: Banded_Stream_Frog_1_2_secondary.wav -> Banded_250.wav
# Renamed: Banded_Stream_Frog_1_primary.wav -> Banded_251.wav
# Renamed: Banded_Stream_Frog_1_secondary.wav -> Banded_252.wav
# Renamed: Banded_Stream_Frog_200_primary.wav -> Banded_253.wav
# Renamed: Banded_Stream_Frog_200_secondary.wav -> Banded_254.wav
# Renamed: Banded_Stream_Frog_201_primary.wav -> Banded_255.wav
# Renamed: Banded_Stream_Frog_201_secondary.wav -> Banded_256.wav
# Renamed: Banded_Stream_Frog_202_primary.wav -> Banded_257.wav
# Renamed: Banded_Stream_Frog_202_secondary.wav -> Banded_258.wav
# Renamed: Banded_Stream_Frog_203_primary.wav -> Banded_259.wav
# Renamed: Banded_Stream_Frog_203_secondary.wav -> Banded_260.wav
# Renamed: Banded_Stream_Frog_204_primary.wav -> Banded_261.wav
# Renamed: Banded_Stream_Frog_204_secondary.wav -> Banded_262.wav
# Renamed: Banded_Stream_Frog_205_primary.wav -> Banded_263.wav
# Renamed: Banded_Stream_Frog_205_secondary.wav -> Banded_264.wav
# Renamed: Banded_Stream_Frog_206_primary.wav -> Banded_265.wav
# Renamed: Banded_Stream_Frog_206_secondary.wav -> Banded_266.wav
# Renamed: Banded_Stream_Frog_207_primary.wav -> Banded_267.wav
# Renamed: Banded_Stream_Frog_207_secondary.wav -> Banded_268.wav
# Renamed: Banded_Stream_Frog_208_primary.wav -> Banded_269.wav
# Renamed: Banded_Stream_Frog_208_secondary.wav -> Banded_270.wav
# Renamed: Banded_Stream_Frog_209_primary.wav -> Banded_271.wav
# Renamed: Banded_Stream_Frog_209_secondary.wav -> Banded_272.wav
# Renamed: Banded_Stream_Frog_20_1_primary.wav -> Banded_273.wav
# Renamed: Banded_Stream_Frog_20_1_secondary.wav -> Banded_274.wav
# Renamed: Banded_Stream_Frog_20_primary.wav -> Banded_275.wav
# Renamed: Banded_Stream_Frog_20_secondary.wav -> Banded_276.wav
# Renamed: Banded_Stream_Frog_210_primary.wav -> Banded_277.wav
# Renamed: Banded_Stream_Frog_210_secondary.wav -> Banded_278.wav
# Renamed: Banded_Stream_Frog_211_primary.wav -> Banded_279.wav
# Renamed: Banded_Stream_Frog_211_secondary.wav -> Banded_280.wav
# Renamed: Banded_Stream_Frog_212_primary.wav -> Banded_281.wav
# Renamed: Banded_Stream_Frog_212_secondary.wav -> Banded_282.wav
# Renamed: Banded_Stream_Frog_213_primary.wav -> Banded_283.wav
# Renamed: Banded_Stream_Frog_213_secondary.wav -> Banded_284.wav
# Renamed: Banded_Stream_Frog_214_primary.wav -> Banded_285.wav
# Renamed: Banded_Stream_Frog_214_secondary.wav -> Banded_286.wav
# Renamed: Banded_Stream_Frog_215_primary.wav -> Banded_287.wav
# Renamed: Banded_Stream_Frog_215_secondary.wav -> Banded_288.wav
# Renamed: Banded_Stream_Frog_216_primary.wav -> Banded_289.wav
# Renamed: Banded_Stream_Frog_216_secondary.wav -> Banded_290.wav
# Renamed: Banded_Stream_Frog_217_primary.wav -> Banded_291.wav
# Renamed: Banded_Stream_Frog_217_secondary.wav -> Banded_292.wav
# Renamed: Banded_Stream_Frog_218_primary.wav -> Banded_293.wav
# Renamed: Banded_Stream_Frog_218_secondary.wav -> Banded_294.wav
# Renamed: Banded_Stream_Frog_219_primary.wav -> Banded_295.wav
# Renamed: Banded_Stream_Frog_219_secondary.wav -> Banded_296.wav
# Renamed: Banded_Stream_Frog_21_1_primary.wav -> Banded_297.wav
# Renamed: Banded_Stream_Frog_21_1_secondary.wav -> Banded_298.wav
# Renamed: Banded_Stream_Frog_21_primary.wav -> Banded_299.wav
# Renamed: Banded_Stream_Frog_21_secondary.wav -> Banded_300.wav
# Renamed: Banded_Stream_Frog_220_primary.wav -> Banded_301.wav
# Renamed: Banded_Stream_Frog_220_secondary.wav -> Banded_302.wav
# Renamed: Banded_Stream_Frog_221_primary.wav -> Banded_303.wav
# Renamed: Banded_Stream_Frog_221_secondary.wav -> Banded_304.wav
# Renamed: Banded_Stream_Frog_222_primary.wav -> Banded_305.wav
# Renamed: Banded_Stream_Frog_222_secondary.wav -> Banded_306.wav
# Renamed: Banded_Stream_Frog_223_primary.wav -> Banded_307.wav
# Renamed: Banded_Stream_Frog_223_secondary.wav -> Banded_308.wav
# Renamed: Banded_Stream_Frog_224_primary.wav -> Banded_309.wav
# Renamed: Banded_Stream_Frog_224_secondary.wav -> Banded_310.wav
# Renamed: Banded_Stream_Frog_225_primary.wav -> Banded_311.wav
# Renamed: Banded_Stream_Frog_225_secondary.wav -> Banded_312.wav
# Renamed: Banded_Stream_Frog_226_primary.wav -> Banded_313.wav
# Renamed: Banded_Stream_Frog_226_secondary.wav -> Banded_314.wav
# Renamed: Banded_Stream_Frog_227_primary.wav -> Banded_315.wav
# Renamed: Banded_Stream_Frog_227_secondary.wav -> Banded_316.wav
# Renamed: Banded_Stream_Frog_228_primary.wav -> Banded_317.wav
# Renamed: Banded_Stream_Frog_228_secondary.wav -> Banded_318.wav
# Renamed: Banded_Stream_Frog_229_primary.wav -> Banded_319.wav
# Renamed: Banded_Stream_Frog_229_secondary.wav -> Banded_320.wav
# Renamed: Banded_Stream_Frog_22_1_primary.wav -> Banded_321.wav
# Renamed: Banded_Stream_Frog_22_1_secondary.wav -> Banded_322.wav
# Renamed: Banded_Stream_Frog_22_primary.wav -> Banded_323.wav
# Renamed: Banded_Stream_Frog_22_secondary.wav -> Banded_324.wav
# Renamed: Banded_Stream_Frog_230_primary.wav -> Banded_325.wav
# Renamed: Banded_Stream_Frog_230_secondary.wav -> Banded_326.wav
# Renamed: Banded_Stream_Frog_231_primary.wav -> Banded_327.wav
# Renamed: Banded_Stream_Frog_231_secondary.wav -> Banded_328.wav
# Renamed: Banded_Stream_Frog_232_primary.wav -> Banded_329.wav
# Renamed: Banded_Stream_Frog_232_secondary.wav -> Banded_330.wav
# Renamed: Banded_Stream_Frog_233_primary.wav -> Banded_331.wav
# Renamed: Banded_Stream_Frog_233_secondary.wav -> Banded_332.wav
# Renamed: Banded_Stream_Frog_234_primary.wav -> Banded_333.wav
# Renamed: Banded_Stream_Frog_234_secondary.wav -> Banded_334.wav
# Renamed: Banded_Stream_Frog_235_primary.wav -> Banded_335.wav
# Renamed: Banded_Stream_Frog_235_secondary.wav -> Banded_336.wav
# Renamed: Banded_Stream_Frog_236_primary.wav -> Banded_337.wav
# Renamed: Banded_Stream_Frog_236_secondary.wav -> Banded_338.wav
# Renamed: Banded_Stream_Frog_237_primary.wav -> Banded_339.wav
# Renamed: Banded_Stream_Frog_237_secondary.wav -> Banded_340.wav
# Renamed: Banded_Stream_Frog_238_primary.wav -> Banded_341.wav
# Renamed: Banded_Stream_Frog_238_secondary.wav -> Banded_342.wav
# Renamed: Banded_Stream_Frog_239_primary.wav -> Banded_343.wav
# Renamed: Banded_Stream_Frog_239_secondary.wav -> Banded_344.wav
# Renamed: Banded_Stream_Frog_23_1_primary.wav -> Banded_345.wav
# Renamed: Banded_Stream_Frog_23_1_secondary.wav -> Banded_346.wav
# Renamed: Banded_Stream_Frog_23_primary.wav -> Banded_347.wav
# Renamed: Banded_Stream_Frog_23_secondary.wav -> Banded_348.wav
# Renamed: Banded_Stream_Frog_240_primary.wav -> Banded_349.wav
# Renamed: Banded_Stream_Frog_240_secondary.wav -> Banded_350.wav
# Renamed: Banded_Stream_Frog_241_primary.wav -> Banded_351.wav
# Renamed: Banded_Stream_Frog_241_secondary.wav -> Banded_352.wav
# Renamed: Banded_Stream_Frog_242_primary.wav -> Banded_353.wav
# Renamed: Banded_Stream_Frog_242_secondary.wav -> Banded_354.wav
# Renamed: Banded_Stream_Frog_243_primary.wav -> Banded_355.wav
# Renamed: Banded_Stream_Frog_243_secondary.wav -> Banded_356.wav
# Renamed: Banded_Stream_Frog_244_primary.wav -> Banded_357.wav
# Renamed: Banded_Stream_Frog_244_secondary.wav -> Banded_358.wav
# Renamed: Banded_Stream_Frog_245_primary.wav -> Banded_359.wav
# Renamed: Banded_Stream_Frog_245_secondary.wav -> Banded_360.wav
# Renamed: Banded_Stream_Frog_246_primary.wav -> Banded_361.wav
# Renamed: Banded_Stream_Frog_246_secondary.wav -> Banded_362.wav
# Renamed: Banded_Stream_Frog_247_primary.wav -> Banded_363.wav
# Renamed: Banded_Stream_Frog_247_secondary.wav -> Banded_364.wav
# Renamed: Banded_Stream_Frog_248_primary.wav -> Banded_365.wav
# Renamed: Banded_Stream_Frog_248_secondary.wav -> Banded_366.wav
# Renamed: Banded_Stream_Frog_249_primary.wav -> Banded_367.wav
# Renamed: Banded_Stream_Frog_249_secondary.wav -> Banded_368.wav
# Renamed: Banded_Stream_Frog_24_1_primary.wav -> Banded_369.wav
# Renamed: Banded_Stream_Frog_24_1_secondary.wav -> Banded_370.wav
# Renamed: Banded_Stream_Frog_24_primary.wav -> Banded_371.wav
# Renamed: Banded_Stream_Frog_24_secondary.wav -> Banded_372.wav
# Renamed: Banded_Stream_Frog_250_primary.wav -> Banded_373.wav
# Renamed: Banded_Stream_Frog_250_secondary.wav -> Banded_374.wav
# Renamed: Banded_Stream_Frog_251_primary.wav -> Banded_375.wav
# Renamed: Banded_Stream_Frog_251_secondary.wav -> Banded_376.wav
# Renamed: Banded_Stream_Frog_252_primary.wav -> Banded_377.wav
# Renamed: Banded_Stream_Frog_252_secondary.wav -> Banded_378.wav
# Renamed: Banded_Stream_Frog_253_primary.wav -> Banded_379.wav
# Renamed: Banded_Stream_Frog_253_secondary.wav -> Banded_380.wav
# Renamed: Banded_Stream_Frog_254_primary.wav -> Banded_381.wav
# Renamed: Banded_Stream_Frog_254_secondary.wav -> Banded_382.wav
# Renamed: Banded_Stream_Frog_255_primary.wav -> Banded_383.wav
# Renamed: Banded_Stream_Frog_255_secondary.wav -> Banded_384.wav
# Renamed: Banded_Stream_Frog_256_primary.wav -> Banded_385.wav
# Renamed: Banded_Stream_Frog_256_secondary.wav -> Banded_386.wav
# Renamed: Banded_Stream_Frog_257_primary.wav -> Banded_387.wav
# Renamed: Banded_Stream_Frog_257_secondary.wav -> Banded_388.wav
# Renamed: Banded_Stream_Frog_258_primary.wav -> Banded_389.wav
# Renamed: Banded_Stream_Frog_258_secondary.wav -> Banded_390.wav
# Renamed: Banded_Stream_Frog_259_primary.wav -> Banded_391.wav
# Renamed: Banded_Stream_Frog_259_secondary.wav -> Banded_392.wav
# Renamed: Banded_Stream_Frog_25_1_primary.wav -> Banded_393.wav
# Renamed: Banded_Stream_Frog_25_1_secondary.wav -> Banded_394.wav
# Renamed: Banded_Stream_Frog_25_primary.wav -> Banded_395.wav
# Renamed: Banded_Stream_Frog_25_secondary.wav -> Banded_396.wav
# Renamed: Banded_Stream_Frog_260_primary.wav -> Banded_397.wav
# Renamed: Banded_Stream_Frog_260_secondary.wav -> Banded_398.wav
# Renamed: Banded_Stream_Frog_261_primary.wav -> Banded_399.wav
# Renamed: Banded_Stream_Frog_261_secondary.wav -> Banded_400.wav
# Renamed: Banded_Stream_Frog_262_primary.wav -> Banded_401.wav
# Renamed: Banded_Stream_Frog_262_secondary.wav -> Banded_402.wav
# Renamed: Banded_Stream_Frog_263_primary.wav -> Banded_403.wav
# Renamed: Banded_Stream_Frog_263_secondary.wav -> Banded_404.wav
# Renamed: Banded_Stream_Frog_264_primary.wav -> Banded_405.wav
# Renamed: Banded_Stream_Frog_264_secondary.wav -> Banded_406.wav
# Renamed: Banded_Stream_Frog_265_primary.wav -> Banded_407.wav
# Renamed: Banded_Stream_Frog_265_secondary.wav -> Banded_408.wav
# Renamed: Banded_Stream_Frog_266_primary.wav -> Banded_409.wav
# Renamed: Banded_Stream_Frog_266_secondary.wav -> Banded_410.wav
# Renamed: Banded_Stream_Frog_267_primary.wav -> Banded_411.wav
# Renamed: Banded_Stream_Frog_267_secondary.wav -> Banded_412.wav
# Renamed: Banded_Stream_Frog_268_primary.wav -> Banded_413.wav
# Renamed: Banded_Stream_Frog_268_secondary.wav -> Banded_414.wav
# Renamed: Banded_Stream_Frog_269_primary.wav -> Banded_415.wav
# Renamed: Banded_Stream_Frog_269_secondary.wav -> Banded_416.wav
# Renamed: Banded_Stream_Frog_26_1_primary.wav -> Banded_417.wav
# Renamed: Banded_Stream_Frog_26_1_secondary.wav -> Banded_418.wav
# Renamed: Banded_Stream_Frog_26_primary.wav -> Banded_419.wav
# Renamed: Banded_Stream_Frog_26_secondary.wav -> Banded_420.wav
# Renamed: Banded_Stream_Frog_270_primary.wav -> Banded_421.wav
# Renamed: Banded_Stream_Frog_270_secondary.wav -> Banded_422.wav
# Renamed: Banded_Stream_Frog_271_primary.wav -> Banded_423.wav
# Renamed: Banded_Stream_Frog_271_secondary.wav -> Banded_424.wav
# Renamed: Banded_Stream_Frog_272_primary.wav -> Banded_425.wav
# Renamed: Banded_Stream_Frog_272_secondary.wav -> Banded_426.wav
# Renamed: Banded_Stream_Frog_273_primary.wav -> Banded_427.wav
# Renamed: Banded_Stream_Frog_273_secondary.wav -> Banded_428.wav
# Renamed: Banded_Stream_Frog_274_primary.wav -> Banded_429.wav
# Renamed: Banded_Stream_Frog_274_secondary.wav -> Banded_430.wav
# Renamed: Banded_Stream_Frog_275_primary.wav -> Banded_431.wav
# Renamed: Banded_Stream_Frog_275_secondary.wav -> Banded_432.wav
# Renamed: Banded_Stream_Frog_276_primary.wav -> Banded_433.wav
# Renamed: Banded_Stream_Frog_276_secondary.wav -> Banded_434.wav
# Renamed: Banded_Stream_Frog_277_primary.wav -> Banded_435.wav
# Renamed: Banded_Stream_Frog_277_secondary.wav -> Banded_436.wav
# Renamed: Banded_Stream_Frog_278_primary.wav -> Banded_437.wav
# Renamed: Banded_Stream_Frog_278_secondary.wav -> Banded_438.wav
# Renamed: Banded_Stream_Frog_279_primary.wav -> Banded_439.wav
# Renamed: Banded_Stream_Frog_279_secondary.wav -> Banded_440.wav
# Renamed: Banded_Stream_Frog_27_1_primary.wav -> Banded_441.wav
# Renamed: Banded_Stream_Frog_27_1_secondary.wav -> Banded_442.wav
# Renamed: Banded_Stream_Frog_27_primary.wav -> Banded_443.wav
# Renamed: Banded_Stream_Frog_27_secondary.wav -> Banded_444.wav
# Renamed: Banded_Stream_Frog_280_primary.wav -> Banded_445.wav
# Renamed: Banded_Stream_Frog_280_secondary.wav -> Banded_446.wav
# Renamed: Banded_Stream_Frog_281_primary.wav -> Banded_447.wav
# Renamed: Banded_Stream_Frog_281_secondary.wav -> Banded_448.wav
# Renamed: Banded_Stream_Frog_282_primary.wav -> Banded_449.wav
# Renamed: Banded_Stream_Frog_282_secondary.wav -> Banded_450.wav
# Renamed: Banded_Stream_Frog_283_primary.wav -> Banded_451.wav
# Renamed: Banded_Stream_Frog_283_secondary.wav -> Banded_452.wav
# Renamed: Banded_Stream_Frog_284_primary.wav -> Banded_453.wav
# Renamed: Banded_Stream_Frog_284_secondary.wav -> Banded_454.wav
# Renamed: Banded_Stream_Frog_285_primary.wav -> Banded_455.wav
# Renamed: Banded_Stream_Frog_285_secondary.wav -> Banded_456.wav
# Renamed: Banded_Stream_Frog_286_primary.wav -> Banded_457.wav
# Renamed: Banded_Stream_Frog_286_secondary.wav -> Banded_458.wav
# Renamed: Banded_Stream_Frog_287_primary.wav -> Banded_459.wav
# Renamed: Banded_Stream_Frog_287_secondary.wav -> Banded_460.wav
# Renamed: Banded_Stream_Frog_288_primary.wav -> Banded_461.wav
# Renamed: Banded_Stream_Frog_288_secondary.wav -> Banded_462.wav
# Renamed: Banded_Stream_Frog_289_primary.wav -> Banded_463.wav
# Renamed: Banded_Stream_Frog_289_secondary.wav -> Banded_464.wav
# Renamed: Banded_Stream_Frog_28_1_primary.wav -> Banded_465.wav
# Renamed: Banded_Stream_Frog_28_1_secondary.wav -> Banded_466.wav
# Renamed: Banded_Stream_Frog_28_primary.wav -> Banded_467.wav
# Renamed: Banded_Stream_Frog_28_secondary.wav -> Banded_468.wav
# Renamed: Banded_Stream_Frog_290_primary.wav -> Banded_469.wav
# Renamed: Banded_Stream_Frog_290_secondary.wav -> Banded_470.wav
# Renamed: Banded_Stream_Frog_291_primary.wav -> Banded_471.wav
# Renamed: Banded_Stream_Frog_291_secondary.wav -> Banded_472.wav
# Renamed: Banded_Stream_Frog_292_primary.wav -> Banded_473.wav
# Renamed: Banded_Stream_Frog_292_secondary.wav -> Banded_474.wav
# Renamed: Banded_Stream_Frog_293_primary.wav -> Banded_475.wav
# Renamed: Banded_Stream_Frog_293_secondary.wav -> Banded_476.wav
# Renamed: Banded_Stream_Frog_294_primary.wav -> Banded_477.wav
# Renamed: Banded_Stream_Frog_294_secondary.wav -> Banded_478.wav
# Renamed: Banded_Stream_Frog_295_primary.wav -> Banded_479.wav
# Renamed: Banded_Stream_Frog_295_secondary.wav -> Banded_480.wav
# Renamed: Banded_Stream_Frog_296_primary.wav -> Banded_481.wav
# Renamed: Banded_Stream_Frog_296_secondary.wav -> Banded_482.wav
# Renamed: Banded_Stream_Frog_297_primary.wav -> Banded_483.wav
# Renamed: Banded_Stream_Frog_297_secondary.wav -> Banded_484.wav
# Renamed: Banded_Stream_Frog_298_primary.wav -> Banded_485.wav
# Renamed: Banded_Stream_Frog_298_secondary.wav -> Banded_486.wav
# Renamed: Banded_Stream_Frog_299_primary.wav -> Banded_487.wav
# Renamed: Banded_Stream_Frog_299_secondary.wav -> Banded_488.wav
# Renamed: Banded_Stream_Frog_29_1_primary.wav -> Banded_489.wav
# Renamed: Banded_Stream_Frog_29_1_secondary.wav -> Banded_490.wav
# Renamed: Banded_Stream_Frog_29_primary.wav -> Banded_491.wav
# Renamed: Banded_Stream_Frog_29_secondary.wav -> Banded_492.wav
# Renamed: Banded_Stream_Frog_2_1_primary.wav -> Banded_493.wav
# Renamed: Banded_Stream_Frog_2_1_secondary.wav -> Banded_494.wav
# Renamed: Banded_Stream_Frog_2_2_primary.wav -> Banded_495.wav
# Renamed: Banded_Stream_Frog_2_2_secondary.wav -> Banded_496.wav
# Renamed: Banded_Stream_Frog_2_primary.wav -> Banded_497.wav
# Renamed: Banded_Stream_Frog_2_secondary.wav -> Banded_498.wav
# Renamed: Banded_Stream_Frog_300_primary.wav -> Banded_499.wav
# Renamed: Banded_Stream_Frog_300_secondary.wav -> Banded_500.wav
# Renamed: Banded_Stream_Frog_301_primary.wav -> Banded_501.wav
# Renamed: Banded_Stream_Frog_301_secondary.wav -> Banded_502.wav
# Renamed: Banded_Stream_Frog_302_primary.wav -> Banded_503.wav
# Renamed: Banded_Stream_Frog_302_secondary.wav -> Banded_504.wav
# Renamed: Banded_Stream_Frog_303_primary.wav -> Banded_505.wav
# Renamed: Banded_Stream_Frog_303_secondary.wav -> Banded_506.wav
# Renamed: Banded_Stream_Frog_304_primary.wav -> Banded_507.wav
# Renamed: Banded_Stream_Frog_304_secondary.wav -> Banded_508.wav
# Renamed: Banded_Stream_Frog_305_primary.wav -> Banded_509.wav
# Renamed: Banded_Stream_Frog_305_secondary.wav -> Banded_510.wav
# Renamed: Banded_Stream_Frog_306_primary.wav -> Banded_511.wav
# Renamed: Banded_Stream_Frog_306_secondary.wav -> Banded_512.wav
# Renamed: Banded_Stream_Frog_307_primary.wav -> Banded_513.wav
# Renamed: Banded_Stream_Frog_307_secondary.wav -> Banded_514.wav
# Renamed: Banded_Stream_Frog_308_primary.wav -> Banded_515.wav
# Renamed: Banded_Stream_Frog_308_secondary.wav -> Banded_516.wav
# Renamed: Banded_Stream_Frog_309_primary.wav -> Banded_517.wav
# Renamed: Banded_Stream_Frog_309_secondary.wav -> Banded_518.wav
# Renamed: Banded_Stream_Frog_30_1_primary.wav -> Banded_519.wav
# Renamed: Banded_Stream_Frog_30_1_secondary.wav -> Banded_520.wav
# Renamed: Banded_Stream_Frog_30_primary.wav -> Banded_521.wav
# Renamed: Banded_Stream_Frog_30_secondary.wav -> Banded_522.wav
# Renamed: Banded_Stream_Frog_310_primary.wav -> Banded_523.wav
# Renamed: Banded_Stream_Frog_310_secondary.wav -> Banded_524.wav
# Renamed: Banded_Stream_Frog_311_primary.wav -> Banded_525.wav
# Renamed: Banded_Stream_Frog_311_secondary.wav -> Banded_526.wav
# Renamed: Banded_Stream_Frog_312_primary.wav -> Banded_527.wav
# Renamed: Banded_Stream_Frog_312_secondary.wav -> Banded_528.wav
# Renamed: Banded_Stream_Frog_313_primary.wav -> Banded_529.wav
# Renamed: Banded_Stream_Frog_313_secondary.wav -> Banded_530.wav
# Renamed: Banded_Stream_Frog_314_primary.wav -> Banded_531.wav
# Renamed: Banded_Stream_Frog_314_secondary.wav -> Banded_532.wav
# Renamed: Banded_Stream_Frog_315_primary.wav -> Banded_533.wav
# Renamed: Banded_Stream_Frog_315_secondary.wav -> Banded_534.wav
# Renamed: Banded_Stream_Frog_316_primary.wav -> Banded_535.wav
# Renamed: Banded_Stream_Frog_316_secondary.wav -> Banded_536.wav
# Renamed: Banded_Stream_Frog_317_primary.wav -> Banded_537.wav
# Renamed: Banded_Stream_Frog_317_secondary.wav -> Banded_538.wav
# Renamed: Banded_Stream_Frog_318_primary.wav -> Banded_539.wav
# Renamed: Banded_Stream_Frog_318_secondary.wav -> Banded_540.wav
# Renamed: Banded_Stream_Frog_319_primary.wav -> Banded_541.wav
# Renamed: Banded_Stream_Frog_319_secondary.wav -> Banded_542.wav
# Renamed: Banded_Stream_Frog_31_1_primary.wav -> Banded_543.wav
# Renamed: Banded_Stream_Frog_31_1_secondary.wav -> Banded_544.wav
# Renamed: Banded_Stream_Frog_31_primary.wav -> Banded_545.wav
# Renamed: Banded_Stream_Frog_31_secondary.wav -> Banded_546.wav
# Renamed: Banded_Stream_Frog_320_primary.wav -> Banded_547.wav
# Renamed: Banded_Stream_Frog_320_secondary.wav -> Banded_548.wav
# Renamed: Banded_Stream_Frog_321_primary.wav -> Banded_549.wav
# Renamed: Banded_Stream_Frog_321_secondary.wav -> Banded_550.wav
# Renamed: Banded_Stream_Frog_322_primary.wav -> Banded_551.wav
# Renamed: Banded_Stream_Frog_322_secondary.wav -> Banded_552.wav
# Renamed: Banded_Stream_Frog_323_primary.wav -> Banded_553.wav
# Renamed: Banded_Stream_Frog_323_secondary.wav -> Banded_554.wav
# Renamed: Banded_Stream_Frog_324_primary.wav -> Banded_555.wav
# Renamed: Banded_Stream_Frog_324_secondary.wav -> Banded_556.wav
# Renamed: Banded_Stream_Frog_325_primary.wav -> Banded_557.wav
# Renamed: Banded_Stream_Frog_325_secondary.wav -> Banded_558.wav
# Renamed: Banded_Stream_Frog_326_primary.wav -> Banded_559.wav
# Renamed: Banded_Stream_Frog_326_secondary.wav -> Banded_560.wav
# Renamed: Banded_Stream_Frog_327_primary.wav -> Banded_561.wav
# Renamed: Banded_Stream_Frog_327_secondary.wav -> Banded_562.wav
# Renamed: Banded_Stream_Frog_328_primary.wav -> Banded_563.wav
# Renamed: Banded_Stream_Frog_328_secondary.wav -> Banded_564.wav
# Renamed: Banded_Stream_Frog_329_primary.wav -> Banded_565.wav
# Renamed: Banded_Stream_Frog_329_secondary.wav -> Banded_566.wav
# Renamed: Banded_Stream_Frog_32_1_primary.wav -> Banded_567.wav
# Renamed: Banded_Stream_Frog_32_1_secondary.wav -> Banded_568.wav
# Renamed: Banded_Stream_Frog_32_primary.wav -> Banded_569.wav
# Renamed: Banded_Stream_Frog_32_secondary.wav -> Banded_570.wav
# Renamed: Banded_Stream_Frog_330_primary.wav -> Banded_571.wav
# Renamed: Banded_Stream_Frog_330_secondary.wav -> Banded_572.wav
# Renamed: Banded_Stream_Frog_331_primary.wav -> Banded_573.wav
# Renamed: Banded_Stream_Frog_331_secondary.wav -> Banded_574.wav
# Renamed: Banded_Stream_Frog_332_primary.wav -> Banded_575.wav
# Renamed: Banded_Stream_Frog_332_secondary.wav -> Banded_576.wav
# Renamed: Banded_Stream_Frog_333_primary.wav -> Banded_577.wav
# Renamed: Banded_Stream_Frog_333_secondary.wav -> Banded_578.wav
# Renamed: Banded_Stream_Frog_334_primary.wav -> Banded_579.wav
# Renamed: Banded_Stream_Frog_334_secondary.wav -> Banded_580.wav
# Renamed: Banded_Stream_Frog_335_primary.wav -> Banded_581.wav
# Renamed: Banded_Stream_Frog_335_secondary.wav -> Banded_582.wav
# Renamed: Banded_Stream_Frog_336_primary.wav -> Banded_583.wav
# Renamed: Banded_Stream_Frog_336_secondary.wav -> Banded_584.wav
# Renamed: Banded_Stream_Frog_337_primary.wav -> Banded_585.wav
# Renamed: Banded_Stream_Frog_337_secondary.wav -> Banded_586.wav
# Renamed: Banded_Stream_Frog_338_primary.wav -> Banded_587.wav
# Renamed: Banded_Stream_Frog_338_secondary.wav -> Banded_588.wav
# Renamed: Banded_Stream_Frog_339_primary.wav -> Banded_589.wav
# Renamed: Banded_Stream_Frog_339_secondary.wav -> Banded_590.wav
# Renamed: Banded_Stream_Frog_33_1_primary.wav -> Banded_591.wav
# Renamed: Banded_Stream_Frog_33_1_secondary.wav -> Banded_592.wav
# Renamed: Banded_Stream_Frog_33_primary.wav -> Banded_593.wav
# Renamed: Banded_Stream_Frog_33_secondary.wav -> Banded_594.wav
# Renamed: Banded_Stream_Frog_340_primary.wav -> Banded_595.wav
# Renamed: Banded_Stream_Frog_340_secondary.wav -> Banded_596.wav
# Renamed: Banded_Stream_Frog_341_primary.wav -> Banded_597.wav
# Renamed: Banded_Stream_Frog_341_secondary.wav -> Banded_598.wav
# Renamed: Banded_Stream_Frog_342_primary.wav -> Banded_599.wav
# Renamed: Banded_Stream_Frog_342_secondary.wav -> Banded_600.wav
# Renamed: Banded_Stream_Frog_343_primary.wav -> Banded_601.wav
# Renamed: Banded_Stream_Frog_343_secondary.wav -> Banded_602.wav
# Renamed: Banded_Stream_Frog_344_primary.wav -> Banded_603.wav
# Renamed: Banded_Stream_Frog_344_secondary.wav -> Banded_604.wav
# Renamed: Banded_Stream_Frog_345_primary.wav -> Banded_605.wav
# Renamed: Banded_Stream_Frog_345_secondary.wav -> Banded_606.wav
# Renamed: Banded_Stream_Frog_346_primary.wav -> Banded_607.wav
# Renamed: Banded_Stream_Frog_346_secondary.wav -> Banded_608.wav
# Renamed: Banded_Stream_Frog_347_primary.wav -> Banded_609.wav
# Renamed: Banded_Stream_Frog_347_secondary.wav -> Banded_610.wav
# Renamed: Banded_Stream_Frog_348_primary.wav -> Banded_611.wav
# Renamed: Banded_Stream_Frog_348_secondary.wav -> Banded_612.wav
# Renamed: Banded_Stream_Frog_349_primary.wav -> Banded_613.wav
# Renamed: Banded_Stream_Frog_349_secondary.wav -> Banded_614.wav
# Renamed: Banded_Stream_Frog_34_1_primary.wav -> Banded_615.wav
# Renamed: Banded_Stream_Frog_34_1_secondary.wav -> Banded_616.wav
# Renamed: Banded_Stream_Frog_34_primary.wav -> Banded_617.wav
# Renamed: Banded_Stream_Frog_34_secondary.wav -> Banded_618.wav
# Renamed: Banded_Stream_Frog_350_primary.wav -> Banded_619.wav
# Renamed: Banded_Stream_Frog_350_secondary.wav -> Banded_620.wav
# Renamed: Banded_Stream_Frog_351_primary.wav -> Banded_621.wav
# Renamed: Banded_Stream_Frog_351_secondary.wav -> Banded_622.wav
# Renamed: Banded_Stream_Frog_352_primary.wav -> Banded_623.wav
# Renamed: Banded_Stream_Frog_352_secondary.wav -> Banded_624.wav
# Renamed: Banded_Stream_Frog_353_primary.wav -> Banded_625.wav
# Renamed: Banded_Stream_Frog_353_secondary.wav -> Banded_626.wav
# Renamed: Banded_Stream_Frog_354_primary.wav -> Banded_627.wav
# Renamed: Banded_Stream_Frog_354_secondary.wav -> Banded_628.wav
# Renamed: Banded_Stream_Frog_355_primary.wav -> Banded_629.wav
# Renamed: Banded_Stream_Frog_355_secondary.wav -> Banded_630.wav
# Renamed: Banded_Stream_Frog_356_primary.wav -> Banded_631.wav
# Renamed: Banded_Stream_Frog_356_secondary.wav -> Banded_632.wav
# Renamed: Banded_Stream_Frog_357_primary.wav -> Banded_633.wav
# Renamed: Banded_Stream_Frog_357_secondary.wav -> Banded_634.wav
# Renamed: Banded_Stream_Frog_358_primary.wav -> Banded_635.wav
# Renamed: Banded_Stream_Frog_358_secondary.wav -> Banded_636.wav
# Renamed: Banded_Stream_Frog_359_primary.wav -> Banded_637.wav
# Renamed: Banded_Stream_Frog_359_secondary.wav -> Banded_638.wav
# Renamed: Banded_Stream_Frog_35_1_primary.wav -> Banded_639.wav
# Renamed: Banded_Stream_Frog_35_1_secondary.wav -> Banded_640.wav
# Renamed: Banded_Stream_Frog_35_primary.wav -> Banded_641.wav
# Renamed: Banded_Stream_Frog_35_secondary.wav -> Banded_642.wav
# Renamed: Banded_Stream_Frog_360_primary.wav -> Banded_643.wav
# Renamed: Banded_Stream_Frog_360_secondary.wav -> Banded_644.wav
# Renamed: Banded_Stream_Frog_361_primary.wav -> Banded_645.wav
# Renamed: Banded_Stream_Frog_361_secondary.wav -> Banded_646.wav
# Renamed: Banded_Stream_Frog_362_primary.wav -> Banded_647.wav
# Renamed: Banded_Stream_Frog_362_secondary.wav -> Banded_648.wav
# Renamed: Banded_Stream_Frog_363_primary.wav -> Banded_649.wav
# Renamed: Banded_Stream_Frog_363_secondary.wav -> Banded_650.wav
# Renamed: Banded_Stream_Frog_364_primary.wav -> Banded_651.wav
# Renamed: Banded_Stream_Frog_364_secondary.wav -> Banded_652.wav
# Renamed: Banded_Stream_Frog_365_primary.wav -> Banded_653.wav
# Renamed: Banded_Stream_Frog_365_secondary.wav -> Banded_654.wav
# Renamed: Banded_Stream_Frog_366_primary.wav -> Banded_655.wav
# Renamed: Banded_Stream_Frog_366_secondary.wav -> Banded_656.wav
# Renamed: Banded_Stream_Frog_367_primary.wav -> Banded_657.wav
# Renamed: Banded_Stream_Frog_367_secondary.wav -> Banded_658.wav
# Renamed: Banded_Stream_Frog_368_primary.wav -> Banded_659.wav
# Renamed: Banded_Stream_Frog_368_secondary.wav -> Banded_660.wav
# Renamed: Banded_Stream_Frog_369_primary.wav -> Banded_661.wav
# Renamed: Banded_Stream_Frog_369_secondary.wav -> Banded_662.wav
# Renamed: Banded_Stream_Frog_36_1_primary.wav -> Banded_663.wav
# Renamed: Banded_Stream_Frog_36_1_secondary.wav -> Banded_664.wav
# Renamed: Banded_Stream_Frog_36_primary.wav -> Banded_665.wav
# Renamed: Banded_Stream_Frog_36_secondary.wav -> Banded_666.wav
# Renamed: Banded_Stream_Frog_370_primary.wav -> Banded_667.wav
# Renamed: Banded_Stream_Frog_370_secondary.wav -> Banded_668.wav
# Renamed: Banded_Stream_Frog_371_primary.wav -> Banded_669.wav
# Renamed: Banded_Stream_Frog_371_secondary.wav -> Banded_670.wav
# Renamed: Banded_Stream_Frog_372_primary.wav -> Banded_671.wav
# Renamed: Banded_Stream_Frog_372_secondary.wav -> Banded_672.wav
# Renamed: Banded_Stream_Frog_373_primary.wav -> Banded_673.wav
# Renamed: Banded_Stream_Frog_373_secondary.wav -> Banded_674.wav
# Renamed: Banded_Stream_Frog_374_primary.wav -> Banded_675.wav
# Renamed: Banded_Stream_Frog_374_secondary.wav -> Banded_676.wav
# Renamed: Banded_Stream_Frog_375_primary.wav -> Banded_677.wav
# Renamed: Banded_Stream_Frog_375_secondary.wav -> Banded_678.wav
# Renamed: Banded_Stream_Frog_376_primary.wav -> Banded_679.wav
# Renamed: Banded_Stream_Frog_376_secondary.wav -> Banded_680.wav
# Renamed: Banded_Stream_Frog_377_primary.wav -> Banded_681.wav
# Renamed: Banded_Stream_Frog_377_secondary.wav -> Banded_682.wav
# Renamed: Banded_Stream_Frog_378_primary.wav -> Banded_683.wav
# Renamed: Banded_Stream_Frog_378_secondary.wav -> Banded_684.wav
# Renamed: Banded_Stream_Frog_379_primary.wav -> Banded_685.wav
# Renamed: Banded_Stream_Frog_379_secondary.wav -> Banded_686.wav
# Renamed: Banded_Stream_Frog_37_1_primary.wav -> Banded_687.wav
# Renamed: Banded_Stream_Frog_37_1_secondary.wav -> Banded_688.wav
# Renamed: Banded_Stream_Frog_37_primary.wav -> Banded_689.wav
# Renamed: Banded_Stream_Frog_37_secondary.wav -> Banded_690.wav
# Renamed: Banded_Stream_Frog_380_primary.wav -> Banded_691.wav
# Renamed: Banded_Stream_Frog_380_secondary.wav -> Banded_692.wav
# Renamed: Banded_Stream_Frog_381_primary.wav -> Banded_693.wav
# Renamed: Banded_Stream_Frog_381_secondary.wav -> Banded_694.wav
# Renamed: Banded_Stream_Frog_382_primary.wav -> Banded_695.wav
# Renamed: Banded_Stream_Frog_382_secondary.wav -> Banded_696.wav
# Renamed: Banded_Stream_Frog_383_primary.wav -> Banded_697.wav
# Renamed: Banded_Stream_Frog_383_secondary.wav -> Banded_698.wav
# Renamed: Banded_Stream_Frog_384_primary.wav -> Banded_699.wav
# Renamed: Banded_Stream_Frog_384_secondary.wav -> Banded_700.wav
# Renamed: Banded_Stream_Frog_385_primary.wav -> Banded_701.wav
# Renamed: Banded_Stream_Frog_385_secondary.wav -> Banded_702.wav
# Renamed: Banded_Stream_Frog_386_primary.wav -> Banded_703.wav
# Renamed: Banded_Stream_Frog_386_secondary.wav -> Banded_704.wav
# Renamed: Banded_Stream_Frog_387_primary.wav -> Banded_705.wav
# Renamed: Banded_Stream_Frog_387_secondary.wav -> Banded_706.wav
# Renamed: Banded_Stream_Frog_388_primary.wav -> Banded_707.wav
# Renamed: Banded_Stream_Frog_388_secondary.wav -> Banded_708.wav
# Renamed: Banded_Stream_Frog_389_primary.wav -> Banded_709.wav
# Renamed: Banded_Stream_Frog_389_secondary.wav -> Banded_710.wav
# Renamed: Banded_Stream_Frog_38_1_primary.wav -> Banded_711.wav
# Renamed: Banded_Stream_Frog_38_1_secondary.wav -> Banded_712.wav
# Renamed: Banded_Stream_Frog_38_primary.wav -> Banded_713.wav
# Renamed: Banded_Stream_Frog_38_secondary.wav -> Banded_714.wav
# Renamed: Banded_Stream_Frog_390_primary.wav -> Banded_715.wav
# Renamed: Banded_Stream_Frog_390_secondary.wav -> Banded_716.wav
# Renamed: Banded_Stream_Frog_391_primary.wav -> Banded_717.wav
# Renamed: Banded_Stream_Frog_391_secondary.wav -> Banded_718.wav
# Renamed: Banded_Stream_Frog_392_primary.wav -> Banded_719.wav
# Renamed: Banded_Stream_Frog_392_secondary.wav -> Banded_720.wav
# Renamed: Banded_Stream_Frog_393_primary.wav -> Banded_721.wav
# Renamed: Banded_Stream_Frog_393_secondary.wav -> Banded_722.wav
# Renamed: Banded_Stream_Frog_394_primary.wav -> Banded_723.wav
# Renamed: Banded_Stream_Frog_394_secondary.wav -> Banded_724.wav
# Renamed: Banded_Stream_Frog_395_primary.wav -> Banded_725.wav
# Renamed: Banded_Stream_Frog_395_secondary.wav -> Banded_726.wav
# Renamed: Banded_Stream_Frog_396_primary.wav -> Banded_727.wav
# Renamed: Banded_Stream_Frog_396_secondary.wav -> Banded_728.wav
# Renamed: Banded_Stream_Frog_397_primary.wav -> Banded_729.wav
# Renamed: Banded_Stream_Frog_397_secondary.wav -> Banded_730.wav
# Renamed: Banded_Stream_Frog_398_primary.wav -> Banded_731.wav
# Renamed: Banded_Stream_Frog_398_secondary.wav -> Banded_732.wav
# Renamed: Banded_Stream_Frog_399_primary.wav -> Banded_733.wav
# Renamed: Banded_Stream_Frog_399_secondary.wav -> Banded_734.wav
# Renamed: Banded_Stream_Frog_39_1_primary.wav -> Banded_735.wav
# Renamed: Banded_Stream_Frog_39_1_secondary.wav -> Banded_736.wav
# Renamed: Banded_Stream_Frog_39_primary.wav -> Banded_737.wav
# Renamed: Banded_Stream_Frog_39_secondary.wav -> Banded_738.wav
# Renamed: Banded_Stream_Frog_3_1_primary.wav -> Banded_739.wav
# Renamed: Banded_Stream_Frog_3_1_secondary.wav -> Banded_740.wav
# Renamed: Banded_Stream_Frog_3_2_primary.wav -> Banded_741.wav
# Renamed: Banded_Stream_Frog_3_2_secondary.wav -> Banded_742.wav
# Renamed: Banded_Stream_Frog_3_primary.wav -> Banded_743.wav
# Renamed: Banded_Stream_Frog_3_secondary.wav -> Banded_744.wav
# Renamed: Banded_Stream_Frog_400_primary.wav -> Banded_745.wav
# Renamed: Banded_Stream_Frog_400_secondary.wav -> Banded_746.wav
# Renamed: Banded_Stream_Frog_401_primary.wav -> Banded_747.wav
# Renamed: Banded_Stream_Frog_401_secondary.wav -> Banded_748.wav
# Renamed: Banded_Stream_Frog_402_primary.wav -> Banded_749.wav
# Renamed: Banded_Stream_Frog_402_secondary.wav -> Banded_750.wav
# Renamed: Banded_Stream_Frog_403_primary.wav -> Banded_751.wav
# Renamed: Banded_Stream_Frog_403_secondary.wav -> Banded_752.wav
# Renamed: Banded_Stream_Frog_404_primary.wav -> Banded_753.wav
# Renamed: Banded_Stream_Frog_404_secondary.wav -> Banded_754.wav
# Renamed: Banded_Stream_Frog_405_primary.wav -> Banded_755.wav
# Renamed: Banded_Stream_Frog_405_secondary.wav -> Banded_756.wav
# Renamed: Banded_Stream_Frog_406_primary.wav -> Banded_757.wav
# Renamed: Banded_Stream_Frog_406_secondary.wav -> Banded_758.wav
# Renamed: Banded_Stream_Frog_407_primary.wav -> Banded_759.wav
# Renamed: Banded_Stream_Frog_407_secondary.wav -> Banded_760.wav
# Renamed: Banded_Stream_Frog_408_primary.wav -> Banded_761.wav
# Renamed: Banded_Stream_Frog_408_secondary.wav -> Banded_762.wav
# Renamed: Banded_Stream_Frog_409_primary.wav -> Banded_763.wav
# Renamed: Banded_Stream_Frog_409_secondary.wav -> Banded_764.wav
# ...
# Renamed: other_frog_868_secondary.wav -> other_4985.wav
# Renamed: other_frog_869_primary.wav -> other_4986.wav
# Renamed: other_frog_869_secondary.wav -> other_4987.wav
# Renamed: other_frog_86_primary.wav -> other_4988.wav
# Renamed: other_frog_86_secondary.wav -> other_4989.wav
# Renamed: other_frog_870_primary.wav -> other_4990.wav
# Renamed: other_frog_870_secondary.wav -> other_4991.wav
# Renamed: other_frog_871_primary.wav -> other_4992.wav
# Renamed: other_frog_871_secondary.wav -> other_4993.wav
# Renamed: other_frog_872_primary.wav -> other_4994.wav
# Renamed: other_frog_872_secondary.wav -> other_4995.wav
# Renamed: other_frog_873_primary.wav -> other_4996.wav
# Renamed: other_frog_873_secondary.wav -> other_4997.wav
# Renamed: other_frog_874_primary.wav -> other_4998.wav
# Renamed: other_frog_874_secondary.wav -> other_4999.wav
# Renamed: other_frog_875_primary.wav -> other_5000.wav
# Renamed: other_frog_875_secondary.wav -> other_5001.wav
# Renamed: other_frog_876_primary.wav -> other_5002.wav
# Renamed: other_frog_876_secondary.wav -> other_5003.wav
# Renamed: other_frog_877_primary.wav -> other_5004.wav
# Renamed: other_frog_877_secondary.wav -> other_5005.wav
# Renamed: other_frog_878_primary.wav -> other_5006.wav
# Renamed: other_frog_878_secondary.wav -> other_5007.wav
# Renamed: other_frog_879_primary.wav -> other_5008.wav
# Renamed: other_frog_879_secondary.wav -> other_5009.wav
# Renamed: other_frog_87_primary.wav -> other_5010.wav
# Renamed: other_frog_87_secondary.wav -> other_5011.wav
# Renamed: other_frog_880_primary.wav -> other_5012.wav
# Renamed: other_frog_880_secondary.wav -> other_5013.wav
# Renamed: other_frog_881_primary.wav -> other_5014.wav
# Renamed: other_frog_881_secondary.wav -> other_5015.wav
# Renamed: other_frog_882_primary.wav -> other_5016.wav
# Renamed: other_frog_883_primary.wav -> other_5017.wav
# Renamed: other_frog_883_secondary.wav -> other_5018.wav
# Renamed: other_frog_884_primary.wav -> other_5019.wav
# Renamed: other_frog_884_secondary.wav -> other_5020.wav
# Renamed: other_frog_885_primary.wav -> other_5021.wav
# Renamed: other_frog_885_secondary.wav -> other_5022.wav
# Renamed: other_frog_886_primary.wav -> other_5023.wav
# Renamed: other_frog_886_secondary.wav -> other_5024.wav
# Renamed: other_frog_887_primary.wav -> other_5025.wav
# Renamed: other_frog_887_secondary.wav -> other_5026.wav
# Renamed: other_frog_888_primary.wav -> other_5027.wav
# Renamed: other_frog_888_secondary.wav -> other_5028.wav
# Renamed: other_frog_889_primary.wav -> other_5029.wav
# Renamed: other_frog_889_secondary.wav -> other_5030.wav
# Renamed: other_frog_88_primary.wav -> other_5031.wav
# Renamed: other_frog_88_secondary.wav -> other_5032.wav
# Renamed: other_frog_890_primary.wav -> other_5033.wav
# Renamed: other_frog_890_secondary.wav -> other_5034.wav
# Renamed: other_frog_891_primary.wav -> other_5035.wav
# Renamed: other_frog_891_secondary.wav -> other_5036.wav
# Renamed: other_frog_892_primary.wav -> other_5037.wav
# Renamed: other_frog_892_secondary.wav -> other_5038.wav
# Renamed: other_frog_893_primary.wav -> other_5039.wav
# Renamed: other_frog_893_secondary.wav -> other_5040.wav
# Renamed: other_frog_894_primary.wav -> other_5041.wav
# Renamed: other_frog_894_secondary.wav -> other_5042.wav
# Renamed: other_frog_895_primary.wav -> other_5043.wav
# Renamed: other_frog_895_secondary.wav -> other_5044.wav
# Renamed: other_frog_896_primary.wav -> other_5045.wav
# Renamed: other_frog_896_secondary.wav -> other_5046.wav
# Renamed: other_frog_897_primary.wav -> other_5047.wav
# Renamed: other_frog_897_secondary.wav -> other_5048.wav
# Renamed: other_frog_898_primary.wav -> other_5049.wav
# Renamed: other_frog_898_secondary.wav -> other_5050.wav
# Renamed: other_frog_899_primary.wav -> other_5051.wav
# Renamed: other_frog_899_secondary.wav -> other_5052.wav
# Renamed: other_frog_89_primary.wav -> other_5053.wav
# Renamed: other_frog_89_secondary.wav -> other_5054.wav
# Renamed: other_frog_8_primary.wav -> other_5055.wav
# Renamed: other_frog_8_secondary.wav -> other_5056.wav
# Renamed: other_frog_900_primary.wav -> other_5057.wav
# Renamed: other_frog_900_secondary.wav -> other_5058.wav
# Renamed: other_frog_901_primary.wav -> other_5059.wav
# Renamed: other_frog_901_secondary.wav -> other_5060.wav
# Renamed: other_frog_902_primary.wav -> other_5061.wav
# Renamed: other_frog_902_secondary.wav -> other_5062.wav
# Renamed: other_frog_903_primary.wav -> other_5063.wav
# Renamed: other_frog_903_secondary.wav -> other_5064.wav
# Renamed: other_frog_904_primary.wav -> other_5065.wav
# Renamed: other_frog_904_secondary.wav -> other_5066.wav
# Renamed: other_frog_905_primary.wav -> other_5067.wav
# Renamed: other_frog_905_secondary.wav -> other_5068.wav
# Renamed: other_frog_906_primary.wav -> other_5069.wav
# Renamed: other_frog_906_secondary.wav -> other_5070.wav
# Renamed: other_frog_907_primary.wav -> other_5071.wav
# Renamed: other_frog_907_secondary.wav -> other_5072.wav
# Renamed: other_frog_908_primary.wav -> other_5073.wav
# Renamed: other_frog_908_secondary.wav -> other_5074.wav
# Renamed: other_frog_909_primary.wav -> other_5075.wav
# Renamed: other_frog_909_secondary.wav -> other_5076.wav
# Renamed: other_frog_90_primary.wav -> other_5077.wav
# Renamed: other_frog_90_secondary.wav -> other_5078.wav
# Renamed: other_frog_910_primary.wav -> other_5079.wav
# Renamed: other_frog_910_secondary.wav -> other_5080.wav
# Renamed: other_frog_911_primary.wav -> other_5081.wav
# Renamed: other_frog_911_secondary.wav -> other_5082.wav
# Renamed: other_frog_912_primary.wav -> other_5083.wav
# Renamed: other_frog_912_secondary.wav -> other_5084.wav
# Renamed: other_frog_913_primary.wav -> other_5085.wav
# Renamed: other_frog_913_secondary.wav -> other_5086.wav
# Renamed: other_frog_914_primary.wav -> other_5087.wav
# Renamed: other_frog_914_secondary.wav -> other_5088.wav
# Renamed: other_frog_915_primary.wav -> other_5089.wav
# Renamed: other_frog_915_secondary.wav -> other_5090.wav
# Renamed: other_frog_916_primary.wav -> other_5091.wav
# Renamed: other_frog_916_secondary.wav -> other_5092.wav
# Renamed: other_frog_917_primary.wav -> other_5093.wav
# Renamed: other_frog_917_secondary.wav -> other_5094.wav
# Renamed: other_frog_918_primary.wav -> other_5095.wav
# Renamed: other_frog_918_secondary.wav -> other_5096.wav
# Renamed: other_frog_919_primary.wav -> other_5097.wav
# Renamed: other_frog_919_secondary.wav -> other_5098.wav
# Renamed: other_frog_91_primary.wav -> other_5099.wav
# Renamed: other_frog_91_secondary.wav -> other_5100.wav
# Renamed: other_frog_920_primary.wav -> other_5101.wav
# Renamed: other_frog_920_secondary.wav -> other_5102.wav
# Renamed: other_frog_921_primary.wav -> other_5103.wav
# Renamed: other_frog_921_secondary.wav -> other_5104.wav
# Renamed: other_frog_922_primary.wav -> other_5105.wav
# Renamed: other_frog_922_secondary.wav -> other_5106.wav
# Renamed: other_frog_923_primary.wav -> other_5107.wav
# Renamed: other_frog_923_secondary.wav -> other_5108.wav
# Renamed: other_frog_924_primary.wav -> other_5109.wav
# Renamed: other_frog_924_secondary.wav -> other_5110.wav
# Renamed: other_frog_925_primary.wav -> other_5111.wav
# Renamed: other_frog_925_secondary.wav -> other_5112.wav
# Renamed: other_frog_926_primary.wav -> other_5113.wav
# Renamed: other_frog_926_secondary.wav -> other_5114.wav
# Renamed: other_frog_927_primary.wav -> other_5115.wav
# Renamed: other_frog_927_secondary.wav -> other_5116.wav
# Renamed: other_frog_928_primary.wav -> other_5117.wav
# Renamed: other_frog_928_secondary.wav -> other_5118.wav
# Renamed: other_frog_929_primary.wav -> other_5119.wav
# Renamed: other_frog_929_secondary.wav -> other_5120.wav
# Renamed: other_frog_92_primary.wav -> other_5121.wav
# Renamed: other_frog_92_secondary.wav -> other_5122.wav
# Renamed: other_frog_930_primary.wav -> other_5123.wav
# Renamed: other_frog_930_secondary.wav -> other_5124.wav
# Renamed: other_frog_931_primary.wav -> other_5125.wav
# Renamed: other_frog_931_secondary.wav -> other_5126.wav
# Renamed: other_frog_932_primary.wav -> other_5127.wav
# Renamed: other_frog_932_secondary.wav -> other_5128.wav
# Renamed: other_frog_933_primary.wav -> other_5129.wav
# Renamed: other_frog_933_secondary.wav -> other_5130.wav
# Renamed: other_frog_934_primary.wav -> other_5131.wav
# Renamed: other_frog_934_secondary.wav -> other_5132.wav
# Renamed: other_frog_935_primary.wav -> other_5133.wav
# Renamed: other_frog_935_secondary.wav -> other_5134.wav
# Renamed: other_frog_936_primary.wav -> other_5135.wav
# Renamed: other_frog_936_secondary.wav -> other_5136.wav
# Renamed: other_frog_937_primary.wav -> other_5137.wav
# Renamed: other_frog_937_secondary.wav -> other_5138.wav
# Renamed: other_frog_938_primary.wav -> other_5139.wav
# Renamed: other_frog_938_secondary.wav -> other_5140.wav
# Renamed: other_frog_939_primary.wav -> other_5141.wav
# Renamed: other_frog_939_secondary.wav -> other_5142.wav
# Renamed: other_frog_93_primary.wav -> other_5143.wav
# Renamed: other_frog_93_secondary.wav -> other_5144.wav
# Renamed: other_frog_940_primary.wav -> other_5145.wav
# Renamed: other_frog_940_secondary.wav -> other_5146.wav
# Renamed: other_frog_941_primary.wav -> other_5147.wav
# Renamed: other_frog_941_secondary.wav -> other_5148.wav
# Renamed: other_frog_942_primary.wav -> other_5149.wav
# Renamed: other_frog_942_secondary.wav -> other_5150.wav
# Renamed: other_frog_943_primary.wav -> other_5151.wav
# Renamed: other_frog_943_secondary.wav -> other_5152.wav
# Renamed: other_frog_944_primary.wav -> other_5153.wav
# Renamed: other_frog_944_secondary.wav -> other_5154.wav
# Renamed: other_frog_945_primary.wav -> other_5155.wav
# Renamed: other_frog_945_secondary.wav -> other_5156.wav
# Renamed: other_frog_946_primary.wav -> other_5157.wav
# Renamed: other_frog_946_secondary.wav -> other_5158.wav
# Renamed: other_frog_947_primary.wav -> other_5159.wav
# Renamed: other_frog_947_secondary.wav -> other_5160.wav
# Renamed: other_frog_948_primary.wav -> other_5161.wav
# Renamed: other_frog_948_secondary.wav -> other_5162.wav
# Renamed: other_frog_949_primary.wav -> other_5163.wav
# Renamed: other_frog_949_secondary.wav -> other_5164.wav
# Renamed: other_frog_94_primary.wav -> other_5165.wav
# Renamed: other_frog_94_secondary.wav -> other_5166.wav
# Renamed: other_frog_950_primary.wav -> other_5167.wav
# Renamed: other_frog_950_secondary.wav -> other_5168.wav
# Renamed: other_frog_951_primary.wav -> other_5169.wav
# Renamed: other_frog_951_secondary.wav -> other_5170.wav
# Renamed: other_frog_952_primary.wav -> other_5171.wav
# Renamed: other_frog_952_secondary.wav -> other_5172.wav
# Renamed: other_frog_953_primary.wav -> other_5173.wav
# Renamed: other_frog_953_secondary.wav -> other_5174.wav
# Renamed: other_frog_954_primary.wav -> other_5175.wav
# Renamed: other_frog_954_secondary.wav -> other_5176.wav
# Renamed: other_frog_955_primary.wav -> other_5177.wav
# Renamed: other_frog_955_secondary.wav -> other_5178.wav
# Renamed: other_frog_956_primary.wav -> other_5179.wav
# Renamed: other_frog_956_secondary.wav -> other_5180.wav
# Renamed: other_frog_957_primary.wav -> other_5181.wav
# Renamed: other_frog_957_secondary.wav -> other_5182.wav
# Renamed: other_frog_958_primary.wav -> other_5183.wav
# Renamed: other_frog_958_secondary.wav -> other_5184.wav
# Renamed: other_frog_959_primary.wav -> other_5185.wav
# Renamed: other_frog_959_secondary.wav -> other_5186.wav
# Renamed: other_frog_95_primary.wav -> other_5187.wav
# Renamed: other_frog_95_secondary.wav -> other_5188.wav
# Renamed: other_frog_960_primary.wav -> other_5189.wav
# Renamed: other_frog_960_secondary.wav -> other_5190.wav
# Renamed: other_frog_961_primary.wav -> other_5191.wav
# Renamed: other_frog_961_secondary.wav -> other_5192.wav
# Renamed: other_frog_962_primary.wav -> other_5193.wav
# Renamed: other_frog_962_secondary.wav -> other_5194.wav
# Renamed: other_frog_963_primary.wav -> other_5195.wav
# Renamed: other_frog_963_secondary.wav -> other_5196.wav
# Renamed: other_frog_964_primary.wav -> other_5197.wav
# Renamed: other_frog_964_secondary.wav -> other_5198.wav
# Renamed: other_frog_966_primary.wav -> other_5199.wav
# Renamed: other_frog_966_secondary.wav -> other_5200.wav
# Renamed: other_frog_967_primary.wav -> other_5201.wav
# Renamed: other_frog_967_secondary.wav -> other_5202.wav
# Renamed: other_frog_968_primary.wav -> other_5203.wav
# Renamed: other_frog_968_secondary.wav -> other_5204.wav
# Renamed: other_frog_969_primary.wav -> other_5205.wav
# Renamed: other_frog_969_secondary.wav -> other_5206.wav
# Renamed: other_frog_96_primary.wav -> other_5207.wav
# Renamed: other_frog_970_primary.wav -> other_5208.wav
# Renamed: other_frog_970_secondary.wav -> other_5209.wav
# Renamed: other_frog_971_primary.wav -> other_5210.wav
# Renamed: other_frog_971_secondary.wav -> other_5211.wav
# Renamed: other_frog_972_primary.wav -> other_5212.wav
# Renamed: other_frog_972_secondary.wav -> other_5213.wav
# Renamed: other_frog_973_primary.wav -> other_5214.wav
# Renamed: other_frog_973_secondary.wav -> other_5215.wav
# Renamed: other_frog_974_primary.wav -> other_5216.wav
# Renamed: other_frog_974_secondary.wav -> other_5217.wav
# Renamed: other_frog_975_primary.wav -> other_5218.wav
# Renamed: other_frog_975_secondary.wav -> other_5219.wav
# Renamed: other_frog_976_primary.wav -> other_5220.wav
# Renamed: other_frog_976_secondary.wav -> other_5221.wav
# Renamed: other_frog_977_primary.wav -> other_5222.wav
# Renamed: other_frog_977_secondary.wav -> other_5223.wav
# Renamed: other_frog_978_primary.wav -> other_5224.wav
# Renamed: other_frog_978_secondary.wav -> other_5225.wav
# Renamed: other_frog_979_primary.wav -> other_5226.wav
# Renamed: other_frog_979_secondary.wav -> other_5227.wav
# Renamed: other_frog_97_primary.wav -> other_5228.wav
# Renamed: other_frog_97_secondary.wav -> other_5229.wav
# Renamed: other_frog_980_primary.wav -> other_5230.wav
# Renamed: other_frog_980_secondary.wav -> other_5231.wav
# Renamed: other_frog_981_primary.wav -> other_5232.wav
# Renamed: other_frog_981_secondary.wav -> other_5233.wav
# Renamed: other_frog_982_primary.wav -> other_5234.wav
# Renamed: other_frog_982_secondary.wav -> other_5235.wav
# Renamed: other_frog_983_primary.wav -> other_5236.wav
# Renamed: other_frog_983_secondary.wav -> other_5237.wav
# Renamed: other_frog_984_primary.wav -> other_5238.wav
# Renamed: other_frog_984_secondary.wav -> other_5239.wav
# Renamed: other_frog_985_primary.wav -> other_5240.wav
# Renamed: other_frog_985_secondary.wav -> other_5241.wav
# Renamed: other_frog_986_primary.wav -> other_5242.wav
# Renamed: other_frog_986_secondary.wav -> other_5243.wav
# Renamed: other_frog_987_primary.wav -> other_5244.wav
# Renamed: other_frog_987_secondary.wav -> other_5245.wav
# Renamed: other_frog_988_primary.wav -> other_5246.wav
# Renamed: other_frog_988_secondary.wav -> other_5247.wav
# Renamed: other_frog_989_primary.wav -> other_5248.wav
# Renamed: other_frog_989_secondary.wav -> other_5249.wav
# Renamed: other_frog_98_primary.wav -> other_5250.wav
# Renamed: other_frog_98_secondary.wav -> other_5251.wav
# Renamed: other_frog_990_primary.wav -> other_5252.wav
# Renamed: other_frog_990_secondary.wav -> other_5253.wav
# Renamed: other_frog_991_primary.wav -> other_5254.wav
# Renamed: other_frog_991_secondary.wav -> other_5255.wav
# Renamed: other_frog_992_primary.wav -> other_5256.wav
# Renamed: other_frog_992_secondary.wav -> other_5257.wav
# Renamed: other_frog_993_primary.wav -> other_5258.wav
# Renamed: other_frog_993_secondary.wav -> other_5259.wav
# Renamed: other_frog_994_primary.wav -> other_5260.wav
# Renamed: other_frog_994_secondary.wav -> other_5261.wav
# Renamed: other_frog_995_primary.wav -> other_5262.wav
# Renamed: other_frog_995_secondary.wav -> other_5263.wav
# Renamed: other_frog_996_primary.wav -> other_5264.wav
# Renamed: other_frog_996_secondary.wav -> other_5265.wav
# Renamed: other_frog_997_primary.wav -> other_5266.wav
# Renamed: other_frog_997_secondary.wav -> other_5267.wav
# Renamed: other_frog_998_primary.wav -> other_5268.wav
# Renamed: other_frog_998_secondary.wav -> other_5269.wav
# Renamed: other_frog_999_primary.wav -> other_5270.wav
# Renamed: other_frog_999_secondary.wav -> other_5271.wav
# Renamed: other_frog_99_primary.wav -> other_5272.wav
# Renamed: other_frog_99_secondary.wav -> other_5273.wav
# Renamed: other_frog_9_primary.wav -> other_5274.wav
# Renamed: other_frog_9_secondary.wav -> other_5275.wav
# Renaming complete!

# %% [markdown]
# ## Renaming for southern african frog calls set

# %%
import os

# Target keywords (case-insensitive)
keywords = ['Banded', 'Clicking', 'De', 'Eastern', 'Mountain', 'Painted', 
            'Peninsula', 'Rain', 'Southern', 'Weale', 'none', 'other']

# Directory containing files
directory = '../Datasets/old/calls/'  # Current directory (change if needed)

# Counters for each keyword
counters = {keyword: 1 for keyword in keywords}

# Iterate through files
for filename in os.listdir(directory):
    if filename.endswith('.wav'):
        lower_filename = filename.lower()
        matched_keyword = None
        
        # Check for keyword matches
        for keyword in keywords:
            if keyword.lower() in lower_filename:
                matched_keyword = keyword
                break
        
        # If no keyword matched, default to 'other'
        if not matched_keyword:
            matched_keyword = 'other'
        
        # Generate new filename
        new_name = f"{matched_keyword}__{counters[matched_keyword]}.wav"
        counters[matched_keyword] += 1
        
        # Rename the file
        old_path = os.path.join(directory, filename)
        new_path = os.path.join(directory, new_name)
        
        os.rename(old_path, new_path)
        print(f"Renamed: {filename} → {new_name}")
# Out:
# Renamed: Eastern_1.wav → Eastern__1.wav
# Renamed: other_19.wav → other__1.wav
# Renamed: other_41.wav → other__2.wav
# Renamed: Rain_3.wav → Rain__1.wav
# Renamed: Rain_15.wav → Rain__2.wav
# Renamed: Rain_8.wav → Rain__3.wav
# Renamed: other_42.wav → other__3.wav
# Renamed: other_33.wav → other__4.wav
# Renamed: other_53.wav → other__5.wav
# Renamed: other_99.wav → other__6.wav
# Renamed: other_52.wav → other__7.wav
# Renamed: other_37.wav → other__8.wav
# Renamed: Rain_4.wav → Rain__4.wav
# Renamed: other_4.wav → other__9.wav
# Renamed: Southern_2.wav → Southern__1.wav
# Renamed: other_100.wav → other__10.wav
# Renamed: Southern_1.wav → Southern__2.wav
# Renamed: other_45.wav → other__11.wav
# Renamed: De_6.wav → De__1.wav
# Renamed: other_32.wav → other__12.wav
# Renamed: other_91.wav → other__13.wav
# Renamed: Rain_19.wav → Rain__5.wav
# Renamed: other_61.wav → other__14.wav
# Renamed: other_71.wav → other__15.wav
# Renamed: Peninsula_1.wav → Peninsula__1.wav
# Renamed: other_79.wav → other__16.wav
# Renamed: Rain_14.wav → Rain__6.wav
# Renamed: other_57.wav → other__17.wav
# Renamed: De_3.wav → De__2.wav
# Renamed: other_40.wav → other__18.wav
# Renamed: other_13.wav → other__19.wav
# Renamed: other_78.wav → other__20.wav
# Renamed: other_95.wav → other__21.wav
# Renamed: De_8.wav → De__3.wav
# Renamed: other_88.wav → other__22.wav
# Renamed: other_20.wav → other__23.wav
# Renamed: other_83.wav → other__24.wav
# Renamed: other_21.wav → other__25.wav
# Renamed: other_90.wav → other__26.wav
# Renamed: other_104.wav → other__27.wav
# Renamed: Rain_11.wav → Rain__7.wav
# Renamed: Rain_16.wav → Rain__8.wav
# Renamed: other_92.wav → other__28.wav
# Renamed: Eastern_2.wav → Eastern__2.wav
# Renamed: other_74.wav → other__29.wav
# Renamed: Rain_1.wav → Rain__9.wav
# Renamed: De_4.wav → De__4.wav
# Renamed: Eastern_3.wav → Eastern__3.wav
# Renamed: other_108.wav → other__30.wav
# Renamed: other_36.wav → other__31.wav
# Renamed: other_66.wav → other__32.wav
# Renamed: other_115.wav → other__33.wav
# Renamed: other_80.wav → other__34.wav
# Renamed: other_15.wav → other__35.wav
# Renamed: De_7.wav → De__5.wav
# Renamed: other_112.wav → other__36.wav
# Renamed: other_25.wav → other__37.wav
# Renamed: other_10.wav → other__38.wav
# Renamed: other_27.wav → other__39.wav
# Renamed: other_101.wav → other__40.wav
# Renamed: other_12.wav → other__41.wav
# Renamed: other_69.wav → other__42.wav
# Renamed: other_11.wav → other__43.wav
# Renamed: other_55.wav → other__44.wav
# Renamed: Banded_2.wav → Banded__1.wav
# Renamed: other_59.wav → other__45.wav
# Renamed: other_86.wav → other__46.wav
# Renamed: other_3.wav → other__47.wav
# Renamed: Banded_1.wav → Banded__2.wav
# Renamed: other_17.wav → other__48.wav
# Renamed: other_29.wav → other__49.wav
# Renamed: other_113.wav → other__50.wav
# Renamed: Rain_6.wav → Rain__10.wav
# Renamed: Mountain_3.wav → Mountain__1.wav
# Renamed: other_89.wav → other__51.wav
# Renamed: other_56.wav → other__52.wav
# Renamed: other_98.wav → other__53.wav
# Renamed: other_67.wav → other__54.wav
# Renamed: other_73.wav → other__55.wav
# Renamed: other_63.wav → other__56.wav
# Renamed: other_81.wav → other__57.wav
# Renamed: other_72.wav → other__58.wav
# Renamed: other_47.wav → other__59.wav
# Renamed: other_44.wav → other__60.wav
# Renamed: other_35.wav → other__61.wav
# Renamed: other_48.wav → other__62.wav
# Renamed: other_6.wav → other__63.wav
# Renamed: other_7.wav → other__64.wav
# Renamed: other_22.wav → other__65.wav
# Renamed: other_34.wav → other__66.wav
# Renamed: Rain_7.wav → Rain__11.wav
# Renamed: De_9.wav → De__6.wav
# Renamed: other_24.wav → other__67.wav
# Renamed: Rain_5.wav → Rain__12.wav
# Renamed: other_28.wav → other__68.wav
# Renamed: other_93.wav → other__69.wav
# Renamed: other_30.wav → other__70.wav
# Renamed: other_38.wav → other__71.wav
# Renamed: other_8.wav → other__72.wav
# Renamed: other_76.wav → other__73.wav
# Renamed: De_5.wav → De__7.wav
# Renamed: other_109.wav → other__74.wav
# Renamed: Mountain_1.wav → Mountain__2.wav
# Renamed: other_5.wav → other__75.wav
# Renamed: other_68.wav → other__76.wav
# Renamed: other_31.wav → other__77.wav
# Renamed: other_94.wav → other__78.wav
# Renamed: De_1.wav → De__8.wav
# Renamed: other_26.wav → other__79.wav
# Renamed: other_96.wav → other__80.wav
# Renamed: Banded_3.wav → Banded__3.wav
# Renamed: other_110.wav → other__81.wav
# Renamed: other_9.wav → other__82.wav
# Renamed: Southern_3.wav → Southern__3.wav
# Renamed: other_75.wav → other__83.wav
# Renamed: other_39.wav → other__84.wav
# Renamed: Mountain_2.wav → Mountain__3.wav
# Renamed: other_87.wav → other__85.wav
# Renamed: other_54.wav → other__86.wav
# Renamed: other_58.wav → other__87.wav
# Renamed: other_16.wav → other__88.wav
# Renamed: other_84.wav → other__89.wav
# Renamed: other_14.wav → other__90.wav
# Renamed: other_64.wav → other__91.wav
# Renamed: Painted_1.wav → Painted__1.wav
# Renamed: other_65.wav → other__92.wav
# Renamed: other_51.wav → other__93.wav
# Renamed: other_46.wav → other__94.wav
# Renamed: other_77.wav → other__95.wav
# Renamed: Clicking_1.wav → Clicking__1.wav
# Renamed: Rain_18.wav → Rain__13.wav
# Renamed: other_82.wav → other__96.wav
# Renamed: other_102.wav → other__97.wav
# Renamed: other_116.wav → other__98.wav
# Renamed: Rain_9.wav → Rain__14.wav
# Renamed: other_18.wav → other__99.wav
# Renamed: Rain_2.wav → Rain__15.wav
# Renamed: Rain_13.wav → Rain__16.wav
# Renamed: other_105.wav → other__100.wav
# Renamed: other_111.wav → other__101.wav
# Renamed: Southern_4.wav → Southern__4.wav
# Renamed: other_60.wav → other__102.wav
# Renamed: other_114.wav → other__103.wav
# Renamed: other_107.wav → other__104.wav
# Renamed: De_2.wav → De__9.wav
# Renamed: other_97.wav → other__105.wav
# Renamed: other_49.wav → other__106.wav
# Renamed: other_85.wav → other__107.wav
# Renamed: other_50.wav → other__108.wav
# Renamed: Mountain_4.wav → Mountain__4.wav
# Renamed: other_23.wav → other__109.wav
# Renamed: Rain_12.wav → Rain__17.wav
# Renamed: other_103.wav → other__110.wav
# Renamed: Rain_10.wav → Rain__18.wav
# Renamed: other_106.wav → other__111.wav
# Renamed: other_62.wav → other__112.wav
# Renamed: Rain_17.wav → Rain__19.wav
# Renamed: other_1.wav → other__113.wav
# Renamed: other_2.wav → other__114.wav
# Renamed: other_70.wav → other__115.wav
# Renamed: other_43.wav → other__116.wav

# %% [markdown]
# ## Convert all of the audio files into Spectrograms and save as .h5

# %%
import os
import numpy as np
import librosa
from joblib import Parallel, delayed
import multiprocessing
import h5py
from tqdm import tqdm
import noisereduce as nr

# Configuration
AUDIO_DIR = "../Datasets/clipped-3.05s/"
OUTPUT_DIR = "../Datasets/"
os.makedirs(OUTPUT_DIR, exist_ok=True)

SAMPLE_RATE = 22050
N_FFT = 1028
HOP_LENGTH = 128
N_MELS = 256

SAMPLE_RATE = 22050
N_FFT = 2048  # FFT window size
HOP_LENGTH = 256  # Hop length
N_MELS = 128  # Number of Mel bands

# Desired spectrogram size
TARGET_HEIGHT = 128
TARGET_WIDTH = 128

def process_file(file, duration=3.05):
    try:
        if file.lower().endswith('.wav'):
            audio_path = os.path.join(AUDIO_DIR, file)
            y, sr = librosa.load(audio_path, sr=SAMPLE_RATE, res_type='kaiser_fast', mono=True)
            
            # Ensure length is an integer
            length = int(duration * sr)  # Cast length to integer
            
            # Clip the audio around the center
            y_clipped = y[len(y)//2 - length//2 : len(y)//2 + length//2]
            
            # Generate Mel spectrogram
            S = librosa.feature.melspectrogram(y=y_clipped, sr=sr, n_fft=N_FFT, hop_length=HOP_LENGTH, n_mels=N_MELS)
            S_dB = librosa.power_to_db(S, ref=np.max)
            
            # Resize to target size
            S_resized = librosa.util.fix_length(S_dB, size=TARGET_WIDTH, axis=-1)[:TARGET_HEIGHT, :]
            
            key = os.path.splitext(file)[0]
            return key, S_resized
    except Exception as e:
        print(f"\nSkipped {file}: {str(e)}")
        return None

# Get list of files first for accurate tqdm progress
files = [f for f in os.listdir(AUDIO_DIR) if f.lower().endswith('.wav')]
print(f"Processing {len(files)} audio files...")

batch_size = 500
for i in tqdm(range(0, len(files), batch_size)):
    batch = files[i:i+batch_size]
    results = Parallel(n_jobs=2)(delayed(process_file)(f) for f in batch)
    with h5py.File(os.path.join(OUTPUT_DIR, 'FD_5.1.h5'), 'a') as hf:  # 'a' for append
        for result in results:
            if result is not None:
                key, S_dB = result
                hf.create_dataset(key, data=S_dB)


print(f"\nDone! Spectrograms saved to {OUTPUT_DIR}")
# Out:
# Processing 17930 audio files...
#   0%|          | 0/36 [00:00<?, ?it/s]
#  44%|████▍     | 16/36 [00:37<00:45,  2.26s/it]/home/james/.local/lib/python3.10/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=717
#   warnings.warn(
#  50%|█████     | 18/36 [00:42<00:42,  2.34s/it]/home/james/.local/lib/python3.10/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1797
#   warnings.warn(
#  53%|█████▎    | 19/36 [00:45<00:40,  2.37s/it]/home/james/.local/lib/python3.10/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1478
#   warnings.warn(
#  56%|█████▌    | 20/36 [00:47<00:37,  2.33s/it]/home/james/.local/lib/python3.10/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1841
#   warnings.warn(
# /home/james/.local/lib/python3.10/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=684
#   warnings.warn(
#  86%|████████▌ | 31/36 [01:16<00:14,  2.89s/it]/home/james/.local/lib/python3.10/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=110
#   warnings.warn(
# 100%|██████████| 36/36 [01:31<00:00,  2.55s/it]
# Done! Spectrograms saved to ../Datasets/

# %%
import h5py

# Path to your .h5 file
h5_file_path = 'path/to/your/file.h5'

# Open the HDF5 file
with h5py.File(h5_file_path, 'r') as file:
    # List all the keys (dataset names) in the HDF5 file
    print("Available datasets:", list(file.keys()))
    
    # Assuming you know the dataset name (e.g., the first key in the file)
    # You can print the shape of the dataset to see the matrix size
    dataset_name = list(file.keys())[0]  # or replace with the specific dataset name you want
    dataset = file[dataset_name]
    
    # Print the shape of the spectrogram matrix
    print(f"Shape of the spectrogram matrix: {dataset.shape}")

# %%
import os
import numpy as np
import librosa
from joblib import Parallel, delayed
from tqdm import tqdm
import noisereduce as nr

# Configuration
AUDIO_DIR = "../Datasets/clipped-3.05s/"
OUTPUT_DIR = "../Datasets/"
os.makedirs(OUTPUT_DIR, exist_ok=True)

SAMPLE_RATE = 22050
N_FFT = 1028
HOP_LENGTH = 128
N_MELS = 256

def process_file(file):
    try:
        if file.lower().endswith('.wav'):
            audio_path = os.path.join(AUDIO_DIR, file)
            y, sr = librosa.load(audio_path, sr=SAMPLE_RATE, res_type='kaiser_fast', mono=True)
            y = nr.reduce_noise(y=y, sr=sr)
            S = librosa.feature.melspectrogram(
                y=y, sr=sr, n_fft=N_FFT, hop_length=HOP_LENGTH, n_mels=N_MELS
            )
            S_dB = librosa.power_to_db(S, ref=np.max)
            key = os.path.splitext(file)[0]
            return key, S_dB
    except Exception as e:
        print(f"\nSkipped {file}: {str(e)}")
        return None

# Get list of files
files = [f for f in os.listdir(AUDIO_DIR) if f.lower().endswith('.wav')]
print(f"Processing {len(files)} audio files...")

batch_size = 500
for i in tqdm(range(0, len(files), batch_size), desc="Batches"):
    batch = files[i:i+batch_size]
    results = Parallel(n_jobs=2)(delayed(process_file)(f) for f in batch)

    # Collect valid results into dict
    spectros = {key: S_dB for key, S_dB in results if result is not None for key, S_dB in [result]}

    if spectros:
        npz_path = os.path.join(OUTPUT_DIR, f"FD_5.0_batch{i//batch_size}.npz")
        np.savez_compressed(npz_path, **spectros)

print(f"\nDone! Spectrograms saved as NPZ files in {OUTPUT_DIR}")
# Out:
# Processing 17930 audio files...
# Batches:   0%|          | 0/36 [00:00<?, ?it/s]/home/james/.local/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Batches:   3%|▎         | 1/36 [00:25<14:51, 25.46s/it]/home/james/.local/lib/python3.10/site-packages/noisereduce/spectralgate/nonstationary.py:70: RuntimeWarning: invalid value encountered in divide
#   sig_mult_above_thresh = (abs_sig_stft - sig_stft_smooth) / sig_stft_smooth
# Skipped other_264.wav: Audio buffer is not finite everywhere
# Batches:   3%|▎         | 1/36 [00:47<27:49, 47.70s/it]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 44
#      41 results = Parallel(n_jobs=2)(delayed(process_file)(f) for f in batch)
#      43 # Collect valid results into dict
# ---> 44 spectros = {key: S_dB for key, S_dB in results if result is not None for key, S_dB in [result]}
#      46 if spectros:
#      47     npz_path = os.path.join(OUTPUT_DIR, f"FD_5.0_batch{i//batch_size}.npz")
#
# Cell In[6], line 44, in <dictcomp>(.0)
#      41 results = Parallel(n_jobs=2)(delayed(process_file)(f) for f in batch)
#      43 # Collect valid results into dict
# ---> 44 spectros = {key: S_dB for key, S_dB in results if result is not None for key, S_dB in [result]}
#      46 if spectros:
#      47     npz_path = os.path.join(OUTPUT_DIR, f"FD_5.0_batch{i//batch_size}.npz")
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
import os
import numpy as np
import librosa
from joblib import Parallel, delayed
import multiprocessing
from tqdm import tqdm
import random
import noisereduce as nr

# Configuration
AUDIO_DIR = "../Datasets/clipped-3.05s/"
OUTPUT_DIR = "../Datasets/folds_10_5.0/"
os.makedirs(OUTPUT_DIR, exist_ok=True)

SAMPLE_RATE = 22050
N_FFT = 1028
HOP_LENGTH = 512
N_MELS = 256

def process_file(file):
    try:
        if file.lower().endswith('.wav'):
            audio_path = os.path.join(AUDIO_DIR, file)
            y, sr = librosa.load(audio_path, sr=SAMPLE_RATE, res_type='kaiser_fast', mono=True)
            # y = nr.reduce_noise(y=y, sr=sr) 
            S = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=N_FFT, hop_length=HOP_LENGTH, n_mels=N_MELS)
            S_dB = librosa.power_to_db(S, ref=np.max)
            key = os.path.splitext(file)[0]
            return key, S_dB
    except Exception as e:
        print(f"\nSkipped {file}: {str(e)}")
        return None

def create_batches(files, num_batches):
    # Shuffle all files randomly
    random.shuffle(files)
    
    # Calculate batch size
    batch_size = len(files) // num_batches
    remaining_files = len(files) % num_batches
    
    batches = []
    
    # Create batches of size 'batch_size'
    for i in range(num_batches):
        if i < remaining_files:
            # Add an extra file to the first 'remaining_files' batches
            batches.append(files[i * (batch_size + 1):(i + 1) * (batch_size + 1)])
        else:
            batches.append(files[i * batch_size + remaining_files:(i + 1) * batch_size + remaining_files])
    
    return batches

# Get list of files first for accurate tqdm progress
files = [f for f in os.listdir(AUDIO_DIR) if f.lower().endswith('.wav')]
print(f"Processing {len(files)} audio files...")

# Create exactly 11 batches
num_batches = 11
batches = create_batches(files, num_batches)

# Process and save spectrograms for each batch
for i, batch in tqdm(enumerate(batches), total=len(batches)):
    results = Parallel(n_jobs=multiprocessing.cpu_count() - 1)(delayed(process_file)(f) for f in batch)
    
    # Save the results into an .npz file
    npz_filename = os.path.join(OUTPUT_DIR, f'shard{i}.npz')
    spectrograms = {}
    
    for result in results:
        if result is not None:
            key, S_dB = result
            spectrograms[key] = S_dB

    # Save all spectrograms in a single .npz file
    if spectrograms:
        np.savez(npz_filename, **spectrograms)

print(f"\nDone! Spectrograms saved to {OUTPUT_DIR}")
# Out:
# Processing 17930 audio files...
# 100%|██████████| 11/11 [00:31<00:00,  2.84s/it]
# Done! Spectrograms saved to ../Datasets/folds_10_5.0/
