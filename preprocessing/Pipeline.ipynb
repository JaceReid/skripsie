# %% [markdown]
# # Data Preproccesing for CNN Model

# %% [markdown]
# ## Data Downloader from iNaturlist

# %%
import pandas as pd
import requests
import os
from urllib.parse import urlparse
from tqdm import tqdm  # Import tqdm for the progress bar

# Read the CSV file
df = pd.read_csv('../Datasets/Inat/observations-all-recordings.csv/observations-598206.csv')

# Create a directory to save the sound files
os.makedirs('frog_sounds', exist_ok=True)

# Helper function to generate a unique filename
def get_unique_filename(directory, base_name, extension):
    full_path = os.path.join(directory, base_name + extension)
    counter = 1
    while os.path.exists(full_path):
        full_path = os.path.join(directory, f"{base_name}_{counter}{extension}")
        counter += 1
    return full_path

# Create a progress bar for the total number of downloads
with tqdm(total=len(df), desc="Downloading frog sounds") as pbar:
    # Iterate through each row in the DataFrame
    for index, row in df.iterrows():
        sound_url = row['sound_url']
        common_name = row['common_name']
        
        if pd.notna(sound_url) and pd.notna(common_name):
            try:
                # Extract the file extension from the URL
                parsed_url = urlparse(sound_url)
                filename = os.path.basename(parsed_url.path)
                extension = os.path.splitext(filename)[1]
                
                # Clean the common name to make it a valid filename
                clean_name = "".join(c if c.isalnum() or c in (' ', '-') else '_' for c in common_name).strip()
                clean_name = clean_name.replace(' ', '_')  # Optional: replace spaces with underscores
                
                # Generate a unique filename
                unique_filename = get_unique_filename('frog_sounds', clean_name, extension)
                
                # Download the file
                response = requests.get(sound_url, stream=True)
                if response.status_code == 200:
                    with open(unique_filename, 'wb') as f:
                        for chunk in response.iter_content(1024):
                            f.write(chunk)
                    # print(f"Downloaded: {unique_filename}")
                else:
                    print(f"Failed to download: {sound_url}")
            except Exception as e:
                print(f"Error processing {sound_url}: {e}")

            # Update the progress bar after each download
            pbar.update(1)

print("Download complete.")

# %% [markdown]
# ## Convert all files into .WAV

# %%
import os
import subprocess
from pathlib import Path
from tqdm import tqdm

def convert_to_spectrogram_ready(input_dir, output_dir, sample_rate=22050, mono=True):
    
    Path(output_dir).mkdir(parents=True, exist_ok=True)
    
    audio_files = []
    extensions = ('.wav', '.mp3', '.mp4', '.m4a', '.aac', '.flac', '.ogg', '.mpga')
    
    for root, _, files in os.walk(input_dir):
        for file in files:
            # if file.lower().endswith(extensions):
                audio_files.append(Path(root) / file)
    
    print(f"Found {len(audio_files)} audio files to process")
    
    for input_file in tqdm(audio_files, desc="Converting for spectrograms"):
        output_file = Path(output_dir) / f"{input_file.stem}.wav"
        
        # Check if file exists and modify name if needed
        counter = 1
        while output_file.exists():
            output_file = Path(output_dir) / f"{input_file.stem}_{counter}.wav"
            counter += 1
        
        cmd = [
            'ffmpeg',
            '-i', str(input_file),
            '-ac', '1' if mono else '2',  # mono recommended for spectrograms
            '-ar', str(sample_rate),  # 22050 is standard for many ML models
            '-sample_fmt', 's16',  # 16-bit PCM
            '-acodec', 'pcm_s16le',  # Standard WAV format
            '-y',  # Still overwrites if same name, but we prevent that with the loop
            str(output_file)
        ]
        
        try:
            subprocess.run(cmd, check=True, 
                         stdout=subprocess.DEVNULL, 
                         stderr=subprocess.PIPE)
        except subprocess.CalledProcessError as e:
            print(f"\nError processing {input_file}: {e.stderr.decode('utf-8')}")
    
    print(f"\nConversion complete. Files ready for spectrogram generation in {output_dir}")

if __name__ == "__main__":
    convert_to_spectrogram_ready(
        input_dir="../Datasets/Raw-audio/none-frog-audio/",
        output_dir="../Datasets/Raw-audio/none-frog-audio/"
    )
# Out:
# Found 4 audio files to process
# Converting for spectrograms: 100%|██████████| 4/4 [00:03<00:00,  1.29it/s]
# Conversion complete. Files ready for spectrogram generation in ../Datasets/Raw-audio/none-frog-audio/

# %% [markdown]
# ## Rename files for only ID 4 most common frogs

# %%
import os
from pathlib import Path
from collections import defaultdict

def rename_frog_files(directory):
    """
    Renames frog audio files according to specific rules:
    - Keeps original names for Mountain_Rain_Frog, Southern_Dainty_Frog, Clicking_Stream_Frog
    - Renames others to other_frog_X.wav with incrementing X
    """
    # Files to keep original names
    KEEP_NAMES = {
        "mountain_rain_frog",
        "southern_dainty_frog",
        "clicking_stream_frog"
    }
    
    # Initialize counter for other_frog files
    other_counter = 1
    # Dictionary to track original name to new name mappings (for avoiding duplicates)
    name_mapping = defaultdict(str)
    
    # Get all .wav files in directory
    for filepath in Path(directory).glob("*.wav"):
        original_name = filepath.stem.lower()  # Get filename without extension
        
        # Check if we should keep original name
        should_keep = any(
            keep_name in original_name 
            for keep_name in KEEP_NAMES
        )
        
        if should_keep:
            continue  # Skip renaming
        
        # Generate new name
        new_name = f"other_frog_{other_counter}.wav"
        new_path = filepath.with_name(new_name)
        
        # Handle potential name conflicts
        while new_path.exists():
            other_counter += 1
            new_name = f"other_frog_{other_counter}.wav"
            new_path = filepath.with_name(new_name)
        
        # Rename the file
        filepath.rename(new_path)
        print(f"Renamed: {filepath.name} -> {new_name}")
        other_counter += 1

if __name__ == "__main__":
    directory_path = "./frog_sounds_wav/"  # Change to your directory
    rename_frog_files(directory_path)
    print("File renaming complete!")

# %% [markdown]
# ## Get file Info

# %%
import os
from pathlib import Path
import wave
import contextlib
from collections import defaultdict

def analyze_short_frog_files(directory, max_duration=4):
    """
    Finds all WAV files shorter than specified duration and counts by frog type.
    
    Args:
        directory (str): Path to directory containing WAV files
        max_duration (float): Maximum duration in seconds to consider as "short"
        
    Returns:
        tuple: (list of short files with durations, frog type counts, total count)
    """
    short_files = []
    frog_counts = defaultdict(int)
    special_frogs = {
        'mountain_rain_frog',
        'southern_dainty_frog',
        'clicking_stream_frog'
    }

    for filepath in Path(directory).glob('*.wav'):
        try:
            with contextlib.closing(wave.open(str(filepath), 'r')) as wav_file:
                frames = wav_file.getnframes()
                rate = wav_file.getframerate()
                duration = frames / float(rate)
                
                if duration < max_duration:
                    filename = filepath.stem.lower()
                    
                    # Determine frog type
                    frog_type = "other"
                    for special in special_frogs:
                        if special in filename:
                            frog_type = special.replace('_', ' ').title()
                            break
                    
                    short_files.append((filepath.name, duration, frog_type))
                    frog_counts[frog_type] += 1
                    
        except (wave.Error, EOFError) as e:
            print(f"Error processing {filepath.name}: {str(e)}")
            continue
    
    return short_files, frog_counts, len(short_files)

if __name__ == "__main__":
    folder_path = "./frog_sounds_wav/"  # Replace with your folder path
    try:
        short_files, frog_counts, total_count = analyze_short_frog_files(folder_path)
        
        if not short_files:
            print("No files shorter than 5 seconds found.")
        else:
            print("Files shorter than 5 seconds:")
            print("-" * 65)
            print(f"{'Filename':<40} {'Duration':<10} {'Frog Type':<15}")
            print("-" * 65)
            for filename, duration, frog_type in short_files:
                print(f"{filename:<40} {duration:.2f}s{'':<5} {frog_type:<15}")
            
            print("-" * 65)
            print("\nFrog Type Counts:")
            for frog_type, count in sorted(frog_counts.items(), key=lambda x: x[1], reverse=True):
                print(f"{frog_type:<20}: {count}")
            
            print("-" * 65)
            print(f"Total files shorter than 5 seconds: {total_count}")
            
    except Exception as e:
        print(f"Error: {str(e)}")
# Out:
# Files shorter than 5 seconds:
# -----------------------------------------------------------------
# Filename                                 Duration   Frog Type
# -----------------------------------------------------------------
# other_frog_1818.wav                      3.01s      other
# other_frog_3281.wav                      2.40s      other
# other_frog_2736.wav                      2.53s      other
# Clicking_Stream_Frog_191.wav             3.76s      Clicking Stream Frog
# other_frog_269.wav                       3.16s      other
# other_frog_111.wav                       2.03s      other
# other_frog_661.wav                       3.37s      other
# other_frog_962.wav                       3.99s      other
# other_frog_1705.wav                      1.08s      other
# other_frog_523.wav                       1.19s      other
# other_frog_3282.wav                      1.21s      other
# other_frog_2594.wav                      0.40s      other
# other_frog_2158.wav                      2.09s      other
# other_frog_2325.wav                      3.40s      other
# other_frog_44.wav                        2.56s      other
# other_frog_1145.wav                      3.75s      other
# other_frog_2582.wav                      3.43s      other
# other_frog_3202.wav                      3.78s      other
# other_frog_3169.wav                      3.41s      other
# other_frog_2925.wav                      3.05s      other
# other_frog_1180.wav                      3.36s      other
# other_frog_780.wav                       3.72s      other
# other_frog_2543.wav                      2.19s      other
# Clicking_Stream_Frog_59.wav              3.60s      Clicking Stream Frog
# other_frog_2133.wav                      1.01s      other
# other_frog_2928.wav                      3.76s      other
# other_frog_703.wav                       3.65s      other
# other_frog_2487.wav                      3.03s      other
# other_frog_594.wav                       3.46s      other
# Clicking_Stream_Frog_43.wav              2.65s      Clicking Stream Frog
# other_frog_1375.wav                      3.58s      other
# other_frog_1146.wav                      1.25s      other
# other_frog_2326.wav                      3.44s      other
# other_frog_2196.wav                      3.74s      other
# other_frog_1225.wav                      2.83s      other
# other_frog_2927.wav                      3.41s      other
# other_frog_2628.wav                      3.99s      other
# other_frog_379.wav                       3.20s      other
# Clicking_Stream_Frog_199.wav             3.48s      Clicking Stream Frog
# other_frog_3425.wav                      2.02s      other
# other_frog_10.wav                        3.74s      other
# other_frog_1510.wav                      2.81s      other
# other_frog_1990.wav                      1.98s      other
# other_frog_3423.wav                      2.93s      other
# other_frog_338.wav                       2.37s      other
# other_frog_214.wav                       1.26s      other
# other_frog_1367.wav                      3.79s      other
# other_frog_2948.wav                      3.04s      other
# Clicking_Stream_Frog_439.wav             3.25s      Clicking Stream Frog
# other_frog_1547.wav                      1.02s      other
# Clicking_Stream_Frog_24.wav              2.30s      Clicking Stream Frog
# Clicking_Stream_Frog_317.wav             2.93s      Clicking Stream Frog
# other_frog_424.wav                       1.28s      other
# other_frog_2637.wav                      3.90s      other
# other_frog_3316.wav                      3.82s      other
# Mountain_Rain_Frog_3.wav                 2.30s      Mountain Rain Frog
# other_frog_2774.wav                      1.51s      other
# other_frog_1229.wav                      3.29s      other
# -----------------------------------------------------------------
#
# Frog Type Counts:
# other               : 50
# Clicking Stream Frog: 7
# Mountain Rain Frog  : 1
# -----------------------------------------------------------------
# Total files shorter than 5 seconds: 58

# %%
import os
import csv
from collections import defaultdict
from pathlib import Path

def analyze_frog_recordings(directory_path, min_threshold=100000):
    """
    Analyze frog recordings to find species with few recordings.
    
    Args:
        directory_path: Path to directory containing audio files
        min_threshold: Minimum number of recordings to not be considered "few"
    
    Returns:
        dict: {frog_species: count} for species with fewer than min_threshold recordings
    """
    # Initialize dictionary to store counts
    frog_counts = defaultdict(int)
    
    # Supported audio file extensions
    audio_extensions = {'.wav'}
    
    # Count recordings per frog species
    for file in Path(directory_path).iterdir():
        if file.suffix.lower() in audio_extensions:
            # Extract frog species name (handling formats like "common_name_number" or "common_name_number_primary")
            frog_species = file.stem.split('_', 1)[0]
            frog_counts[frog_species] += 1
            
            # # Case 1: common_name_number
            # if len(parts) >= 2 and parts[-1].isdigit():
            #     frog_species = '_'.join(parts[:-1])
            #     frog_counts[frog_species] += 1
            # # Case 2: common_name_number_primary/secondary
            # elif len(parts) == 3 and parts[1].isdigit() and parts[2] in ['primary', 'secondary']:
            #     frog_species = parts[0]
            #     frog_counts[frog_species] += 1

            # print(frog_species)
    
    # Filter for species with few recordings
    few_recordings = {
        species: count 
        for species, count in frog_counts.items() 
        # if count < min_threshold
    }
    
    return few_recordings

def print_frog_report(few_recordings, output_csv=None):
    """Print a formatted report of frogs with few recordings and optionally save to CSV."""
    if not few_recordings:
        print("All frog species have sufficient recordings (10 or more each).")
        if output_csv:
            with open(output_csv, 'w', newline='') as csvfile:
                writer = csv.writer(csvfile)
                writer.writerow(["Species", "Recording Count"])
                writer.writerow(["All species have sufficient recordings", ""])
        return
    
    # Print console report
    print("Frog species with fewer than 10 recordings:")
    print("-" * 45)
    for species, count in sorted(few_recordings.items(), key=lambda item: (item[1], item[0])):
        print(f"{species.ljust(30)}: {count} recording{'s' if count != 1 else ''}")
    print("-" * 45)
    print(f"Total under-represented species: {len(few_recordings)}")
    
    # Save to CSV if requested
    if output_csv:
        with open(output_csv, 'w', newline='') as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow(["Species", "Recording Count"])
            for species, count in sorted(few_recordings.items(), key=lambda item: (item[1], item[0])):
                writer.writerow([species, count])


# Example usage
if __name__ == "__main__":
    directory_path = "../Datasets/clipped-4s/"  # Change this to your directory
    # output_csv = "frog_recording_report.csv"  # Output CSV filename
    few_recordings = analyze_frog_recordings(directory_path, min_threshold=10)
    print_frog_report(few_recordings)
# Out:
# Frog species with fewer than 10 recordings:
# ---------------------------------------------
# none                          : 876 recordings
# Clicking                      : 939 recordings
# Southern                      : 1583 recordings
# Mountain                      : 2687 recordings
# other                         : 6878 recordings
# ---------------------------------------------
# Total under-represented species: 5

# %% [markdown]
# ## Clip files to 4 seconds

# %%
import os
import numpy as np
from pathlib import Path
from scipy.io import wavfile

def process_audio_files(input_dir, output_dir="../Datasets/clipped_4sec/"):
    """
    Process mono audio files:
    - For files >4 seconds: create 4-second clip centered at max amplitude
    - For files <=4 seconds: copy as-is to output directory
    - All files saved to output directory
    """
    input_path = Path(input_dir)
    output_path = Path(output_dir)
    
    output_path.mkdir(exist_ok=True)
    
    processed_count = 0
    clipped_count = 0
    copied_count = 0
    
    for filepath in input_path.glob('*.wav'):
        try:
            # Read WAV file (mono)
            sample_rate, data = wavfile.read(filepath)
            
            # Ensure mono audio
            if len(data.shape) > 1:
                print(f"Skipping {filepath.name} - stereo audio not supported")
                continue
            
            duration = len(data) / sample_rate
            output_file = output_path / filepath.name
            
            if duration <= 4.0:
                # For short files, just copy to output directory
                wavfile.write(output_file, sample_rate, data)
                copied_count += 1
                print(f"Copied: {filepath.name} ({duration:.2f}s)")
            else:
                # Find point of max amplitude
                abs_data = np.abs(data)
                
                # Find all peaks sorted by amplitude
                
                sorted_indices = np.argsort(abs_data)
                max_idx = sorted_indices[-1]
                
                # Calculate 4-second exclusion zone around max peak
                
                half_window = int(2 * sample_rate)
                exclusion_start = max(0, max_idx - half_window)
                exclusion_end = min(len(data), max_idx + half_window)
                
                # Create mask for valid regions (outside exclusion zone)
                
                valid_mask = np.ones(len(data), dtype=bool)
                valid_mask[exclusion_start:exclusion_end] = False
                
                # Find secondary peak outside exclusion zone
                
                if np.any(valid_mask):
                    
                    # Create modified data where excluded region is set to minimum value
                    
                    modified_data = abs_data.copy()
                    modified_data[~valid_mask] = 0
                    second_max_idx = np.argmax(modified_data)
    
                    # Only accept if secondary peak is at least 10% as loud as primary
                    
                    if abs_data[second_max_idx] < 0.1 * abs_data[max_idx]:
                        second_max_idx = None
                
                else:
                    second_max_idx = None

                # Create 4-second clip around primary peak
                start = max(0, max_idx - half_window)
                end = min(len(data), max_idx + half_window)

                # Adjust if window exceeds file length
                
                if end - start < 4 * sample_rate:
                    if start == 0:
                        end = min(len(data), 4 * sample_rate)
                    else:
                        start = max(0, len(data) - 4 * sample_rate)

                clipped_data = data[start:end]

                # Optional: Create secondary clip if valid secondary peak exists
                
                if second_max_idx is not None:
                    sec_start = max(0, second_max_idx - half_window)
                    sec_end = min(len(data), second_max_idx + half_window)
    
                    # Adjust secondary clip window if needed
                    
                    if sec_end - sec_start < 4 * sample_rate:
                        if sec_start == 0:
                            sec_end = min(len(data), 4 * sample_rate)
                        else:
                            sec_start = max(0, len(data) - 4 * sample_rate)
    
                    secondary_clip = data[sec_start:sec_end]
                else:
                    secondary_clip = None
                
                # Write primary clip
                primary_clip = data[max(0, max_idx - 2*sample_rate):min(len(data), max_idx + 2*sample_rate)]
                if len(primary_clip) < 4 * sample_rate:
                    pad_before = (4 * sample_rate - len(primary_clip)) // 2
                    pad_after = (4 * sample_rate - len(primary_clip)) - pad_before
                    primary_clip = np.pad(primary_clip, (pad_before, pad_after), mode='constant')
                wavfile.write(f"{output_file.stem}_primary.wav", sample_rate, primary_clip)

                # Write secondary clip if valid
                if second_max_idx is not None:
                    secondary_clip = data[max(0, second_max_idx - 2*sample_rate):min(len(data), second_max_idx + 2*sample_rate)]
                    if len(secondary_clip) < 4 * sample_rate:
                        pad_before = (4 * sample_rate - len(secondary_clip)) // 2
                        pad_after = (4 * sample_rate - len(secondary_clip)) - pad_before
                        secondary_clip = np.pad(secondary_clip, (pad_before, pad_after), mode='constant')
                    wavfile.write(f"{output_file.stem}_secondary.wav", sample_rate, secondary_clip)
                    processed_count += 1
                    clipped_count += 1
                
            processed_count += 1
            clipped_count += 1
            
        except Exception as e:
            print(f"Error processing {filepath.name}: {str(e)}")
            continue
    
    print("\nProcessing complete!")
    print(f"Processed {processed_count} files")
    print(f"- {clipped_count} files clipped to 4 seconds")
    print(f"- {copied_count} files copied as-is (<=4 seconds)")
    print(f"Output directory: {output_path.resolve()}")

if __name__ == "__main__":
    input_directory = "../Datasets/Raw-audio/frog_sounds_wav/" 
    process_audio_files(input_directory)
# Out:
# Copied: other_frog_1818.wav (3.01s)
# Copied: other_frog_3281.wav (2.40s)
# Copied: other_frog_2736.wav (2.53s)
# Copied: Clicking_Stream_Frog_191.wav (3.76s)
# Copied: other_frog_269.wav (3.16s)
# Copied: other_frog_111.wav (2.03s)
# Copied: other_frog_661.wav (3.37s)
# Copied: other_frog_962.wav (3.99s)
# Copied: other_frog_1705.wav (1.08s)
# Copied: other_frog_523.wav (1.19s)
# Copied: other_frog_3282.wav (1.21s)
# Copied: other_frog_2594.wav (0.40s)
# Copied: other_frog_2158.wav (2.09s)
# Copied: other_frog_2325.wav (3.40s)
# Copied: other_frog_44.wav (2.56s)
# Copied: other_frog_1145.wav (3.75s)
# Copied: other_frog_2582.wav (3.43s)
# Copied: other_frog_3202.wav (3.78s)
# Copied: other_frog_3169.wav (3.41s)
# Copied: other_frog_2925.wav (3.05s)
# Copied: other_frog_1180.wav (3.36s)
# Copied: other_frog_780.wav (3.72s)
# Copied: other_frog_2543.wav (2.19s)
# Copied: Clicking_Stream_Frog_59.wav (3.60s)
# Copied: other_frog_2133.wav (1.01s)
# Copied: other_frog_2928.wav (3.76s)
# Copied: other_frog_703.wav (3.65s)
# Copied: other_frog_2487.wav (3.03s)
# Copied: other_frog_594.wav (3.46s)
# Copied: Clicking_Stream_Frog_43.wav (2.65s)
# Copied: other_frog_1375.wav (3.58s)
# Copied: other_frog_1146.wav (1.25s)
# Copied: other_frog_2326.wav (3.44s)
# Copied: other_frog_2196.wav (3.74s)
# Copied: other_frog_1225.wav (2.83s)
# Copied: other_frog_2927.wav (3.41s)
# Copied: other_frog_2628.wav (3.99s)
# Copied: other_frog_379.wav (3.20s)
# Copied: Clicking_Stream_Frog_199.wav (3.48s)
# Copied: other_frog_3425.wav (2.02s)
# Copied: other_frog_10.wav (3.74s)
# Copied: other_frog_1510.wav (2.81s)
# Copied: other_frog_1990.wav (1.98s)
# Copied: other_frog_3423.wav (2.93s)
# Copied: other_frog_338.wav (2.37s)
# Copied: other_frog_214.wav (1.26s)
# Copied: other_frog_1367.wav (3.79s)
# Copied: other_frog_2948.wav (3.04s)
# Copied: Clicking_Stream_Frog_439.wav (3.25s)
# Copied: other_frog_1547.wav (1.02s)
# Copied: Clicking_Stream_Frog_24.wav (2.30s)
# Copied: Clicking_Stream_Frog_317.wav (2.93s)
# Copied: other_frog_424.wav (1.28s)
# Copied: other_frog_2637.wav (3.90s)
# Copied: other_frog_3316.wav (3.82s)
# Copied: Mountain_Rain_Frog_3.wav (2.30s)
# Copied: other_frog_2774.wav (1.51s)
# Copied: other_frog_1229.wav (3.29s)
#
# Processing complete!
# Processed 12147 files
# - 0 files clipped to 4 seconds
# - 58 files copied as-is (<=4 seconds)
# Output directory: /home/james/Documents/semester-2/skripsie/code/Datasets/clipped_4sec

# %% [markdown]
# ## Rename files to first word_number

# %%
import os
import re
from collections import defaultdict

def rename_wav_files(directory):
    # Get all .wav files in the directory
    wav_files = [f for f in os.listdir(directory) if f.lower().endswith('.wav')]
    
    # Sort the files to ensure consistent ordering
    wav_files.sort()
    
    # Dictionary to keep track of counters for each prefix
    counters = defaultdict(int)
    
    for filename in wav_files:
        # Split the filename at the first underscore
        parts = re.split('_', filename, 1)
        
        # Get the first part (before first underscore) or whole filename if no underscore
        prefix = parts[0]
        
        # Increment the counter for this prefix
        counters[prefix] += 1
        
        # Create new filename
        new_name = f"{prefix}_{counters[prefix]}.wav"
        
        # Full paths for old and new names
        old_path = os.path.join(directory, filename)
        new_path = os.path.join(directory, new_name)
        
        # Rename the file
        try:
            os.rename(old_path, new_path)
            print(f"Renamed: {filename} -> {new_name}")
        except OSError as e:
            print(f"Error renaming {filename}: {e}")

if __name__ == "__main__":
    # Get the directory containing the .wav files
    # dir_path = input("Enter the directory path containing .wav files: ").strip()
    dir_path = "../Datasets/clipped-4s/"
    
    # Verify the directory exists
    if os.path.isdir(dir_path):
        rename_wav_files(dir_path)
        print("Renaming complete!")
    else:
        print("Error: The specified directory does not exist.")
# Out:
# Renamed: Clicking_Stream_Frog_100_primary.wav -> Clicking_1.wav
# Renamed: Clicking_Stream_Frog_100_secondary.wav -> Clicking_2.wav
# Renamed: Clicking_Stream_Frog_101_primary.wav -> Clicking_3.wav
# Renamed: Clicking_Stream_Frog_101_secondary.wav -> Clicking_4.wav
# Renamed: Clicking_Stream_Frog_102_primary.wav -> Clicking_5.wav
# Renamed: Clicking_Stream_Frog_102_secondary.wav -> Clicking_6.wav
# Renamed: Clicking_Stream_Frog_103_primary.wav -> Clicking_7.wav
# Renamed: Clicking_Stream_Frog_103_secondary.wav -> Clicking_8.wav
# Renamed: Clicking_Stream_Frog_104_primary.wav -> Clicking_9.wav
# Renamed: Clicking_Stream_Frog_104_secondary.wav -> Clicking_10.wav
# Renamed: Clicking_Stream_Frog_105_primary.wav -> Clicking_11.wav
# Renamed: Clicking_Stream_Frog_105_secondary.wav -> Clicking_12.wav
# Renamed: Clicking_Stream_Frog_106_primary.wav -> Clicking_13.wav
# Renamed: Clicking_Stream_Frog_106_secondary.wav -> Clicking_14.wav
# Renamed: Clicking_Stream_Frog_107_primary.wav -> Clicking_15.wav
# Renamed: Clicking_Stream_Frog_107_secondary.wav -> Clicking_16.wav
# Renamed: Clicking_Stream_Frog_108_primary.wav -> Clicking_17.wav
# Renamed: Clicking_Stream_Frog_108_secondary.wav -> Clicking_18.wav
# Renamed: Clicking_Stream_Frog_109_primary.wav -> Clicking_19.wav
# Renamed: Clicking_Stream_Frog_109_secondary.wav -> Clicking_20.wav
# Renamed: Clicking_Stream_Frog_10_primary.wav -> Clicking_21.wav
# Renamed: Clicking_Stream_Frog_10_secondary.wav -> Clicking_22.wav
# Renamed: Clicking_Stream_Frog_110_primary.wav -> Clicking_23.wav
# Renamed: Clicking_Stream_Frog_110_secondary.wav -> Clicking_24.wav
# Renamed: Clicking_Stream_Frog_111_primary.wav -> Clicking_25.wav
# Renamed: Clicking_Stream_Frog_111_secondary.wav -> Clicking_26.wav
# Renamed: Clicking_Stream_Frog_112_primary.wav -> Clicking_27.wav
# Renamed: Clicking_Stream_Frog_112_secondary.wav -> Clicking_28.wav
# Renamed: Clicking_Stream_Frog_113_primary.wav -> Clicking_29.wav
# Renamed: Clicking_Stream_Frog_113_secondary.wav -> Clicking_30.wav
# Renamed: Clicking_Stream_Frog_114_primary.wav -> Clicking_31.wav
# Renamed: Clicking_Stream_Frog_114_secondary.wav -> Clicking_32.wav
# Renamed: Clicking_Stream_Frog_115_primary.wav -> Clicking_33.wav
# Renamed: Clicking_Stream_Frog_115_secondary.wav -> Clicking_34.wav
# Renamed: Clicking_Stream_Frog_116_primary.wav -> Clicking_35.wav
# Renamed: Clicking_Stream_Frog_116_secondary.wav -> Clicking_36.wav
# Renamed: Clicking_Stream_Frog_117_primary.wav -> Clicking_37.wav
# Renamed: Clicking_Stream_Frog_117_secondary.wav -> Clicking_38.wav
# Renamed: Clicking_Stream_Frog_118_primary.wav -> Clicking_39.wav
# Renamed: Clicking_Stream_Frog_118_secondary.wav -> Clicking_40.wav
# Renamed: Clicking_Stream_Frog_119_primary.wav -> Clicking_41.wav
# Renamed: Clicking_Stream_Frog_11_primary.wav -> Clicking_42.wav
# Renamed: Clicking_Stream_Frog_11_secondary.wav -> Clicking_43.wav
# Renamed: Clicking_Stream_Frog_120_primary.wav -> Clicking_44.wav
# Renamed: Clicking_Stream_Frog_120_secondary.wav -> Clicking_45.wav
# Renamed: Clicking_Stream_Frog_121_primary.wav -> Clicking_46.wav
# Renamed: Clicking_Stream_Frog_121_secondary.wav -> Clicking_47.wav
# Renamed: Clicking_Stream_Frog_122_primary.wav -> Clicking_48.wav
# Renamed: Clicking_Stream_Frog_122_secondary.wav -> Clicking_49.wav
# Renamed: Clicking_Stream_Frog_123_primary.wav -> Clicking_50.wav
# Renamed: Clicking_Stream_Frog_123_secondary.wav -> Clicking_51.wav
# Renamed: Clicking_Stream_Frog_124_primary.wav -> Clicking_52.wav
# Renamed: Clicking_Stream_Frog_124_secondary.wav -> Clicking_53.wav
# Renamed: Clicking_Stream_Frog_125_primary.wav -> Clicking_54.wav
# Renamed: Clicking_Stream_Frog_125_secondary.wav -> Clicking_55.wav
# Renamed: Clicking_Stream_Frog_126_primary.wav -> Clicking_56.wav
# Renamed: Clicking_Stream_Frog_126_secondary.wav -> Clicking_57.wav
# Renamed: Clicking_Stream_Frog_127_primary.wav -> Clicking_58.wav
# Renamed: Clicking_Stream_Frog_127_secondary.wav -> Clicking_59.wav
# Renamed: Clicking_Stream_Frog_128_primary.wav -> Clicking_60.wav
# Renamed: Clicking_Stream_Frog_129_primary.wav -> Clicking_61.wav
# Renamed: Clicking_Stream_Frog_129_secondary.wav -> Clicking_62.wav
# Renamed: Clicking_Stream_Frog_12_primary.wav -> Clicking_63.wav
# Renamed: Clicking_Stream_Frog_130_primary.wav -> Clicking_64.wav
# Renamed: Clicking_Stream_Frog_130_secondary.wav -> Clicking_65.wav
# Renamed: Clicking_Stream_Frog_131_primary.wav -> Clicking_66.wav
# Renamed: Clicking_Stream_Frog_131_secondary.wav -> Clicking_67.wav
# Renamed: Clicking_Stream_Frog_132_primary.wav -> Clicking_68.wav
# Renamed: Clicking_Stream_Frog_132_secondary.wav -> Clicking_69.wav
# Renamed: Clicking_Stream_Frog_133_primary.wav -> Clicking_70.wav
# Renamed: Clicking_Stream_Frog_133_secondary.wav -> Clicking_71.wav
# Renamed: Clicking_Stream_Frog_134_primary.wav -> Clicking_72.wav
# Renamed: Clicking_Stream_Frog_134_secondary.wav -> Clicking_73.wav
# Renamed: Clicking_Stream_Frog_135_primary.wav -> Clicking_74.wav
# Renamed: Clicking_Stream_Frog_135_secondary.wav -> Clicking_75.wav
# Renamed: Clicking_Stream_Frog_136_primary.wav -> Clicking_76.wav
# Renamed: Clicking_Stream_Frog_136_secondary.wav -> Clicking_77.wav
# Renamed: Clicking_Stream_Frog_137_primary.wav -> Clicking_78.wav
# Renamed: Clicking_Stream_Frog_137_secondary.wav -> Clicking_79.wav
# Renamed: Clicking_Stream_Frog_138_primary.wav -> Clicking_80.wav
# Renamed: Clicking_Stream_Frog_138_secondary.wav -> Clicking_81.wav
# Renamed: Clicking_Stream_Frog_139_primary.wav -> Clicking_82.wav
# Renamed: Clicking_Stream_Frog_139_secondary.wav -> Clicking_83.wav
# Renamed: Clicking_Stream_Frog_13_primary.wav -> Clicking_84.wav
# Renamed: Clicking_Stream_Frog_140_primary.wav -> Clicking_85.wav
# Renamed: Clicking_Stream_Frog_140_secondary.wav -> Clicking_86.wav
# Renamed: Clicking_Stream_Frog_141_primary.wav -> Clicking_87.wav
# Renamed: Clicking_Stream_Frog_141_secondary.wav -> Clicking_88.wav
# Renamed: Clicking_Stream_Frog_142_primary.wav -> Clicking_89.wav
# Renamed: Clicking_Stream_Frog_142_secondary.wav -> Clicking_90.wav
# Renamed: Clicking_Stream_Frog_143_primary.wav -> Clicking_91.wav
# Renamed: Clicking_Stream_Frog_143_secondary.wav -> Clicking_92.wav
# Renamed: Clicking_Stream_Frog_144_primary.wav -> Clicking_93.wav
# Renamed: Clicking_Stream_Frog_144_secondary.wav -> Clicking_94.wav
# Renamed: Clicking_Stream_Frog_145_primary.wav -> Clicking_95.wav
# Renamed: Clicking_Stream_Frog_145_secondary.wav -> Clicking_96.wav
# Renamed: Clicking_Stream_Frog_146_primary.wav -> Clicking_97.wav
# Renamed: Clicking_Stream_Frog_146_secondary.wav -> Clicking_98.wav
# Renamed: Clicking_Stream_Frog_147_primary.wav -> Clicking_99.wav
# Renamed: Clicking_Stream_Frog_147_secondary.wav -> Clicking_100.wav
# Renamed: Clicking_Stream_Frog_148_primary.wav -> Clicking_101.wav
# Renamed: Clicking_Stream_Frog_148_secondary.wav -> Clicking_102.wav
# Renamed: Clicking_Stream_Frog_149_primary.wav -> Clicking_103.wav
# Renamed: Clicking_Stream_Frog_149_secondary.wav -> Clicking_104.wav
# Renamed: Clicking_Stream_Frog_14_primary.wav -> Clicking_105.wav
# Renamed: Clicking_Stream_Frog_14_secondary.wav -> Clicking_106.wav
# Renamed: Clicking_Stream_Frog_150_primary.wav -> Clicking_107.wav
# Renamed: Clicking_Stream_Frog_150_secondary.wav -> Clicking_108.wav
# Renamed: Clicking_Stream_Frog_151_primary.wav -> Clicking_109.wav
# Renamed: Clicking_Stream_Frog_151_secondary.wav -> Clicking_110.wav
# Renamed: Clicking_Stream_Frog_152_primary.wav -> Clicking_111.wav
# Renamed: Clicking_Stream_Frog_152_secondary.wav -> Clicking_112.wav
# Renamed: Clicking_Stream_Frog_153_primary.wav -> Clicking_113.wav
# Renamed: Clicking_Stream_Frog_153_secondary.wav -> Clicking_114.wav
# Renamed: Clicking_Stream_Frog_154_primary.wav -> Clicking_115.wav
# Renamed: Clicking_Stream_Frog_154_secondary.wav -> Clicking_116.wav
# Renamed: Clicking_Stream_Frog_155_primary.wav -> Clicking_117.wav
# Renamed: Clicking_Stream_Frog_156_primary.wav -> Clicking_118.wav
# Renamed: Clicking_Stream_Frog_156_secondary.wav -> Clicking_119.wav
# Renamed: Clicking_Stream_Frog_157_primary.wav -> Clicking_120.wav
# Renamed: Clicking_Stream_Frog_157_secondary.wav -> Clicking_121.wav
# Renamed: Clicking_Stream_Frog_158_primary.wav -> Clicking_122.wav
# Renamed: Clicking_Stream_Frog_158_secondary.wav -> Clicking_123.wav
# Renamed: Clicking_Stream_Frog_159_primary.wav -> Clicking_124.wav
# Renamed: Clicking_Stream_Frog_159_secondary.wav -> Clicking_125.wav
# Renamed: Clicking_Stream_Frog_15_primary.wav -> Clicking_126.wav
# Renamed: Clicking_Stream_Frog_15_secondary.wav -> Clicking_127.wav
# Renamed: Clicking_Stream_Frog_160_primary.wav -> Clicking_128.wav
# Renamed: Clicking_Stream_Frog_160_secondary.wav -> Clicking_129.wav
# Renamed: Clicking_Stream_Frog_161_primary.wav -> Clicking_130.wav
# Renamed: Clicking_Stream_Frog_161_secondary.wav -> Clicking_131.wav
# Renamed: Clicking_Stream_Frog_162_primary.wav -> Clicking_132.wav
# Renamed: Clicking_Stream_Frog_162_secondary.wav -> Clicking_133.wav
# Renamed: Clicking_Stream_Frog_163_primary.wav -> Clicking_134.wav
# Renamed: Clicking_Stream_Frog_163_secondary.wav -> Clicking_135.wav
# Renamed: Clicking_Stream_Frog_164_primary.wav -> Clicking_136.wav
# Renamed: Clicking_Stream_Frog_164_secondary.wav -> Clicking_137.wav
# Renamed: Clicking_Stream_Frog_165_primary.wav -> Clicking_138.wav
# Renamed: Clicking_Stream_Frog_165_secondary.wav -> Clicking_139.wav
# Renamed: Clicking_Stream_Frog_166_primary.wav -> Clicking_140.wav
# Renamed: Clicking_Stream_Frog_166_secondary.wav -> Clicking_141.wav
# Renamed: Clicking_Stream_Frog_167_primary.wav -> Clicking_142.wav
# Renamed: Clicking_Stream_Frog_167_secondary.wav -> Clicking_143.wav
# Renamed: Clicking_Stream_Frog_168_primary.wav -> Clicking_144.wav
# Renamed: Clicking_Stream_Frog_168_secondary.wav -> Clicking_145.wav
# Renamed: Clicking_Stream_Frog_169_primary.wav -> Clicking_146.wav
# Renamed: Clicking_Stream_Frog_16_primary.wav -> Clicking_147.wav
# Renamed: Clicking_Stream_Frog_16_secondary.wav -> Clicking_148.wav
# Renamed: Clicking_Stream_Frog_170_primary.wav -> Clicking_149.wav
# Renamed: Clicking_Stream_Frog_170_secondary.wav -> Clicking_150.wav
# Renamed: Clicking_Stream_Frog_171_primary.wav -> Clicking_151.wav
# Renamed: Clicking_Stream_Frog_171_secondary.wav -> Clicking_152.wav
# Renamed: Clicking_Stream_Frog_172_primary.wav -> Clicking_153.wav
# Renamed: Clicking_Stream_Frog_172_secondary.wav -> Clicking_154.wav
# Renamed: Clicking_Stream_Frog_173_primary.wav -> Clicking_155.wav
# Renamed: Clicking_Stream_Frog_173_secondary.wav -> Clicking_156.wav
# Renamed: Clicking_Stream_Frog_174_primary.wav -> Clicking_157.wav
# Renamed: Clicking_Stream_Frog_174_secondary.wav -> Clicking_158.wav
# Renamed: Clicking_Stream_Frog_175_primary.wav -> Clicking_159.wav
# Renamed: Clicking_Stream_Frog_175_secondary.wav -> Clicking_160.wav
# Renamed: Clicking_Stream_Frog_176_primary.wav -> Clicking_161.wav
# Renamed: Clicking_Stream_Frog_176_secondary.wav -> Clicking_162.wav
# Renamed: Clicking_Stream_Frog_177_primary.wav -> Clicking_163.wav
# Renamed: Clicking_Stream_Frog_177_secondary.wav -> Clicking_164.wav
# Renamed: Clicking_Stream_Frog_178_primary.wav -> Clicking_165.wav
# Renamed: Clicking_Stream_Frog_178_secondary.wav -> Clicking_166.wav
# Renamed: Clicking_Stream_Frog_179_primary.wav -> Clicking_167.wav
# Renamed: Clicking_Stream_Frog_179_secondary.wav -> Clicking_168.wav
# Renamed: Clicking_Stream_Frog_17_primary.wav -> Clicking_169.wav
# Renamed: Clicking_Stream_Frog_17_secondary.wav -> Clicking_170.wav
# Renamed: Clicking_Stream_Frog_180_primary.wav -> Clicking_171.wav
# Renamed: Clicking_Stream_Frog_180_secondary.wav -> Clicking_172.wav
# Renamed: Clicking_Stream_Frog_181_primary.wav -> Clicking_173.wav
# Renamed: Clicking_Stream_Frog_181_secondary.wav -> Clicking_174.wav
# Renamed: Clicking_Stream_Frog_182_primary.wav -> Clicking_175.wav
# Renamed: Clicking_Stream_Frog_183_primary.wav -> Clicking_176.wav
# Renamed: Clicking_Stream_Frog_183_secondary.wav -> Clicking_177.wav
# Renamed: Clicking_Stream_Frog_184_primary.wav -> Clicking_178.wav
# Renamed: Clicking_Stream_Frog_185_primary.wav -> Clicking_179.wav
# Renamed: Clicking_Stream_Frog_185_secondary.wav -> Clicking_180.wav
# Renamed: Clicking_Stream_Frog_186_primary.wav -> Clicking_181.wav
# Renamed: Clicking_Stream_Frog_186_secondary.wav -> Clicking_182.wav
# Renamed: Clicking_Stream_Frog_187_primary.wav -> Clicking_183.wav
# Renamed: Clicking_Stream_Frog_187_secondary.wav -> Clicking_184.wav
# Renamed: Clicking_Stream_Frog_188_primary.wav -> Clicking_185.wav
# Renamed: Clicking_Stream_Frog_188_secondary.wav -> Clicking_186.wav
# Renamed: Clicking_Stream_Frog_189_primary.wav -> Clicking_187.wav
# Renamed: Clicking_Stream_Frog_189_secondary.wav -> Clicking_188.wav
# Renamed: Clicking_Stream_Frog_18_primary.wav -> Clicking_189.wav
# Renamed: Clicking_Stream_Frog_18_secondary.wav -> Clicking_190.wav
# Renamed: Clicking_Stream_Frog_190_primary.wav -> Clicking_191.wav
# Renamed: Clicking_Stream_Frog_190_secondary.wav -> Clicking_192.wav
# Renamed: Clicking_Stream_Frog_192_primary.wav -> Clicking_193.wav
# Renamed: Clicking_Stream_Frog_192_secondary.wav -> Clicking_194.wav
# Renamed: Clicking_Stream_Frog_193_primary.wav -> Clicking_195.wav
# Renamed: Clicking_Stream_Frog_193_secondary.wav -> Clicking_196.wav
# Renamed: Clicking_Stream_Frog_194_primary.wav -> Clicking_197.wav
# Renamed: Clicking_Stream_Frog_194_secondary.wav -> Clicking_198.wav
# Renamed: Clicking_Stream_Frog_195_primary.wav -> Clicking_199.wav
# Renamed: Clicking_Stream_Frog_195_secondary.wav -> Clicking_200.wav
# Renamed: Clicking_Stream_Frog_196_primary.wav -> Clicking_201.wav
# Renamed: Clicking_Stream_Frog_196_secondary.wav -> Clicking_202.wav
# Renamed: Clicking_Stream_Frog_197_primary.wav -> Clicking_203.wav
# Renamed: Clicking_Stream_Frog_197_secondary.wav -> Clicking_204.wav
# Renamed: Clicking_Stream_Frog_198_primary.wav -> Clicking_205.wav
# Renamed: Clicking_Stream_Frog_198_secondary.wav -> Clicking_206.wav
# Renamed: Clicking_Stream_Frog_19_primary.wav -> Clicking_207.wav
# Renamed: Clicking_Stream_Frog_19_secondary.wav -> Clicking_208.wav
# Renamed: Clicking_Stream_Frog_1_primary.wav -> Clicking_209.wav
# Renamed: Clicking_Stream_Frog_1_secondary.wav -> Clicking_210.wav
# Renamed: Clicking_Stream_Frog_200_primary.wav -> Clicking_211.wav
# Renamed: Clicking_Stream_Frog_200_secondary.wav -> Clicking_212.wav
# Renamed: Clicking_Stream_Frog_201_primary.wav -> Clicking_213.wav
# Renamed: Clicking_Stream_Frog_201_secondary.wav -> Clicking_214.wav
# Renamed: Clicking_Stream_Frog_202_primary.wav -> Clicking_215.wav
# Renamed: Clicking_Stream_Frog_202_secondary.wav -> Clicking_216.wav
# Renamed: Clicking_Stream_Frog_203_primary.wav -> Clicking_217.wav
# Renamed: Clicking_Stream_Frog_203_secondary.wav -> Clicking_218.wav
# Renamed: Clicking_Stream_Frog_204_primary.wav -> Clicking_219.wav
# Renamed: Clicking_Stream_Frog_204_secondary.wav -> Clicking_220.wav
# Renamed: Clicking_Stream_Frog_205_primary.wav -> Clicking_221.wav
# Renamed: Clicking_Stream_Frog_205_secondary.wav -> Clicking_222.wav
# Renamed: Clicking_Stream_Frog_206_primary.wav -> Clicking_223.wav
# Renamed: Clicking_Stream_Frog_206_secondary.wav -> Clicking_224.wav
# Renamed: Clicking_Stream_Frog_207_primary.wav -> Clicking_225.wav
# Renamed: Clicking_Stream_Frog_207_secondary.wav -> Clicking_226.wav
# Renamed: Clicking_Stream_Frog_208_primary.wav -> Clicking_227.wav
# Renamed: Clicking_Stream_Frog_208_secondary.wav -> Clicking_228.wav
# Renamed: Clicking_Stream_Frog_209_primary.wav -> Clicking_229.wav
# Renamed: Clicking_Stream_Frog_209_secondary.wav -> Clicking_230.wav
# Renamed: Clicking_Stream_Frog_20_primary.wav -> Clicking_231.wav
# Renamed: Clicking_Stream_Frog_210_primary.wav -> Clicking_232.wav
# Renamed: Clicking_Stream_Frog_210_secondary.wav -> Clicking_233.wav
# Renamed: Clicking_Stream_Frog_211_primary.wav -> Clicking_234.wav
# Renamed: Clicking_Stream_Frog_211_secondary.wav -> Clicking_235.wav
# Renamed: Clicking_Stream_Frog_212_primary.wav -> Clicking_236.wav
# Renamed: Clicking_Stream_Frog_212_secondary.wav -> Clicking_237.wav
# Renamed: Clicking_Stream_Frog_213_primary.wav -> Clicking_238.wav
# Renamed: Clicking_Stream_Frog_213_secondary.wav -> Clicking_239.wav
# Renamed: Clicking_Stream_Frog_214_primary.wav -> Clicking_240.wav
# Renamed: Clicking_Stream_Frog_214_secondary.wav -> Clicking_241.wav
# Renamed: Clicking_Stream_Frog_215_primary.wav -> Clicking_242.wav
# Renamed: Clicking_Stream_Frog_215_secondary.wav -> Clicking_243.wav
# Renamed: Clicking_Stream_Frog_216_primary.wav -> Clicking_244.wav
# Renamed: Clicking_Stream_Frog_216_secondary.wav -> Clicking_245.wav
# Renamed: Clicking_Stream_Frog_217_primary.wav -> Clicking_246.wav
# Renamed: Clicking_Stream_Frog_217_secondary.wav -> Clicking_247.wav
# Renamed: Clicking_Stream_Frog_218_primary.wav -> Clicking_248.wav
# Renamed: Clicking_Stream_Frog_218_secondary.wav -> Clicking_249.wav
# Renamed: Clicking_Stream_Frog_219_primary.wav -> Clicking_250.wav
# Renamed: Clicking_Stream_Frog_219_secondary.wav -> Clicking_251.wav
# Renamed: Clicking_Stream_Frog_21_primary.wav -> Clicking_252.wav
# Renamed: Clicking_Stream_Frog_220_primary.wav -> Clicking_253.wav
# Renamed: Clicking_Stream_Frog_220_secondary.wav -> Clicking_254.wav
# Renamed: Clicking_Stream_Frog_221_primary.wav -> Clicking_255.wav
# Renamed: Clicking_Stream_Frog_221_secondary.wav -> Clicking_256.wav
# Renamed: Clicking_Stream_Frog_222_primary.wav -> Clicking_257.wav
# Renamed: Clicking_Stream_Frog_222_secondary.wav -> Clicking_258.wav
# Renamed: Clicking_Stream_Frog_223_primary.wav -> Clicking_259.wav
# Renamed: Clicking_Stream_Frog_223_secondary.wav -> Clicking_260.wav
# Renamed: Clicking_Stream_Frog_224_primary.wav -> Clicking_261.wav
# Renamed: Clicking_Stream_Frog_224_secondary.wav -> Clicking_262.wav
# Renamed: Clicking_Stream_Frog_225_primary.wav -> Clicking_263.wav
# Renamed: Clicking_Stream_Frog_225_secondary.wav -> Clicking_264.wav
# Renamed: Clicking_Stream_Frog_226_primary.wav -> Clicking_265.wav
# Renamed: Clicking_Stream_Frog_226_secondary.wav -> Clicking_266.wav
# Renamed: Clicking_Stream_Frog_227_primary.wav -> Clicking_267.wav
# Renamed: Clicking_Stream_Frog_227_secondary.wav -> Clicking_268.wav
# Renamed: Clicking_Stream_Frog_228_primary.wav -> Clicking_269.wav
# Renamed: Clicking_Stream_Frog_228_secondary.wav -> Clicking_270.wav
# Renamed: Clicking_Stream_Frog_229_primary.wav -> Clicking_271.wav
# Renamed: Clicking_Stream_Frog_229_secondary.wav -> Clicking_272.wav
# Renamed: Clicking_Stream_Frog_22_primary.wav -> Clicking_273.wav
# Renamed: Clicking_Stream_Frog_22_secondary.wav -> Clicking_274.wav
# Renamed: Clicking_Stream_Frog_230_primary.wav -> Clicking_275.wav
# Renamed: Clicking_Stream_Frog_230_secondary.wav -> Clicking_276.wav
# Renamed: Clicking_Stream_Frog_231_primary.wav -> Clicking_277.wav
# Renamed: Clicking_Stream_Frog_231_secondary.wav -> Clicking_278.wav
# Renamed: Clicking_Stream_Frog_232_primary.wav -> Clicking_279.wav
# Renamed: Clicking_Stream_Frog_232_secondary.wav -> Clicking_280.wav
# Renamed: Clicking_Stream_Frog_233_primary.wav -> Clicking_281.wav
# Renamed: Clicking_Stream_Frog_233_secondary.wav -> Clicking_282.wav
# Renamed: Clicking_Stream_Frog_234_primary.wav -> Clicking_283.wav
# Renamed: Clicking_Stream_Frog_234_secondary.wav -> Clicking_284.wav
# Renamed: Clicking_Stream_Frog_235_primary.wav -> Clicking_285.wav
# Renamed: Clicking_Stream_Frog_235_secondary.wav -> Clicking_286.wav
# Renamed: Clicking_Stream_Frog_236_primary.wav -> Clicking_287.wav
# Renamed: Clicking_Stream_Frog_236_secondary.wav -> Clicking_288.wav
# Renamed: Clicking_Stream_Frog_237_primary.wav -> Clicking_289.wav
# Renamed: Clicking_Stream_Frog_237_secondary.wav -> Clicking_290.wav
# Renamed: Clicking_Stream_Frog_238_primary.wav -> Clicking_291.wav
# Renamed: Clicking_Stream_Frog_238_secondary.wav -> Clicking_292.wav
# Renamed: Clicking_Stream_Frog_239_primary.wav -> Clicking_293.wav
# Renamed: Clicking_Stream_Frog_239_secondary.wav -> Clicking_294.wav
# Renamed: Clicking_Stream_Frog_23_primary.wav -> Clicking_295.wav
# Renamed: Clicking_Stream_Frog_23_secondary.wav -> Clicking_296.wav
# Renamed: Clicking_Stream_Frog_240_primary.wav -> Clicking_297.wav
# Renamed: Clicking_Stream_Frog_240_secondary.wav -> Clicking_298.wav
# Renamed: Clicking_Stream_Frog_241_primary.wav -> Clicking_299.wav
# Renamed: Clicking_Stream_Frog_241_secondary.wav -> Clicking_300.wav
# Renamed: Clicking_Stream_Frog_242_primary.wav -> Clicking_301.wav
# Renamed: Clicking_Stream_Frog_242_secondary.wav -> Clicking_302.wav
# Renamed: Clicking_Stream_Frog_243_primary.wav -> Clicking_303.wav
# Renamed: Clicking_Stream_Frog_243_secondary.wav -> Clicking_304.wav
# Renamed: Clicking_Stream_Frog_244_primary.wav -> Clicking_305.wav
# Renamed: Clicking_Stream_Frog_244_secondary.wav -> Clicking_306.wav
# Renamed: Clicking_Stream_Frog_245_primary.wav -> Clicking_307.wav
# Renamed: Clicking_Stream_Frog_245_secondary.wav -> Clicking_308.wav
# Renamed: Clicking_Stream_Frog_246_primary.wav -> Clicking_309.wav
# Renamed: Clicking_Stream_Frog_246_secondary.wav -> Clicking_310.wav
# Renamed: Clicking_Stream_Frog_247_primary.wav -> Clicking_311.wav
# Renamed: Clicking_Stream_Frog_247_secondary.wav -> Clicking_312.wav
# Renamed: Clicking_Stream_Frog_248_primary.wav -> Clicking_313.wav
# Renamed: Clicking_Stream_Frog_248_secondary.wav -> Clicking_314.wav
# Renamed: Clicking_Stream_Frog_249_primary.wav -> Clicking_315.wav
# Renamed: Clicking_Stream_Frog_249_secondary.wav -> Clicking_316.wav
# Renamed: Clicking_Stream_Frog_250_primary.wav -> Clicking_317.wav
# Renamed: Clicking_Stream_Frog_250_secondary.wav -> Clicking_318.wav
# Renamed: Clicking_Stream_Frog_251_primary.wav -> Clicking_319.wav
# Renamed: Clicking_Stream_Frog_251_secondary.wav -> Clicking_320.wav
# Renamed: Clicking_Stream_Frog_252_primary.wav -> Clicking_321.wav
# Renamed: Clicking_Stream_Frog_252_secondary.wav -> Clicking_322.wav
# Renamed: Clicking_Stream_Frog_253_primary.wav -> Clicking_323.wav
# Renamed: Clicking_Stream_Frog_253_secondary.wav -> Clicking_324.wav
# Renamed: Clicking_Stream_Frog_254_primary.wav -> Clicking_325.wav
# Renamed: Clicking_Stream_Frog_254_secondary.wav -> Clicking_326.wav
# Renamed: Clicking_Stream_Frog_255_primary.wav -> Clicking_327.wav
# Renamed: Clicking_Stream_Frog_255_secondary.wav -> Clicking_328.wav
# Renamed: Clicking_Stream_Frog_256_primary.wav -> Clicking_329.wav
# Renamed: Clicking_Stream_Frog_256_secondary.wav -> Clicking_330.wav
# Renamed: Clicking_Stream_Frog_257_primary.wav -> Clicking_331.wav
# Renamed: Clicking_Stream_Frog_257_secondary.wav -> Clicking_332.wav
# Renamed: Clicking_Stream_Frog_258_primary.wav -> Clicking_333.wav
# Renamed: Clicking_Stream_Frog_258_secondary.wav -> Clicking_334.wav
# Renamed: Clicking_Stream_Frog_259_primary.wav -> Clicking_335.wav
# Renamed: Clicking_Stream_Frog_259_secondary.wav -> Clicking_336.wav
# Renamed: Clicking_Stream_Frog_25_primary.wav -> Clicking_337.wav
# Renamed: Clicking_Stream_Frog_25_secondary.wav -> Clicking_338.wav
# Renamed: Clicking_Stream_Frog_260_primary.wav -> Clicking_339.wav
# Renamed: Clicking_Stream_Frog_260_secondary.wav -> Clicking_340.wav
# Renamed: Clicking_Stream_Frog_261_primary.wav -> Clicking_341.wav
# Renamed: Clicking_Stream_Frog_261_secondary.wav -> Clicking_342.wav
# Renamed: Clicking_Stream_Frog_262_primary.wav -> Clicking_343.wav
# Renamed: Clicking_Stream_Frog_262_secondary.wav -> Clicking_344.wav
# Renamed: Clicking_Stream_Frog_263_primary.wav -> Clicking_345.wav
# Renamed: Clicking_Stream_Frog_263_secondary.wav -> Clicking_346.wav
# Renamed: Clicking_Stream_Frog_264_primary.wav -> Clicking_347.wav
# Renamed: Clicking_Stream_Frog_264_secondary.wav -> Clicking_348.wav
# Renamed: Clicking_Stream_Frog_265_primary.wav -> Clicking_349.wav
# Renamed: Clicking_Stream_Frog_265_secondary.wav -> Clicking_350.wav
# Renamed: Clicking_Stream_Frog_266_primary.wav -> Clicking_351.wav
# Renamed: Clicking_Stream_Frog_266_secondary.wav -> Clicking_352.wav
# Renamed: Clicking_Stream_Frog_267_primary.wav -> Clicking_353.wav
# Renamed: Clicking_Stream_Frog_267_secondary.wav -> Clicking_354.wav
# Renamed: Clicking_Stream_Frog_268_primary.wav -> Clicking_355.wav
# Renamed: Clicking_Stream_Frog_268_secondary.wav -> Clicking_356.wav
# Renamed: Clicking_Stream_Frog_269_primary.wav -> Clicking_357.wav
# Renamed: Clicking_Stream_Frog_269_secondary.wav -> Clicking_358.wav
# Renamed: Clicking_Stream_Frog_26_primary.wav -> Clicking_359.wav
# Renamed: Clicking_Stream_Frog_26_secondary.wav -> Clicking_360.wav
# Renamed: Clicking_Stream_Frog_270_primary.wav -> Clicking_361.wav
# Renamed: Clicking_Stream_Frog_270_secondary.wav -> Clicking_362.wav
# Renamed: Clicking_Stream_Frog_271_primary.wav -> Clicking_363.wav
# Renamed: Clicking_Stream_Frog_271_secondary.wav -> Clicking_364.wav
# Renamed: Clicking_Stream_Frog_272_primary.wav -> Clicking_365.wav
# Renamed: Clicking_Stream_Frog_272_secondary.wav -> Clicking_366.wav
# Renamed: Clicking_Stream_Frog_273_primary.wav -> Clicking_367.wav
# Renamed: Clicking_Stream_Frog_273_secondary.wav -> Clicking_368.wav
# Renamed: Clicking_Stream_Frog_274_primary.wav -> Clicking_369.wav
# Renamed: Clicking_Stream_Frog_274_secondary.wav -> Clicking_370.wav
# Renamed: Clicking_Stream_Frog_275_primary.wav -> Clicking_371.wav
# Renamed: Clicking_Stream_Frog_275_secondary.wav -> Clicking_372.wav
# Renamed: Clicking_Stream_Frog_276_primary.wav -> Clicking_373.wav
# Renamed: Clicking_Stream_Frog_276_secondary.wav -> Clicking_374.wav
# Renamed: Clicking_Stream_Frog_277_primary.wav -> Clicking_375.wav
# Renamed: Clicking_Stream_Frog_277_secondary.wav -> Clicking_376.wav
# Renamed: Clicking_Stream_Frog_278_primary.wav -> Clicking_377.wav
# Renamed: Clicking_Stream_Frog_278_secondary.wav -> Clicking_378.wav
# Renamed: Clicking_Stream_Frog_279_primary.wav -> Clicking_379.wav
# Renamed: Clicking_Stream_Frog_279_secondary.wav -> Clicking_380.wav
# Renamed: Clicking_Stream_Frog_27_primary.wav -> Clicking_381.wav
# Renamed: Clicking_Stream_Frog_27_secondary.wav -> Clicking_382.wav
# Renamed: Clicking_Stream_Frog_280_primary.wav -> Clicking_383.wav
# Renamed: Clicking_Stream_Frog_280_secondary.wav -> Clicking_384.wav
# Renamed: Clicking_Stream_Frog_281_primary.wav -> Clicking_385.wav
# Renamed: Clicking_Stream_Frog_281_secondary.wav -> Clicking_386.wav
# Renamed: Clicking_Stream_Frog_282_primary.wav -> Clicking_387.wav
# Renamed: Clicking_Stream_Frog_282_secondary.wav -> Clicking_388.wav
# Renamed: Clicking_Stream_Frog_283_primary.wav -> Clicking_389.wav
# Renamed: Clicking_Stream_Frog_283_secondary.wav -> Clicking_390.wav
# Renamed: Clicking_Stream_Frog_284_primary.wav -> Clicking_391.wav
# Renamed: Clicking_Stream_Frog_284_secondary.wav -> Clicking_392.wav
# Renamed: Clicking_Stream_Frog_285_primary.wav -> Clicking_393.wav
# Renamed: Clicking_Stream_Frog_285_secondary.wav -> Clicking_394.wav
# Renamed: Clicking_Stream_Frog_286_primary.wav -> Clicking_395.wav
# Renamed: Clicking_Stream_Frog_286_secondary.wav -> Clicking_396.wav
# Renamed: Clicking_Stream_Frog_287_primary.wav -> Clicking_397.wav
# Renamed: Clicking_Stream_Frog_287_secondary.wav -> Clicking_398.wav
# Renamed: Clicking_Stream_Frog_288_primary.wav -> Clicking_399.wav
# Renamed: Clicking_Stream_Frog_288_secondary.wav -> Clicking_400.wav
# Renamed: Clicking_Stream_Frog_289_primary.wav -> Clicking_401.wav
# Renamed: Clicking_Stream_Frog_289_secondary.wav -> Clicking_402.wav
# Renamed: Clicking_Stream_Frog_28_primary.wav -> Clicking_403.wav
# Renamed: Clicking_Stream_Frog_28_secondary.wav -> Clicking_404.wav
# Renamed: Clicking_Stream_Frog_290_primary.wav -> Clicking_405.wav
# Renamed: Clicking_Stream_Frog_290_secondary.wav -> Clicking_406.wav
# Renamed: Clicking_Stream_Frog_291_primary.wav -> Clicking_407.wav
# Renamed: Clicking_Stream_Frog_291_secondary.wav -> Clicking_408.wav
# Renamed: Clicking_Stream_Frog_292_primary.wav -> Clicking_409.wav
# Renamed: Clicking_Stream_Frog_292_secondary.wav -> Clicking_410.wav
# Renamed: Clicking_Stream_Frog_293_primary.wav -> Clicking_411.wav
# Renamed: Clicking_Stream_Frog_293_secondary.wav -> Clicking_412.wav
# Renamed: Clicking_Stream_Frog_294_primary.wav -> Clicking_413.wav
# Renamed: Clicking_Stream_Frog_294_secondary.wav -> Clicking_414.wav
# Renamed: Clicking_Stream_Frog_295_primary.wav -> Clicking_415.wav
# Renamed: Clicking_Stream_Frog_295_secondary.wav -> Clicking_416.wav
# Renamed: Clicking_Stream_Frog_296_primary.wav -> Clicking_417.wav
# Renamed: Clicking_Stream_Frog_296_secondary.wav -> Clicking_418.wav
# Renamed: Clicking_Stream_Frog_297_primary.wav -> Clicking_419.wav
# Renamed: Clicking_Stream_Frog_297_secondary.wav -> Clicking_420.wav
# Renamed: Clicking_Stream_Frog_298_primary.wav -> Clicking_421.wav
# Renamed: Clicking_Stream_Frog_298_secondary.wav -> Clicking_422.wav
# Renamed: Clicking_Stream_Frog_299_primary.wav -> Clicking_423.wav
# Renamed: Clicking_Stream_Frog_299_secondary.wav -> Clicking_424.wav
# Renamed: Clicking_Stream_Frog_29_primary.wav -> Clicking_425.wav
# Renamed: Clicking_Stream_Frog_29_secondary.wav -> Clicking_426.wav
# Renamed: Clicking_Stream_Frog_2_primary.wav -> Clicking_427.wav
# Renamed: Clicking_Stream_Frog_2_secondary.wav -> Clicking_428.wav
# Renamed: Clicking_Stream_Frog_300_primary.wav -> Clicking_429.wav
# Renamed: Clicking_Stream_Frog_300_secondary.wav -> Clicking_430.wav
# Renamed: Clicking_Stream_Frog_301_primary.wav -> Clicking_431.wav
# Renamed: Clicking_Stream_Frog_301_secondary.wav -> Clicking_432.wav
# Renamed: Clicking_Stream_Frog_302_primary.wav -> Clicking_433.wav
# Renamed: Clicking_Stream_Frog_302_secondary.wav -> Clicking_434.wav
# Renamed: Clicking_Stream_Frog_303_primary.wav -> Clicking_435.wav
# Renamed: Clicking_Stream_Frog_303_secondary.wav -> Clicking_436.wav
# Renamed: Clicking_Stream_Frog_304_primary.wav -> Clicking_437.wav
# Renamed: Clicking_Stream_Frog_304_secondary.wav -> Clicking_438.wav
# Renamed: Clicking_Stream_Frog_305_primary.wav -> Clicking_439.wav
# Renamed: Clicking_Stream_Frog_305_secondary.wav -> Clicking_440.wav
# Renamed: Clicking_Stream_Frog_306_primary.wav -> Clicking_441.wav
# Renamed: Clicking_Stream_Frog_306_secondary.wav -> Clicking_442.wav
# Renamed: Clicking_Stream_Frog_307_primary.wav -> Clicking_443.wav
# Renamed: Clicking_Stream_Frog_307_secondary.wav -> Clicking_444.wav
# Renamed: Clicking_Stream_Frog_308_primary.wav -> Clicking_445.wav
# Renamed: Clicking_Stream_Frog_308_secondary.wav -> Clicking_446.wav
# Renamed: Clicking_Stream_Frog_309_primary.wav -> Clicking_447.wav
# Renamed: Clicking_Stream_Frog_309_secondary.wav -> Clicking_448.wav
# Renamed: Clicking_Stream_Frog_30_primary.wav -> Clicking_449.wav
# Renamed: Clicking_Stream_Frog_30_secondary.wav -> Clicking_450.wav
# Renamed: Clicking_Stream_Frog_310_primary.wav -> Clicking_451.wav
# Renamed: Clicking_Stream_Frog_310_secondary.wav -> Clicking_452.wav
# Renamed: Clicking_Stream_Frog_311_primary.wav -> Clicking_453.wav
# Renamed: Clicking_Stream_Frog_311_secondary.wav -> Clicking_454.wav
# Renamed: Clicking_Stream_Frog_312_primary.wav -> Clicking_455.wav
# Renamed: Clicking_Stream_Frog_312_secondary.wav -> Clicking_456.wav
# Renamed: Clicking_Stream_Frog_313_primary.wav -> Clicking_457.wav
# Renamed: Clicking_Stream_Frog_313_secondary.wav -> Clicking_458.wav
# Renamed: Clicking_Stream_Frog_314_primary.wav -> Clicking_459.wav
# Renamed: Clicking_Stream_Frog_314_secondary.wav -> Clicking_460.wav
# Renamed: Clicking_Stream_Frog_315_primary.wav -> Clicking_461.wav
# Renamed: Clicking_Stream_Frog_315_secondary.wav -> Clicking_462.wav
# Renamed: Clicking_Stream_Frog_316_primary.wav -> Clicking_463.wav
# Renamed: Clicking_Stream_Frog_316_secondary.wav -> Clicking_464.wav
# Renamed: Clicking_Stream_Frog_318_primary.wav -> Clicking_465.wav
# Renamed: Clicking_Stream_Frog_318_secondary.wav -> Clicking_466.wav
# Renamed: Clicking_Stream_Frog_319_primary.wav -> Clicking_467.wav
# Renamed: Clicking_Stream_Frog_319_secondary.wav -> Clicking_468.wav
# Renamed: Clicking_Stream_Frog_31_primary.wav -> Clicking_469.wav
# Renamed: Clicking_Stream_Frog_31_secondary.wav -> Clicking_470.wav
# Renamed: Clicking_Stream_Frog_320_primary.wav -> Clicking_471.wav
# Renamed: Clicking_Stream_Frog_320_secondary.wav -> Clicking_472.wav
# Renamed: Clicking_Stream_Frog_321_primary.wav -> Clicking_473.wav
# Renamed: Clicking_Stream_Frog_321_secondary.wav -> Clicking_474.wav
# Renamed: Clicking_Stream_Frog_322_primary.wav -> Clicking_475.wav
# Renamed: Clicking_Stream_Frog_322_secondary.wav -> Clicking_476.wav
# Renamed: Clicking_Stream_Frog_323_primary.wav -> Clicking_477.wav
# Renamed: Clicking_Stream_Frog_323_secondary.wav -> Clicking_478.wav
# Renamed: Clicking_Stream_Frog_324_primary.wav -> Clicking_479.wav
# Renamed: Clicking_Stream_Frog_324_secondary.wav -> Clicking_480.wav
# Renamed: Clicking_Stream_Frog_325_primary.wav -> Clicking_481.wav
# Renamed: Clicking_Stream_Frog_325_secondary.wav -> Clicking_482.wav
# Renamed: Clicking_Stream_Frog_326_primary.wav -> Clicking_483.wav
# Renamed: Clicking_Stream_Frog_326_secondary.wav -> Clicking_484.wav
# Renamed: Clicking_Stream_Frog_327_primary.wav -> Clicking_485.wav
# Renamed: Clicking_Stream_Frog_327_secondary.wav -> Clicking_486.wav
# Renamed: Clicking_Stream_Frog_328_primary.wav -> Clicking_487.wav
# Renamed: Clicking_Stream_Frog_328_secondary.wav -> Clicking_488.wav
# Renamed: Clicking_Stream_Frog_329_primary.wav -> Clicking_489.wav
# Renamed: Clicking_Stream_Frog_329_secondary.wav -> Clicking_490.wav
# Renamed: Clicking_Stream_Frog_32_primary.wav -> Clicking_491.wav
# Renamed: Clicking_Stream_Frog_32_secondary.wav -> Clicking_492.wav
# Renamed: Clicking_Stream_Frog_330_primary.wav -> Clicking_493.wav
# Renamed: Clicking_Stream_Frog_330_secondary.wav -> Clicking_494.wav
# Renamed: Clicking_Stream_Frog_331_primary.wav -> Clicking_495.wav
# Renamed: Clicking_Stream_Frog_331_secondary.wav -> Clicking_496.wav
# Renamed: Clicking_Stream_Frog_332_primary.wav -> Clicking_497.wav
# Renamed: Clicking_Stream_Frog_332_secondary.wav -> Clicking_498.wav
# Renamed: Clicking_Stream_Frog_333_primary.wav -> Clicking_499.wav
# Renamed: Clicking_Stream_Frog_333_secondary.wav -> Clicking_500.wav
# Renamed: Clicking_Stream_Frog_334_primary.wav -> Clicking_501.wav
# Renamed: Clicking_Stream_Frog_334_secondary.wav -> Clicking_502.wav
# Renamed: Clicking_Stream_Frog_335_primary.wav -> Clicking_503.wav
# Renamed: Clicking_Stream_Frog_335_secondary.wav -> Clicking_504.wav
# Renamed: Clicking_Stream_Frog_336_primary.wav -> Clicking_505.wav
# Renamed: Clicking_Stream_Frog_336_secondary.wav -> Clicking_506.wav
# Renamed: Clicking_Stream_Frog_337_primary.wav -> Clicking_507.wav
# Renamed: Clicking_Stream_Frog_337_secondary.wav -> Clicking_508.wav
# Renamed: Clicking_Stream_Frog_338_primary.wav -> Clicking_509.wav
# Renamed: Clicking_Stream_Frog_338_secondary.wav -> Clicking_510.wav
# Renamed: Clicking_Stream_Frog_339_primary.wav -> Clicking_511.wav
# Renamed: Clicking_Stream_Frog_339_secondary.wav -> Clicking_512.wav
# Renamed: Clicking_Stream_Frog_33_primary.wav -> Clicking_513.wav
# Renamed: Clicking_Stream_Frog_33_secondary.wav -> Clicking_514.wav
# Renamed: Clicking_Stream_Frog_340_primary.wav -> Clicking_515.wav
# Renamed: Clicking_Stream_Frog_340_secondary.wav -> Clicking_516.wav
# Renamed: Clicking_Stream_Frog_341_primary.wav -> Clicking_517.wav
# Renamed: Clicking_Stream_Frog_341_secondary.wav -> Clicking_518.wav
# Renamed: Clicking_Stream_Frog_342_primary.wav -> Clicking_519.wav
# Renamed: Clicking_Stream_Frog_342_secondary.wav -> Clicking_520.wav
# Renamed: Clicking_Stream_Frog_343_primary.wav -> Clicking_521.wav
# Renamed: Clicking_Stream_Frog_343_secondary.wav -> Clicking_522.wav
# Renamed: Clicking_Stream_Frog_344_primary.wav -> Clicking_523.wav
# Renamed: Clicking_Stream_Frog_344_secondary.wav -> Clicking_524.wav
# Renamed: Clicking_Stream_Frog_345_primary.wav -> Clicking_525.wav
# Renamed: Clicking_Stream_Frog_345_secondary.wav -> Clicking_526.wav
# Renamed: Clicking_Stream_Frog_346_primary.wav -> Clicking_527.wav
# Renamed: Clicking_Stream_Frog_346_secondary.wav -> Clicking_528.wav
# Renamed: Clicking_Stream_Frog_347_primary.wav -> Clicking_529.wav
# Renamed: Clicking_Stream_Frog_347_secondary.wav -> Clicking_530.wav
# Renamed: Clicking_Stream_Frog_348_primary.wav -> Clicking_531.wav
# Renamed: Clicking_Stream_Frog_348_secondary.wav -> Clicking_532.wav
# Renamed: Clicking_Stream_Frog_349_primary.wav -> Clicking_533.wav
# Renamed: Clicking_Stream_Frog_349_secondary.wav -> Clicking_534.wav
# Renamed: Clicking_Stream_Frog_34_primary.wav -> Clicking_535.wav
# Renamed: Clicking_Stream_Frog_34_secondary.wav -> Clicking_536.wav
# Renamed: Clicking_Stream_Frog_350_primary.wav -> Clicking_537.wav
# Renamed: Clicking_Stream_Frog_350_secondary.wav -> Clicking_538.wav
# Renamed: Clicking_Stream_Frog_351_primary.wav -> Clicking_539.wav
# Renamed: Clicking_Stream_Frog_351_secondary.wav -> Clicking_540.wav
# Renamed: Clicking_Stream_Frog_352_primary.wav -> Clicking_541.wav
# Renamed: Clicking_Stream_Frog_352_secondary.wav -> Clicking_542.wav
# Renamed: Clicking_Stream_Frog_353_primary.wav -> Clicking_543.wav
# Renamed: Clicking_Stream_Frog_353_secondary.wav -> Clicking_544.wav
# Renamed: Clicking_Stream_Frog_354_primary.wav -> Clicking_545.wav
# Renamed: Clicking_Stream_Frog_354_secondary.wav -> Clicking_546.wav
# Renamed: Clicking_Stream_Frog_355_primary.wav -> Clicking_547.wav
# Renamed: Clicking_Stream_Frog_355_secondary.wav -> Clicking_548.wav
# Renamed: Clicking_Stream_Frog_356_primary.wav -> Clicking_549.wav
# Renamed: Clicking_Stream_Frog_356_secondary.wav -> Clicking_550.wav
# Renamed: Clicking_Stream_Frog_357_primary.wav -> Clicking_551.wav
# Renamed: Clicking_Stream_Frog_357_secondary.wav -> Clicking_552.wav
# Renamed: Clicking_Stream_Frog_358_primary.wav -> Clicking_553.wav
# Renamed: Clicking_Stream_Frog_358_secondary.wav -> Clicking_554.wav
# Renamed: Clicking_Stream_Frog_359_primary.wav -> Clicking_555.wav
# Renamed: Clicking_Stream_Frog_359_secondary.wav -> Clicking_556.wav
# Renamed: Clicking_Stream_Frog_35_primary.wav -> Clicking_557.wav
# Renamed: Clicking_Stream_Frog_35_secondary.wav -> Clicking_558.wav
# Renamed: Clicking_Stream_Frog_360_primary.wav -> Clicking_559.wav
# Renamed: Clicking_Stream_Frog_360_secondary.wav -> Clicking_560.wav
# Renamed: Clicking_Stream_Frog_361_primary.wav -> Clicking_561.wav
# Renamed: Clicking_Stream_Frog_361_secondary.wav -> Clicking_562.wav
# Renamed: Clicking_Stream_Frog_362_primary.wav -> Clicking_563.wav
# Renamed: Clicking_Stream_Frog_362_secondary.wav -> Clicking_564.wav
# Renamed: Clicking_Stream_Frog_363_primary.wav -> Clicking_565.wav
# Renamed: Clicking_Stream_Frog_363_secondary.wav -> Clicking_566.wav
# Renamed: Clicking_Stream_Frog_364_primary.wav -> Clicking_567.wav
# Renamed: Clicking_Stream_Frog_364_secondary.wav -> Clicking_568.wav
# Renamed: Clicking_Stream_Frog_365_primary.wav -> Clicking_569.wav
# Renamed: Clicking_Stream_Frog_365_secondary.wav -> Clicking_570.wav
# Renamed: Clicking_Stream_Frog_366_primary.wav -> Clicking_571.wav
# Renamed: Clicking_Stream_Frog_366_secondary.wav -> Clicking_572.wav
# Renamed: Clicking_Stream_Frog_367_primary.wav -> Clicking_573.wav
# Renamed: Clicking_Stream_Frog_367_secondary.wav -> Clicking_574.wav
# Renamed: Clicking_Stream_Frog_368_primary.wav -> Clicking_575.wav
# Renamed: Clicking_Stream_Frog_368_secondary.wav -> Clicking_576.wav
# Renamed: Clicking_Stream_Frog_369_primary.wav -> Clicking_577.wav
# Renamed: Clicking_Stream_Frog_369_secondary.wav -> Clicking_578.wav
# Renamed: Clicking_Stream_Frog_36_primary.wav -> Clicking_579.wav
# Renamed: Clicking_Stream_Frog_36_secondary.wav -> Clicking_580.wav
# Renamed: Clicking_Stream_Frog_370_primary.wav -> Clicking_581.wav
# Renamed: Clicking_Stream_Frog_370_secondary.wav -> Clicking_582.wav
# Renamed: Clicking_Stream_Frog_371_primary.wav -> Clicking_583.wav
# Renamed: Clicking_Stream_Frog_371_secondary.wav -> Clicking_584.wav
# Renamed: Clicking_Stream_Frog_372_primary.wav -> Clicking_585.wav
# Renamed: Clicking_Stream_Frog_372_secondary.wav -> Clicking_586.wav
# Renamed: Clicking_Stream_Frog_373_primary.wav -> Clicking_587.wav
# Renamed: Clicking_Stream_Frog_373_secondary.wav -> Clicking_588.wav
# Renamed: Clicking_Stream_Frog_374_primary.wav -> Clicking_589.wav
# Renamed: Clicking_Stream_Frog_374_secondary.wav -> Clicking_590.wav
# Renamed: Clicking_Stream_Frog_375_primary.wav -> Clicking_591.wav
# Renamed: Clicking_Stream_Frog_375_secondary.wav -> Clicking_592.wav
# Renamed: Clicking_Stream_Frog_376_primary.wav -> Clicking_593.wav
# Renamed: Clicking_Stream_Frog_376_secondary.wav -> Clicking_594.wav
# Renamed: Clicking_Stream_Frog_377_primary.wav -> Clicking_595.wav
# Renamed: Clicking_Stream_Frog_377_secondary.wav -> Clicking_596.wav
# Renamed: Clicking_Stream_Frog_378_primary.wav -> Clicking_597.wav
# Renamed: Clicking_Stream_Frog_378_secondary.wav -> Clicking_598.wav
# Renamed: Clicking_Stream_Frog_379_primary.wav -> Clicking_599.wav
# Renamed: Clicking_Stream_Frog_379_secondary.wav -> Clicking_600.wav
# Renamed: Clicking_Stream_Frog_37_primary.wav -> Clicking_601.wav
# Renamed: Clicking_Stream_Frog_37_secondary.wav -> Clicking_602.wav
# Renamed: Clicking_Stream_Frog_380_primary.wav -> Clicking_603.wav
# Renamed: Clicking_Stream_Frog_380_secondary.wav -> Clicking_604.wav
# Renamed: Clicking_Stream_Frog_381_primary.wav -> Clicking_605.wav
# Renamed: Clicking_Stream_Frog_381_secondary.wav -> Clicking_606.wav
# Renamed: Clicking_Stream_Frog_382_primary.wav -> Clicking_607.wav
# Renamed: Clicking_Stream_Frog_382_secondary.wav -> Clicking_608.wav
# Renamed: Clicking_Stream_Frog_383_primary.wav -> Clicking_609.wav
# Renamed: Clicking_Stream_Frog_384_primary.wav -> Clicking_610.wav
# Renamed: Clicking_Stream_Frog_384_secondary.wav -> Clicking_611.wav
# Renamed: Clicking_Stream_Frog_385_primary.wav -> Clicking_612.wav
# Renamed: Clicking_Stream_Frog_385_secondary.wav -> Clicking_613.wav
# Renamed: Clicking_Stream_Frog_386_primary.wav -> Clicking_614.wav
# Renamed: Clicking_Stream_Frog_386_secondary.wav -> Clicking_615.wav
# Renamed: Clicking_Stream_Frog_387_primary.wav -> Clicking_616.wav
# Renamed: Clicking_Stream_Frog_387_secondary.wav -> Clicking_617.wav
# Renamed: Clicking_Stream_Frog_388_primary.wav -> Clicking_618.wav
# Renamed: Clicking_Stream_Frog_388_secondary.wav -> Clicking_619.wav
# Renamed: Clicking_Stream_Frog_389_primary.wav -> Clicking_620.wav
# Renamed: Clicking_Stream_Frog_389_secondary.wav -> Clicking_621.wav
# Renamed: Clicking_Stream_Frog_38_primary.wav -> Clicking_622.wav
# Renamed: Clicking_Stream_Frog_38_secondary.wav -> Clicking_623.wav
# Renamed: Clicking_Stream_Frog_390_primary.wav -> Clicking_624.wav
# Renamed: Clicking_Stream_Frog_390_secondary.wav -> Clicking_625.wav
# Renamed: Clicking_Stream_Frog_391_primary.wav -> Clicking_626.wav
# Renamed: Clicking_Stream_Frog_391_secondary.wav -> Clicking_627.wav
# Renamed: Clicking_Stream_Frog_392_primary.wav -> Clicking_628.wav
# Renamed: Clicking_Stream_Frog_392_secondary.wav -> Clicking_629.wav
# Renamed: Clicking_Stream_Frog_393_primary.wav -> Clicking_630.wav
# Renamed: Clicking_Stream_Frog_393_secondary.wav -> Clicking_631.wav
# Renamed: Clicking_Stream_Frog_394_primary.wav -> Clicking_632.wav
# Renamed: Clicking_Stream_Frog_394_secondary.wav -> Clicking_633.wav
# Renamed: Clicking_Stream_Frog_395_primary.wav -> Clicking_634.wav
# Renamed: Clicking_Stream_Frog_395_secondary.wav -> Clicking_635.wav
# Renamed: Clicking_Stream_Frog_396_primary.wav -> Clicking_636.wav
# Renamed: Clicking_Stream_Frog_396_secondary.wav -> Clicking_637.wav
# Renamed: Clicking_Stream_Frog_397_primary.wav -> Clicking_638.wav
# Renamed: Clicking_Stream_Frog_397_secondary.wav -> Clicking_639.wav
# Renamed: Clicking_Stream_Frog_398_primary.wav -> Clicking_640.wav
# Renamed: Clicking_Stream_Frog_398_secondary.wav -> Clicking_641.wav
# Renamed: Clicking_Stream_Frog_399_primary.wav -> Clicking_642.wav
# Renamed: Clicking_Stream_Frog_399_secondary.wav -> Clicking_643.wav
# Renamed: Clicking_Stream_Frog_39_primary.wav -> Clicking_644.wav
# Renamed: Clicking_Stream_Frog_39_secondary.wav -> Clicking_645.wav
# Renamed: Clicking_Stream_Frog_3_primary.wav -> Clicking_646.wav
# Renamed: Clicking_Stream_Frog_3_secondary.wav -> Clicking_647.wav
# Renamed: Clicking_Stream_Frog_400_primary.wav -> Clicking_648.wav
# Renamed: Clicking_Stream_Frog_400_secondary.wav -> Clicking_649.wav
# Renamed: Clicking_Stream_Frog_401_primary.wav -> Clicking_650.wav
# Renamed: Clicking_Stream_Frog_401_secondary.wav -> Clicking_651.wav
# Renamed: Clicking_Stream_Frog_402_primary.wav -> Clicking_652.wav
# Renamed: Clicking_Stream_Frog_402_secondary.wav -> Clicking_653.wav
# Renamed: Clicking_Stream_Frog_403_primary.wav -> Clicking_654.wav
# Renamed: Clicking_Stream_Frog_403_secondary.wav -> Clicking_655.wav
# Renamed: Clicking_Stream_Frog_404_primary.wav -> Clicking_656.wav
# Renamed: Clicking_Stream_Frog_404_secondary.wav -> Clicking_657.wav
# Renamed: Clicking_Stream_Frog_405_primary.wav -> Clicking_658.wav
# Renamed: Clicking_Stream_Frog_405_secondary.wav -> Clicking_659.wav
# Renamed: Clicking_Stream_Frog_406_primary.wav -> Clicking_660.wav
# Renamed: Clicking_Stream_Frog_406_secondary.wav -> Clicking_661.wav
# Renamed: Clicking_Stream_Frog_407_primary.wav -> Clicking_662.wav
# Renamed: Clicking_Stream_Frog_407_secondary.wav -> Clicking_663.wav
# Renamed: Clicking_Stream_Frog_408_primary.wav -> Clicking_664.wav
# Renamed: Clicking_Stream_Frog_408_secondary.wav -> Clicking_665.wav
# Renamed: Clicking_Stream_Frog_409_primary.wav -> Clicking_666.wav
# Renamed: Clicking_Stream_Frog_409_secondary.wav -> Clicking_667.wav
# Renamed: Clicking_Stream_Frog_40_primary.wav -> Clicking_668.wav
# Renamed: Clicking_Stream_Frog_40_secondary.wav -> Clicking_669.wav
# Renamed: Clicking_Stream_Frog_410_primary.wav -> Clicking_670.wav
# Renamed: Clicking_Stream_Frog_410_secondary.wav -> Clicking_671.wav
# Renamed: Clicking_Stream_Frog_411_primary.wav -> Clicking_672.wav
# Renamed: Clicking_Stream_Frog_411_secondary.wav -> Clicking_673.wav
# Renamed: Clicking_Stream_Frog_412_primary.wav -> Clicking_674.wav
# Renamed: Clicking_Stream_Frog_412_secondary.wav -> Clicking_675.wav
# Renamed: Clicking_Stream_Frog_413_primary.wav -> Clicking_676.wav
# Renamed: Clicking_Stream_Frog_413_secondary.wav -> Clicking_677.wav
# Renamed: Clicking_Stream_Frog_414_primary.wav -> Clicking_678.wav
# Renamed: Clicking_Stream_Frog_414_secondary.wav -> Clicking_679.wav
# Renamed: Clicking_Stream_Frog_415_primary.wav -> Clicking_680.wav
# Renamed: Clicking_Stream_Frog_415_secondary.wav -> Clicking_681.wav
# Renamed: Clicking_Stream_Frog_416_primary.wav -> Clicking_682.wav
# Renamed: Clicking_Stream_Frog_416_secondary.wav -> Clicking_683.wav
# Renamed: Clicking_Stream_Frog_417_primary.wav -> Clicking_684.wav
# Renamed: Clicking_Stream_Frog_417_secondary.wav -> Clicking_685.wav
# Renamed: Clicking_Stream_Frog_418_primary.wav -> Clicking_686.wav
# Renamed: Clicking_Stream_Frog_418_secondary.wav -> Clicking_687.wav
# Renamed: Clicking_Stream_Frog_419_primary.wav -> Clicking_688.wav
# Renamed: Clicking_Stream_Frog_419_secondary.wav -> Clicking_689.wav
# Renamed: Clicking_Stream_Frog_41_primary.wav -> Clicking_690.wav
# Renamed: Clicking_Stream_Frog_41_secondary.wav -> Clicking_691.wav
# Renamed: Clicking_Stream_Frog_420_primary.wav -> Clicking_692.wav
# Renamed: Clicking_Stream_Frog_420_secondary.wav -> Clicking_693.wav
# Renamed: Clicking_Stream_Frog_421_primary.wav -> Clicking_694.wav
# Renamed: Clicking_Stream_Frog_421_secondary.wav -> Clicking_695.wav
# Renamed: Clicking_Stream_Frog_422_primary.wav -> Clicking_696.wav
# Renamed: Clicking_Stream_Frog_422_secondary.wav -> Clicking_697.wav
# Renamed: Clicking_Stream_Frog_423_primary.wav -> Clicking_698.wav
# Renamed: Clicking_Stream_Frog_423_secondary.wav -> Clicking_699.wav
# Renamed: Clicking_Stream_Frog_424_primary.wav -> Clicking_700.wav
# Renamed: Clicking_Stream_Frog_424_secondary.wav -> Clicking_701.wav
# Renamed: Clicking_Stream_Frog_425_primary.wav -> Clicking_702.wav
# Renamed: Clicking_Stream_Frog_425_secondary.wav -> Clicking_703.wav
# Renamed: Clicking_Stream_Frog_426_primary.wav -> Clicking_704.wav
# Renamed: Clicking_Stream_Frog_426_secondary.wav -> Clicking_705.wav
# Renamed: Clicking_Stream_Frog_427_primary.wav -> Clicking_706.wav
# Renamed: Clicking_Stream_Frog_427_secondary.wav -> Clicking_707.wav
# Renamed: Clicking_Stream_Frog_428_primary.wav -> Clicking_708.wav
# Renamed: Clicking_Stream_Frog_428_secondary.wav -> Clicking_709.wav
# Renamed: Clicking_Stream_Frog_429_primary.wav -> Clicking_710.wav
# Renamed: Clicking_Stream_Frog_429_secondary.wav -> Clicking_711.wav
# Renamed: Clicking_Stream_Frog_42_primary.wav -> Clicking_712.wav
# Renamed: Clicking_Stream_Frog_42_secondary.wav -> Clicking_713.wav
# Renamed: Clicking_Stream_Frog_430_primary.wav -> Clicking_714.wav
# Renamed: Clicking_Stream_Frog_430_secondary.wav -> Clicking_715.wav
# Renamed: Clicking_Stream_Frog_431_primary.wav -> Clicking_716.wav
# Renamed: Clicking_Stream_Frog_431_secondary.wav -> Clicking_717.wav
# Renamed: Clicking_Stream_Frog_432_primary.wav -> Clicking_718.wav
# Renamed: Clicking_Stream_Frog_432_secondary.wav -> Clicking_719.wav
# ...
# Renamed: other_frog_869_primary.wav -> other_6588.wav
# Renamed: other_frog_869_secondary.wav -> other_6589.wav
# Renamed: other_frog_86_primary.wav -> other_6590.wav
# Renamed: other_frog_86_secondary.wav -> other_6591.wav
# Renamed: other_frog_870_primary.wav -> other_6592.wav
# Renamed: other_frog_870_secondary.wav -> other_6593.wav
# Renamed: other_frog_871_primary.wav -> other_6594.wav
# Renamed: other_frog_871_secondary.wav -> other_6595.wav
# Renamed: other_frog_872_primary.wav -> other_6596.wav
# Renamed: other_frog_872_secondary.wav -> other_6597.wav
# Renamed: other_frog_873_primary.wav -> other_6598.wav
# Renamed: other_frog_873_secondary.wav -> other_6599.wav
# Renamed: other_frog_874_primary.wav -> other_6600.wav
# Renamed: other_frog_874_secondary.wav -> other_6601.wav
# Renamed: other_frog_875_primary.wav -> other_6602.wav
# Renamed: other_frog_875_secondary.wav -> other_6603.wav
# Renamed: other_frog_876_primary.wav -> other_6604.wav
# Renamed: other_frog_876_secondary.wav -> other_6605.wav
# Renamed: other_frog_877_primary.wav -> other_6606.wav
# Renamed: other_frog_877_secondary.wav -> other_6607.wav
# Renamed: other_frog_878_primary.wav -> other_6608.wav
# Renamed: other_frog_878_secondary.wav -> other_6609.wav
# Renamed: other_frog_879_primary.wav -> other_6610.wav
# Renamed: other_frog_879_secondary.wav -> other_6611.wav
# Renamed: other_frog_87_primary.wav -> other_6612.wav
# Renamed: other_frog_87_secondary.wav -> other_6613.wav
# Renamed: other_frog_880_primary.wav -> other_6614.wav
# Renamed: other_frog_880_secondary.wav -> other_6615.wav
# Renamed: other_frog_881_primary.wav -> other_6616.wav
# Renamed: other_frog_881_secondary.wav -> other_6617.wav
# Renamed: other_frog_882_primary.wav -> other_6618.wav
# Renamed: other_frog_882_secondary.wav -> other_6619.wav
# Renamed: other_frog_883_primary.wav -> other_6620.wav
# Renamed: other_frog_883_secondary.wav -> other_6621.wav
# Renamed: other_frog_884_primary.wav -> other_6622.wav
# Renamed: other_frog_884_secondary.wav -> other_6623.wav
# Renamed: other_frog_885_primary.wav -> other_6624.wav
# Renamed: other_frog_885_secondary.wav -> other_6625.wav
# Renamed: other_frog_886_primary.wav -> other_6626.wav
# Renamed: other_frog_886_secondary.wav -> other_6627.wav
# Renamed: other_frog_887_primary.wav -> other_6628.wav
# Renamed: other_frog_887_secondary.wav -> other_6629.wav
# Renamed: other_frog_888_primary.wav -> other_6630.wav
# Renamed: other_frog_888_secondary.wav -> other_6631.wav
# Renamed: other_frog_889_primary.wav -> other_6632.wav
# Renamed: other_frog_889_secondary.wav -> other_6633.wav
# Renamed: other_frog_88_primary.wav -> other_6634.wav
# Renamed: other_frog_88_secondary.wav -> other_6635.wav
# Renamed: other_frog_890_primary.wav -> other_6636.wav
# Renamed: other_frog_890_secondary.wav -> other_6637.wav
# Renamed: other_frog_891_primary.wav -> other_6638.wav
# Renamed: other_frog_891_secondary.wav -> other_6639.wav
# Renamed: other_frog_892_primary.wav -> other_6640.wav
# Renamed: other_frog_892_secondary.wav -> other_6641.wav
# Renamed: other_frog_893_primary.wav -> other_6642.wav
# Renamed: other_frog_893_secondary.wav -> other_6643.wav
# Renamed: other_frog_894_primary.wav -> other_6644.wav
# Renamed: other_frog_894_secondary.wav -> other_6645.wav
# Renamed: other_frog_895_primary.wav -> other_6646.wav
# Renamed: other_frog_895_secondary.wav -> other_6647.wav
# Renamed: other_frog_896_primary.wav -> other_6648.wav
# Renamed: other_frog_896_secondary.wav -> other_6649.wav
# Renamed: other_frog_897_primary.wav -> other_6650.wav
# Renamed: other_frog_897_secondary.wav -> other_6651.wav
# Renamed: other_frog_898_primary.wav -> other_6652.wav
# Renamed: other_frog_898_secondary.wav -> other_6653.wav
# Renamed: other_frog_899_primary.wav -> other_6654.wav
# Renamed: other_frog_899_secondary.wav -> other_6655.wav
# Renamed: other_frog_89_primary.wav -> other_6656.wav
# Renamed: other_frog_89_secondary.wav -> other_6657.wav
# Renamed: other_frog_8_primary.wav -> other_6658.wav
# Renamed: other_frog_8_secondary.wav -> other_6659.wav
# Renamed: other_frog_900_primary.wav -> other_6660.wav
# Renamed: other_frog_900_secondary.wav -> other_6661.wav
# Renamed: other_frog_901_primary.wav -> other_6662.wav
# Renamed: other_frog_901_secondary.wav -> other_6663.wav
# Renamed: other_frog_902_primary.wav -> other_6664.wav
# Renamed: other_frog_902_secondary.wav -> other_6665.wav
# Renamed: other_frog_903_primary.wav -> other_6666.wav
# Renamed: other_frog_903_secondary.wav -> other_6667.wav
# Renamed: other_frog_904_primary.wav -> other_6668.wav
# Renamed: other_frog_904_secondary.wav -> other_6669.wav
# Renamed: other_frog_905_primary.wav -> other_6670.wav
# Renamed: other_frog_905_secondary.wav -> other_6671.wav
# Renamed: other_frog_906_primary.wav -> other_6672.wav
# Renamed: other_frog_906_secondary.wav -> other_6673.wav
# Renamed: other_frog_907_primary.wav -> other_6674.wav
# Renamed: other_frog_907_secondary.wav -> other_6675.wav
# Renamed: other_frog_908_primary.wav -> other_6676.wav
# Renamed: other_frog_908_secondary.wav -> other_6677.wav
# Renamed: other_frog_909_primary.wav -> other_6678.wav
# Renamed: other_frog_909_secondary.wav -> other_6679.wav
# Renamed: other_frog_90_primary.wav -> other_6680.wav
# Renamed: other_frog_90_secondary.wav -> other_6681.wav
# Renamed: other_frog_910_primary.wav -> other_6682.wav
# Renamed: other_frog_910_secondary.wav -> other_6683.wav
# Renamed: other_frog_911_primary.wav -> other_6684.wav
# Renamed: other_frog_911_secondary.wav -> other_6685.wav
# Renamed: other_frog_912_primary.wav -> other_6686.wav
# Renamed: other_frog_912_secondary.wav -> other_6687.wav
# Renamed: other_frog_913_primary.wav -> other_6688.wav
# Renamed: other_frog_913_secondary.wav -> other_6689.wav
# Renamed: other_frog_914_primary.wav -> other_6690.wav
# Renamed: other_frog_914_secondary.wav -> other_6691.wav
# Renamed: other_frog_915_primary.wav -> other_6692.wav
# Renamed: other_frog_915_secondary.wav -> other_6693.wav
# Renamed: other_frog_916_primary.wav -> other_6694.wav
# Renamed: other_frog_916_secondary.wav -> other_6695.wav
# Renamed: other_frog_917_primary.wav -> other_6696.wav
# Renamed: other_frog_917_secondary.wav -> other_6697.wav
# Renamed: other_frog_918_primary.wav -> other_6698.wav
# Renamed: other_frog_918_secondary.wav -> other_6699.wav
# Renamed: other_frog_919_primary.wav -> other_6700.wav
# Renamed: other_frog_919_secondary.wav -> other_6701.wav
# Renamed: other_frog_91_primary.wav -> other_6702.wav
# Renamed: other_frog_91_secondary.wav -> other_6703.wav
# Renamed: other_frog_920_primary.wav -> other_6704.wav
# Renamed: other_frog_920_secondary.wav -> other_6705.wav
# Renamed: other_frog_921_primary.wav -> other_6706.wav
# Renamed: other_frog_921_secondary.wav -> other_6707.wav
# Renamed: other_frog_922_primary.wav -> other_6708.wav
# Renamed: other_frog_922_secondary.wav -> other_6709.wav
# Renamed: other_frog_923_primary.wav -> other_6710.wav
# Renamed: other_frog_923_secondary.wav -> other_6711.wav
# Renamed: other_frog_924_primary.wav -> other_6712.wav
# Renamed: other_frog_924_secondary.wav -> other_6713.wav
# Renamed: other_frog_925_primary.wav -> other_6714.wav
# Renamed: other_frog_925_secondary.wav -> other_6715.wav
# Renamed: other_frog_926_primary.wav -> other_6716.wav
# Renamed: other_frog_926_secondary.wav -> other_6717.wav
# Renamed: other_frog_927_primary.wav -> other_6718.wav
# Renamed: other_frog_927_secondary.wav -> other_6719.wav
# Renamed: other_frog_928_primary.wav -> other_6720.wav
# Renamed: other_frog_928_secondary.wav -> other_6721.wav
# Renamed: other_frog_929_primary.wav -> other_6722.wav
# Renamed: other_frog_929_secondary.wav -> other_6723.wav
# Renamed: other_frog_92_primary.wav -> other_6724.wav
# Renamed: other_frog_92_secondary.wav -> other_6725.wav
# Renamed: other_frog_930_primary.wav -> other_6726.wav
# Renamed: other_frog_930_secondary.wav -> other_6727.wav
# Renamed: other_frog_931_primary.wav -> other_6728.wav
# Renamed: other_frog_931_secondary.wav -> other_6729.wav
# Renamed: other_frog_932_primary.wav -> other_6730.wav
# Renamed: other_frog_932_secondary.wav -> other_6731.wav
# Renamed: other_frog_933_primary.wav -> other_6732.wav
# Renamed: other_frog_933_secondary.wav -> other_6733.wav
# Renamed: other_frog_934_primary.wav -> other_6734.wav
# Renamed: other_frog_934_secondary.wav -> other_6735.wav
# Renamed: other_frog_935_primary.wav -> other_6736.wav
# Renamed: other_frog_935_secondary.wav -> other_6737.wav
# Renamed: other_frog_936_primary.wav -> other_6738.wav
# Renamed: other_frog_936_secondary.wav -> other_6739.wav
# Renamed: other_frog_937_primary.wav -> other_6740.wav
# Renamed: other_frog_937_secondary.wav -> other_6741.wav
# Renamed: other_frog_938_primary.wav -> other_6742.wav
# Renamed: other_frog_938_secondary.wav -> other_6743.wav
# Renamed: other_frog_939_primary.wav -> other_6744.wav
# Renamed: other_frog_939_secondary.wav -> other_6745.wav
# Renamed: other_frog_93_primary.wav -> other_6746.wav
# Renamed: other_frog_93_secondary.wav -> other_6747.wav
# Renamed: other_frog_940_primary.wav -> other_6748.wav
# Renamed: other_frog_940_secondary.wav -> other_6749.wav
# Renamed: other_frog_941_primary.wav -> other_6750.wav
# Renamed: other_frog_941_secondary.wav -> other_6751.wav
# Renamed: other_frog_942_primary.wav -> other_6752.wav
# Renamed: other_frog_942_secondary.wav -> other_6753.wav
# Renamed: other_frog_943_primary.wav -> other_6754.wav
# Renamed: other_frog_943_secondary.wav -> other_6755.wav
# Renamed: other_frog_944_primary.wav -> other_6756.wav
# Renamed: other_frog_944_secondary.wav -> other_6757.wav
# Renamed: other_frog_945_primary.wav -> other_6758.wav
# Renamed: other_frog_945_secondary.wav -> other_6759.wav
# Renamed: other_frog_946_primary.wav -> other_6760.wav
# Renamed: other_frog_946_secondary.wav -> other_6761.wav
# Renamed: other_frog_947_primary.wav -> other_6762.wav
# Renamed: other_frog_948_primary.wav -> other_6763.wav
# Renamed: other_frog_948_secondary.wav -> other_6764.wav
# Renamed: other_frog_949_primary.wav -> other_6765.wav
# Renamed: other_frog_949_secondary.wav -> other_6766.wav
# Renamed: other_frog_94_primary.wav -> other_6767.wav
# Renamed: other_frog_94_secondary.wav -> other_6768.wav
# Renamed: other_frog_950_primary.wav -> other_6769.wav
# Renamed: other_frog_950_secondary.wav -> other_6770.wav
# Renamed: other_frog_951_primary.wav -> other_6771.wav
# Renamed: other_frog_951_secondary.wav -> other_6772.wav
# Renamed: other_frog_952_primary.wav -> other_6773.wav
# Renamed: other_frog_952_secondary.wav -> other_6774.wav
# Renamed: other_frog_953_primary.wav -> other_6775.wav
# Renamed: other_frog_953_secondary.wav -> other_6776.wav
# Renamed: other_frog_954_primary.wav -> other_6777.wav
# Renamed: other_frog_954_secondary.wav -> other_6778.wav
# Renamed: other_frog_955_primary.wav -> other_6779.wav
# Renamed: other_frog_955_secondary.wav -> other_6780.wav
# Renamed: other_frog_956_primary.wav -> other_6781.wav
# Renamed: other_frog_956_secondary.wav -> other_6782.wav
# Renamed: other_frog_957_primary.wav -> other_6783.wav
# Renamed: other_frog_957_secondary.wav -> other_6784.wav
# Renamed: other_frog_958_primary.wav -> other_6785.wav
# Renamed: other_frog_958_secondary.wav -> other_6786.wav
# Renamed: other_frog_959_primary.wav -> other_6787.wav
# Renamed: other_frog_959_secondary.wav -> other_6788.wav
# Renamed: other_frog_95_primary.wav -> other_6789.wav
# Renamed: other_frog_95_secondary.wav -> other_6790.wav
# Renamed: other_frog_960_primary.wav -> other_6791.wav
# Renamed: other_frog_960_secondary.wav -> other_6792.wav
# Renamed: other_frog_961_primary.wav -> other_6793.wav
# Renamed: other_frog_961_secondary.wav -> other_6794.wav
# Renamed: other_frog_963_primary.wav -> other_6795.wav
# Renamed: other_frog_963_secondary.wav -> other_6796.wav
# Renamed: other_frog_964_primary.wav -> other_6797.wav
# Renamed: other_frog_964_secondary.wav -> other_6798.wav
# Renamed: other_frog_965_primary.wav -> other_6799.wav
# Renamed: other_frog_965_secondary.wav -> other_6800.wav
# Renamed: other_frog_966_primary.wav -> other_6801.wav
# Renamed: other_frog_966_secondary.wav -> other_6802.wav
# Renamed: other_frog_967_primary.wav -> other_6803.wav
# Renamed: other_frog_967_secondary.wav -> other_6804.wav
# Renamed: other_frog_968_primary.wav -> other_6805.wav
# Renamed: other_frog_968_secondary.wav -> other_6806.wav
# Renamed: other_frog_969_primary.wav -> other_6807.wav
# Renamed: other_frog_969_secondary.wav -> other_6808.wav
# Renamed: other_frog_96_primary.wav -> other_6809.wav
# Renamed: other_frog_96_secondary.wav -> other_6810.wav
# Renamed: other_frog_970_primary.wav -> other_6811.wav
# Renamed: other_frog_970_secondary.wav -> other_6812.wav
# Renamed: other_frog_971_primary.wav -> other_6813.wav
# Renamed: other_frog_971_secondary.wav -> other_6814.wav
# Renamed: other_frog_972_primary.wav -> other_6815.wav
# Renamed: other_frog_972_secondary.wav -> other_6816.wav
# Renamed: other_frog_973_primary.wav -> other_6817.wav
# Renamed: other_frog_973_secondary.wav -> other_6818.wav
# Renamed: other_frog_974_primary.wav -> other_6819.wav
# Renamed: other_frog_974_secondary.wav -> other_6820.wav
# Renamed: other_frog_975_primary.wav -> other_6821.wav
# Renamed: other_frog_975_secondary.wav -> other_6822.wav
# Renamed: other_frog_976_primary.wav -> other_6823.wav
# Renamed: other_frog_976_secondary.wav -> other_6824.wav
# Renamed: other_frog_977_primary.wav -> other_6825.wav
# Renamed: other_frog_977_secondary.wav -> other_6826.wav
# Renamed: other_frog_978_primary.wav -> other_6827.wav
# Renamed: other_frog_978_secondary.wav -> other_6828.wav
# Renamed: other_frog_979_primary.wav -> other_6829.wav
# Renamed: other_frog_979_secondary.wav -> other_6830.wav
# Renamed: other_frog_97_primary.wav -> other_6831.wav
# Renamed: other_frog_97_secondary.wav -> other_6832.wav
# Renamed: other_frog_980_primary.wav -> other_6833.wav
# Renamed: other_frog_980_secondary.wav -> other_6834.wav
# Renamed: other_frog_981_primary.wav -> other_6835.wav
# Renamed: other_frog_981_secondary.wav -> other_6836.wav
# Renamed: other_frog_982_primary.wav -> other_6837.wav
# Renamed: other_frog_982_secondary.wav -> other_6838.wav
# Renamed: other_frog_983_primary.wav -> other_6839.wav
# Renamed: other_frog_983_secondary.wav -> other_6840.wav
# Renamed: other_frog_984_primary.wav -> other_6841.wav
# Renamed: other_frog_984_secondary.wav -> other_6842.wav
# Renamed: other_frog_985_primary.wav -> other_6843.wav
# Renamed: other_frog_985_secondary.wav -> other_6844.wav
# Renamed: other_frog_986_primary.wav -> other_6845.wav
# Renamed: other_frog_986_secondary.wav -> other_6846.wav
# Renamed: other_frog_987_primary.wav -> other_6847.wav
# Renamed: other_frog_987_secondary.wav -> other_6848.wav
# Renamed: other_frog_988_primary.wav -> other_6849.wav
# Renamed: other_frog_988_secondary.wav -> other_6850.wav
# Renamed: other_frog_989_primary.wav -> other_6851.wav
# Renamed: other_frog_989_secondary.wav -> other_6852.wav
# Renamed: other_frog_98_primary.wav -> other_6853.wav
# Renamed: other_frog_98_secondary.wav -> other_6854.wav
# Renamed: other_frog_990_primary.wav -> other_6855.wav
# Renamed: other_frog_990_secondary.wav -> other_6856.wav
# Renamed: other_frog_991_primary.wav -> other_6857.wav
# Renamed: other_frog_991_secondary.wav -> other_6858.wav
# Renamed: other_frog_992_primary.wav -> other_6859.wav
# Renamed: other_frog_992_secondary.wav -> other_6860.wav
# Renamed: other_frog_993_primary.wav -> other_6861.wav
# Renamed: other_frog_993_secondary.wav -> other_6862.wav
# Renamed: other_frog_994_primary.wav -> other_6863.wav
# Renamed: other_frog_994_secondary.wav -> other_6864.wav
# Renamed: other_frog_995_primary.wav -> other_6865.wav
# Renamed: other_frog_995_secondary.wav -> other_6866.wav
# Renamed: other_frog_996_primary.wav -> other_6867.wav
# Renamed: other_frog_996_secondary.wav -> other_6868.wav
# Renamed: other_frog_997_primary.wav -> other_6869.wav
# Renamed: other_frog_997_secondary.wav -> other_6870.wav
# Renamed: other_frog_998_primary.wav -> other_6871.wav
# Renamed: other_frog_998_secondary.wav -> other_6872.wav
# Renamed: other_frog_999_primary.wav -> other_6873.wav
# Renamed: other_frog_999_secondary.wav -> other_6874.wav
# Renamed: other_frog_99_primary.wav -> other_6875.wav
# Renamed: other_frog_99_secondary.wav -> other_6876.wav
# Renamed: other_frog_9_primary.wav -> other_6877.wav
# Renamed: other_frog_9_secondary.wav -> other_6878.wav
# Renaming complete!

# %% [markdown]
# ## Convert all of the audio files into Spectrograms and save as .h5

# %%
import os
import numpy as np
import librosa
from joblib import Parallel, delayed
import multiprocessing
import h5py
from tqdm import tqdm

# Configuration
AUDIO_DIR = "../Datasets/clipped-4s/"
OUTPUT_DIR = "../Datasets/"
os.makedirs(OUTPUT_DIR, exist_ok=True)

SAMPLE_RATE = 22050
N_FFT = 2048
HOP_LENGTH = 256
N_MELS = 128

def process_file(file):
    try:
        if file.lower().endswith('.wav'):
            audio_path = os.path.join(AUDIO_DIR, file)
            y, sr = librosa.load(audio_path, sr=SAMPLE_RATE, res_type='kaiser_fast', mono=True)
            S = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=N_FFT, hop_length=HOP_LENGTH, n_mels=N_MELS)
            S_dB = librosa.power_to_db(S, ref=np.max)
            key = os.path.splitext(file)[0]
            return key, S_dB
    except Exception as e:
        print(f"\nSkipped {file}: {str(e)}")
        return None

# Get list of files first for accurate tqdm progress
files = [f for f in os.listdir(AUDIO_DIR) if f.lower().endswith('.wav')]
print(f"Processing {len(files)} audio files...")


batch_size = 500
for i in tqdm(range(0, len(files), batch_size)):
    batch = files[i:i+batch_size]
    results = Parallel(n_jobs=2)(delayed(process_file)(f) for f in batch)
    with h5py.File(os.path.join(OUTPUT_DIR, 'FD_0.4.h5'), 'a') as hf:  # 'a' for append
        for result in results:
            if result is not None:
                key, S_dB = result
                hf.create_dataset(key, data=S_dB)


print(f"\nDone! Spectrograms saved to {OUTPUT_DIR}")
# Out:
# Processing 12963 audio files...
# 100%|██████████| 26/26 [01:32<00:00,  3.54s/it]
# Done! Spectrograms saved to ../Datasets/
