# %% [markdown]
# # Data Preproccesing for CNN Model

# %% [markdown]
# ## Data Downloader from iNaturlist

# %%
import pandas as pd
import requests
import os
from urllib.parse import urlparse
from tqdm import tqdm  # Import tqdm for the progress bar

# Read the CSV file
df = pd.read_csv('../Datasets/Inat/observations-all-recordings.csv/observations-598206.csv')

# Create a directory to save the sound files
os.makedirs('frog_sounds', exist_ok=True)

# Helper function to generate a unique filename
def get_unique_filename(directory, base_name, extension):
    full_path = os.path.join(directory, base_name + extension)
    counter = 1
    while os.path.exists(full_path):
        full_path = os.path.join(directory, f"{base_name}_{counter}{extension}")
        counter += 1
    return full_path

# Create a progress bar for the total number of downloads
with tqdm(total=len(df), desc="Downloading frog sounds") as pbar:
    # Iterate through each row in the DataFrame
    for index, row in df.iterrows():
        sound_url = row['sound_url']
        common_name = row['common_name']
        
        if pd.notna(sound_url) and pd.notna(common_name):
            try:
                # Extract the file extension from the URL
                parsed_url = urlparse(sound_url)
                filename = os.path.basename(parsed_url.path)
                extension = os.path.splitext(filename)[1]
                
                # Clean the common name to make it a valid filename
                clean_name = "".join(c if c.isalnum() or c in (' ', '-') else '_' for c in common_name).strip()
                clean_name = clean_name.replace(' ', '_')  # Optional: replace spaces with underscores
                
                # Generate a unique filename
                unique_filename = get_unique_filename('frog_sounds', clean_name, extension)
                
                # Download the file
                response = requests.get(sound_url, stream=True)
                if response.status_code == 200:
                    with open(unique_filename, 'wb') as f:
                        for chunk in response.iter_content(1024):
                            f.write(chunk)
                    # print(f"Downloaded: {unique_filename}")
                else:
                    print(f"Failed to download: {sound_url}")
            except Exception as e:
                print(f"Error processing {sound_url}: {e}")

            # Update the progress bar after each download
            pbar.update(1)

print("Download complete.")

# %% [markdown]
# ## Convert all files into .WAV

# %%
import os
import subprocess
from pathlib import Path
from tqdm import tqdm

def convert_to_spectrogram_ready(input_dir, output_dir, sample_rate=22050, mono=True):
    
    Path(output_dir).mkdir(parents=True, exist_ok=True)
    
    audio_files = []
    extensions = ('.wav', '.mp3', '.mp4', '.m4a', '.aac', '.flac', '.ogg', '.mpga')
    
    for root, _, files in os.walk(input_dir):
        for file in files:
            # if file.lower().endswith(extensions):
                audio_files.append(Path(root) / file)
    
    print(f"Found {len(audio_files)} audio files to process")
    
    for input_file in tqdm(audio_files, desc="Converting for spectrograms"):
        output_file = Path(output_dir) / f"{input_file.stem}.wav"
        
        cmd = [
            'ffmpeg',
            '-i', str(input_file),
            '-ac', '1' if mono else '2',  # mono recommended for spectrograms
            '-ar', str(sample_rate),  # 22050 is standard for many ML models
            '-sample_fmt', 's16',  # 16-bit PCM
            '-acodec', 'pcm_s16le',  # Standard WAV format
            '-y',
            str(output_file)
        ]
        
        try:
            subprocess.run(cmd, check=True, 
                         stdout=subprocess.DEVNULL, 
                         stderr=subprocess.PIPE)
        except subprocess.CalledProcessError as e:
            print(f"\nError processing {input_file}: {e.stderr.decode('utf-8')}")
    
    print(f"\nConversion complete. Files ready for spectrogram generation in {output_dir}")

if __name__ == "__main__":
    convert_to_spectrogram_ready(
        input_dir="frog_sounds/",
        output_dir="./frog_sounds_wav/"
    )
# Out:
# Found 7632 audio files to process
# Converting for spectrograms: 100%|██████████| 7632/7632 [08:05<00:00, 15.71it/s]
# Conversion complete. Files ready for spectrogram generation in ./frog_sounds_wav/

# %% [markdown]
# ## Rename files for only ID 4 most common frogs

# %%
import os
from pathlib import Path
from collections import defaultdict

def rename_frog_files(directory):
    """
    Renames frog audio files according to specific rules:
    - Keeps original names for Mountain_Rain_Frog, Southern_Dainty_Frog, Clicking_Stream_Frog
    - Renames others to other_frog_X.wav with incrementing X
    """
    # Files to keep original names
    KEEP_NAMES = {
        "mountain_rain_frog",
        "southern_dainty_frog",
        "clicking_stream_frog"
    }
    
    # Initialize counter for other_frog files
    other_counter = 1
    # Dictionary to track original name to new name mappings (for avoiding duplicates)
    name_mapping = defaultdict(str)
    
    # Get all .wav files in directory
    for filepath in Path(directory).glob("*.wav"):
        original_name = filepath.stem.lower()  # Get filename without extension
        
        # Check if we should keep original name
        should_keep = any(
            keep_name in original_name 
            for keep_name in KEEP_NAMES
        )
        
        if should_keep:
            continue  # Skip renaming
        
        # Generate new name
        new_name = f"other_frog_{other_counter}.wav"
        new_path = filepath.with_name(new_name)
        
        # Handle potential name conflicts
        while new_path.exists():
            other_counter += 1
            new_name = f"other_frog_{other_counter}.wav"
            new_path = filepath.with_name(new_name)
        
        # Rename the file
        filepath.rename(new_path)
        print(f"Renamed: {filepath.name} -> {new_name}")
        other_counter += 1

if __name__ == "__main__":
    directory_path = "./frog_sounds_wav/"  # Change to your directory
    rename_frog_files(directory_path)
    print("File renaming complete!")

# %% [markdown]
# ## Get file Info

# %%
import os
from pathlib import Path
import wave
import contextlib
from collections import defaultdict

def analyze_short_frog_files(directory, max_duration=4):
    """
    Finds all WAV files shorter than specified duration and counts by frog type.
    
    Args:
        directory (str): Path to directory containing WAV files
        max_duration (float): Maximum duration in seconds to consider as "short"
        
    Returns:
        tuple: (list of short files with durations, frog type counts, total count)
    """
    short_files = []
    frog_counts = defaultdict(int)
    special_frogs = {
        'mountain_rain_frog',
        'southern_dainty_frog',
        'clicking_stream_frog'
    }

    for filepath in Path(directory).glob('*.wav'):
        try:
            with contextlib.closing(wave.open(str(filepath), 'r')) as wav_file:
                frames = wav_file.getnframes()
                rate = wav_file.getframerate()
                duration = frames / float(rate)
                
                if duration < max_duration:
                    filename = filepath.stem.lower()
                    
                    # Determine frog type
                    frog_type = "other"
                    for special in special_frogs:
                        if special in filename:
                            frog_type = special.replace('_', ' ').title()
                            break
                    
                    short_files.append((filepath.name, duration, frog_type))
                    frog_counts[frog_type] += 1
                    
        except (wave.Error, EOFError) as e:
            print(f"Error processing {filepath.name}: {str(e)}")
            continue
    
    return short_files, frog_counts, len(short_files)

if __name__ == "__main__":
    folder_path = "./frog_sounds_wav/"  # Replace with your folder path
    try:
        short_files, frog_counts, total_count = analyze_short_frog_files(folder_path)
        
        if not short_files:
            print("No files shorter than 5 seconds found.")
        else:
            print("Files shorter than 5 seconds:")
            print("-" * 65)
            print(f"{'Filename':<40} {'Duration':<10} {'Frog Type':<15}")
            print("-" * 65)
            for filename, duration, frog_type in short_files:
                print(f"{filename:<40} {duration:.2f}s{'':<5} {frog_type:<15}")
            
            print("-" * 65)
            print("\nFrog Type Counts:")
            for frog_type, count in sorted(frog_counts.items(), key=lambda x: x[1], reverse=True):
                print(f"{frog_type:<20}: {count}")
            
            print("-" * 65)
            print(f"Total files shorter than 5 seconds: {total_count}")
            
    except Exception as e:
        print(f"Error: {str(e)}")
# Out:
# Files shorter than 5 seconds:
# -----------------------------------------------------------------
# Filename                                 Duration   Frog Type
# -----------------------------------------------------------------
# other_frog_1818.wav                      3.01s      other
# other_frog_3281.wav                      2.40s      other
# other_frog_2736.wav                      2.53s      other
# Clicking_Stream_Frog_191.wav             3.76s      Clicking Stream Frog
# other_frog_269.wav                       3.16s      other
# other_frog_111.wav                       2.03s      other
# other_frog_661.wav                       3.37s      other
# other_frog_962.wav                       3.99s      other
# other_frog_1705.wav                      1.08s      other
# other_frog_523.wav                       1.19s      other
# other_frog_3282.wav                      1.21s      other
# other_frog_2594.wav                      0.40s      other
# other_frog_2158.wav                      2.09s      other
# other_frog_2325.wav                      3.40s      other
# other_frog_44.wav                        2.56s      other
# other_frog_1145.wav                      3.75s      other
# other_frog_2582.wav                      3.43s      other
# other_frog_3202.wav                      3.78s      other
# other_frog_3169.wav                      3.41s      other
# other_frog_2925.wav                      3.05s      other
# other_frog_1180.wav                      3.36s      other
# other_frog_780.wav                       3.72s      other
# other_frog_2543.wav                      2.19s      other
# Clicking_Stream_Frog_59.wav              3.60s      Clicking Stream Frog
# other_frog_2133.wav                      1.01s      other
# other_frog_2928.wav                      3.76s      other
# other_frog_703.wav                       3.65s      other
# other_frog_2487.wav                      3.03s      other
# other_frog_594.wav                       3.46s      other
# Clicking_Stream_Frog_43.wav              2.65s      Clicking Stream Frog
# other_frog_1375.wav                      3.58s      other
# other_frog_1146.wav                      1.25s      other
# other_frog_2326.wav                      3.44s      other
# other_frog_2196.wav                      3.74s      other
# other_frog_1225.wav                      2.83s      other
# other_frog_2927.wav                      3.41s      other
# other_frog_2628.wav                      3.99s      other
# other_frog_379.wav                       3.20s      other
# Clicking_Stream_Frog_199.wav             3.48s      Clicking Stream Frog
# other_frog_3425.wav                      2.02s      other
# other_frog_10.wav                        3.74s      other
# other_frog_1510.wav                      2.81s      other
# other_frog_1990.wav                      1.98s      other
# other_frog_3423.wav                      2.93s      other
# other_frog_338.wav                       2.37s      other
# other_frog_214.wav                       1.26s      other
# other_frog_1367.wav                      3.79s      other
# other_frog_2948.wav                      3.04s      other
# Clicking_Stream_Frog_439.wav             3.25s      Clicking Stream Frog
# other_frog_1547.wav                      1.02s      other
# Clicking_Stream_Frog_24.wav              2.30s      Clicking Stream Frog
# Clicking_Stream_Frog_317.wav             2.93s      Clicking Stream Frog
# other_frog_424.wav                       1.28s      other
# other_frog_2637.wav                      3.90s      other
# other_frog_3316.wav                      3.82s      other
# Mountain_Rain_Frog_3.wav                 2.30s      Mountain Rain Frog
# other_frog_2774.wav                      1.51s      other
# other_frog_1229.wav                      3.29s      other
# -----------------------------------------------------------------
#
# Frog Type Counts:
# other               : 50
# Clicking Stream Frog: 7
# Mountain Rain Frog  : 1
# -----------------------------------------------------------------
# Total files shorter than 5 seconds: 58

# %% [markdown]
# ## Clip files to 4 seconds

# %%
import os
import numpy as np
from pathlib import Path
from scipy.io import wavfile

def process_audio_files(input_dir, output_dir="clipped_4sec"):
    """
    Process mono audio files:
    - For files >4 seconds: create 4-second clip centered at max amplitude
    - For files <=4 seconds: copy as-is to output directory
    - All files saved to output directory
    """
    input_path = Path(input_dir)
    output_path = Path(output_dir)
    
    # Create output directory if it doesn't exist
    output_path.mkdir(exist_ok=True)
    
    processed_count = 0
    clipped_count = 0
    copied_count = 0
    
    for filepath in input_path.glob('*.wav'):
        try:
            # Read WAV file (mono)
            sample_rate, data = wavfile.read(filepath)
            
            # Ensure mono audio
            if len(data.shape) > 1:
                print(f"Skipping {filepath.name} - stereo audio not supported")
                continue
            
            duration = len(data) / sample_rate
            output_file = output_path / filepath.name
            
            if duration <= 4.0:
                # For short files, just copy to output directory
                wavfile.write(output_file, sample_rate, data)
                copied_count += 1
                print(f"Copied: {filepath.name} ({duration:.2f}s)")
            else:
                # Find point of max amplitude
                max_idx = np.argmax(np.abs(data))
                
                # Calculate 4-second window (2 seconds before and after max amplitude)
                half_window = int(2 * sample_rate)
                start = max(0, max_idx - half_window)
                end = start + 4 * sample_rate
                
                # Adjust if window exceeds file length
                if end > len(data):
                    end = len(data)
                    start = max(0, end - 4 * sample_rate)
                
                # Extract 4-second clip
                clipped_data = data[start:end]
                
                # Ensure exactly 4 seconds (pad with zeros if needed)
                if len(clipped_data) < 4 * sample_rate:
                    clipped_data = np.pad(clipped_data, 
                                        (0, 4 * sample_rate - len(clipped_data)), 
                                        mode='constant')
                
                # Save clipped file
                wavfile.write(output_file, sample_rate, clipped_data)
                clipped_count += 1
                print(f"Clipped: {filepath.name} ({duration:.2f}s -> 4.00s)")
                
            processed_count += 1
            
        except Exception as e:
            print(f"Error processing {filepath.name}: {str(e)}")
            continue
    
    print("\nProcessing complete!")
    print(f"Processed {processed_count} files")
    print(f"- {clipped_count} files clipped to 4 seconds")
    print(f"- {copied_count} files copied as-is (<=4 seconds)")
    print(f"Output directory: {output_path.resolve()}")

if __name__ == "__main__":
    input_directory = "./frog_sounds_wav/"  # Replace with your input directory
    process_audio_files(input_directory)
# Out:
# Clipped: Southern_Dainty_Frog_660.wav (60.00s -> 4.00s)
# Clipped: other_frog_708.wav (60.00s -> 4.00s)
# Copied: other_frog_1818.wav (3.01s)
# Clipped: Mountain_Rain_Frog_291.wav (60.00s -> 4.00s)
# Clipped: other_frog_817.wav (60.00s -> 4.00s)
# Clipped: other_frog_2425.wav (60.00s -> 4.00s)
# Clipped: other_frog_3113.wav (60.00s -> 4.00s)
# Clipped: other_frog_1119.wav (60.00s -> 4.00s)
# Copied: other_frog_3281.wav (2.40s)
# Clipped: other_frog_441.wav (28.12s -> 4.00s)
# Clipped: other_frog_2310.wav (60.00s -> 4.00s)
# Clipped: other_frog_3214.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_154.wav (6.83s -> 4.00s)
# Clipped: other_frog_325.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_576.wav (60.00s -> 4.00s)
# Clipped: other_frog_3285.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_333.wav (60.00s -> 4.00s)
# Clipped: other_frog_1779.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_231.wav (60.00s -> 4.00s)
# Clipped: other_frog_208.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_139.wav (60.00s -> 4.00s)
# Clipped: other_frog_2498.wav (26.97s -> 4.00s)
# Clipped: Mountain_Rain_Frog_775.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_129.wav (60.00s -> 4.00s)
# Clipped: other_frog_1234.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1040.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_335.wav (18.60s -> 4.00s)
# Clipped: other_frog_2175.wav (31.90s -> 4.00s)
# Clipped: other_frog_463.wav (6.72s -> 4.00s)
# Clipped: other_frog_2920.wav (60.00s -> 4.00s)
# Clipped: other_frog_974.wav (60.00s -> 4.00s)
# Clipped: other_frog_2674.wav (6.01s -> 4.00s)
# Clipped: Mountain_Rain_Frog_384.wav (60.00s -> 4.00s)
# Clipped: other_frog_3222.wav (15.14s -> 4.00s)
# Clipped: other_frog_420.wav (44.36s -> 4.00s)
# Clipped: Southern_Dainty_Frog_667.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_791.wav (60.00s -> 4.00s)
# Clipped: other_frog_636.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_707.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1271.wav (60.00s -> 4.00s)
# Clipped: other_frog_1291.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_738.wav (60.00s -> 4.00s)
# Clipped: other_frog_1093.wav (6.92s -> 4.00s)
# Clipped: other_frog_3242.wav (38.08s -> 4.00s)
# Copied: other_frog_2736.wav (2.53s)
# Clipped: other_frog_2082.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_424.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_719.wav (60.00s -> 4.00s)
# Clipped: other_frog_1203.wav (11.99s -> 4.00s)
# Clipped: other_frog_2468.wav (13.69s -> 4.00s)
# Clipped: other_frog_2813.wav (60.00s -> 4.00s)
# Clipped: other_frog_2457.wav (29.44s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1108.wav (60.00s -> 4.00s)
# Clipped: other_frog_1237.wav (13.86s -> 4.00s)
# Clipped: Mountain_Rain_Frog_771.wav (60.00s -> 4.00s)
# Clipped: other_frog_3370.wav (22.57s -> 4.00s)
# Clipped: other_frog_943.wav (32.72s -> 4.00s)
# Clipped: other_frog_2391.wav (60.00s -> 4.00s)
# Clipped: other_frog_1814.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_419.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1293.wav (60.00s -> 4.00s)
# Clipped: other_frog_2866.wav (11.20s -> 4.00s)
# Clipped: other_frog_427.wav (14.93s -> 4.00s)
# Clipped: other_frog_1034.wav (10.84s -> 4.00s)
# Clipped: Mountain_Rain_Frog_625.wav (60.00s -> 4.00s)
# Clipped: other_frog_582.wav (23.01s -> 4.00s)
# Clipped: other_frog_1955.wav (60.00s -> 4.00s)
# Clipped: other_frog_845.wav (60.00s -> 4.00s)
# Clipped: other_frog_1877.wav (23.28s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1104.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_522.wav (60.00s -> 4.00s)
# Clipped: other_frog_3079.wav (60.00s -> 4.00s)
# Clipped: other_frog_2678.wav (60.00s -> 4.00s)
# Clipped: other_frog_2823.wav (60.00s -> 4.00s)
# Clipped: other_frog_496.wav (60.00s -> 4.00s)
# Clipped: other_frog_616.wav (13.76s -> 4.00s)
# Clipped: other_frog_821.wav (60.00s -> 4.00s)
# Clipped: other_frog_1627.wav (6.20s -> 4.00s)
# Clipped: other_frog_982.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_24.wav (10.52s -> 4.00s)
# Clipped: other_frog_869.wav (10.43s -> 4.00s)
# Clipped: Clicking_Stream_Frog_27.wav (11.47s -> 4.00s)
# Clipped: Mountain_Rain_Frog_576.wav (60.00s -> 4.00s)
# Clipped: other_frog_2531.wav (23.98s -> 4.00s)
# Clipped: other_frog_649.wav (60.00s -> 4.00s)
# Clipped: other_frog_1459.wav (60.00s -> 4.00s)
# Clipped: other_frog_828.wav (8.03s -> 4.00s)
# Clipped: other_frog_1192.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1089.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1253.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1066.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_82.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1179.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_100.wav (60.00s -> 4.00s)
# Clipped: other_frog_3497.wav (60.00s -> 4.00s)
# Clipped: other_frog_2836.wav (42.42s -> 4.00s)
# Clipped: other_frog_2263.wav (60.00s -> 4.00s)
# Clipped: other_frog_1910.wav (60.00s -> 4.00s)
# Copied: Clicking_Stream_Frog_191.wav (3.76s)
# Clipped: Mountain_Rain_Frog_308.wav (60.00s -> 4.00s)
# Clipped: other_frog_2001.wav (31.36s -> 4.00s)
# Clipped: other_frog_1134.wav (60.00s -> 4.00s)
# Clipped: other_frog_3504.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_129.wav (12.10s -> 4.00s)
# Clipped: other_frog_2807.wav (15.53s -> 4.00s)
# Clipped: other_frog_1233.wav (21.71s -> 4.00s)
# Clipped: Southern_Dainty_Frog_159.wav (60.00s -> 4.00s)
# Clipped: other_frog_2278.wav (60.00s -> 4.00s)
# Clipped: other_frog_1806.wav (60.00s -> 4.00s)
# Clipped: other_frog_2589.wav (6.41s -> 4.00s)
# Clipped: other_frog_3342.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_408.wav (10.84s -> 4.00s)
# Clipped: Mountain_Rain_Frog_128.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_157.wav (21.08s -> 4.00s)
# Clipped: Mountain_Rain_Frog_310.wav (60.00s -> 4.00s)
# Clipped: other_frog_813.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_211.wav (11.89s -> 4.00s)
# Clipped: Clicking_Stream_Frog_346.wav (8.52s -> 4.00s)
# Clipped: Mountain_Rain_Frog_75.wav (60.00s -> 4.00s)
# Clipped: other_frog_921.wav (5.60s -> 4.00s)
# Clipped: Southern_Dainty_Frog_706.wav (60.00s -> 4.00s)
# Clipped: other_frog_2739.wav (60.00s -> 4.00s)
# Clipped: other_frog_258.wav (21.12s -> 4.00s)
# Clipped: Southern_Dainty_Frog_406.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_165.wav (60.00s -> 4.00s)
# Clipped: other_frog_911.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_955.wav (60.00s -> 4.00s)
# Clipped: other_frog_1279.wav (18.72s -> 4.00s)
# Clipped: other_frog_1322.wav (60.00s -> 4.00s)
# Clipped: other_frog_1952.wav (60.00s -> 4.00s)
# Clipped: other_frog_2525.wav (7.11s -> 4.00s)
# Clipped: Southern_Dainty_Frog_41.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1158.wav (60.00s -> 4.00s)
# Clipped: other_frog_1278.wav (16.60s -> 4.00s)
# Clipped: other_frog_3163.wav (11.29s -> 4.00s)
# Clipped: other_frog_421.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_239.wav (21.36s -> 4.00s)
# Clipped: other_frog_932.wav (11.68s -> 4.00s)
# Clipped: other_frog_810.wav (11.19s -> 4.00s)
# Clipped: other_frog_3398.wav (34.20s -> 4.00s)
# Clipped: other_frog_1836.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_960.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_103.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1259.wav (60.00s -> 4.00s)
# Clipped: other_frog_2480.wav (16.28s -> 4.00s)
# Clipped: other_frog_2101.wav (7.20s -> 4.00s)
# Clipped: Mountain_Rain_Frog_146.wav (60.00s -> 4.00s)
# Clipped: other_frog_787.wav (22.85s -> 4.00s)
# Clipped: other_frog_2171.wav (17.81s -> 4.00s)
# Clipped: Southern_Dainty_Frog_379.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1297.wav (60.00s -> 4.00s)
# Clipped: other_frog_1971.wav (5.80s -> 4.00s)
# Clipped: other_frog_1319.wav (19.88s -> 4.00s)
# Clipped: other_frog_1115.wav (60.00s -> 4.00s)
# Clipped: other_frog_534.wav (27.20s -> 4.00s)
# Clipped: other_frog_2443.wav (60.00s -> 4.00s)
# Clipped: other_frog_483.wav (15.86s -> 4.00s)
# Clipped: other_frog_3032.wav (11.63s -> 4.00s)
# Clipped: other_frog_612.wav (52.74s -> 4.00s)
# Clipped: Clicking_Stream_Frog_45.wav (46.24s -> 4.00s)
# Clipped: other_frog_3506.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_16.wav (8.64s -> 4.00s)
# Clipped: other_frog_856.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_497.wav (60.00s -> 4.00s)
# Clipped: other_frog_942.wav (12.68s -> 4.00s)
# Clipped: Clicking_Stream_Frog_98.wav (25.69s -> 4.00s)
# Clipped: Mountain_Rain_Frog_199.wav (60.00s -> 4.00s)
# Clipped: other_frog_2400.wav (15.20s -> 4.00s)
# Clipped: Clicking_Stream_Frog_21.wav (17.01s -> 4.00s)
# Clipped: Southern_Dainty_Frog_591.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_898.wav (60.00s -> 4.00s)
# Clipped: other_frog_688.wav (20.76s -> 4.00s)
# Clipped: other_frog_1616.wav (60.00s -> 4.00s)
# Clipped: other_frog_2842.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_319.wav (7.52s -> 4.00s)
# Clipped: other_frog_3323.wav (27.58s -> 4.00s)
# Clipped: other_frog_876.wav (11.28s -> 4.00s)
# Clipped: Mountain_Rain_Frog_366.wav (60.00s -> 4.00s)
# Clipped: other_frog_1800.wav (12.19s -> 4.00s)
# Clipped: other_frog_3056.wav (10.05s -> 4.00s)
# Clipped: Southern_Dainty_Frog_692.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_183.wav (60.00s -> 4.00s)
# Clipped: other_frog_2459.wav (11.98s -> 4.00s)
# Clipped: Mountain_Rain_Frog_528.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_328.wav (26.91s -> 4.00s)
# Clipped: other_frog_938.wav (60.00s -> 4.00s)
# Clipped: other_frog_1803.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_73.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1214.wav (60.00s -> 4.00s)
# Clipped: other_frog_2768.wav (60.00s -> 4.00s)
# Clipped: other_frog_3301.wav (9.02s -> 4.00s)
# Clipped: other_frog_2100.wav (8.19s -> 4.00s)
# Clipped: Southern_Dainty_Frog_583.wav (60.00s -> 4.00s)
# Clipped: other_frog_1842.wav (11.80s -> 4.00s)
# Clipped: Southern_Dainty_Frog_701.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_659.wav (60.00s -> 4.00s)
# Clipped: other_frog_1266.wav (12.27s -> 4.00s)
# Clipped: other_frog_1565.wav (49.28s -> 4.00s)
# Clipped: Mountain_Rain_Frog_493.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_212.wav (60.00s -> 4.00s)
# Clipped: other_frog_3114.wav (25.55s -> 4.00s)
# Clipped: Southern_Dainty_Frog_748.wav (60.00s -> 4.00s)
# Clipped: other_frog_2892.wav (7.45s -> 4.00s)
# Clipped: Southern_Dainty_Frog_644.wav (60.00s -> 4.00s)
# Clipped: other_frog_2521.wav (20.12s -> 4.00s)
# Clipped: Clicking_Stream_Frog_442.wav (5.92s -> 4.00s)
# Clipped: Southern_Dainty_Frog_579.wav (60.00s -> 4.00s)
# Clipped: other_frog_2357.wav (56.21s -> 4.00s)
# Clipped: other_frog_1545.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1304.wav (60.00s -> 4.00s)
# Clipped: other_frog_1835.wav (60.00s -> 4.00s)
# Clipped: other_frog_1334.wav (5.60s -> 4.00s)
# Clipped: other_frog_741.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1076.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_303.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_415.wav (49.71s -> 4.00s)
# Clipped: Clicking_Stream_Frog_193.wav (5.94s -> 4.00s)
# Clipped: other_frog_795.wav (8.75s -> 4.00s)
# Clipped: other_frog_189.wav (60.00s -> 4.00s)
# Clipped: other_frog_488.wav (16.43s -> 4.00s)
# Clipped: Mountain_Rain_Frog_459.wav (60.00s -> 4.00s)
# Clipped: other_frog_1820.wav (20.95s -> 4.00s)
# Clipped: other_frog_2752.wav (60.00s -> 4.00s)
# Clipped: other_frog_3262.wav (60.00s -> 4.00s)
# Clipped: other_frog_1391.wav (60.00s -> 4.00s)
# Clipped: other_frog_200.wav (35.32s -> 4.00s)
# Clipped: other_frog_3129.wav (60.00s -> 4.00s)
# Clipped: other_frog_1487.wav (60.00s -> 4.00s)
# Clipped: other_frog_592.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_495.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_573.wav (60.00s -> 4.00s)
# Clipped: other_frog_207.wav (25.86s -> 4.00s)
# Clipped: other_frog_3203.wav (20.48s -> 4.00s)
# Clipped: other_frog_1670.wav (53.36s -> 4.00s)
# Clipped: Mountain_Rain_Frog_520.wav (60.00s -> 4.00s)
# Clipped: other_frog_3389.wav (7.83s -> 4.00s)
# Clipped: other_frog_580.wav (60.00s -> 4.00s)
# Clipped: other_frog_230.wav (9.88s -> 4.00s)
# Clipped: Mountain_Rain_Frog_227.wav (60.00s -> 4.00s)
# Clipped: other_frog_2904.wav (25.17s -> 4.00s)
# Clipped: Mountain_Rain_Frog_519.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1147.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_18.wav (60.00s -> 4.00s)
# Copied: other_frog_269.wav (3.16s)
# Clipped: Mountain_Rain_Frog_489.wav (60.00s -> 4.00s)
# Clipped: other_frog_838.wav (12.48s -> 4.00s)
# Clipped: Mountain_Rain_Frog_144.wav (60.00s -> 4.00s)
# Clipped: other_frog_2511.wav (60.00s -> 4.00s)
# Clipped: other_frog_193.wav (17.44s -> 4.00s)
# Clipped: other_frog_1205.wav (23.17s -> 4.00s)
# Clipped: other_frog_917.wav (25.17s -> 4.00s)
# Clipped: other_frog_1365.wav (5.14s -> 4.00s)
# Clipped: other_frog_3135.wav (17.04s -> 4.00s)
# Copied: other_frog_111.wav (2.03s)
# Clipped: other_frog_792.wav (21.27s -> 4.00s)
# Clipped: other_frog_3005.wav (60.00s -> 4.00s)
# Clipped: other_frog_3043.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_585.wav (60.00s -> 4.00s)
# Clipped: other_frog_2879.wav (60.00s -> 4.00s)
# Clipped: other_frog_114.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1295.wav (60.00s -> 4.00s)
# Clipped: other_frog_1708.wav (20.02s -> 4.00s)
# Clipped: other_frog_234.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_843.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_943.wav (60.00s -> 4.00s)
# Clipped: other_frog_2313.wav (10.00s -> 4.00s)
# Clipped: other_frog_570.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_613.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_792.wav (60.00s -> 4.00s)
# Copied: other_frog_661.wav (3.37s)
# Clipped: other_frog_1079.wav (11.35s -> 4.00s)
# Clipped: Mountain_Rain_Frog_913.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_438.wav (11.22s -> 4.00s)
# Clipped: Mountain_Rain_Frog_797.wav (60.00s -> 4.00s)
# Clipped: other_frog_281.wav (12.35s -> 4.00s)
# Clipped: other_frog_2111.wav (6.39s -> 4.00s)
# Clipped: other_frog_801.wav (23.22s -> 4.00s)
# Clipped: Southern_Dainty_Frog_501.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_463.wav (20.48s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1234.wav (60.00s -> 4.00s)
# Clipped: other_frog_1335.wav (16.67s -> 4.00s)
# Clipped: Clicking_Stream_Frog_236.wav (11.94s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1231.wav (60.00s -> 4.00s)
# Clipped: other_frog_1912.wav (4.96s -> 4.00s)
# Clipped: Mountain_Rain_Frog_271.wav (60.00s -> 4.00s)
# Clipped: other_frog_2812.wav (32.72s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1090.wav (60.00s -> 4.00s)
# Clipped: other_frog_2397.wav (19.65s -> 4.00s)
# Clipped: Southern_Dainty_Frog_151.wav (60.00s -> 4.00s)
# Clipped: other_frog_683.wav (7.64s -> 4.00s)
# Clipped: Clicking_Stream_Frog_430.wav (11.01s -> 4.00s)
# Clipped: Southern_Dainty_Frog_23.wav (7.80s -> 4.00s)
# Clipped: Mountain_Rain_Frog_452.wav (60.00s -> 4.00s)
# Clipped: other_frog_468.wav (60.00s -> 4.00s)
# Clipped: other_frog_3137.wav (27.07s -> 4.00s)
# Clipped: Clicking_Stream_Frog_371.wav (17.09s -> 4.00s)
# Clipped: Southern_Dainty_Frog_321.wav (60.00s -> 4.00s)
# Clipped: other_frog_1559.wav (13.61s -> 4.00s)
# Clipped: other_frog_501.wav (60.00s -> 4.00s)
# Clipped: other_frog_980.wav (11.12s -> 4.00s)
# Clipped: Mountain_Rain_Frog_367.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_696.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_215.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1294.wav (60.00s -> 4.00s)
# Clipped: other_frog_1737.wav (9.12s -> 4.00s)
# Clipped: other_frog_2694.wav (7.03s -> 4.00s)
# Clipped: Clicking_Stream_Frog_137.wav (11.26s -> 4.00s)
# Clipped: Mountain_Rain_Frog_923.wav (60.00s -> 4.00s)
# Clipped: other_frog_1072.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_519.wav (60.00s -> 4.00s)
# Clipped: other_frog_1458.wav (26.09s -> 4.00s)
# Clipped: other_frog_2504.wav (24.62s -> 4.00s)
# Clipped: other_frog_1652.wav (60.00s -> 4.00s)
# Clipped: other_frog_2744.wav (20.99s -> 4.00s)
# Clipped: Southern_Dainty_Frog_218.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_280.wav (60.00s -> 4.00s)
# Clipped: other_frog_378.wav (24.32s -> 4.00s)
# Clipped: other_frog_3098.wav (60.00s -> 4.00s)
# Clipped: other_frog_73.wav (12.03s -> 4.00s)
# Clipped: other_frog_1217.wav (60.00s -> 4.00s)
# Clipped: other_frog_3397.wav (14.49s -> 4.00s)
# Clipped: other_frog_1531.wav (8.53s -> 4.00s)
# Clipped: other_frog_66.wav (6.11s -> 4.00s)
# Clipped: Southern_Dainty_Frog_347.wav (60.00s -> 4.00s)
# Clipped: other_frog_3170.wav (8.80s -> 4.00s)
# Clipped: other_frog_491.wav (10.82s -> 4.00s)
# Clipped: other_frog_1767.wav (9.47s -> 4.00s)
# Clipped: other_frog_3461.wav (7.36s -> 4.00s)
# Clipped: Mountain_Rain_Frog_248.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_337.wav (60.00s -> 4.00s)
# Clipped: other_frog_1730.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_51.wav (10.77s -> 4.00s)
# Clipped: Mountain_Rain_Frog_628.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_197.wav (22.08s -> 4.00s)
# Clipped: Mountain_Rain_Frog_879.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_330.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_523.wav (60.00s -> 4.00s)
# Clipped: other_frog_2478.wav (25.05s -> 4.00s)
# Clipped: other_frog_1328.wav (13.87s -> 4.00s)
# Clipped: other_frog_2434.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_292.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_57.wav (7.84s -> 4.00s)
# Clipped: other_frog_128.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_633.wav (60.00s -> 4.00s)
# Clipped: other_frog_2381.wav (57.03s -> 4.00s)
# Clipped: Mountain_Rain_Frog_938.wav (60.00s -> 4.00s)
# Clipped: other_frog_2780.wav (12.20s -> 4.00s)
# Clipped: other_frog_1491.wav (13.95s -> 4.00s)
# Clipped: other_frog_443.wav (60.00s -> 4.00s)
# Clipped: other_frog_2844.wav (7.80s -> 4.00s)
# Clipped: other_frog_1739.wav (60.00s -> 4.00s)
# Clipped: other_frog_3138.wav (11.98s -> 4.00s)
# Clipped: other_frog_2216.wav (13.95s -> 4.00s)
# Clipped: other_frog_2661.wav (10.05s -> 4.00s)
# Clipped: Southern_Dainty_Frog_757.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_512.wav (60.00s -> 4.00s)
# Clipped: other_frog_3187.wav (10.22s -> 4.00s)
# Clipped: other_frog_3165.wav (34.72s -> 4.00s)
# Clipped: other_frog_2050.wav (32.79s -> 4.00s)
# Clipped: other_frog_2980.wav (60.00s -> 4.00s)
# Clipped: other_frog_968.wav (19.41s -> 4.00s)
# Clipped: Clicking_Stream_Frog_276.wav (14.21s -> 4.00s)
# Clipped: Mountain_Rain_Frog_460.wav (60.00s -> 4.00s)
# Clipped: other_frog_584.wav (4.41s -> 4.00s)
# Clipped: Mountain_Rain_Frog_472.wav (60.00s -> 4.00s)
# Clipped: other_frog_1521.wav (60.00s -> 4.00s)
# Clipped: other_frog_2724.wav (60.00s -> 4.00s)
# Clipped: other_frog_3272.wav (12.28s -> 4.00s)
# Clipped: Clicking_Stream_Frog_398.wav (16.25s -> 4.00s)
# Clipped: other_frog_2779.wav (30.91s -> 4.00s)
# Clipped: other_frog_890.wav (60.00s -> 4.00s)
# Clipped: other_frog_1247.wav (15.34s -> 4.00s)
# Clipped: other_frog_1658.wav (5.11s -> 4.00s)
# Clipped: other_frog_3369.wav (60.00s -> 4.00s)
# Clipped: other_frog_1506.wav (15.95s -> 4.00s)
# Clipped: Mountain_Rain_Frog_849.wav (60.00s -> 4.00s)
# Clipped: other_frog_1597.wav (9.17s -> 4.00s)
# Clipped: other_frog_2454.wav (23.20s -> 4.00s)
# Clipped: Mountain_Rain_Frog_537.wav (60.00s -> 4.00s)
# Clipped: other_frog_924.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_157.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_785.wav (60.00s -> 4.00s)
# Clipped: other_frog_753.wav (10.68s -> 4.00s)
# Clipped: other_frog_1894.wav (18.37s -> 4.00s)
# Clipped: Southern_Dainty_Frog_293.wav (60.00s -> 4.00s)
# Clipped: other_frog_1948.wav (60.00s -> 4.00s)
# Clipped: other_frog_2622.wav (11.03s -> 4.00s)
# Clipped: Mountain_Rain_Frog_779.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_757.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_910.wav (60.00s -> 4.00s)
# Clipped: other_frog_3081.wav (17.79s -> 4.00s)
# Clipped: other_frog_2142.wav (10.39s -> 4.00s)
# Clipped: other_frog_1397.wav (14.78s -> 4.00s)
# Clipped: Mountain_Rain_Frog_265.wav (60.00s -> 4.00s)
# Clipped: other_frog_789.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_725.wav (60.00s -> 4.00s)
# Clipped: other_frog_2951.wav (14.76s -> 4.00s)
# Clipped: other_frog_2992.wav (60.00s -> 4.00s)
# Clipped: other_frog_1111.wav (7.73s -> 4.00s)
# Clipped: other_frog_1190.wav (60.00s -> 4.00s)
# Clipped: other_frog_2914.wav (60.00s -> 4.00s)
# Clipped: other_frog_2229.wav (10.24s -> 4.00s)
# Clipped: other_frog_2563.wav (14.59s -> 4.00s)
# Clipped: Clicking_Stream_Frog_460.wav (6.41s -> 4.00s)
# Clipped: Southern_Dainty_Frog_291.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_112.wav (45.82s -> 4.00s)
# Clipped: Mountain_Rain_Frog_450.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_505.wav (60.00s -> 4.00s)
# Clipped: other_frog_1698.wav (12.40s -> 4.00s)
# Clipped: Southern_Dainty_Frog_64.wav (21.12s -> 4.00s)
# Clipped: other_frog_2031.wav (60.00s -> 4.00s)
# Clipped: other_frog_2131.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_240.wav (15.53s -> 4.00s)
# Clipped: other_frog_2975.wav (5.50s -> 4.00s)
# Clipped: other_frog_2294.wav (27.37s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1138.wav (60.00s -> 4.00s)
# Clipped: other_frog_1112.wav (23.50s -> 4.00s)
# Clipped: other_frog_3354.wav (12.84s -> 4.00s)
# Clipped: other_frog_1641.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1174.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_649.wav (60.00s -> 4.00s)
# Clipped: other_frog_2241.wav (22.15s -> 4.00s)
# Clipped: other_frog_298.wav (60.00s -> 4.00s)
# Clipped: other_frog_519.wav (21.44s -> 4.00s)
# Clipped: Southern_Dainty_Frog_312.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_103.wav (60.00s -> 4.00s)
# Clipped: other_frog_485.wav (16.90s -> 4.00s)
# Clipped: Mountain_Rain_Frog_791.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_557.wav (60.00s -> 4.00s)
# Clipped: other_frog_1881.wav (60.00s -> 4.00s)
# Clipped: other_frog_2117.wav (60.00s -> 4.00s)
# Clipped: other_frog_3200.wav (60.00s -> 4.00s)
# Clipped: other_frog_160.wav (12.38s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1302.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_922.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_701.wav (60.00s -> 4.00s)
# Clipped: other_frog_1600.wav (60.00s -> 4.00s)
# Clipped: other_frog_1884.wav (60.00s -> 4.00s)
# Clipped: other_frog_231.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_259.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_467.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1067.wav (60.00s -> 4.00s)
# Clipped: other_frog_743.wav (26.22s -> 4.00s)
# Clipped: Mountain_Rain_Frog_496.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_121.wav (11.87s -> 4.00s)
# Clipped: Mountain_Rain_Frog_242.wav (60.00s -> 4.00s)
# Clipped: other_frog_765.wav (60.00s -> 4.00s)
# Clipped: other_frog_265.wav (7.72s -> 4.00s)
# Clipped: Mountain_Rain_Frog_108.wav (60.00s -> 4.00s)
# Clipped: other_frog_2492.wav (60.00s -> 4.00s)
# Clipped: other_frog_1986.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_376.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_325.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_308.wav (60.00s -> 4.00s)
# Clipped: other_frog_1248.wav (22.08s -> 4.00s)
# Clipped: other_frog_3143.wav (9.86s -> 4.00s)
# Clipped: other_frog_3064.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_974.wav (60.00s -> 4.00s)
# Clipped: other_frog_2551.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1008.wav (60.00s -> 4.00s)
# Clipped: other_frog_2428.wav (19.14s -> 4.00s)
# Clipped: Southern_Dainty_Frog_616.wav (60.00s -> 4.00s)
# Clipped: other_frog_966.wav (33.60s -> 4.00s)
# Clipped: other_frog_1750.wav (60.00s -> 4.00s)
# Clipped: other_frog_2790.wav (9.98s -> 4.00s)
# Clipped: other_frog_2810.wav (21.66s -> 4.00s)
# Clipped: other_frog_331.wav (14.56s -> 4.00s)
# Clipped: Southern_Dainty_Frog_556.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1199.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_112.wav (60.00s -> 4.00s)
# Clipped: other_frog_2703.wav (60.00s -> 4.00s)
# Clipped: other_frog_627.wav (6.72s -> 4.00s)
# Clipped: other_frog_2970.wav (60.00s -> 4.00s)
# Clipped: other_frog_2529.wav (60.00s -> 4.00s)
# Clipped: other_frog_1758.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_189.wav (60.00s -> 4.00s)
# Clipped: other_frog_1123.wav (11.24s -> 4.00s)
# Clipped: Southern_Dainty_Frog_716.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_965.wav (60.00s -> 4.00s)
# Clipped: other_frog_3095.wav (10.42s -> 4.00s)
# Clipped: other_frog_2203.wav (21.50s -> 4.00s)
# Clipped: Clicking_Stream_Frog_278.wav (17.88s -> 4.00s)
# Clipped: other_frog_1660.wav (8.76s -> 4.00s)
# Clipped: Southern_Dainty_Frog_485.wav (60.00s -> 4.00s)
# Clipped: other_frog_1364.wav (17.71s -> 4.00s)
# Clipped: Clicking_Stream_Frog_220.wav (9.68s -> 4.00s)
# Clipped: other_frog_1295.wav (15.99s -> 4.00s)
# Clipped: Southern_Dainty_Frog_184.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_524.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_175.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_684.wav (60.00s -> 4.00s)
# Clipped: other_frog_2648.wav (13.24s -> 4.00s)
# Clipped: other_frog_1992.wav (60.00s -> 4.00s)
# Clipped: other_frog_961.wav (20.16s -> 4.00s)
# Clipped: Mountain_Rain_Frog_374.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_321.wav (13.59s -> 4.00s)
# Clipped: Southern_Dainty_Frog_666.wav (60.00s -> 4.00s)
# Clipped: other_frog_465.wav (60.00s -> 4.00s)
# Clipped: other_frog_3463.wav (14.86s -> 4.00s)
# Clipped: other_frog_840.wav (60.00s -> 4.00s)
# Clipped: other_frog_1350.wav (19.60s -> 4.00s)
# Clipped: Southern_Dainty_Frog_647.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_998.wav (60.00s -> 4.00s)
# Clipped: other_frog_527.wav (15.97s -> 4.00s)
# Clipped: Southern_Dainty_Frog_586.wav (60.00s -> 4.00s)
# Clipped: other_frog_351.wav (16.35s -> 4.00s)
# Clipped: other_frog_853.wav (60.00s -> 4.00s)
# Clipped: other_frog_1393.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_20.wav (18.76s -> 4.00s)
# Clipped: Mountain_Rain_Frog_478.wav (60.00s -> 4.00s)
# Clipped: other_frog_179.wav (18.27s -> 4.00s)
# Clipped: Clicking_Stream_Frog_54.wav (19.99s -> 4.00s)
# Clipped: Southern_Dainty_Frog_393.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_438.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_354.wav (7.27s -> 4.00s)
# Clipped: Clicking_Stream_Frog_339.wav (16.42s -> 4.00s)
# Clipped: Clicking_Stream_Frog_23.wav (14.00s -> 4.00s)
# Clipped: other_frog_1740.wav (9.31s -> 4.00s)
# Copied: other_frog_962.wav (3.99s)
# Clipped: other_frog_2236.wav (60.00s -> 4.00s)
# Clipped: other_frog_1967.wav (60.00s -> 4.00s)
# Clipped: other_frog_1735.wav (34.18s -> 4.00s)
# Clipped: other_frog_161.wav (6.90s -> 4.00s)
# Clipped: other_frog_1355.wav (21.52s -> 4.00s)
# Clipped: Southern_Dainty_Frog_549.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_13.wav (7.17s -> 4.00s)
# Clipped: other_frog_2084.wav (18.76s -> 4.00s)
# Clipped: Southern_Dainty_Frog_3.wav (13.98s -> 4.00s)
# Clipped: other_frog_3083.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_208.wav (60.00s -> 4.00s)
# Clipped: other_frog_2596.wav (15.84s -> 4.00s)
# Clipped: other_frog_1932.wav (5.67s -> 4.00s)
# Clipped: other_frog_1742.wav (7.73s -> 4.00s)
# Clipped: Mountain_Rain_Frog_731.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_383.wav (4.27s -> 4.00s)
# Clipped: other_frog_1120.wav (6.19s -> 4.00s)
# Clipped: Southern_Dainty_Frog_710.wav (60.00s -> 4.00s)
# Clipped: other_frog_851.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_149.wav (60.00s -> 4.00s)
# Clipped: other_frog_3198.wav (15.68s -> 4.00s)
# Clipped: other_frog_2932.wav (7.34s -> 4.00s)
# Clipped: Mountain_Rain_Frog_430.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_115.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_290.wav (60.00s -> 4.00s)
# Clipped: other_frog_1422.wav (16.36s -> 4.00s)
# Clipped: Mountain_Rain_Frog_311.wav (60.00s -> 4.00s)
# Clipped: other_frog_3245.wav (12.56s -> 4.00s)
# Clipped: Southern_Dainty_Frog_428.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1232.wav (60.00s -> 4.00s)
# Clipped: other_frog_1987.wav (14.31s -> 4.00s)
# Clipped: other_frog_2959.wav (60.00s -> 4.00s)
# Clipped: other_frog_1786.wav (12.66s -> 4.00s)
# Clipped: other_frog_3161.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1036.wav (60.00s -> 4.00s)
# Clipped: other_frog_2875.wav (60.00s -> 4.00s)
# Clipped: other_frog_2430.wav (37.25s -> 4.00s)
# Clipped: Mountain_Rain_Frog_477.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_209.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_115.wav (60.00s -> 4.00s)
# Clipped: other_frog_2784.wav (7.85s -> 4.00s)
# Clipped: other_frog_1790.wav (60.00s -> 4.00s)
# Clipped: other_frog_2998.wav (16.24s -> 4.00s)
# Clipped: Mountain_Rain_Frog_785.wav (60.00s -> 4.00s)
# Clipped: other_frog_2296.wav (60.00s -> 4.00s)
# Clipped: other_frog_3447.wav (60.00s -> 4.00s)
# Clipped: other_frog_2279.wav (60.00s -> 4.00s)
# Clipped: other_frog_913.wav (32.92s -> 4.00s)
# Clipped: Southern_Dainty_Frog_282.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_265.wav (17.48s -> 4.00s)
# Clipped: other_frog_2398.wav (9.66s -> 4.00s)
# Clipped: other_frog_3000.wav (12.98s -> 4.00s)
# Clipped: other_frog_3455.wav (60.00s -> 4.00s)
# Clipped: other_frog_1973.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_166.wav (60.00s -> 4.00s)
# Clipped: other_frog_2885.wav (16.88s -> 4.00s)
# Clipped: other_frog_1284.wav (60.00s -> 4.00s)
# Clipped: other_frog_461.wav (14.63s -> 4.00s)
# Clipped: Southern_Dainty_Frog_174.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_422.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_113.wav (60.00s -> 4.00s)
# Clipped: other_frog_504.wav (8.48s -> 4.00s)
# Clipped: Southern_Dainty_Frog_749.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_920.wav (60.00s -> 4.00s)
# Clipped: other_frog_2731.wav (9.52s -> 4.00s)
# Clipped: Clicking_Stream_Frog_405.wav (35.90s -> 4.00s)
# Clipped: Mountain_Rain_Frog_742.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_122.wav (11.19s -> 4.00s)
# Clipped: Southern_Dainty_Frog_96.wav (60.00s -> 4.00s)
# Clipped: other_frog_1646.wav (31.76s -> 4.00s)
# Clipped: other_frog_3219.wav (21.86s -> 4.00s)
# Clipped: other_frog_1305.wav (34.94s -> 4.00s)
# Clipped: other_frog_3053.wav (23.52s -> 4.00s)
# Clipped: other_frog_1970.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_126.wav (60.00s -> 4.00s)
# Clipped: other_frog_3294.wav (60.00s -> 4.00s)
# Clipped: other_frog_1204.wav (12.80s -> 4.00s)
# Clipped: Southern_Dainty_Frog_165.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_711.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_433.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_967.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_355.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_389.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1309.wav (60.00s -> 4.00s)
# Clipped: other_frog_3459.wav (7.41s -> 4.00s)
# Clipped: Mountain_Rain_Frog_250.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_533.wav (60.00s -> 4.00s)
# Clipped: other_frog_3210.wav (14.63s -> 4.00s)
# Clipped: Mountain_Rain_Frog_160.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_736.wav (60.00s -> 4.00s)
# Clipped: other_frog_1872.wav (36.80s -> 4.00s)
# Clipped: other_frog_2144.wav (13.10s -> 4.00s)
# Clipped: Southern_Dainty_Frog_66.wav (60.00s -> 4.00s)
# Clipped: other_frog_2330.wav (14.37s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1098.wav (60.00s -> 4.00s)
# Clipped: other_frog_462.wav (14.87s -> 4.00s)
# Clipped: Clicking_Stream_Frog_349.wav (15.68s -> 4.00s)
# Clipped: other_frog_1558.wav (11.96s -> 4.00s)
# Clipped: other_frog_870.wav (7.89s -> 4.00s)
# Clipped: other_frog_3246.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_655.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_491.wav (60.00s -> 4.00s)
# Clipped: other_frog_494.wav (19.64s -> 4.00s)
# Clipped: Mountain_Rain_Frog_131.wav (60.00s -> 4.00s)
# Clipped: other_frog_2147.wav (12.12s -> 4.00s)
# Clipped: Mountain_Rain_Frog_66.wav (12.82s -> 4.00s)
# Clipped: Clicking_Stream_Frog_153.wav (23.30s -> 4.00s)
# Clipped: other_frog_290.wav (27.42s -> 4.00s)
# Clipped: other_frog_613.wav (9.95s -> 4.00s)
# Clipped: Clicking_Stream_Frog_91.wav (6.04s -> 4.00s)
# Clipped: other_frog_349.wav (18.69s -> 4.00s)
# Clipped: other_frog_3107.wav (17.79s -> 4.00s)
# Clipped: Mountain_Rain_Frog_801.wav (60.00s -> 4.00s)
# Clipped: other_frog_987.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_587.wav (60.00s -> 4.00s)
# Clipped: other_frog_3091.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_295.wav (60.72s -> 4.00s)
# Clipped: other_frog_880.wav (60.00s -> 4.00s)
# Clipped: other_frog_2194.wav (6.64s -> 4.00s)
# Clipped: Southern_Dainty_Frog_425.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_194.wav (7.78s -> 4.00s)
# Clipped: other_frog_2650.wav (30.97s -> 4.00s)
# Clipped: Southern_Dainty_Frog_63.wav (38.57s -> 4.00s)
# Clipped: other_frog_278.wav (21.08s -> 4.00s)
# Clipped: Southern_Dainty_Frog_532.wav (60.00s -> 4.00s)
# Clipped: other_frog_2580.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1133.wav (60.00s -> 4.00s)
# Clipped: other_frog_285.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_168.wav (6.39s -> 4.00s)
# Clipped: other_frog_245.wav (60.00s -> 4.00s)
# Clipped: other_frog_697.wav (16.70s -> 4.00s)
# Clipped: Mountain_Rain_Frog_527.wav (60.00s -> 4.00s)
# Clipped: other_frog_859.wav (25.36s -> 4.00s)
# Clipped: Mountain_Rain_Frog_534.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1201.wav (60.00s -> 4.00s)
# Clipped: other_frog_1013.wav (6.15s -> 4.00s)
# Clipped: other_frog_989.wav (60.00s -> 4.00s)
# Clipped: other_frog_1453.wav (20.41s -> 4.00s)
# Clipped: Mountain_Rain_Frog_360.wav (60.00s -> 4.00s)
# Clipped: other_frog_1789.wav (7.01s -> 4.00s)
# Clipped: other_frog_314.wav (29.95s -> 4.00s)
# Clipped: other_frog_2607.wav (22.22s -> 4.00s)
# Clipped: other_frog_675.wav (60.00s -> 4.00s)
# Clipped: other_frog_2390.wav (60.00s -> 4.00s)
# Clipped: other_frog_2163.wav (60.00s -> 4.00s)
# Clipped: other_frog_2232.wav (17.00s -> 4.00s)
# Clipped: other_frog_1482.wav (6.97s -> 4.00s)
# Clipped: other_frog_1426.wav (23.10s -> 4.00s)
# Clipped: Mountain_Rain_Frog_22.wav (60.00s -> 4.00s)
# Clipped: other_frog_3306.wav (60.00s -> 4.00s)
# Clipped: other_frog_1433.wav (10.45s -> 4.00s)
# Clipped: other_frog_2586.wav (10.73s -> 4.00s)
# Clipped: other_frog_3283.wav (60.00s -> 4.00s)
# Clipped: other_frog_3206.wav (60.00s -> 4.00s)
# Clipped: other_frog_691.wav (60.00s -> 4.00s)
# Clipped: other_frog_2126.wav (5.12s -> 4.00s)
# Clipped: other_frog_2960.wav (60.00s -> 4.00s)
# Clipped: other_frog_1905.wav (60.00s -> 4.00s)
# Clipped: other_frog_3068.wav (11.49s -> 4.00s)
# Clipped: other_frog_2794.wav (4.99s -> 4.00s)
# Clipped: other_frog_2396.wav (11.70s -> 4.00s)
# Clipped: other_frog_403.wav (8.21s -> 4.00s)
# Clipped: other_frog_928.wav (13.01s -> 4.00s)
# Clipped: Southern_Dainty_Frog_759.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_897.wav (60.00s -> 4.00s)
# Clipped: other_frog_3458.wav (60.00s -> 4.00s)
# Clipped: other_frog_2049.wav (4.88s -> 4.00s)
# Clipped: other_frog_377.wav (6.53s -> 4.00s)
# Clipped: Southern_Dainty_Frog_120.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_34.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_45.wav (10.01s -> 4.00s)
# Clipped: Mountain_Rain_Frog_645.wav (60.00s -> 4.00s)
# Clipped: other_frog_38.wav (8.62s -> 4.00s)
# Clipped: other_frog_3489.wav (10.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_574.wav (60.00s -> 4.00s)
# Clipped: other_frog_3133.wav (11.77s -> 4.00s)
# Clipped: Mountain_Rain_Frog_509.wav (60.00s -> 4.00s)
# Clipped: other_frog_1444.wav (11.28s -> 4.00s)
# Clipped: other_frog_782.wav (7.62s -> 4.00s)
# Clipped: other_frog_868.wav (17.86s -> 4.00s)
# Clipped: Southern_Dainty_Frog_1.wav (39.92s -> 4.00s)
# Clipped: Mountain_Rain_Frog_886.wav (60.00s -> 4.00s)
# Clipped: other_frog_2331.wav (60.00s -> 4.00s)
# Copied: other_frog_1705.wav (1.08s)
# Clipped: other_frog_1250.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_929.wav (60.00s -> 4.00s)
# Clipped: other_frog_350.wav (39.01s -> 4.00s)
# Clipped: Clicking_Stream_Frog_462.wav (11.98s -> 4.00s)
# Clipped: other_frog_807.wav (12.94s -> 4.00s)
# Clipped: Southern_Dainty_Frog_399.wav (60.00s -> 4.00s)
# Clipped: other_frog_1713.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_624.wav (60.00s -> 4.00s)
# Clipped: other_frog_3403.wav (4.78s -> 4.00s)
# Clipped: other_frog_1141.wav (24.71s -> 4.00s)
# Clipped: Southern_Dainty_Frog_12.wav (23.68s -> 4.00s)
# Clipped: Clicking_Stream_Frog_329.wav (12.42s -> 4.00s)
# Clipped: other_frog_2702.wav (60.00s -> 4.00s)
# Clipped: other_frog_237.wav (6.34s -> 4.00s)
# Clipped: Mountain_Rain_Frog_821.wav (60.00s -> 4.00s)
# Clipped: other_frog_2506.wav (60.00s -> 4.00s)
# Clipped: other_frog_1828.wav (10.90s -> 4.00s)
# Clipped: Southern_Dainty_Frog_572.wav (60.00s -> 4.00s)
# Clipped: other_frog_3393.wav (7.66s -> 4.00s)
# Clipped: Clicking_Stream_Frog_261.wav (11.38s -> 4.00s)
# Clipped: Southern_Dainty_Frog_672.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_317.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_22.wav (10.08s -> 4.00s)
# Clipped: other_frog_288.wav (60.00s -> 4.00s)
# Clipped: other_frog_2579.wav (4.02s -> 4.00s)
# Clipped: Southern_Dainty_Frog_367.wav (60.00s -> 4.00s)
# Clipped: other_frog_393.wav (28.54s -> 4.00s)
# Clipped: other_frog_2671.wav (6.18s -> 4.00s)
# Clipped: Mountain_Rain_Frog_136.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_675.wav (60.00s -> 4.00s)
# Clipped: other_frog_2553.wav (25.70s -> 4.00s)
# Clipped: Southern_Dainty_Frog_717.wav (60.00s -> 4.00s)
# Clipped: other_frog_579.wav (60.00s -> 4.00s)
# Copied: other_frog_523.wav (1.19s)
# Clipped: Mountain_Rain_Frog_766.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_373.wav (60.00s -> 4.00s)
# Clipped: other_frog_2575.wav (10.75s -> 4.00s)
# Clipped: Southern_Dainty_Frog.wav (21.97s -> 4.00s)
# Clipped: other_frog_1321.wav (33.72s -> 4.00s)
# Clipped: Clicking_Stream_Frog_96.wav (7.96s -> 4.00s)
# Clipped: other_frog_671.wav (7.89s -> 4.00s)
# Clipped: other_frog_1938.wav (24.91s -> 4.00s)
# Clipped: other_frog_2441.wav (60.00s -> 4.00s)
# Clipped: other_frog_648.wav (60.00s -> 4.00s)
# Clipped: other_frog_1887.wav (60.00s -> 4.00s)
# Clipped: other_frog_2853.wav (31.79s -> 4.00s)
# Clipped: Southern_Dainty_Frog_727.wav (60.00s -> 4.00s)
# Clipped: other_frog_3023.wav (60.00s -> 4.00s)
# Clipped: other_frog_476.wav (60.00s -> 4.00s)
# Clipped: other_frog_2259.wav (60.00s -> 4.00s)
# Clipped: other_frog_1336.wav (4.33s -> 4.00s)
# Clipped: Clicking_Stream_Frog_284.wav (16.04s -> 4.00s)
# Clipped: Southern_Dainty_Frog_502.wav (60.00s -> 4.00s)
# Clipped: other_frog_2664.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_114.wav (15.13s -> 4.00s)
# Clipped: other_frog_2103.wav (4.79s -> 4.00s)
# Clipped: other_frog_3201.wav (60.00s -> 4.00s)
# Clipped: other_frog_1709.wav (64.67s -> 4.00s)
# Clipped: other_frog_1419.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_610.wav (60.00s -> 4.00s)
# Copied: other_frog_3282.wav (1.21s)
# Clipped: other_frog_1260.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_220.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_541.wav (60.00s -> 4.00s)
# Clipped: other_frog_3031.wav (60.00s -> 4.00s)
# Clipped: other_frog_607.wav (31.22s -> 4.00s)
# Clipped: Southern_Dainty_Frog_525.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1144.wav (60.00s -> 4.00s)
# Clipped: other_frog_1954.wav (60.00s -> 4.00s)
# Clipped: other_frog_746.wav (60.00s -> 4.00s)
# Clipped: other_frog_384.wav (60.00s -> 4.00s)
# Clipped: other_frog_958.wav (60.00s -> 4.00s)
# Clipped: other_frog_3414.wav (25.21s -> 4.00s)
# Clipped: other_frog_1503.wav (16.96s -> 4.00s)
# Clipped: Clicking_Stream_Frog_172.wav (6.55s -> 4.00s)
# Clipped: other_frog_86.wav (6.62s -> 4.00s)
# Clipped: other_frog_1543.wav (8.61s -> 4.00s)
# Clipped: other_frog_79.wav (60.00s -> 4.00s)
# Clipped: other_frog_59.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_119.wav (60.00s -> 4.00s)
# Clipped: other_frog_2211.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_274.wav (20.87s -> 4.00s)
# Clipped: Mountain_Rain_Frog_635.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_434.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_937.wav (60.00s -> 4.00s)
# Clipped: other_frog_1777.wav (12.21s -> 4.00s)
# Clipped: other_frog_1898.wav (60.00s -> 4.00s)
# Clipped: other_frog_4.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_391.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_222.wav (23.87s -> 4.00s)
# Clipped: other_frog_2174.wav (22.57s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1198.wav (60.00s -> 4.00s)
# Clipped: other_frog_1668.wav (19.02s -> 4.00s)
# Clipped: other_frog_1160.wav (9.31s -> 4.00s)
# Clipped: Clicking_Stream_Frog_369.wav (33.25s -> 4.00s)
# Clipped: Southern_Dainty_Frog_351.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_631.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_65.wav (21.76s -> 4.00s)
# Clipped: other_frog_170.wav (16.25s -> 4.00s)
# Clipped: other_frog_1077.wav (60.00s -> 4.00s)
# Clipped: other_frog_515.wav (9.52s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1041.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_477.wav (60.00s -> 4.00s)
# Clipped: other_frog_1431.wav (60.00s -> 4.00s)
# Clipped: other_frog_1418.wav (60.00s -> 4.00s)
# Clipped: other_frog_2924.wav (8.24s -> 4.00s)
# Clipped: Mountain_Rain_Frog_88.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1283.wav (60.00s -> 4.00s)
# Clipped: other_frog_860.wav (6.72s -> 4.00s)
# Clipped: other_frog_2540.wav (7.96s -> 4.00s)
# Clipped: Mountain_Rain_Frog_615.wav (60.00s -> 4.00s)
# Clipped: other_frog_1783.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_971.wav (60.00s -> 4.00s)
# Clipped: other_frog_1944.wav (5.11s -> 4.00s)
# Clipped: Mountain_Rain_Frog_824.wav (60.00s -> 4.00s)
# Clipped: other_frog_1471.wav (9.40s -> 4.00s)
# Clipped: other_frog_2897.wav (60.00s -> 4.00s)
# Clipped: other_frog_3475.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_74.wav (52.32s -> 4.00s)
# Clipped: Southern_Dainty_Frog_57.wav (10.52s -> 4.00s)
# Clipped: other_frog_975.wav (27.61s -> 4.00s)
# Clipped: Southern_Dainty_Frog_535.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_140.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_200.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_271.wav (60.00s -> 4.00s)
# Clipped: other_frog_1855.wav (60.00s -> 4.00s)
# Clipped: other_frog_1340.wav (8.92s -> 4.00s)
# Clipped: other_frog_1294.wav (60.00s -> 4.00s)
# Clipped: other_frog_754.wav (60.00s -> 4.00s)
# Clipped: other_frog_1383.wav (19.30s -> 4.00s)
# Clipped: other_frog_1414.wav (6.92s -> 4.00s)
# Clipped: other_frog_1856.wav (15.74s -> 4.00s)
# Clipped: other_frog_3108.wav (60.00s -> 4.00s)
# Clipped: other_frog_1370.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_78.wav (60.00s -> 4.00s)
# Clipped: other_frog_614.wav (7.45s -> 4.00s)
# Clipped: other_frog_512.wav (10.47s -> 4.00s)
# Clipped: other_frog_167.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_776.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_318.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_784.wav (60.00s -> 4.00s)
# Clipped: other_frog_1470.wav (12.89s -> 4.00s)
# Clipped: other_frog_1845.wav (14.88s -> 4.00s)
# Clipped: Mountain_Rain_Frog_733.wav (60.00s -> 4.00s)
# Clipped: other_frog_1589.wav (60.00s -> 4.00s)
# Clipped: other_frog_676.wav (60.00s -> 4.00s)
# Clipped: other_frog_559.wav (12.64s -> 4.00s)
# Clipped: Mountain_Rain_Frog_337.wav (60.00s -> 4.00s)
# Clipped: other_frog_2427.wav (60.00s -> 4.00s)
# Clipped: other_frog_1495.wav (12.12s -> 4.00s)
# Clipped: other_frog_965.wav (60.00s -> 4.00s)
# Clipped: other_frog_21.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1038.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1256.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_440.wav (60.00s -> 4.00s)
# Clipped: other_frog_1304.wav (9.92s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1278.wav (60.00s -> 4.00s)
# Clipped: other_frog_2137.wav (60.00s -> 4.00s)
# Clipped: other_frog_1751.wav (46.33s -> 4.00s)
# Clipped: other_frog_1759.wav (60.00s -> 4.00s)
# Clipped: other_frog_1211.wav (60.00s -> 4.00s)
# Clipped: other_frog_2968.wav (12.02s -> 4.00s)
# Clipped: Mountain_Rain_Frog_842.wav (60.00s -> 4.00s)
# Clipped: other_frog_517.wav (16.46s -> 4.00s)
# Clipped: Southern_Dainty_Frog_251.wav (60.00s -> 4.00s)
# Clipped: other_frog_2971.wav (60.00s -> 4.00s)
# Clipped: other_frog_1844.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_327.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_234.wav (19.20s -> 4.00s)
# Clipped: other_frog_3462.wav (11.77s -> 4.00s)
# Clipped: other_frog_1752.wav (18.71s -> 4.00s)
# Clipped: Mountain_Rain_Frog_132.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_815.wav (60.00s -> 4.00s)
# Clipped: other_frog_1562.wav (11.09s -> 4.00s)
# Clipped: Clicking_Stream_Frog_8.wav (12.23s -> 4.00s)
# Clipped: other_frog_3035.wav (60.00s -> 4.00s)
# Clipped: other_frog_2243.wav (26.75s -> 4.00s)
# Clipped: other_frog_65.wav (10.84s -> 4.00s)
# Clipped: other_frog_3025.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_697.wav (60.00s -> 4.00s)
# Clipped: other_frog_2792.wav (11.24s -> 4.00s)
# Clipped: other_frog_1316.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_42.wav (7.52s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1208.wav (60.00s -> 4.00s)
# Clipped: other_frog_542.wav (60.00s -> 4.00s)
# Clipped: other_frog_369.wav (60.00s -> 4.00s)
# Clipped: other_frog_1687.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1152.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_486.wav (60.00s -> 4.00s)
# Clipped: other_frog_3132.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_617.wav (60.00s -> 4.00s)
# Clipped: other_frog_731.wav (13.17s -> 4.00s)
# Clipped: other_frog_3439.wav (13.12s -> 4.00s)
# Clipped: other_frog_1791.wav (20.22s -> 4.00s)
# Clipped: other_frog_3322.wav (60.00s -> 4.00s)
# Clipped: other_frog_1625.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_253.wav (11.77s -> 4.00s)
# Clipped: other_frog_236.wav (60.00s -> 4.00s)
# Clipped: other_frog_1542.wav (15.59s -> 4.00s)
# Clipped: other_frog_1183.wav (60.00s -> 4.00s)
# Clipped: other_frog_2669.wav (14.51s -> 4.00s)
# Clipped: other_frog_432.wav (60.00s -> 4.00s)
# Clipped: other_frog_1648.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1291.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_515.wav (60.00s -> 4.00s)
# Clipped: other_frog_1427.wav (13.44s -> 4.00s)
# Clipped: Mountain_Rain_Frog_174.wav (60.00s -> 4.00s)
# Clipped: other_frog_1766.wav (12.09s -> 4.00s)
# Clipped: Southern_Dainty_Frog_269.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_946.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_430.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_261.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_447.wav (14.68s -> 4.00s)
# Clipped: Southern_Dainty_Frog_536.wav (60.00s -> 4.00s)
# Clipped: other_frog_126.wav (7.24s -> 4.00s)
# Clipped: other_frog_3467.wav (7.13s -> 4.00s)
# Clipped: other_frog_2385.wav (15.28s -> 4.00s)
# Clipped: Mountain_Rain_Frog_69.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_642.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_931.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_336.wav (60.00s -> 4.00s)
# Clipped: other_frog_1052.wav (12.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_521.wav (60.00s -> 4.00s)
# Clipped: other_frog_2490.wav (10.80s -> 4.00s)
# Clipped: Mountain_Rain_Frog_413.wav (60.00s -> 4.00s)
# Clipped: other_frog_117.wav (60.00s -> 4.00s)
# Clipped: other_frog_2708.wav (27.46s -> 4.00s)
# Clipped: other_frog_226.wav (60.00s -> 4.00s)
# Clipped: other_frog_1726.wav (51.84s -> 4.00s)
# Clipped: other_frog_425.wav (9.26s -> 4.00s)
# Clipped: Mountain_Rain_Frog_877.wav (60.00s -> 4.00s)
# Clipped: other_frog_96.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_392.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1185.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_131.wav (15.74s -> 4.00s)
# Clipped: other_frog_2693.wav (14.55s -> 4.00s)
# Clipped: other_frog_2386.wav (5.15s -> 4.00s)
# Clipped: other_frog_411.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_964.wav (60.00s -> 4.00s)
# Clipped: other_frog_2653.wav (13.98s -> 4.00s)
# Clipped: other_frog_1410.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_598.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_407.wav (60.00s -> 4.00s)
# Clipped: other_frog_195.wav (4.32s -> 4.00s)
# Clipped: other_frog_3084.wav (60.00s -> 4.00s)
# Clipped: other_frog_2795.wav (14.83s -> 4.00s)
# Clipped: other_frog_1202.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_99.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_874.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_410.wav (60.00s -> 4.00s)
# Copied: other_frog_2594.wav (0.40s)
# Clipped: Mountain_Rain_Frog_869.wav (60.00s -> 4.00s)
# Clipped: other_frog_3361.wav (20.01s -> 4.00s)
# Clipped: other_frog_2431.wav (5.46s -> 4.00s)
# Clipped: Clicking_Stream_Frog_421.wav (17.00s -> 4.00s)
# Clipped: other_frog_698.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1101.wav (60.00s -> 4.00s)
# Clipped: other_frog_3134.wav (11.55s -> 4.00s)
# Clipped: other_frog_619.wav (60.00s -> 4.00s)
# ...
# Clipped: Mountain_Rain_Frog_2.wav (6.04s -> 4.00s)
# Clipped: other_frog_1251.wav (60.00s -> 4.00s)
# Clipped: other_frog_2626.wav (60.00s -> 4.00s)
# Clipped: other_frog_823.wav (60.00s -> 4.00s)
# Clipped: other_frog_2488.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_589.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_813.wav (60.00s -> 4.00s)
# Clipped: other_frog_2271.wav (16.06s -> 4.00s)
# Clipped: Mountain_Rain_Frog_663.wav (60.00s -> 4.00s)
# Clipped: other_frog_3020.wav (11.20s -> 4.00s)
# Clipped: Southern_Dainty_Frog_18.wav (29.18s -> 4.00s)
# Clipped: Mountain_Rain_Frog_859.wav (60.00s -> 4.00s)
# Clipped: other_frog_3472.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_423.wav (60.00s -> 4.00s)
# Clipped: other_frog_1150.wav (26.22s -> 4.00s)
# Clipped: other_frog_963.wav (20.45s -> 4.00s)
# Clipped: Southern_Dainty_Frog_143.wav (60.00s -> 4.00s)
# Clipped: other_frog_1592.wav (9.49s -> 4.00s)
# Clipped: other_frog_2982.wav (60.00s -> 4.00s)
# Clipped: other_frog_3485.wav (26.50s -> 4.00s)
# Clipped: Clicking_Stream_Frog_323.wav (15.40s -> 4.00s)
# Clipped: other_frog_3321.wav (9.60s -> 4.00s)
# Clipped: other_frog_1577.wav (31.05s -> 4.00s)
# Clipped: Mountain_Rain_Frog_807.wav (60.00s -> 4.00s)
# Clipped: other_frog_2949.wav (60.00s -> 4.00s)
# Copied: other_frog_3316.wav (3.82s)
# Clipped: Mountain_Rain_Frog_293.wav (60.00s -> 4.00s)
# Clipped: other_frog_1314.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1248.wav (60.00s -> 4.00s)
# Clipped: other_frog_2364.wav (60.00s -> 4.00s)
# Clipped: other_frog_3468.wav (60.00s -> 4.00s)
# Clipped: other_frog_2182.wav (7.64s -> 4.00s)
# Clipped: Southern_Dainty_Frog_266.wav (60.00s -> 4.00s)
# Clipped: other_frog_591.wav (23.04s -> 4.00s)
# Clipped: Southern_Dainty_Frog_286.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_247.wav (60.00s -> 4.00s)
# Clipped: other_frog_1756.wav (21.85s -> 4.00s)
# Clipped: other_frog_2843.wav (6.91s -> 4.00s)
# Clipped: other_frog_16.wav (60.00s -> 4.00s)
# Clipped: other_frog_653.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_602.wav (60.00s -> 4.00s)
# Clipped: other_frog_2318.wav (5.63s -> 4.00s)
# Clipped: Mountain_Rain_Frog_80.wav (60.00s -> 4.00s)
# Clipped: other_frog_2611.wav (5.25s -> 4.00s)
# Clipped: other_frog_1341.wav (38.34s -> 4.00s)
# Clipped: other_frog_1517.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_253.wav (60.00s -> 4.00s)
# Clipped: other_frog_2235.wav (5.59s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1262.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_35.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_263.wav (60.00s -> 4.00s)
# Clipped: other_frog_2907.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1032.wav (60.00s -> 4.00s)
# Clipped: other_frog_25.wav (60.00s -> 4.00s)
# Clipped: other_frog_948.wav (5.53s -> 4.00s)
# Clipped: Clicking_Stream_Frog_403.wav (13.75s -> 4.00s)
# Clipped: other_frog_3196.wav (9.12s -> 4.00s)
# Clipped: other_frog_800.wav (60.00s -> 4.00s)
# Clipped: other_frog_2590.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_876.wav (60.00s -> 4.00s)
# Clipped: other_frog_150.wav (21.85s -> 4.00s)
# Clipped: other_frog_2712.wav (8.31s -> 4.00s)
# Clipped: other_frog_2901.wav (29.95s -> 4.00s)
# Clipped: Mountain_Rain_Frog_751.wav (60.00s -> 4.00s)
# Clipped: other_frog_995.wav (10.08s -> 4.00s)
# Clipped: other_frog_2720.wav (57.03s -> 4.00s)
# Clipped: other_frog_1058.wav (15.84s -> 4.00s)
# Clipped: other_frog_3413.wav (6.15s -> 4.00s)
# Clipped: other_frog_2424.wav (60.00s -> 4.00s)
# Clipped: other_frog_2040.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_726.wav (60.00s -> 4.00s)
# Clipped: other_frog_702.wav (13.61s -> 4.00s)
# Clipped: other_frog_3105.wav (60.00s -> 4.00s)
# Clipped: other_frog_2219.wav (21.29s -> 4.00s)
# Clipped: other_frog_2038.wav (60.00s -> 4.00s)
# Clipped: other_frog_3490.wav (6.27s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1131.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_888.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_190.wav (60.00s -> 4.00s)
# Clipped: other_frog_2974.wav (60.00s -> 4.00s)
# Clipped: other_frog_3292.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_600.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_555.wav (60.00s -> 4.00s)
# Clipped: other_frog_1650.wav (9.64s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1117.wav (60.00s -> 4.00s)
# Clipped: other_frog_3036.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_412.wav (9.87s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1181.wav (60.00s -> 4.00s)
# Clipped: other_frog_3110.wav (60.00s -> 4.00s)
# Clipped: other_frog_423.wav (60.00s -> 4.00s)
# Clipped: other_frog_2735.wav (60.00s -> 4.00s)
# Clipped: other_frog_3174.wav (16.47s -> 4.00s)
# Clipped: Southern_Dainty_Frog_453.wav (60.00s -> 4.00s)
# Clipped: other_frog_2707.wav (6.78s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1228.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_4.wav (10.40s -> 4.00s)
# Clipped: Southern_Dainty_Frog_630.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1092.wav (60.00s -> 4.00s)
# Clipped: other_frog_641.wav (5.48s -> 4.00s)
# Clipped: other_frog_2185.wav (14.49s -> 4.00s)
# Clipped: Southern_Dainty_Frog_150.wav (60.00s -> 4.00s)
# Copied: Mountain_Rain_Frog_3.wav (2.30s)
# Clipped: Mountain_Rain_Frog_155.wav (60.00s -> 4.00s)
# Clipped: other_frog_805.wav (17.79s -> 4.00s)
# Clipped: other_frog_1920.wav (60.00s -> 4.00s)
# Clipped: other_frog_1860.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_528.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_611.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_446.wav (23.50s -> 4.00s)
# Clipped: Clicking_Stream_Frog_242.wav (20.34s -> 4.00s)
# Clipped: Clicking_Stream_Frog_85.wav (5.09s -> 4.00s)
# Clipped: other_frog_3069.wav (60.00s -> 4.00s)
# Clipped: other_frog_1143.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_198.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_50.wav (60.00s -> 4.00s)
# Clipped: other_frog_123.wav (12.63s -> 4.00s)
# Clipped: Mountain_Rain_Frog_811.wav (60.00s -> 4.00s)
# Clipped: other_frog_3311.wav (33.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_49.wav (15.70s -> 4.00s)
# Clipped: other_frog_2882.wav (13.42s -> 4.00s)
# Clipped: other_frog_8.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_259.wav (60.00s -> 4.00s)
# Clipped: other_frog_1440.wav (16.42s -> 4.00s)
# Clipped: Southern_Dainty_Frog_309.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_187.wav (60.00s -> 4.00s)
# Clipped: other_frog_2755.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_352.wav (60.00s -> 4.00s)
# Clipped: other_frog_1179.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_562.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_511.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_470.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_80.wav (14.68s -> 4.00s)
# Clipped: Mountain_Rain_Frog_285.wav (60.00s -> 4.00s)
# Clipped: other_frog_3213.wav (16.30s -> 4.00s)
# Clipped: Mountain_Rain_Frog_488.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_21.wav (6.16s -> 4.00s)
# Clipped: other_frog_1693.wav (10.48s -> 4.00s)
# Clipped: other_frog_1906.wav (7.27s -> 4.00s)
# Clipped: Clicking_Stream_Frog_202.wav (15.17s -> 4.00s)
# Clipped: other_frog_1712.wav (4.46s -> 4.00s)
# Clipped: other_frog_1272.wav (6.56s -> 4.00s)
# Clipped: other_frog_2093.wav (50.62s -> 4.00s)
# Clipped: other_frog_363.wav (21.66s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1072.wav (60.00s -> 4.00s)
# Clipped: other_frog_1908.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1244.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_725.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_294.wav (60.00s -> 4.00s)
# Clipped: other_frog_2835.wav (60.00s -> 4.00s)
# Clipped: other_frog_1722.wav (27.37s -> 4.00s)
# Clipped: Southern_Dainty_Frog_712.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_248.wav (15.35s -> 4.00s)
# Clipped: Southern_Dainty_Frog_263.wav (60.00s -> 4.00s)
# Clipped: other_frog_212.wav (9.48s -> 4.00s)
# Clipped: Mountain_Rain_Frog_536.wav (60.00s -> 4.00s)
# Clipped: other_frog_3018.wav (8.16s -> 4.00s)
# Clipped: other_frog_3003.wav (4.40s -> 4.00s)
# Clipped: other_frog_1586.wav (6.70s -> 4.00s)
# Clipped: Mountain_Rain_Frog_996.wav (60.00s -> 4.00s)
# Clipped: other_frog_808.wav (60.00s -> 4.00s)
# Clipped: other_frog_2485.wav (10.12s -> 4.00s)
# Clipped: other_frog_1486.wav (12.72s -> 4.00s)
# Clipped: Mountain_Rain_Frog_123.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_900.wav (60.00s -> 4.00s)
# Clipped: other_frog_1645.wav (10.82s -> 4.00s)
# Clipped: Clicking_Stream_Frog_180.wav (28.18s -> 4.00s)
# Clipped: Mountain_Rain_Frog_676.wav (60.00s -> 4.00s)
# Clipped: other_frog_1148.wav (29.28s -> 4.00s)
# Clipped: other_frog_830.wav (60.00s -> 4.00s)
# Clipped: other_frog_3433.wav (16.90s -> 4.00s)
# Clipped: other_frog_2106.wav (30.74s -> 4.00s)
# Clipped: Mountain_Rain_Frog_104.wav (60.00s -> 4.00s)
# Clipped: other_frog_2349.wav (14.51s -> 4.00s)
# Clipped: other_frog_2909.wav (11.77s -> 4.00s)
# Clipped: other_frog_1421.wav (10.57s -> 4.00s)
# Clipped: other_frog_1914.wav (5.12s -> 4.00s)
# Clipped: other_frog_115.wav (4.97s -> 4.00s)
# Clipped: Mountain_Rain_Frog_705.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_490.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_117.wav (8.59s -> 4.00s)
# Clipped: Southern_Dainty_Frog_207.wav (60.00s -> 4.00s)
# Clipped: other_frog_794.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_337.wav (11.71s -> 4.00s)
# Clipped: other_frog_371.wav (16.11s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1114.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_234.wav (60.00s -> 4.00s)
# Clipped: other_frog_2119.wav (16.32s -> 4.00s)
# Clipped: other_frog_2260.wav (9.76s -> 4.00s)
# Clipped: other_frog_1524.wav (15.17s -> 4.00s)
# Clipped: other_frog_3265.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1093.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_619.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_587.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_97.wav (10.98s -> 4.00s)
# Clipped: Mountain_Rain_Frog_730.wav (60.00s -> 4.00s)
# Clipped: other_frog_2558.wav (14.47s -> 4.00s)
# Clipped: other_frog_2094.wav (13.86s -> 4.00s)
# Clipped: Clicking_Stream_Frog_64.wav (33.92s -> 4.00s)
# Clipped: other_frog_1609.wav (60.00s -> 4.00s)
# Clipped: other_frog_2274.wav (7.36s -> 4.00s)
# Clipped: other_frog_7.wav (60.00s -> 4.00s)
# Clipped: other_frog_272.wav (60.00s -> 4.00s)
# Clipped: other_frog_3065.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_57.wav (11.49s -> 4.00s)
# Clipped: other_frog_3057.wav (13.37s -> 4.00s)
# Clipped: Clicking_Stream_Frog_36.wav (14.24s -> 4.00s)
# Clipped: other_frog_3353.wav (16.87s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1053.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_127.wav (60.00s -> 4.00s)
# Clipped: other_frog_2029.wav (25.86s -> 4.00s)
# Clipped: other_frog_286.wav (15.53s -> 4.00s)
# Clipped: Southern_Dainty_Frog_765.wav (60.00s -> 4.00s)
# Clipped: other_frog_1532.wav (60.00s -> 4.00s)
# Clipped: other_frog_1049.wav (14.24s -> 4.00s)
# Clipped: Mountain_Rain_Frog_90.wav (60.00s -> 4.00s)
# Clipped: other_frog_1048.wav (4.80s -> 4.00s)
# Clipped: other_frog_188.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_296.wav (26.42s -> 4.00s)
# Clipped: other_frog_2534.wav (9.44s -> 4.00s)
# Clipped: other_frog_2091.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_81.wav (5.04s -> 4.00s)
# Clipped: other_frog_3048.wav (15.70s -> 4.00s)
# Clipped: other_frog_3507.wav (60.00s -> 4.00s)
# Clipped: other_frog_752.wav (60.00s -> 4.00s)
# Clipped: other_frog_3249.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_479.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_99.wav (60.00s -> 4.00s)
# Clipped: other_frog_602.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_28.wav (60.00s -> 4.00s)
# Clipped: other_frog_540.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_619.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_638.wav (60.00s -> 4.00s)
# Clipped: other_frog_1227.wav (60.00s -> 4.00s)
# Clipped: other_frog_143.wav (15.78s -> 4.00s)
# Clipped: other_frog_2785.wav (60.00s -> 4.00s)
# Clipped: other_frog_3188.wav (60.86s -> 4.00s)
# Clipped: other_frog_254.wav (20.02s -> 4.00s)
# Clipped: other_frog_2688.wav (26.49s -> 4.00s)
# Clipped: other_frog_2043.wav (31.84s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1134.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1202.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_488.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_746.wav (60.00s -> 4.00s)
# Clipped: other_frog_1001.wav (14.68s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1339.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_419.wav (7.80s -> 4.00s)
# Clipped: other_frog_2465.wav (60.00s -> 4.00s)
# Clipped: other_frog_1669.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_304.wav (60.00s -> 4.00s)
# Clipped: other_frog_1796.wav (4.76s -> 4.00s)
# Clipped: other_frog_1871.wav (60.00s -> 4.00s)
# Clipped: other_frog_2576.wav (60.00s -> 4.00s)
# Clipped: other_frog_674.wav (9.89s -> 4.00s)
# Clipped: Southern_Dainty_Frog_387.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_283.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1326.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_685.wav (60.00s -> 4.00s)
# Clipped: other_frog_822.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_487.wav (60.00s -> 4.00s)
# Clipped: other_frog_147.wav (15.88s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1330.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_484.wav (60.00s -> 4.00s)
# Clipped: other_frog_1368.wav (7.71s -> 4.00s)
# Clipped: Mountain_Rain_Frog_64.wav (60.00s -> 4.00s)
# Clipped: other_frog_2208.wav (23.34s -> 4.00s)
# Clipped: Mountain_Rain_Frog_575.wav (60.00s -> 4.00s)
# Clipped: other_frog_1647.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_365.wav (6.94s -> 4.00s)
# Copied: other_frog_2774.wav (1.51s)
# Clipped: Mountain_Rain_Frog_1120.wav (60.00s -> 4.00s)
# Clipped: other_frog_819.wav (10.26s -> 4.00s)
# Clipped: Mountain_Rain_Frog_836.wav (60.00s -> 4.00s)
# Clipped: other_frog_3094.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_16.wav (6.06s -> 4.00s)
# Clipped: other_frog_1399.wav (12.82s -> 4.00s)
# Clipped: Clicking_Stream_Frog_217.wav (10.73s -> 4.00s)
# Clipped: Mountain_Rain_Frog_788.wav (60.00s -> 4.00s)
# Clipped: other_frog_3295.wav (60.00s -> 4.00s)
# Clipped: other_frog_2571.wav (7.83s -> 4.00s)
# Clipped: Mountain_Rain_Frog_556.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_852.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_584.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_976.wav (60.00s -> 4.00s)
# Clipped: other_frog_824.wav (23.38s -> 4.00s)
# Clipped: Mountain_Rain_Frog_411.wav (60.00s -> 4.00s)
# Clipped: other_frog_1916.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1325.wav (60.00s -> 4.00s)
# Copied: other_frog_1229.wav (3.29s)
# Clipped: Southern_Dainty_Frog_36.wav (28.42s -> 4.00s)
# Clipped: Mountain_Rain_Frog_326.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_31.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_143.wav (60.00s -> 4.00s)
# Clipped: other_frog_1691.wav (6.72s -> 4.00s)
# Clipped: other_frog_247.wav (39.49s -> 4.00s)
# Clipped: other_frog_2343.wav (60.00s -> 4.00s)
# Clipped: other_frog_1878.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_358.wav (60.00s -> 4.00s)
# Clipped: Mountain_Rain_Frog_84.wav (60.00s -> 4.00s)
# Clipped: other_frog_885.wav (60.00s -> 4.00s)
# Clipped: other_frog_1899.wav (12.32s -> 4.00s)
# Clipped: other_frog_923.wav (43.15s -> 4.00s)
# Clipped: Mountain_Rain_Frog_1240.wav (60.00s -> 4.00s)
# Clipped: other_frog_320.wav (10.08s -> 4.00s)
# Clipped: Clicking_Stream_Frog_283.wav (28.51s -> 4.00s)
# Clipped: other_frog_889.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_541.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_305.wav (60.00s -> 4.00s)
# Clipped: other_frog_2375.wav (60.00s -> 4.00s)
# Clipped: Southern_Dainty_Frog_186.wav (60.00s -> 4.00s)
# Clipped: other_frog_3327.wav (9.71s -> 4.00s)
# Clipped: other_frog_1479.wav (60.00s -> 4.00s)
# Clipped: Clicking_Stream_Frog_456.wav (17.58s -> 4.00s)
# Clipped: Southern_Dainty_Frog_506.wav (60.00s -> 4.00s)
# Clipped: other_frog_978.wav (5.00s -> 4.00s)
#
# Processing complete!
# Processed 6141 files
# - 6083 files clipped to 4 seconds
# - 58 files copied as-is (<=4 seconds)
# Output directory: /home/james/Documents/semester-2/skripsie/code/preprocessing/clipped_4sec

# %% [markdown]
# ## Convert all of the audio files into Spectrograms and save as .h5

# %%
import os
import numpy as np
import librosa
from joblib import Parallel, delayed
import multiprocessing
import h5py
from tqdm import tqdm

# Configuration
AUDIO_DIR = "./clipped_4sec"
OUTPUT_DIR = "./Datasets/FD-0.3/"
os.makedirs(OUTPUT_DIR, exist_ok=True)

SAMPLE_RATE = 22050
N_FFT = 2048
HOP_LENGTH = 256
N_MELS = 128

def process_file(file):
    try:
        if file.lower().endswith('.wav'):
            audio_path = os.path.join(AUDIO_DIR, file)
            y, sr = librosa.load(audio_path, sr=SAMPLE_RATE, res_type='kaiser_fast', mono=True)
            S = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=N_FFT, hop_length=HOP_LENGTH, n_mels=N_MELS)
            S_dB = librosa.power_to_db(S, ref=np.max)
            key = os.path.splitext(file)[0]
            return key, S_dB
    except Exception as e:
        print(f"\nSkipped {file}: {str(e)}")
        return None

# Get list of files first for accurate tqdm progress
files = [f for f in os.listdir(AUDIO_DIR) if f.lower().endswith('.wav')]
print(f"Processing {len(files)} audio files...")


batch_size = 500
for i in tqdm(range(0, len(files), batch_size)):
    batch = files[i:i+batch_size]
    results = Parallel(n_jobs=2)(delayed(process_file)(f) for f in batch)
    with h5py.File(os.path.join(OUTPUT_DIR, 'spectrograms.h5'), 'a') as hf:  # 'a' for append
        for result in results:
            if result is not None:
                key, S_dB = result
                hf.create_dataset(key, data=S_dB)


print(f"\nDone! Spectrograms saved to {OUTPUT_DIR}")
# Out:
# Processing 6141 audio files...
#   0%|          | 0/13 [00:05<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 45
#      43             if result is not None:
#      44                 key, S_dB = result
# ---> 45                 hf.create_dataset(key, data=S_dB)
#      48 print(f"\nDone! Spectrograms saved to {OUTPUT_DIR}")
#
# File ~/.local/lib/python3.10/site-packages/h5py/_hl/group.py:186, in Group.create_dataset(self, name, shape, dtype, data, **kwds)
#     183         parent_path, name = name.rsplit(b'/', 1)
#     184         group = self.require_group(parent_path)
# --> 186 dsid = dataset.make_new_dset(group, shape, dtype, data, name, **kwds)
#     187 dset = dataset.Dataset(dsid)
#     188 return dset
#
# File ~/.local/lib/python3.10/site-packages/h5py/_hl/dataset.py:175, in make_new_dset(parent, shape, dtype, data, name, chunks, compression, shuffle, fletcher32, maxshape, compression_opts, fillvalue, scaleoffset, track_times, external, track_order, dcpl, dapl, efile_prefix, virtual_prefix, allow_unknown_filter, rdcc_nslots, rdcc_nbytes, rdcc_w0, fill_time)
#     172 else:
#     173     sid = h5s.create_simple(shape, maxshape)
# --> 175 dset_id = h5d.create(parent.id, name, tid, sid, dcpl=dcpl, dapl=dapl)
#     177 if (data is not None) and (not isinstance(data, Empty)):
#     178     dset_id.write(h5s.ALL, h5s.ALL, data)
#
# File h5py/_objects.pyx:56, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:57, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5d.pyx:136, in h5py.h5d.create()
#
# ValueError: Unable to synchronously create dataset (name already exists)
